# %%
#!pip install pyzotero
import requests
import sddk
import getpass

# %% [markdown]
# # Zotero API configuration
#
# 1. find your zotero user ID and insert it interactively in the cell below (you can find it e.g. from https://www.zotero.org/settings/keys)

# %%
userID = input("Paste your Zotero user ID: ")
# Out:
# Paste your Zotero user ID: 5925766

# %% [markdown]
# 2. go to https://www.zotero.org/settings/keys
# 3. `Create new private key`
# 4. name your key in `Key description`, e.g. `pyzot`.
# 5. click at `Save Key`
# 6. copy the generated key into clipboard
# 7 insert it in the cell below

# %%
api_key =  getpass.getpass("Paste your key: ")
# Out:
# Paste your key: ········

# %%
# prepare the authorization
base_url = "https://api.zotero.org/users/" + str(userID) + "/"
headers ={"Authorization": "Bearer " + api_key}

# %%
# list all personal collections
url = "https://api.zotero.org/users/5925766/collections"
resp = requests.get(url, headers=headers)
resp.json()
# Out:
# [{'key': 'LFPMLWZ2',
#   'version': 77,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/collections/LFPMLWZ2',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/collections/LFPMLWZ2',
#     'type': 'text/html'}},
#   'meta': {'numCollections': 0, 'numItems': 78},
#   'data': {'key': 'LFPMLWZ2',
#    'version': 77,
#    'name': 'JDH_article',
#    'parentCollection': False,
#    'relations': {}}}]

# %% [markdown]
# Among these collections, find the one you want to use and copy its `key` (i.e. the value of the `key` attribute.

# %%
collection_key = input("your collection key: ")
# Out:
# your collection key: LFPMLWZ2

# %%
# list all items within preselected collection:
url = "https://api.zotero.org/users/5925766/collections/" + collection_key + "/items?limit=1000"
collection_items_json = requests.get(url, headers=headers).json()

# %%
# inspect the items
collection_items_json
# Out:
# [{'key': '5DKTH37I',
#   'version': 134,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/5DKTH37I',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/8C5W7WYE',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I/file/view',
#     'title': 'Lowndes et al. - 2017 - Our path to better science in less time using open.pdf',
#     'length': 412129}},
#   'meta': {'numChildren': False},
#   'data': {'key': '5DKTH37I',
#    'version': 134,
#    'parentItem': '8C5W7WYE',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-06-11T07:08:22Z',
#    'url': 'https://www.nature.com/articles/s41559-017-0160.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Lowndes et al. - 2017 - Our path to better science in less time using open.pdf',
#    'md5': '9df40be7f5764434c04e44af6fc2369a',
#    'mtime': 1623395302000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/NHJ9DBJB'},
#    'dateAdded': '2021-06-11T07:08:22Z',
#    'dateModified': '2021-06-11T07:08:22Z'}},
#  {'key': '8C5W7WYE',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/8C5W7WYE',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/8C5W7WYE',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 412129}},
#   'meta': {'creatorSummary': 'Lowndes et al.',
#    'parsedDate': '2017',
#    'numChildren': 1},
#   'data': {'key': '8C5W7WYE',
#    'version': 133,
#    'itemType': 'journalArticle',
#    'title': 'Our path to better science in less time using open data science tools',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Julia S. Stewart',
#      'lastName': 'Lowndes'},
#     {'creatorType': 'author', 'firstName': 'Benjamin D.', 'lastName': 'Best'},
#     {'creatorType': 'author',
#      'firstName': 'Courtney',
#      'lastName': 'Scarborough'},
#     {'creatorType': 'author',
#      'firstName': 'Jamie C.',
#      'lastName': 'Afflerbach'},
#     {'creatorType': 'author',
#      'firstName': 'Melanie R.',
#      'lastName': 'Frazier'},
#     {'creatorType': 'author', 'firstName': 'Casey C.', 'lastName': 'O’Hara'},
#     {'creatorType': 'author', 'firstName': 'Ning', 'lastName': 'Jiang'},
#     {'creatorType': 'author',
#      'firstName': 'Benjamin S.',
#      'lastName': 'Halpern'}],
#    'abstractNote': '',
#    'publicationTitle': 'Nature Ecology & Evolution',
#    'volume': '1',
#    'issue': '6',
#    'pages': '0160',
#    'date': '6/2017',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Nat Ecol Evol',
#    'language': 'en',
#    'DOI': '10.1038/s41559-017-0160',
#    'ISSN': '2397-334X',
#    'shortTitle': '',
#    'url': 'http://www.nature.com/articles/s41559-017-0160',
#    'accessDate': '2021-06-11T07:08:21Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/2IMKYASB'},
#    'dateAdded': '2021-06-11T07:08:21Z',
#    'dateModified': '2021-06-11T07:08:21Z'}},
#  {'key': '3J5XSHJ2',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3J5XSHJ2',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3J5XSHJ2',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Scheidel',
#    'parsedDate': '2018',
#    'numChildren': 0},
#   'data': {'key': '3J5XSHJ2',
#    'version': 133,
#    'itemType': 'book',
#    'title': 'The Great Leveler: Violence and the History of Inequality from the Stone Age to the Twenty-First Century',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Walter',
#      'lastName': 'Scheidel'}],
#    'abstractNote': '',
#    'series': 'The Princeton Economic History of the Western World',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Princeton University Press',
#    'date': '2018',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-691-18325-1',
#    'shortTitle': '',
#    'url': 'https://press.princeton.edu/books/paperback/9780691183251/the-great-leveler',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/5NVGQ6LK'},
#    'dateAdded': '2021-06-11T07:03:13Z',
#    'dateModified': '2021-06-11T07:04:19Z'}},
#  {'key': 'CY54CMQ9',
#   'version': 129,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/CY54CMQ9',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/CY54CMQ9',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Huggett',
#    'parsedDate': '2017-05-23',
#    'numChildren': 0},
#   'data': {'key': 'CY54CMQ9',
#    'version': 129,
#    'itemType': 'blogPost',
#    'title': 'Citing Data Reuse',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Jeremy',
#      'lastName': 'Huggett'}],
#    'abstractNote': '',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '23/05/2017',
#    'url': 'https://introspectivedigitalarchaeology.com/2017/05/23/citing-data-reuse/',
#    'accessDate': '',
#    'language': 'eng',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/RDNH84EL',
#      'http://zotero.org/groups/2784584/items/NRWZY682']},
#    'dateAdded': '2021-06-10T10:36:07Z',
#    'dateModified': '2021-06-10T10:36:48Z'}},
#  {'key': 'QZV4FHQ6',
#   'version': 129,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/QZV4FHQ6',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/QZV4FHQ6',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Huggett',
#    'parsedDate': '2016-06-29',
#    'numChildren': 0},
#   'data': {'key': 'QZV4FHQ6',
#    'version': 129,
#    'itemType': 'blogPost',
#    'title': 'Digital Data Realities',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Jeremy',
#      'lastName': 'Huggett'}],
#    'abstractNote': '',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '29/06/2016',
#    'url': 'https://introspectivedigitalarchaeology.com/2016/06/29/digital-data-realities/',
#    'accessDate': '',
#    'language': 'eng',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/X6C44E8B',
#      'http://zotero.org/groups/2784584/items/45PITQ5E']},
#    'dateAdded': '2021-06-10T10:34:48Z',
#    'dateModified': '2021-06-10T10:35:40Z'}},
#  {'key': '3NH6EHMA',
#   'version': 126,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3NH6EHMA',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3NH6EHMA',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Raymond',
#    'parsedDate': '2001',
#    'numChildren': 0},
#   'data': {'key': '3NH6EHMA',
#    'version': 126,
#    'itemType': 'book',
#    'title': 'The Cathedral & the Bazaar',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Eric S.',
#      'lastName': 'Raymond'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': "O'Reilly Media",
#    'date': '2001',
#    'numPages': '',
#    'language': 'English',
#    'ISBN': '978-0-596-00108-7',
#    'shortTitle': '',
#    'url': 'https://www.oreilly.com/library/view/the-cathedral/0596001088/',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/GC8B39KI',
#      'http://zotero.org/groups/2784584/items/NHPHYMF9']},
#    'dateAdded': '2021-06-10T10:31:39Z',
#    'dateModified': '2021-06-10T10:33:26Z'}},
#  {'key': 'CAJ8RP6I',
#   'version': 125,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/CAJ8RP6I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/CAJ8RP6I',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Iversen',
#    'parsedDate': '2007',
#    'numChildren': 0},
#   'data': {'key': 'CAJ8RP6I',
#    'version': 125,
#    'itemType': 'journalArticle',
#    'title': 'The Packard Humanities Institute (PHI) Greek Epigraphy Project and the Revolution in Greek Epigraphy',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Paul A.',
#      'lastName': 'Iversen'}],
#    'abstractNote': 'In this paper, the history, purpose and importance\nof the Packard Humanities Institute (PHI) Greek\nEpigraphy Project are discussed.',
#    'publicationTitle': 'Abgadiyat',
#    'volume': '2.1',
#    'issue': '',
#    'pages': '51-55',
#    'date': '2007',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'eng',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'https://journals.ekb.eg/article_62069_38414a2fca56893baf78323065072f95.pdf',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/PL944VJ3'},
#    'dateAdded': '2021-06-10T09:03:00Z',
#    'dateModified': '2021-06-10T09:03:00Z'}},
#  {'key': 'GZXS5Q8K',
#   'version': 125,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/GZXS5Q8K',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/GZXS5Q8K',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/3ADCMC6C',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 424666}},
#   'meta': {'creatorSummary': 'Sherratt',
#    'parsedDate': '2019-10-29',
#    'numChildren': 1},
#   'data': {'key': 'GZXS5Q8K',
#    'version': 125,
#    'itemType': 'bookSection',
#    'title': 'Hacking heritage: Understanding the limits of online access',
#    'creators': [{'creatorType': 'editor',
#      'firstName': 'Hannah',
#      'lastName': 'Lewi'},
#     {'creatorType': 'editor', 'firstName': 'Wally', 'lastName': 'Smith'},
#     {'creatorType': 'editor', 'firstName': 'Dirk', 'lastName': 'vom Lehn'},
#     {'creatorType': 'editor', 'firstName': 'Steven', 'lastName': 'Cooke'},
#     {'creatorType': 'author', 'firstName': 'Tim', 'lastName': 'Sherratt'}],
#    'abstractNote': '',
#    'bookTitle': 'The Routledge International Handbook of New Digital Practices in Galleries, Libraries, Archives, Museums and Heritage Sites',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '1',
#    'place': '',
#    'publisher': 'Routledge',
#    'date': '2019-10-29',
#    'pages': '15',
#    'language': 'en',
#    'ISBN': '978-0-429-50676-5',
#    'shortTitle': '',
#    'url': 'https://www.taylorfrancis.com/books/9780429015304',
#    'accessDate': '2021-06-10T08:47:42Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.4324/9780429506765',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2784584/items/HL5NIEMG',
#      'http://zotero.org/groups/2366083/items/5IZH2L65']},
#    'dateAdded': '2021-06-10T08:47:42Z',
#    'dateModified': '2021-06-10T08:51:57Z'}},
#  {'key': '3ADCMC6C',
#   'version': 125,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3ADCMC6C',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3ADCMC6C',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/GZXS5Q8K',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/3ADCMC6C/file/view',
#     'title': 'Lewi et al. - 2019 - The Routledge International Handbook of New Digita.pdf',
#     'length': 424666}},
#   'meta': {'numChildren': False},
#   'data': {'key': '3ADCMC6C',
#    'version': 125,
#    'parentItem': 'GZXS5Q8K',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-06-10T08:47:49Z',
#    'url': 'https://dro.deakin.edu.au/eserv/DU:30122388/cooke-investigatingordinary-post-2019.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Lewi et al. - 2019 - The Routledge International Handbook of New Digita.pdf',
#    'md5': 'adec219e425056f1440b2c94e772921b',
#    'mtime': 1623314869000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/DPK3EJID'},
#    'dateAdded': '2021-06-10T08:47:49Z',
#    'dateModified': '2021-06-10T08:47:49Z'}},
#  {'key': 'XDAURK5G',
#   'version': 136,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/XDAURK5G',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/XDAURK5G',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Madzharov',
#    'parsedDate': '2009',
#    'numChildren': 0},
#   'data': {'key': 'XDAURK5G',
#    'version': 136,
#    'itemType': 'book',
#    'title': 'Rimski patishta v Balgaria: prinos v razvitieto na rimskata patna sistema v provintsiite Mizia i Trakia',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Mitko',
#      'lastName': 'Madzharov'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'Veliko Turnovo',
#    'publisher': 'Faber Publisher',
#    'date': '2009',
#    'numPages': '',
#    'language': '',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/W5EPKGJU',
#      'http://zotero.org/groups/2784584/items/PTEB9H2F']},
#    'dateAdded': '2021-06-09T11:51:03Z',
#    'dateModified': '2021-06-09T11:51:03Z'}},
#  {'key': '7DY6HUZB',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/7DY6HUZB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/7DY6HUZB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Hollenstein',
#    'parsedDate': '1975',
#    'numChildren': 0},
#   'data': {'key': '7DY6HUZB',
#    'version': 133,
#    'itemType': 'journalArticle',
#    'title': 'Zu den Meilensteinen der römischen Provinzen Thracia und Moesia Inferior',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Lorenz',
#      'lastName': 'Hollenstein'}],
#    'abstractNote': '',
#    'publicationTitle': 'Studia Balcanica',
#    'volume': '10',
#    'issue': '',
#    'pages': '23–44',
#    'date': '1975',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/RVP5YXG7',
#      'http://zotero.org/groups/2784584/items/YWEFPW8B']},
#    'dateAdded': '2021-06-09T11:50:52Z',
#    'dateModified': '2021-06-09T11:50:52Z'}},
#  {'key': 'J6GWZWL4',
#   'version': 115,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/J6GWZWL4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/J6GWZWL4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Duncan-Jones',
#    'parsedDate': '2018',
#    'numChildren': 0},
#   'data': {'key': 'J6GWZWL4',
#    'version': 115,
#    'itemType': 'journalArticle',
#    'title': 'The Antonine Plague Revisited',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Richard',
#      'lastName': 'Duncan-Jones'}],
#    'abstractNote': '',
#    'publicationTitle': 'Arctos',
#    'volume': '52',
#    'issue': '',
#    'pages': '41-72',
#    'date': '2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'eng',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/73AJRHE5'},
#    'dateAdded': '2021-06-04T14:17:06Z',
#    'dateModified': '2021-06-04T14:17:06Z'}},
#  {'key': 'YFQQLVBK',
#   'version': 114,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/YFQQLVBK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/YFQQLVBK',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Duncan-Jones',
#    'parsedDate': '1990-04-12',
#    'numChildren': 0},
#   'data': {'key': 'YFQQLVBK',
#    'version': 114,
#    'itemType': 'book',
#    'title': 'Structure and Scale in the Roman Economy',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Richard',
#      'lastName': 'Duncan-Jones'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '1',
#    'place': '',
#    'publisher': 'Cambridge University Press',
#    'date': '1990-04-12',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-521-35477-6 978-0-521-89289-6 978-0-511-55264-9',
#    'shortTitle': '',
#    'url': 'https://www.cambridge.org/core/product/identifier/9780511552649/type/book',
#    'accessDate': '2021-06-03T16:01:19Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1017/CBO9780511552649',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2784584/items/8GNR2ZUR',
#      'http://zotero.org/groups/2366083/items/6GH6YG72']},
#    'dateAdded': '2021-06-03T16:01:19Z',
#    'dateModified': '2021-06-03T16:01:19Z'}},
#  {'key': 'HCU3WEJB',
#   'version': 114,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/HCU3WEJB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/HCU3WEJB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Duncan-Jones',
#    'parsedDate': '1996',
#    'numChildren': 0},
#   'data': {'key': 'HCU3WEJB',
#    'version': 114,
#    'itemType': 'journalArticle',
#    'title': 'The impact of the Antonine plague',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'R. P.',
#      'lastName': 'Duncan-Jones'}],
#    'abstractNote': '',
#    'publicationTitle': 'Journal of Roman Archaeology',
#    'volume': '9',
#    'issue': '',
#    'pages': '108-136',
#    'date': '1996',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'J. Roman archaeol.',
#    'language': 'en',
#    'DOI': '10.1017/S1047759400016524',
#    'ISSN': '1047-7594, 2331-5709',
#    'shortTitle': '',
#    'url': 'https://www.cambridge.org/core/product/identifier/S1047759400016524/type/journal_article',
#    'accessDate': '2021-06-03T15:53:46Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2784584/items/PCA83JEZ',
#      'http://zotero.org/groups/2366083/items/LHLXI5ID']},
#    'dateAdded': '2021-06-03T15:53:46Z',
#    'dateModified': '2021-06-03T15:53:46Z'}},
#  {'key': 'UH4L3837',
#   'version': 137,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/UH4L3837',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/UH4L3837',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Tahmasebi and Hengchen',
#    'parsedDate': '2019',
#    'numChildren': 0},
#   'data': {'key': 'UH4L3837',
#    'version': 137,
#    'itemType': 'journalArticle',
#    'title': 'The Strengths and Pitfalls of Large-Scale Text Mining for Literary Studies',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Nina',
#      'lastName': 'Tahmasebi'},
#     {'creatorType': 'author', 'firstName': 'Simon', 'lastName': 'Hengchen'}],
#    'abstractNote': '',
#    'publicationTitle': 'Samlaren',
#    'volume': '140',
#    'issue': '',
#    'pages': '198–227',
#    'date': '2019',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'http://uu.diva-portal.org/smash/get/diva2:1415010/FULLTEXT01.pdf',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/2CDUBU8M',
#      'http://zotero.org/groups/2784584/items/S8JAXRPN']},
#    'dateAdded': '2021-06-03T14:34:37Z',
#    'dateModified': '2021-06-03T14:34:37Z'}},
#  {'key': 'TARVRY26',
#   'version': 112,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/TARVRY26',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/TARVRY26',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Wilson', 'parsedDate': '2009', 'numChildren': 0},
#   'data': {'key': 'TARVRY26',
#    'version': 112,
#    'itemType': 'journalArticle',
#    'title': 'Indicators for Roman economic growth: a response to Walter Scheidel',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Andrew',
#      'lastName': 'Wilson'}],
#    'abstractNote': '',
#    'publicationTitle': 'Journal of Roman Archaeology',
#    'volume': '22',
#    'issue': '',
#    'pages': '71-82',
#    'date': '2009',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'J. Roman archaeol.',
#    'language': 'en',
#    'DOI': '10.1017/S1047759400020596',
#    'ISSN': '1047-7594, 2331-5709',
#    'shortTitle': 'Indicators for Roman economic growth',
#    'url': 'https://www.cambridge.org/core/product/identifier/S1047759400020596/type/journal_article',
#    'accessDate': '2021-06-01T10:30:08Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2784584/items/Z7J9QKJK'},
#    'dateAdded': '2021-06-03T13:54:57Z',
#    'dateModified': '2021-06-03T13:54:57Z'}},
#  {'key': 'WRRYLBT4',
#   'version': 111,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/WRRYLBT4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/WRRYLBT4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Liuzzo',
#    'parsedDate': '2019-10-17',
#    'numChildren': 0},
#   'data': {'key': 'WRRYLBT4',
#    'version': 111,
#    'itemType': 'book',
#    'title': 'Digital Approaches to Ethiopian and Eritrean Studies',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Pietro Maria',
#      'lastName': 'Liuzzo'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '1',
#    'place': '',
#    'publisher': 'Harrassowitz, O',
#    'date': '2019-10-17',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-3-447-19913-1 978-3-447-11291-8',
#    'shortTitle': '',
#    'url': 'http://www.jstor.org/stable/10.2307/j.ctvrnfr3q',
#    'accessDate': '2021-05-31T11:55:56Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.2307/j.ctvrnfr3q',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/TI2L8FYJ'},
#    'dateAdded': '2021-05-31T11:56:09Z',
#    'dateModified': '2021-05-31T11:56:09Z'}},
#  {'key': 'DWGK7BKK',
#   'version': 110,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/DWGK7BKK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/DWGK7BKK',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/VI7N28PJ',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/DWGK7BKK/file/view',
#     'title': 'Wilkinson et al. - 2016 - The FAIR Guiding Principles for scientific data ma.pdf',
#     'length': 254899}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'DWGK7BKK',
#    'version': 110,
#    'parentItem': 'VI7N28PJ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-31T11:49:28Z',
#    'url': 'https://www.nature.com/articles/sdata201618.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Wilkinson et al. - 2016 - The FAIR Guiding Principles for scientific data ma.pdf',
#    'md5': 'c673d5848f1e19b935c01eb7819e2b2c',
#    'mtime': 1622461788000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/58V6B494'},
#    'dateAdded': '2021-05-31T11:49:48Z',
#    'dateModified': '2021-05-31T11:49:48Z'}},
#  {'key': 'VI7N28PJ',
#   'version': 109,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/VI7N28PJ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/VI7N28PJ',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/DWGK7BKK',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 254899}},
#   'meta': {'creatorSummary': 'Wilkinson et al.',
#    'parsedDate': '2016',
#    'numChildren': 1},
#   'data': {'key': 'VI7N28PJ',
#    'version': 109,
#    'itemType': 'journalArticle',
#    'title': 'The FAIR Guiding Principles for scientific data management and stewardship',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Mark D.',
#      'lastName': 'Wilkinson'},
#     {'creatorType': 'author', 'firstName': 'Michel', 'lastName': 'Dumontier'},
#     {'creatorType': 'author',
#      'firstName': 'IJsbrand Jan',
#      'lastName': 'Aalbersberg'},
#     {'creatorType': 'author',
#      'firstName': 'Gabrielle',
#      'lastName': 'Appleton'},
#     {'creatorType': 'author', 'firstName': 'Myles', 'lastName': 'Axton'},
#     {'creatorType': 'author', 'firstName': 'Arie', 'lastName': 'Baak'},
#     {'creatorType': 'author', 'firstName': 'Niklas', 'lastName': 'Blomberg'},
#     {'creatorType': 'author', 'firstName': 'Jan-Willem', 'lastName': 'Boiten'},
#     {'creatorType': 'author',
#      'firstName': 'Luiz Bonino',
#      'lastName': 'da Silva Santos'},
#     {'creatorType': 'author', 'firstName': 'Philip E.', 'lastName': 'Bourne'},
#     {'creatorType': 'author', 'firstName': 'Jildau', 'lastName': 'Bouwman'},
#     {'creatorType': 'author',
#      'firstName': 'Anthony J.',
#      'lastName': 'Brookes'},
#     {'creatorType': 'author', 'firstName': 'Tim', 'lastName': 'Clark'},
#     {'creatorType': 'author', 'firstName': 'Mercè', 'lastName': 'Crosas'},
#     {'creatorType': 'author', 'firstName': 'Ingrid', 'lastName': 'Dillo'},
#     {'creatorType': 'author', 'firstName': 'Olivier', 'lastName': 'Dumon'},
#     {'creatorType': 'author', 'firstName': 'Scott', 'lastName': 'Edmunds'},
#     {'creatorType': 'author', 'firstName': 'Chris T.', 'lastName': 'Evelo'},
#     {'creatorType': 'author', 'firstName': 'Richard', 'lastName': 'Finkers'},
#     {'creatorType': 'author',
#      'firstName': 'Alejandra',
#      'lastName': 'Gonzalez-Beltran'},
#     {'creatorType': 'author',
#      'firstName': 'Alasdair J.G.',
#      'lastName': 'Gray'},
#     {'creatorType': 'author', 'firstName': 'Paul', 'lastName': 'Groth'},
#     {'creatorType': 'author', 'firstName': 'Carole', 'lastName': 'Goble'},
#     {'creatorType': 'author', 'firstName': 'Jeffrey S.', 'lastName': 'Grethe'},
#     {'creatorType': 'author', 'firstName': 'Jaap', 'lastName': 'Heringa'},
#     {'creatorType': 'author', 'firstName': 'Peter A.C', 'lastName': '’t Hoen'},
#     {'creatorType': 'author', 'firstName': 'Rob', 'lastName': 'Hooft'},
#     {'creatorType': 'author', 'firstName': 'Tobias', 'lastName': 'Kuhn'},
#     {'creatorType': 'author', 'firstName': 'Ruben', 'lastName': 'Kok'},
#     {'creatorType': 'author', 'firstName': 'Joost', 'lastName': 'Kok'},
#     {'creatorType': 'author', 'firstName': 'Scott J.', 'lastName': 'Lusher'},
#     {'creatorType': 'author',
#      'firstName': 'Maryann E.',
#      'lastName': 'Martone'},
#     {'creatorType': 'author', 'firstName': 'Albert', 'lastName': 'Mons'},
#     {'creatorType': 'author', 'firstName': 'Abel L.', 'lastName': 'Packer'},
#     {'creatorType': 'author', 'firstName': 'Bengt', 'lastName': 'Persson'},
#     {'creatorType': 'author',
#      'firstName': 'Philippe',
#      'lastName': 'Rocca-Serra'},
#     {'creatorType': 'author', 'firstName': 'Marco', 'lastName': 'Roos'},
#     {'creatorType': 'author', 'firstName': 'Rene', 'lastName': 'van Schaik'},
#     {'creatorType': 'author',
#      'firstName': 'Susanna-Assunta',
#      'lastName': 'Sansone'},
#     {'creatorType': 'author', 'firstName': 'Erik', 'lastName': 'Schultes'},
#     {'creatorType': 'author', 'firstName': 'Thierry', 'lastName': 'Sengstag'},
#     {'creatorType': 'author', 'firstName': 'Ted', 'lastName': 'Slater'},
#     {'creatorType': 'author', 'firstName': 'George', 'lastName': 'Strawn'},
#     {'creatorType': 'author', 'firstName': 'Morris A.', 'lastName': 'Swertz'},
#     {'creatorType': 'author', 'firstName': 'Mark', 'lastName': 'Thompson'},
#     {'creatorType': 'author', 'firstName': 'Johan', 'lastName': 'van der Lei'},
#     {'creatorType': 'author', 'firstName': 'Erik', 'lastName': 'van Mulligen'},
#     {'creatorType': 'author', 'firstName': 'Jan', 'lastName': 'Velterop'},
#     {'creatorType': 'author', 'firstName': 'Andra', 'lastName': 'Waagmeester'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Wittenburg'},
#     {'creatorType': 'author',
#      'firstName': 'Katherine',
#      'lastName': 'Wolstencroft'},
#     {'creatorType': 'author', 'firstName': 'Jun', 'lastName': 'Zhao'},
#     {'creatorType': 'author', 'firstName': 'Barend', 'lastName': 'Mons'}],
#    'abstractNote': '',
#    'publicationTitle': 'Scientific Data',
#    'volume': '3',
#    'issue': '1',
#    'pages': '160018',
#    'date': '12/2016',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Sci Data',
#    'language': 'en',
#    'DOI': '10.1038/sdata.2016.18',
#    'ISSN': '2052-4463',
#    'shortTitle': '',
#    'url': 'http://www.nature.com/articles/sdata201618',
#    'accessDate': '2021-05-31T11:49:27Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/HUNSU4A3'},
#    'dateAdded': '2021-05-31T11:49:48Z',
#    'dateModified': '2021-05-31T11:49:48Z'}},
#  {'key': 'KGBLD6FY',
#   'version': 105,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/KGBLD6FY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/KGBLD6FY',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Ballsun-Stanton',
#    'parsedDate': '2020',
#    'numChildren': 0},
#   'data': {'key': 'KGBLD6FY',
#    'version': 105,
#    'itemType': 'computerProgram',
#    'title': 'Lat Epig 2.0',
#    'creators': [{'creatorType': 'programmer',
#      'firstName': 'Brian',
#      'lastName': 'Ballsun-Stanton'},
#     {'creatorType': 'contributor',
#      'firstName': 'Petra',
#      'lastName': 'Hermankova'},
#     {'creatorType': 'contributor',
#      'firstName': 'Ray',
#      'lastName': 'Laurence'}],
#    'abstractNote': '',
#    'seriesTitle': '',
#    'versionNumber': '',
#    'date': '2020',
#    'system': '',
#    'place': '',
#    'company': 'Macquarie University',
#    'programmingLanguage': 'python',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#    'rights': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'accessDate': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/84QIQ6VP'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  {'key': 'MCUQLXCG',
#   'version': 105,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/MCUQLXCG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/MCUQLXCG',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Kolb',
#    'parsedDate': '2019-06-17',
#    'numChildren': 0},
#   'data': {'key': 'MCUQLXCG',
#    'version': 105,
#    'itemType': 'bookSection',
#    'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Anne',
#      'lastName': 'Kolb'},
#     {'creatorType': 'editor', 'firstName': 'Anne', 'lastName': 'Kolb'}],
#    'abstractNote': '',
#    'bookTitle': 'Roman Roads: New Evidence - New Perspectives',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'De Gruyter',
#    'date': '2019-06-17',
#    'pages': '3-21',
#    'language': '',
#    'ISBN': '978-3-11-063833-2',
#    'shortTitle': '',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#    'accessDate': '2021-05-19T07:51:54Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1515/9783110638332',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WBXNR587'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  {'key': 'RB28J3CE',
#   'version': 105,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/RB28J3CE',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/RB28J3CE',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Ober', 'parsedDate': '2015', 'numChildren': 0},
#   'data': {'key': 'RB28J3CE',
#    'version': 105,
#    'itemType': 'book',
#    'title': 'The rise and fall of classical Greece',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Josiah.',
#      'lastName': 'Ober'}],
#    'abstractNote': '"Lord Byron described Greece as great, fallen, and immortal, a characterization more apt than he knew. Through most of its long history, Greece was poor. But in the classical era, Greece was densely populated and highly urbanized. Many surprisingly healthy Greeks lived in remarkably big houses and worked for high wages at specialized occupations. Middle-class spending drove sustained economic growth. Classical wealth produced a stunning cultural efflorescence lasting hundreds of years. Why did Greece reach such heights in the classical period--and why only then? And how, after \'the Greek miracle\' had endured for centuries, did the Macedonians defeat the Greeks, seemingly bringing an end to their glory? Drawing on a massive body of newly available data and employing novel approaches to evidence, Josiah Ober offers a major new history of classical Greece and an unprecedented account of its rise and fall. Ober argues that Greece\'s rise was no miracle but rather the result of political breakthroughs and economic development. The extraordinary emergence of citizen-centered city-states transformed Greece into a society that defeated the mighty Persian Empire. Yet Philip and Alexander of Macedon were able to beat the Greeks in the Battle of Chaeronea in 338 BCE, a victory enabled by the Macedonians\' appropriation of Greek innovations. After Alexander\'s death, battle-hardened warlords fought ruthlessly over the remnants of his empire. But Greek cities remained populous and wealthy, their economy and culture surviving to be passed on to the Romans--and to us. A compelling narrative filled with uncanny modern parallels, this is a book for anyone interested in how great civilizations are born and die. This book is based on evidence available on a new interactive website. To learn more, please visit: http://polis.stanford.edu/"--',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': '',
#    'date': '2015',
#    'numPages': '',
#    'language': 'English',
#    'ISBN': '978-0-691-14091-9 0-691-14091-X',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '/z-wcorg/',
#    'archiveLocation': '',
#    'libraryCatalog': 'http://worldcat.org',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/R7SBJXLH'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  {'key': 'TGQ9TAPF',
#   'version': 104,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/TGQ9TAPF',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/TGQ9TAPF',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2010', 'numChildren': 0},
#   'data': {'key': 'TGQ9TAPF',
#    'version': 104,
#    'itemType': 'book',
#    'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'New York',
#    'publisher': 'Farrar, Straus and Giroux',
#    'date': '2010',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '978-0-312-61169-9',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#    'tags': [{'tag': 'civilisationens historie'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WC3F7GTN'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  {'key': '93X7WDDV',
#   'version': 104,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/93X7WDDV',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/93X7WDDV',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2013', 'numChildren': 0},
#   'data': {'key': '93X7WDDV',
#    'version': 104,
#    'itemType': 'book',
#    'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': 'Course Book',
#    'place': 'Princeton, NJ',
#    'publisher': 'Princeton University Press',
#    'date': '2013',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '1-299-14683-X',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'tags': [{'tag': 'Social structure'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/YTH8LCMQ'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  {'key': 'WZ6MD9YX',
#   'version': 104,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/WZ6MD9YX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/WZ6MD9YX',
# ...
#    'dateModified': '2021-05-07T13:47:11Z'}},
#  {'key': 'A6W7Q3HZ',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/A6W7Q3HZ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/A6W7Q3HZ',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Woolf', 'parsedDate': '1996', 'numChildren': 0},
#   'data': {'key': 'A6W7Q3HZ',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Greg',
#      'lastName': 'Woolf'}],
#    'abstractNote': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#    'publicationTitle': 'Journal of Roman Studies',
#    'volume': '86',
#    'issue': '',
#    'pages': '22–39',
#    'date': '1996',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.2307/300421',
#    'ISSN': '0075-4358',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'epigraphic habit'},
#     {'tag': 'epigraphy'},
#     {'tag': 'epipgaphic infrastructure'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/97CQ2NB2'},
#    'dateAdded': '2021-05-07T13:47:11Z',
#    'dateModified': '2021-05-07T13:47:11Z'}},
#  {'key': 'YWIASGX4',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/YWIASGX4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/YWIASGX4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Grieshaber',
#    'parsedDate': '2019',
#    'numChildren': 0},
#   'data': {'key': 'YWIASGX4',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Epigraphic Database Heidelberg – Data Reuse Options',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Frank',
#      'lastName': 'Grieshaber'}],
#    'abstractNote': '',
#    'publicationTitle': '',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '2019',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.11588/HEIDOK.00026599',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/26599',
#    'accessDate': '2021-05-07T13:16:00Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Datacite)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Heidelberg University Library',
#    'tags': [{'tag': '470 Italic Latin', 'type': 1},
#     {'tag': '930 History of ancient world', 'type': 1}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/U6IWIHZP'},
#    'dateAdded': '2021-05-07T13:16:00Z',
#    'dateModified': '2021-05-07T13:16:00Z'}},
#  {'key': 'MGBT6ZCX',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/MGBT6ZCX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/MGBT6ZCX',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Feraudi-Gruénais and Grieshaber',
#    'parsedDate': '2016',
#    'numChildren': 0},
#   'data': {'key': 'MGBT6ZCX',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Digital Epigraphy am Scheideweg? / Digital Epigraphy at a crossroads?',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Francisca',
#      'lastName': 'Feraudi-Gruénais'},
#     {'creatorType': 'author', 'firstName': 'Frank', 'lastName': 'Grieshaber'}],
#    'abstractNote': '',
#    'publicationTitle': '',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '2016',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.11588/HEIDOK.00022141',
#    'ISSN': '',
#    'shortTitle': 'Digital Epigraphy am Scheideweg?',
#    'url': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/22141',
#    'accessDate': '2021-05-07T13:11:36Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Datacite)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Heidelberg University Library',
#    'tags': [{'tag': '000 Generalities, Science', 'type': 1},
#     {'tag': '470 Italic Latin', 'type': 1},
#     {'tag': '480 Hellenic languages Classical Greek', 'type': 1}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/92AWXFTV'},
#    'dateAdded': '2021-05-07T13:11:36Z',
#    'dateModified': '2021-05-07T13:11:36Z'}},
#  {'key': '2WIJQZDC',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/2WIJQZDC',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/2WIJQZDC',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Bolle et al.',
#    'parsedDate': '2017',
#    'numChildren': 0},
#   'data': {'key': '2WIJQZDC',
#    'version': 99,
#    'itemType': 'book',
#    'title': 'The Epigraphic Cultures of Late Antiquity',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'K.',
#      'lastName': 'Bolle'},
#     {'creatorType': 'author', 'firstName': 'C.', 'lastName': 'Machado'},
#     {'creatorType': 'author', 'firstName': 'C.', 'lastName': 'Witschel'}],
#    'abstractNote': '',
#    'series': 'Alte Geschichte',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Franz Steiner Verlag',
#    'date': '2017',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-3-515-11558-2',
#    'shortTitle': '',
#    'url': 'https://books.google.dk/books?id=iJBdMQAACAAJ',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/VEGXDB34'},
#    'dateAdded': '2021-05-07T13:03:09Z',
#    'dateModified': '2021-05-07T13:03:09Z'}},
#  {'key': 'N8YT927J',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/N8YT927J',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/N8YT927J',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Beltrán Lloris',
#    'parsedDate': '2014',
#    'numChildren': 0},
#   'data': {'key': 'N8YT927J',
#    'version': 99,
#    'itemType': 'bookSection',
#    'title': 'The “Epigraphic Habit” in the Roman World',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Francisco',
#      'lastName': 'Beltrán Lloris'}],
#    'abstractNote': 'Since the 1980s scholars have ceased considering Roman inscriptions simply in functional terms—as sources of historical information—and started to treat them as a cultural phenomenon worthy of serious consideration. This change in perspective, as well as the realization that there was a permanent bond between text and monument, represents the most productive shift in approach in recent epigraphic scholarship. This chapter analyzes the “epigraphic habit” in order to explain why people wrote on stone throughout Italy and the provinces, linking its rise to the proliferation of urbanization, literacy, and the desire for self-representation.',
#    'bookTitle': 'The Oxford Handbook of Roman Epigraphy',
#    'series': 'Oxford Handbooks',
#    'seriesNumber': '',
#    'volume': '1',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Oxford University Press',
#    'date': '2014',
#    'pages': '',
#    'language': 'eng',
#    'ISBN': '0-19-533646-1',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Italy'},
#     {'tag': 'Principate'},
#     {'tag': 'Roman provinces'},
#     {'tag': 'Rome'},
#     {'tag': 'epigraphic habit'},
#     {'tag': 'epitaphs'},
#     {'tag': 'freedmen'},
#     {'tag': 'furor epigraphicus'},
#     {'tag': 'inscriptions'},
#     {'tag': 'urbanization'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/MX4RX9KU'},
#    'dateAdded': '2021-05-07T12:39:58Z',
#    'dateModified': '2021-05-07T12:39:58Z'}},
#  {'key': 'KBJ7VEJ8',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/KBJ7VEJ8',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/KBJ7VEJ8',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Pérez', 'parsedDate': '2021', 'numChildren': 0},
#   'data': {'key': 'KBJ7VEJ8',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy: The End of a Habit?',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Aitor Blanco',
#      'lastName': 'Pérez'}],
#    'abstractNote': '<p>The political communities of western Asia Minor produced an enormous amount of inscriptions under Roman rule. For the period between AD 260 and 280, however, the epigraphic habit falls dramatically and this situation largely continues in the 4<sup>th</sup> and 5<sup>th</sup> centuries. The aim of this paper is to analyse the phenomenon in the transitional Tetrarchic age, when a notable increase in testimony, particularly milestones and texts related to the new regime (e. g. ‘Edict of Prices’), can be observed. My study of continuities and changes concludes that the propagandistic efforts under the Tetrarchs did not ultimately coincide with a full reactivation of civic epigraphic culture and this new scenario should remain fundamental for our assessment of Late Antiquity in the region.</p>',
#    'publicationTitle': 'Historia',
#    'volume': '70',
#    'issue': '1',
#    'pages': '116-132',
#    'date': '2021',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'historia',
#    'language': 'en',
#    'DOI': '10.25162/historia-2021-0006',
#    'ISSN': '0018-2311',
#    'shortTitle': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy',
#    'url': 'https://elibrary.steiner-verlag.de/article/10.25162/historia-2021-0006',
#    'accessDate': '2021-05-07T12:22:35Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'elibrary.steiner-verlag.de',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/FZSBUKPJ'},
#    'dateAdded': '2021-05-07T12:22:36Z',
#    'dateModified': '2021-05-07T12:22:36Z'}},
#  {'key': 'RAG327R6',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/RAG327R6',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/RAG327R6',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Trout', 'parsedDate': '2009', 'numChildren': 0},
#   'data': {'key': 'RAG327R6',
#    'version': 99,
#    'itemType': 'bookSection',
#    'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Dennis E.',
#      'lastName': 'Trout'}],
#    'abstractNote': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#    'bookTitle': 'A Companion to Late Antiquity',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'John Wiley & Sons, Ltd',
#    'date': '2009',
#    'pages': '170-186',
#    'language': 'en',
#    'ISBN': '978-1-4443-0610-1',
#    'shortTitle': 'Inscribing Identity',
#    'url': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#    'accessDate': '2021-05-07T12:15:20Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Wiley Online Library',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1002/9781444306101.ch12',
#    'tags': [{'tag': "Latin of Late Antiquity's non-elites", 'type': 1},
#     {'tag': 'civic history and public memory', 'type': 1},
#     {'tag': 'epigraphic corpora and epigraphic curves', 'type': 1},
#     {'tag': 'epigraphic horizons', 'type': 1},
#     {'tag': 'epigraphy of Christians', 'type': 1},
#     {'tag': 'evolution of Vulgar (or demotic) Latin toward Romance languages',
#      'type': 1},
#     {'tag': 'inscribing identity - Latin epigraphic habit', 'type': 1},
#     {'tag': 'inscriptions preserving unique images of late antique life and society',
#      'type': 1}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/H728XWCW'},
#    'dateAdded': '2021-05-07T12:15:20Z',
#    'dateModified': '2021-05-07T12:15:20Z'}}]

# %%
# ids of items
citation_keys_pairs = {}
for item in collection_items_json:
    if item["data"]["itemType"] != "attachment":
        try:
            item_key = item["meta"]["creatorSummary"] + " " + item["meta"]["parsedDate"]
        except: 
            try:
                item_key = item["data"]["title"]
            except:
                item_key = ""
        citation_keys_pairs[item_key] = item["data"]["key"]

# %%
citation_keys_pairs
# Out:
# {'Lowndes et al. 2017': '8C5W7WYE',
#  'Scheidel 2018': '3J5XSHJ2',
#  'Huggett 2017-05-23': 'CY54CMQ9',
#  'Huggett 2016-06-29': 'QZV4FHQ6',
#  'Raymond 2001': '3NH6EHMA',
#  'Iversen 2007': 'CAJ8RP6I',
#  'Sherratt 2019-10-29': 'GZXS5Q8K',
#  'Madzharov 2009': 'XDAURK5G',
#  'Hollenstein 1975': '7DY6HUZB',
#  'Duncan-Jones 2018': 'J6GWZWL4',
#  'Duncan-Jones 1990-04-12': 'YFQQLVBK',
#  'Duncan-Jones 1996': 'HCU3WEJB',
#  'Tahmasebi and Hengchen 2019': 'UH4L3837',
#  'Wilson 2009': 'TARVRY26',
#  'Liuzzo 2019-10-17': 'WRRYLBT4',
#  'Wilkinson et al. 2016': 'VI7N28PJ',
#  'Ballsun-Stanton 2020': 'KGBLD6FY',
#  'Kolb 2019-06-17': 'MCUQLXCG',
#  'Ober 2015': 'RB28J3CE',
#  'Morris 2010': 'TGQ9TAPF',
#  'Morris 2013': '93X7WDDV',
#  'Hanson et al. 2017': 'WZ6MD9YX',
#  'Mullins et al. 2018': '2ASLDCJP',
#  'Borgman 2015': 'FBAWXZ3I',
#  'Cayless et al. 2010-12-31': 'EYTI8IQA',
#  'Laurence 1999': 'QSJYQVZZ',
#  'Bodard 2008': 'KE9T4566',
#  'Bodard et al. 2021-03-26': '2KEXYJLP',
#  'Avanzini et al. 2018-12-31': '7EHKTWQD',
#  'Liuzzo 2018-12-31': 'TKXWFLYN',
#  'de Ligt and Tacoma 2016-01-19': '75PC3E2A',
#  'Harper 2016': 'SVYA23ZT',
#  'Littman and Littman 1973': 'D2YZ7HDA',
#  'Verhagen 2019': 'BG7SH7C4',
#  'De Santis and Rossi 2018-12-31': 'NKKHMIDW',
#  'Wilson and Flohr 2016-01-01': 'L73K2ZRY',
#  'Kemkes 2020-03-24': 'TISH84GY',
#  'Hanel 2020-03-24': 'ZESEJVF2',
#  'Bodel 2001': '82J5J52N',
#  'Verhagen et al. 2016': 'FLW2G53N',
#  'Rabinowitz et al. 2018-12-31': 'XLJYXMEV',
#  'Elliot et al. 2017': 'T45AYTCM',
#  'Hartmann 2018-10-13': 'EAY2DVSF',
#  'Oksanen and Lewis 2020': 'YW3AIT6K',
#  'Hedrick 1999': 'IRUVQAYJ',
#  'Wilson 2012': 'BRZQ3MUL',
#  'Keppie 1991': 'YMB2QZ7K',
#  'Cooley et al. 2007': '283Z83RT',
#  'Bowman and Wilson 2009': 'QS4C5IAS',
#  'Turchin et al. 2018': '3L9BKAXW',
#  'Turchin and Scheidel 2009': 'PE4PYNDX',
#  'Lotz 2020-10-07': 'ARLWKWIA',
#  'Kaše 2021-03-31': 'A38DT8IA',
#  'Johnson 2004': 'T6MN4QSJ',
#  'Crema 2012': 'A9IA3B55',
#  'Crema and Kobayashi 2020': '6GLRJFFY',
#  'Janouchová (Heřmánková) 2021': 'AUPFZAAL',
#  'Prag 2013': '7U7NNBAA',
#  'Korhonen 2011': '7AA3T3HM',
#  'Prag 2002': 'JAXUAMNH',
#  'Roueche and Sotinel 2017-03': 'TWB9XHFH',
#  'Bloch 1947': 'WLLWUZT7',
#  'Bloch 1967': 'JCIXA2RJ',
#  'Elliot et al. 2020': '9J244TYE',
#  'Dow 1969': 'EBFQEFW3',
#  'Nawotka 2021': 'TXCY5XL8',
#  'Meyer 1990': 'AU6JTRIU',
#  'Elliot 2015': '5W97HIK9',
#  'Duthoy 2002': 'VDS8KTIA',
#  'McLean 2016': 'SBV9XF6H',
#  'MacMullen 1982': 'C5QVR3SE',
#  'Woolf 1996': 'A6W7Q3HZ',
#  'Grieshaber 2019': 'YWIASGX4',
#  'Feraudi-Gruénais and Grieshaber 2016': 'MGBT6ZCX',
#  'Bolle et al. 2017': '2WIJQZDC',
#  'Beltrán Lloris 2014': 'N8YT927J',
#  'Pérez 2021': 'KBJ7VEJ8',
#  'Trout 2009': 'RAG327R6'}

# %% [markdown]
# # Test with one item

# %%
item_id = "RAG327R6"
url = "https://api.zotero.org/users/5925766/items/" + item_id + "?format=csljson"
item_json = requests.get(url, headers=headers).json()
item_json
# Out:
# {'items': [{'id': '7109337/RAG327R6',
#    'type': 'chapter',
#    'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#    'container-title': 'A Companion to Late Antiquity',
#    'publisher': 'John Wiley & Sons, Ltd',
#    'page': '170-186',
#    'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#    'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#    'ISBN': '978-1-4443-0610-1',
#    'note': 'DOI: 10.1002/9781444306101.ch12',
#    'shortTitle': 'Inscribing Identity',
#    'language': 'en',
#    'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#    'issued': {'date-parts': [[2009]]},
#    'accessed': {'date-parts': [[2021, 5, 7]]}}]}

# %%
# list all items within preselected collection:
url = "https://api.zotero.org/users/5925766/collections/" + collection_key + "/items?limit=1000&format=csljson"
collection_items_csljson = requests.get(url, headers=headers).json()
collection_items_csljson["items"][:5]
# Out:
# [{'id': '7109337/5DKTH37I',
#   'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.nature.com/articles/s41559-017-0160.pdf',
#   'accessed': {'date-parts': [[2021, 6, 11]]}},
#  {'id': '7109337/8C5W7WYE',
#   'type': 'article-journal',
#   'title': 'Our path to better science in less time using open data science tools',
#   'container-title': 'Nature Ecology & Evolution',
#   'page': '0160',
#   'volume': '1',
#   'issue': '6',
#   'URL': 'http://www.nature.com/articles/s41559-017-0160',
#   'DOI': '10.1038/s41559-017-0160',
#   'journalAbbreviation': 'Nat Ecol Evol',
#   'language': 'en',
#   'author': [{'family': 'Lowndes', 'given': 'Julia S. Stewart'},
#    {'family': 'Best', 'given': 'Benjamin D.'},
#    {'family': 'Scarborough', 'given': 'Courtney'},
#    {'family': 'Afflerbach', 'given': 'Jamie C.'},
#    {'family': 'Frazier', 'given': 'Melanie R.'},
#    {'family': 'O’Hara', 'given': 'Casey C.'},
#    {'family': 'Jiang', 'given': 'Ning'},
#    {'family': 'Halpern', 'given': 'Benjamin S.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 6, 11]]}},
#  {'id': '7109337/3J5XSHJ2',
#   'type': 'book',
#   'title': 'The Great Leveler: Violence and the History of Inequality from the Stone Age to the Twenty-First Century',
#   'collection-title': 'The Princeton Economic History of the Western World',
#   'publisher': 'Princeton University Press',
#   'URL': 'https://press.princeton.edu/books/paperback/9780691183251/the-great-leveler',
#   'ISBN': '978-0-691-18325-1',
#   'author': [{'family': 'Scheidel', 'given': 'Walter'}],
#   'issued': {'date-parts': [[2018]]}},
#  {'id': '7109337/CY54CMQ9',
#   'type': 'post-weblog',
#   'title': 'Citing Data Reuse',
#   'URL': 'https://introspectivedigitalarchaeology.com/2017/05/23/citing-data-reuse/',
#   'language': 'eng',
#   'author': [{'family': 'Huggett', 'given': 'Jeremy'}],
#   'issued': {'date-parts': [[2017, 5, 23]]}},
#  {'id': '7109337/QZV4FHQ6',
#   'type': 'post-weblog',
#   'title': 'Digital Data Realities',
#   'URL': 'https://introspectivedigitalarchaeology.com/2016/06/29/digital-data-realities/',
#   'language': 'eng',
#   'author': [{'family': 'Huggett', 'given': 'Jeremy'}],
#   'issued': {'date-parts': [[2016, 6, 29]]}}]

# %%
citations = {}
for item in collection_items_csljson["items"]:
    try:
        citations[item["id"]] = item
        citations[item["id"]].pop("id", None)
    except:
        pass

# %%
citations
# Out:
# {'7109337/5DKTH37I': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.nature.com/articles/s41559-017-0160.pdf',
#   'accessed': {'date-parts': [[2021, 6, 11]]}},
#  '7109337/8C5W7WYE': {'type': 'article-journal',
#   'title': 'Our path to better science in less time using open data science tools',
#   'container-title': 'Nature Ecology & Evolution',
#   'page': '0160',
#   'volume': '1',
#   'issue': '6',
#   'URL': 'http://www.nature.com/articles/s41559-017-0160',
#   'DOI': '10.1038/s41559-017-0160',
#   'journalAbbreviation': 'Nat Ecol Evol',
#   'language': 'en',
#   'author': [{'family': 'Lowndes', 'given': 'Julia S. Stewart'},
#    {'family': 'Best', 'given': 'Benjamin D.'},
#    {'family': 'Scarborough', 'given': 'Courtney'},
#    {'family': 'Afflerbach', 'given': 'Jamie C.'},
#    {'family': 'Frazier', 'given': 'Melanie R.'},
#    {'family': 'O’Hara', 'given': 'Casey C.'},
#    {'family': 'Jiang', 'given': 'Ning'},
#    {'family': 'Halpern', 'given': 'Benjamin S.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 6, 11]]}},
#  '7109337/3J5XSHJ2': {'type': 'book',
#   'title': 'The Great Leveler: Violence and the History of Inequality from the Stone Age to the Twenty-First Century',
#   'collection-title': 'The Princeton Economic History of the Western World',
#   'publisher': 'Princeton University Press',
#   'URL': 'https://press.princeton.edu/books/paperback/9780691183251/the-great-leveler',
#   'ISBN': '978-0-691-18325-1',
#   'author': [{'family': 'Scheidel', 'given': 'Walter'}],
#   'issued': {'date-parts': [[2018]]}},
#  '7109337/CY54CMQ9': {'type': 'post-weblog',
#   'title': 'Citing Data Reuse',
#   'URL': 'https://introspectivedigitalarchaeology.com/2017/05/23/citing-data-reuse/',
#   'language': 'eng',
#   'author': [{'family': 'Huggett', 'given': 'Jeremy'}],
#   'issued': {'date-parts': [[2017, 5, 23]]}},
#  '7109337/QZV4FHQ6': {'type': 'post-weblog',
#   'title': 'Digital Data Realities',
#   'URL': 'https://introspectivedigitalarchaeology.com/2016/06/29/digital-data-realities/',
#   'language': 'eng',
#   'author': [{'family': 'Huggett', 'given': 'Jeremy'}],
#   'issued': {'date-parts': [[2016, 6, 29]]}},
#  '7109337/3NH6EHMA': {'type': 'book',
#   'title': 'The Cathedral & the Bazaar',
#   'publisher': "O'Reilly Media",
#   'URL': 'https://www.oreilly.com/library/view/the-cathedral/0596001088/',
#   'ISBN': '978-0-596-00108-7',
#   'language': 'English',
#   'author': [{'family': 'Raymond', 'given': 'Eric S.'}],
#   'issued': {'date-parts': [[2001]]}},
#  '7109337/CAJ8RP6I': {'type': 'article-journal',
#   'title': 'The Packard Humanities Institute (PHI) Greek Epigraphy Project and the Revolution in Greek Epigraphy',
#   'container-title': 'Abgadiyat',
#   'page': '51-55',
#   'volume': '2.1',
#   'abstract': 'In this paper, the history, purpose and importance\nof the Packard Humanities Institute (PHI) Greek\nEpigraphy Project are discussed.',
#   'URL': 'https://journals.ekb.eg/article_62069_38414a2fca56893baf78323065072f95.pdf',
#   'language': 'eng',
#   'author': [{'family': 'Iversen', 'given': 'Paul A.'}],
#   'issued': {'date-parts': [[2007]]}},
#  '7109337/GZXS5Q8K': {'type': 'chapter',
#   'title': 'Hacking heritage: Understanding the limits of online access',
#   'container-title': 'The Routledge International Handbook of New Digital Practices in Galleries, Libraries, Archives, Museums and Heritage Sites',
#   'publisher': 'Routledge',
#   'page': '15',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9780429015304',
#   'ISBN': '978-0-429-50676-5',
#   'note': 'DOI: 10.4324/9780429506765',
#   'language': 'en',
#   'editor': [{'family': 'Lewi', 'given': 'Hannah'},
#    {'family': 'Smith', 'given': 'Wally'},
#    {'family': 'vom Lehn', 'given': 'Dirk'},
#    {'family': 'Cooke', 'given': 'Steven'}],
#   'author': [{'family': 'Sherratt', 'given': 'Tim'}],
#   'issued': {'date-parts': [[2019, 10, 29]]},
#   'accessed': {'date-parts': [[2021, 6, 10]]}},
#  '7109337/3ADCMC6C': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://dro.deakin.edu.au/eserv/DU:30122388/cooke-investigatingordinary-post-2019.pdf',
#   'accessed': {'date-parts': [[2021, 6, 10]]}},
#  '7109337/XDAURK5G': {'type': 'book',
#   'title': 'Rimski patishta v Balgaria: prinos v razvitieto na rimskata patna sistema v provintsiite Mizia i Trakia',
#   'publisher': 'Faber Publisher',
#   'publisher-place': 'Veliko Turnovo',
#   'event-place': 'Veliko Turnovo',
#   'author': [{'family': 'Madzharov', 'given': 'Mitko'}],
#   'issued': {'date-parts': [[2009]]}},
#  '7109337/7DY6HUZB': {'type': 'article-journal',
#   'title': 'Zu den Meilensteinen der römischen Provinzen Thracia und Moesia Inferior',
#   'container-title': 'Studia Balcanica',
#   'page': '23–44',
#   'volume': '10',
#   'author': [{'family': 'Hollenstein', 'given': 'Lorenz'}],
#   'issued': {'date-parts': [[1975]]}},
#  '7109337/J6GWZWL4': {'type': 'article-journal',
#   'title': 'The Antonine Plague Revisited',
#   'container-title': 'Arctos',
#   'page': '41-72',
#   'volume': '52',
#   'language': 'eng',
#   'author': [{'family': 'Duncan-Jones', 'given': 'Richard'}],
#   'issued': {'date-parts': [[2018]]}},
#  '7109337/YFQQLVBK': {'type': 'book',
#   'title': 'Structure and Scale in the Roman Economy',
#   'publisher': 'Cambridge University Press',
#   'edition': '1',
#   'URL': 'https://www.cambridge.org/core/product/identifier/9780511552649/type/book',
#   'ISBN': '978-0-521-35477-6 978-0-521-89289-6 978-0-511-55264-9',
#   'note': 'DOI: 10.1017/CBO9780511552649',
#   'author': [{'family': 'Duncan-Jones', 'given': 'Richard'}],
#   'issued': {'date-parts': [[1990, 4, 12]]},
#   'accessed': {'date-parts': [[2021, 6, 3]]}},
#  '7109337/HCU3WEJB': {'type': 'article-journal',
#   'title': 'The impact of the Antonine plague',
#   'container-title': 'Journal of Roman Archaeology',
#   'page': '108-136',
#   'volume': '9',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S1047759400016524/type/journal_article',
#   'DOI': '10.1017/S1047759400016524',
#   'journalAbbreviation': 'J. Roman archaeol.',
#   'language': 'en',
#   'author': [{'family': 'Duncan-Jones', 'given': 'R. P.'}],
#   'issued': {'date-parts': [[1996]]},
#   'accessed': {'date-parts': [[2021, 6, 3]]}},
#  '7109337/UH4L3837': {'type': 'article-journal',
#   'title': 'The Strengths and Pitfalls of Large-Scale Text Mining for Literary Studies',
#   'container-title': 'Samlaren',
#   'page': '198–227',
#   'volume': '140',
#   'URL': 'http://uu.diva-portal.org/smash/get/diva2:1415010/FULLTEXT01.pdf',
#   'author': [{'family': 'Tahmasebi', 'given': 'Nina'},
#    {'family': 'Hengchen', 'given': 'Simon'}],
#   'issued': {'date-parts': [[2019]]}},
#  '7109337/TARVRY26': {'type': 'article-journal',
#   'title': 'Indicators for Roman economic growth: a response to Walter Scheidel',
#   'container-title': 'Journal of Roman Archaeology',
#   'page': '71-82',
#   'volume': '22',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S1047759400020596/type/journal_article',
#   'DOI': '10.1017/S1047759400020596',
#   'shortTitle': 'Indicators for Roman economic growth',
#   'journalAbbreviation': 'J. Roman archaeol.',
#   'language': 'en',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 6, 1]]}},
#  '7109337/WRRYLBT4': {'type': 'book',
#   'title': 'Digital Approaches to Ethiopian and Eritrean Studies',
#   'publisher': 'Harrassowitz, O',
#   'edition': '1',
#   'URL': 'http://www.jstor.org/stable/10.2307/j.ctvrnfr3q',
#   'ISBN': '978-3-447-19913-1 978-3-447-11291-8',
#   'note': 'DOI: 10.2307/j.ctvrnfr3q',
#   'author': [{'family': 'Liuzzo', 'given': 'Pietro Maria'}],
#   'issued': {'date-parts': [[2019, 10, 17]]},
#   'accessed': {'date-parts': [[2021, 5, 31]]}},
#  '7109337/DWGK7BKK': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.nature.com/articles/sdata201618.pdf',
#   'accessed': {'date-parts': [[2021, 5, 31]]}},
#  '7109337/VI7N28PJ': {'type': 'article-journal',
#   'title': 'The FAIR Guiding Principles for scientific data management and stewardship',
#   'container-title': 'Scientific Data',
#   'page': '160018',
#   'volume': '3',
#   'issue': '1',
#   'URL': 'http://www.nature.com/articles/sdata201618',
#   'DOI': '10.1038/sdata.2016.18',
#   'journalAbbreviation': 'Sci Data',
#   'language': 'en',
#   'author': [{'family': 'Wilkinson', 'given': 'Mark D.'},
#    {'family': 'Dumontier', 'given': 'Michel'},
#    {'family': 'Aalbersberg', 'given': 'IJsbrand Jan'},
#    {'family': 'Appleton', 'given': 'Gabrielle'},
#    {'family': 'Axton', 'given': 'Myles'},
#    {'family': 'Baak', 'given': 'Arie'},
#    {'family': 'Blomberg', 'given': 'Niklas'},
#    {'family': 'Boiten', 'given': 'Jan-Willem'},
#    {'family': 'da Silva Santos', 'given': 'Luiz Bonino'},
#    {'family': 'Bourne', 'given': 'Philip E.'},
#    {'family': 'Bouwman', 'given': 'Jildau'},
#    {'family': 'Brookes', 'given': 'Anthony J.'},
#    {'family': 'Clark', 'given': 'Tim'},
#    {'family': 'Crosas', 'given': 'Mercè'},
#    {'family': 'Dillo', 'given': 'Ingrid'},
#    {'family': 'Dumon', 'given': 'Olivier'},
#    {'family': 'Edmunds', 'given': 'Scott'},
#    {'family': 'Evelo', 'given': 'Chris T.'},
#    {'family': 'Finkers', 'given': 'Richard'},
#    {'family': 'Gonzalez-Beltran', 'given': 'Alejandra'},
#    {'family': 'Gray', 'given': 'Alasdair J.G.'},
#    {'family': 'Groth', 'given': 'Paul'},
#    {'family': 'Goble', 'given': 'Carole'},
#    {'family': 'Grethe', 'given': 'Jeffrey S.'},
#    {'family': 'Heringa', 'given': 'Jaap'},
#    {'family': '’t Hoen', 'given': 'Peter A.C'},
#    {'family': 'Hooft', 'given': 'Rob'},
#    {'family': 'Kuhn', 'given': 'Tobias'},
#    {'family': 'Kok', 'given': 'Ruben'},
#    {'family': 'Kok', 'given': 'Joost'},
#    {'family': 'Lusher', 'given': 'Scott J.'},
#    {'family': 'Martone', 'given': 'Maryann E.'},
#    {'family': 'Mons', 'given': 'Albert'},
#    {'family': 'Packer', 'given': 'Abel L.'},
#    {'family': 'Persson', 'given': 'Bengt'},
#    {'family': 'Rocca-Serra', 'given': 'Philippe'},
#    {'family': 'Roos', 'given': 'Marco'},
#    {'family': 'van Schaik', 'given': 'Rene'},
#    {'family': 'Sansone', 'given': 'Susanna-Assunta'},
#    {'family': 'Schultes', 'given': 'Erik'},
#    {'family': 'Sengstag', 'given': 'Thierry'},
#    {'family': 'Slater', 'given': 'Ted'},
#    {'family': 'Strawn', 'given': 'George'},
#    {'family': 'Swertz', 'given': 'Morris A.'},
#    {'family': 'Thompson', 'given': 'Mark'},
#    {'family': 'van der Lei', 'given': 'Johan'},
#    {'family': 'van Mulligen', 'given': 'Erik'},
#    {'family': 'Velterop', 'given': 'Jan'},
#    {'family': 'Waagmeester', 'given': 'Andra'},
#    {'family': 'Wittenburg', 'given': 'Peter'},
#    {'family': 'Wolstencroft', 'given': 'Katherine'},
#    {'family': 'Zhao', 'given': 'Jun'},
#    {'family': 'Mons', 'given': 'Barend'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 31]]}},
#  '7109337/KGBLD6FY': {'type': 'book',
#   'title': 'Lat Epig 2.0',
#   'publisher': 'Macquarie University',
#   'URL': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#   'author': [{'family': 'Ballsun-Stanton', 'given': 'Brian'}],
#   'issued': {'date-parts': [[2020]]}},
#  '7109337/MCUQLXCG': {'type': 'chapter',
#   'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#   'container-title': 'Roman Roads: New Evidence - New Perspectives',
#   'publisher': 'De Gruyter',
#   'page': '3-21',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#   'ISBN': '978-3-11-063833-2',
#   'note': 'DOI: 10.1515/9783110638332',
#   'author': [{'family': 'Kolb', 'given': 'Anne'}],
#   'editor': [{'family': 'Kolb', 'given': 'Anne'}],
#   'issued': {'date-parts': [[2019, 6, 17]]},
#   'accessed': {'date-parts': [[2021, 5, 19]]}},
#  '7109337/RB28J3CE': {'type': 'book',
#   'title': 'The rise and fall of classical Greece',
#   'archive': '/z-wcorg/',
#   'abstract': '"Lord Byron described Greece as great, fallen, and immortal, a characterization more apt than he knew. Through most of its long history, Greece was poor. But in the classical era, Greece was densely populated and highly urbanized. Many surprisingly healthy Greeks lived in remarkably big houses and worked for high wages at specialized occupations. Middle-class spending drove sustained economic growth. Classical wealth produced a stunning cultural efflorescence lasting hundreds of years. Why did Greece reach such heights in the classical period--and why only then? And how, after \'the Greek miracle\' had endured for centuries, did the Macedonians defeat the Greeks, seemingly bringing an end to their glory? Drawing on a massive body of newly available data and employing novel approaches to evidence, Josiah Ober offers a major new history of classical Greece and an unprecedented account of its rise and fall. Ober argues that Greece\'s rise was no miracle but rather the result of political breakthroughs and economic development. The extraordinary emergence of citizen-centered city-states transformed Greece into a society that defeated the mighty Persian Empire. Yet Philip and Alexander of Macedon were able to beat the Greeks in the Battle of Chaeronea in 338 BCE, a victory enabled by the Macedonians\' appropriation of Greek innovations. After Alexander\'s death, battle-hardened warlords fought ruthlessly over the remnants of his empire. But Greek cities remained populous and wealthy, their economy and culture surviving to be passed on to the Romans--and to us. A compelling narrative filled with uncanny modern parallels, this is a book for anyone interested in how great civilizations are born and die. This book is based on evidence available on a new interactive website. To learn more, please visit: http://polis.stanford.edu/"--',
#   'ISBN': '978-0-691-14091-9 0-691-14091-X',
#   'language': 'English',
#   'author': [{'family': 'Ober', 'given': 'Josiah.'}],
#   'issued': {'date-parts': [[2015]]}},
#  '7109337/TGQ9TAPF': {'type': 'book',
#   'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#   'publisher': 'Farrar, Straus and Giroux',
#   'publisher-place': 'New York',
#   'event-place': 'New York',
#   'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#   'ISBN': '978-0-312-61169-9',
#   'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2010]]}},
#  '7109337/93X7WDDV': {'type': 'book',
#   'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'publisher': 'Princeton University Press',
#   'publisher-place': 'Princeton, NJ',
#   'edition': 'Course Book',
#   'event-place': 'Princeton, NJ',
#   'abstract': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#   'ISBN': '1-299-14683-X',
#   'note': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2013]]}},
#  '7109337/WZ6MD9YX': {'type': 'article-journal',
#   'title': 'Urbanism and the division of labour in the Roman Empire',
#   'container-title': 'Journal of The Royal Society Interface',
#   'page': '20170367',
#   'volume': '14',
#   'issue': '136',
#   'abstract': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#   'URL': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#   'DOI': '10.1098/rsif.2017.0367',
#   'journalAbbreviation': 'J. R. Soc. Interface.',
#   'language': 'en',
#   'author': [{'family': 'Hanson', 'given': 'J. W.'},
#    {'family': 'Ortman', 'given': 'S. G.'},
#    {'family': 'Lobo', 'given': 'J.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  '7109337/2ASLDCJP': {'type': 'article-journal',
#   'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#   'container-title': 'American Sociological Review',
#   'page': '596-626',
#   'volume': '83',
#   'issue': '3',
#   'abstract': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#   'URL': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#   'DOI': '10.1177/0003122418772567',
#   'journalAbbreviation': 'Am Sociol Rev',
#   'language': 'en',
#   'author': [{'family': 'Mullins', 'given': 'Daniel Austin'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Currie', 'given': 'Thomas'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Savage', 'given': 'Patrick E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'Turchin', 'given': 'Peter'}],
#   'issued': {'date-parts': [['2018']]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/FBAWXZ3I': {'type': 'book',
#   'title': 'Big Data, Little Data, No Data',
#   'publisher': 'The MIT Press',
#   'archive': 'JSTOR',
#   'abstract': '"Big Data" is on the covers of<em>Science, Nature</em>, the<em>Economist</em>, and<em>Wired</em>magazines, on the front pages of the<em>Wall Street Journal</em>and the<em>New York Times.</em>But despite the media hyperbole, as Christine Borgman points out in this examination of data and scholarly research, having the right data is usually better than having more data; little data can be just as valuable as big data. In many cases, there are no data -- because relevant data don\'t exist, cannot be found, or are not available. Moreover, data sharing is difficult, incentives to do so are minimal, and data practices vary widely across disciplines.Borgman, an often-cited authority on scholarly communication, argues that data have no value or meaning in isolation; they exist within a knowledge infrastructure -- an ecology of people, practices, technologies, institutions, material objects, and relationships. After laying out the premises of her investigation -- six "provocations" meant to inspire discussion about the uses of data in scholarship -- Borgman offers case studies of data practices in the sciences, the social sciences, and the humanities, and then considers the implications of her findings for scholarly practice and research policy. To manage and exploit data over the long term, Borgman argues, requires massive investment in knowledge infrastructures; at stake is the future of scholarship.',
#   'URL': 'http://www.jstor.org/stable/j.ctt17kk8n8',
#   'ISBN': '978-0-262-02856-1',
#   'author': [{'family': 'Borgman', 'given': 'Christine L.'}],
#   'issued': {'date-parts': [[2015]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/EYTI8IQA': {'type': 'chapter',
#   'title': 'EPIGRAPHY IN 2017',
#   'container-title': 'Changing the Center of Gravity',
#   'publisher': 'Gorgias Press',
#   'page': '203-222',
#   'URL': 'https://www.degruyter.com/document/doi/10.31826/9781463219222-012/html',
#   'ISBN': '978-1-4632-1922-2',
#   'note': 'DOI: 10.31826/9781463219222-012',
#   'editor': [{'family': 'Terras', 'given': 'Melissa'},
#    {'family': 'Crane', 'given': 'Gregory'}],
#   'author': [{'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Roueché', 'given': 'Charlotte'},
#    {'family': 'Elliott', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2010, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/QSJYQVZZ': {'type': 'book',
#   'title': 'The roads of Roman Italy: mobility and cultural change',
#   'publisher': 'Routledge',
#   'publisher-place': 'London; New York',
#   'archive': '/z-wcorg/',
#   'event-place': 'London; New York',
#   'abstract': '"The Roads of Roman Italy offers a complete re-evaluation of both the evidence for, and the interpretation of, Roman land transport. The book utilises archaeological, epigraphic and literary evidence for Roman communications, drawing on recent approaches to the human landscape developed by geographers. Among the topics considered are the relationship between the road and the human landscape, the administration and maintenance of the road system, the role of roads as imperial monuments, and the economics of road construction and urban development."--Jacket.',
#   'ISBN': '0-415-16616-0 978-0-415-16616-4',
#   'language': 'English',
#   'author': [{'family': 'Laurence', 'given': 'Ray'}],
#   'issued': {'date-parts': [[1999]]}},
#  '7109337/KE9T4566': {'type': 'article-journal',
#   'title': "The Inscriptions of Aphrodisias as electronic publication: A user's perspective and a proposed paradigm",
#   'container-title': 'Digital Medievalist',
#   'volume': '4',
#   'abstract': 'This paper discusses the value of the electronic medium of\npublication for one project in particular, Inscriptions of Aphrodisias\n(2007), and uses this one example to extrapolate and illustrate a\nuse-case paradigm of electronic publication and its advantages for\nresearch, pedagogy, and dissemination. The categories used in this\nstudy are: accessibility, scale, media, hypertext, updates, and\niterative research and transparency. Not all of these categories\napply equally to any given publication, and the discussion focuses\nDM 4 (2008) The Inscriptions of Aphrodisias as electronic publi... http://www.digitalmedievalist.org/journal/4/bodard/\n1 of 17 6/29/10 1:29 PM\non those that are the most appropriate to a digital publication of\ntagged epigraphic texts and images.',
#   'language': 'eng',
#   'author': [{'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2008]]}},
#  '7109337/2KEXYJLP': {'type': 'article-journal',
#   'title': 'Modeling Epigraphy with an Ontology',
#   'abstract': 'This document is maintained by the Ontology Working Group of Epigraphy.info. (https://epigraphy-info.github.io/epigraphy-info/) Any request or contribution should be made via the Epigraphic Ontology Mailing List of the Epigraphic Ontology WG &lt;epont@googlegroups.com&gt; Contributors are listed alphabetically. Not all listed contributors have confirmed.',
#   'URL': 'https://zenodo.org/record/4639507',
#   'DOI': '10.5281/ZENODO.4639507',
#   'note': 'Publisher: Zenodo\nVersion Number: 0.1',
#   'author': [{'family': 'Bodard', 'given': ''},
#    {'family': 'Cayless', 'given': ''},
#    {'family': 'Cenati', 'given': ''},
#    {'family': 'Cooley', 'given': ''},
#    {'family': 'Elliott', 'given': ''},
#    {'family': 'Evangelisti', 'given': ''},
#    {'family': 'Felicetti', 'given': ''},
#    {'family': 'Granados', 'given': ''},
#    {'family': 'Grieshaber', 'given': ''},
#    {'family': 'Gruber', 'given': ''},
#    {'family': 'Hershkowitz', 'given': ''},
#    {'family': 'Hill', 'given': ''},
#    {'family': 'Kiiskinen', 'given': ''},
#    {'family': 'Kollatz', 'given': ''},
#    {'family': 'Levivier', 'given': ''},
#    {'family': 'Liuzzo', 'given': ''},
#    {'family': 'Luciani', 'given': ''},
#    {'family': 'Mannocci', 'given': ''},
#    {'family': 'Mataix', 'given': ''},
#    {'family': 'Murano', 'given': ''},
#    {'family': 'Murphy', 'given': ''},
#    {'family': 'Mylonas', 'given': ''},
#    {'family': 'Prag', 'given': ''},
#    {'family': 'Razanajao', 'given': ''},
#    {'family': 'Stoyanova', 'given': ''},
#    {'family': 'Tsolakis', 'given': ''},
#    {'family': 'Tupman', 'given': ''},
#    {'family': 'Vagionakis', 'given': ''},
#    {'family': 'Vitale', 'given': ''},
#    {'family': 'Weise', 'given': ''}],
#   'issued': {'date-parts': [[2021, 3, 26]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/7EHKTWQD': {'type': 'chapter',
#   'title': 'Encoding, Interoperability, Lexicography: Digital Epigraphy Through the Lens of DASI Experience',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '1-18',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-002',
#   'shortTitle': '1 Encoding, Interoperability, Lexicography',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Avanzini', 'given': 'Alessandra'},
#    {'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/TKXWFLYN': {'type': 'chapter',
#   'title': 'EAGLE Continued: IDEA. The International Digital Epigraphy Association',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '216-230',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-018',
#   'shortTitle': '17 EAGLE Continued',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Liuzzo', 'given': 'Pietro M.'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/75PC3E2A': {'type': 'book',
#   'title': 'Migration and Mobility in the Early Roman Empire',
#   'publisher': 'BRILL',
#   'URL': 'https://brill.com/view/title/31880',
#   'ISBN': '978-90-04-30736-0 978-90-04-30737-7',
#   'note': 'DOI: 10.1163/9789004307377',
#   'author': [{'family': 'de Ligt', 'given': 'Luuk'},
#    {'family': 'Tacoma', 'given': 'Laurens Ernst'}],
#   'issued': {'date-parts': [[2016, 1, 19]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/SVYA23ZT': {'type': 'article-journal',
#   'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#   'container-title': 'The Journal of Economic History',
#   'page': '803-839',
#   'volume': '76',
#   'issue': '3',
#   'abstract': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0022050716000826/type/journal_article',
#   'DOI': '10.1017/S0022050716000826',
#   'shortTitle': 'People, Plagues, and Prices in the Roman World',
#   'journalAbbreviation': 'J. Econ. Hist.',
#   'language': 'en',
#   'author': [{'family': 'Harper', 'given': 'Kyle'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '7109337/D2YZ7HDA': {'type': 'article-journal',
#   'title': 'Galen and the Antonine Plague',
#   'container-title': 'The American Journal of Philology',
#   'page': '243–255',
#   'volume': '94',
#   'issue': '3',
#   'URL': 'http://www.jstor.org/stable/293979',
#   'note': 'Publisher: Johns Hopkins University Press',
#   'author': [{'family': 'Littman', 'given': 'R. J.'},
#    {'family': 'Littman', 'given': 'M. L.'}],
#   'issued': {'date-parts': [[1973]]}},
#  '7109337/BG7SH7C4': {'type': 'chapter',
#   'title': 'Modelling the Dynamics of Demography in the Dutch Roman Limes Zone: A Revised Model',
#   'container-title': 'Finding the Limits of the Limes: Modelling Demography, Economy and Transport on the Edge of the Roman Empire',
#   'publisher': 'Springer International Publishing',
#   'publisher-place': 'Cham',
#   'page': '43–59',
#   'event-place': 'Cham',
#   'abstract': 'In this chapter, a simulation model for better understanding the population dynamics of the limes zone is presented, building on our earlier study on the possible effects of recruitment of soldiers for the Roman army (Verhagen et al., Modelling the dynamics of demography in the Dutch limes zone. In: Multi-, inter- and transdisciplinary research in landscape archaeology. Proceedings of LAC 2014 Conference, Rome, 19–20 September 2014. Vrije Universiteit Amsterdam, Amsterdam. https://doi.org/10.5463/lac.2014.62, 2016a). In this earlier study, a number of questions were raised concerning the realism of using estimates from historical demographical sources for understanding the population dynamics of the region. In the current paper, the available data sets, approaches and hypotheses regarding fertility and mortality in the Roman period are re-assessed, together with the available archaeological evidence on the population dynamics of the region. A revised model is then presented that allows for more refined experimenting with various demographic scenarios, showing that a much larger number of parameters can be responsible for changes in population growth than is often assumed in archaeological studies. In particular, marriage strategies would seem to play an important role in regulating the number of births. The model remains a work in progress that can be further refined and linked to models of settlement and land use development.',
#   'URL': 'https://doi.org/10.1007/978-3-030-04576-0_3',
#   'ISBN': '978-3-030-04576-0',
#   'note': 'DOI: 10.1007/978-3-030-04576-0_3',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'}],
#   'editor': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Joyce', 'given': 'Jamie'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'}],
#   'issued': {'date-parts': [[2019]]}},
#  '7109337/NKKHMIDW': {'type': 'book',
#   'title': 'Crossing Experiences in Digital Epigraphy: From Practice to Discipline',
#   'publisher': 'De Gruyter',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208',
#   'shortTitle': 'Crossing Experiences in Digital Epigraphy',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/L73K2ZRY': {'type': 'book',
#   'title': 'Urban Craftsmen and Traders in the Roman World',
#   'publisher': 'Oxford University Press',
#   'URL': 'https://oxford.universitypressscholarship.com/view/10.1093/acprof:oso/9780198748489.001.0001/acprof-9780198748489',
#   'ISBN': '978-0-19-874848-9',
#   'note': 'DOI: 10.1093/acprof:oso/9780198748489.001.0001\nDOI: 10.1093/acprof:oso/9780198748489.001.0001',
#   'editor': [{'family': 'Wilson', 'given': 'Andrew'},
#    {'family': 'Flohr', 'given': 'Miko'}],
#   'issued': {'date-parts': [[2016, 1, 1]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/TISH84GY': {'type': 'chapter',
#   'title': 'The Limes',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '165-198',
#   'abstract': 'This chapter examines some important themes associated with research on the\n              limes\n              in Roman Germany, with particular emphasis on the ‘Upper German-Raetian\n              Limes\n              ’ and how the form and function of the outer frontiers of the Roman world were influenced by dynamic evolutionary processes. Before discussing how the\n              limes\n              took on a role as an ‘imperial/barbarian boundary’, the chapter considers the function of boundaries in general and the\n              limes\n              in particular. It then traces historic developments of the\n              limites\n              and their use in erecting frontier installations, watchtowers, and fortlets. It also looks at the crossing points through the\n              limes\n              that have survived in relatively high numbers in\n              Germania Superior\n              and\n              Raetia\n              ; the legions as the backbone of frontier defence; and auxiliary troops (\n              auxilia\n              ) that occupied the frontier along the Rhine in\n              Germania Inferior\n              and the Upper German-Raetian\n              Limes\n              during the second and third centuries AD.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-7',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.7',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '7109337/ZESEJVF2': {'type': 'chapter',
#   'title': 'Archaeology of Germania Inferior: Urbanization',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '91-115',
#   'abstract': 'This chapter focuses on the archaeology of the first urban settlements of Roman type found in\n              Germania Inferior\n              . It first describes\n              coloniae\n              such as the\n              Colonia Claudia Ara Agrippinensium\n              and\n              Colonia Ulpia Traiana\n              , along with the archaeological excavations carried out at the sites. It then turns to the vici, industrial settlements, and agricultural settlements, and concludes with a theoretical explanation of how various forms of urban centres arose in Lower Germany during the period between the Batavian revolt and the Gallic Empire.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-5',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.5',
#   'shortTitle': 'Archaeology of Germania Inferior',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '7109337/82J5J52N': {'type': 'book',
#   'title': 'Epigraphic Evidence: Ancient History from Inscriptions',
#   'collection-title': 'Approaching the ancient world',
#   'publisher': 'Routledge',
#   'URL': 'https://books.google.dk/books?id=Iz5GT7ZfxLsC',
#   'ISBN': '978-0-415-11623-7',
#   'note': 'LCCN: 00059202',
#   'author': [{'family': 'Bodel', 'given': 'J.P.'}],
#   'issued': {'date-parts': [[2001]]}},
#  '7109337/FLW2G53N': {'type': 'article-journal',
#   'title': "Now you see them, now you don't: Defining and using a flexible chronology of sites for spatial analysis of Roman settlement in the Dutch river area",
#   'container-title': 'Journal of Archaeological Science: Reports',
#   'page': '309-321',
#   'volume': '10',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S2352409X16303832',
#   'DOI': '10.1016/j.jasrep.2016.10.006',
#   'shortTitle': "Now you see them, now you don't",
#   'journalAbbreviation': 'Journal of Archaeological Science: Reports',
#   'language': 'en',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Vossen', 'given': 'Ivo'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'},
#    {'family': 'Joyce', 'given': 'Jamie'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '7109337/XLJYXMEV': {'type': 'chapter',
#   'title': 'Making up for Lost Time: Digital Epigraphy, Chronology, and the PeriodO Project',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '202-215',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-017',
#   'shortTitle': '16 Making up for Lost Time',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Rabinowitz', 'given': 'Adam'},
#    {'family': 'Shaw', 'given': 'Ryan'},
#    {'family': 'Golden', 'given': 'Patrick'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '7109337/T45AYTCM': {'type': 'book',
#   'title': 'EpiDoc Reference Stylesheets (version 9)',
#   'abstract': 'XSLT for transformation of EpiDoc XML files into HTML or text versions in Leiden. Includes various XML files containing parameters and other options.',
#   'URL': 'https://sourceforge.net/p/epidoc/wiki/Stylesheets/',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Au', 'given': 'Zaneta'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Lanz', 'given': 'Carmen'},
#    {'family': 'Lawrence', 'given': 'Faith'},
#    {'family': 'Vanderbilt', 'given': 'Scott'},
#    {'family': 'Viglianti', 'given': 'Raffaele'}],
#   'issued': {'date-parts': [[2017]]}},
#  '7109337/EAY2DVSF': {'type': 'article-journal',
#   'title': 'Rezension zu: Epigraphische Datenbank Heidelberg',
#   'container-title': 'H-Soz-Kult',
#   'URL': 'https://www.hsozkult.de/webreview/id/rezwww-179',
#   'language': 'ger',
#   'author': [{'family': 'Hartmann', 'given': 'Andreas'}],
#   'issued': {'date-parts': [[2018, 10, 13]]}},
#  '7109337/YW3AIT6K': {'type': 'article-journal',
#   'title': 'Medieval Commercial Sites: As Seen Through Portable Antiquities Scheme Data',
#   'container-title': 'The Antiquaries Journal',
#   'page': '109-140',
#   'volume': '100',
#   'abstract': 'This paper explores some 220,000 medieval objects recorded in the Portable Antiquities Scheme (PAS) online database of archaeological small finds through Geographic Information System analysis of their relationship with contemporary market sites. First, an overview of the contents of the PAS database is presented in terms of its spatial and ‘object type’ distribution. Second, the relationship of the medieval finds data against documentary evidence of commercial activity is investigated at a national level. Finally, PAS data is contextualised in its historical landscape context through case studies. It is argued that the distribution of PAS finds on the national scale can be linked with patterns of commercial activity, and that while rural and urban finds scatters have distinguishing trends, the countryside population enjoyed access to a range of sophisticated metalwork culture; also, that certain assemblages can be analysed statistically to yield new data and perspectives on local historical development.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0003581520000165/type/journal_article',
#   'DOI': '10.1017/S0003581520000165',
#   'shortTitle': 'MEDIEVAL COMMERCIAL SITES',
#   'journalAbbreviation': 'Antiq. J.',
#   'language': 'en',
#   'author': [{'family': 'Oksanen', 'given': 'Eljas'},
#    {'family': 'Lewis', 'given': 'Michael'}],
#   'issued': {'date-parts': [['2020']]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '7109337/IRUVQAYJ': {'type': 'article-journal',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'container-title': 'Hesperia',
#   'page': '387-439',
#   'volume': '68',
#   'issue': '3',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'DOI': '10.2307/148494',
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'issued': {'date-parts': [[1999]]},
#   'accessed': {'date-parts': [[2019, 11, 21]]}},
#  '7109337/BRZQ3MUL': {'type': 'chapter',
#   'title': 'City Sizes and Urbanization in the Roman Empire',
#   'container-title': 'Settlement, Urbanization and Population',
#   'collection-title': 'Oxford Studies in the Roman Economy',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'page': '161–195',
#   'event-place': 'Oxford - New York',
#   'ISBN': '0-19-960235-2',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2012]]}},
#  '7109337/YMB2QZ7K': {'type': 'webpage',
#   'title': 'Understanding Roman inscriptions',
#   'abstract': 'This is the first comprehensive treatment in English to provide an explanation of not only the language of inscriptions but also the context in which they were produced.',
#   'URL': 'http://site.ebrary.com/id/10062897',
#   'note': 'Archive: /z-wcorg/\nISBN: 0203084675 9780203084670 9780203707357 0203707354 9781134746125 1134746121 9781134746163 1134746164 9781134746170 1134746172 9781138142923 1138142921 9780415151436 0415151430 9786610539277 6610539278 1280539275 9781280539275\nLibrary Catalog: http://worldcat.org\nPlace: Baltimore\nPublisher: Johns Hopkins University Press',
#   'language': 'English.',
#   'author': [{'family': 'Keppie', 'given': 'L. J. F.'}],
#   'issued': {'date-parts': [[1991]]}},
#  '7109337/283Z83RT': {'type': 'article-journal',
#   'title': 'Roman Inscriptions 2001-2005',
#   'container-title': 'The Journal of Roman Studies',
#   'page': '176–263',
#   'volume': '97',
#   'URL': 'http://www.jstor.org/stable/20430576',
#   'note': 'Publisher: [Society for the Promotion of Roman Studies, Cambridge University Press]',
#   'author': [{'family': 'Cooley', 'given': 'Alison E.'},
#    {'family': 'Mitchell', 'given': 'Stephen'},
#    {'family': 'Salway', 'given': 'Benet'}],
#   'issued': {'date-parts': [[2007]]}},
#  '7109337/QS4C5IAS': {'type': 'book',
#   'title': 'Quantifying the Roman Economy: Methods and Problems',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'event-place': 'Oxford - New York',
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2009]]}},
#  '7109337/3L9BKAXW': {'type': 'article-journal',
#   'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'page': 'E144-E151',
#   'volume': '115',
#   'issue': '2',
#   'abstract': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#   'DOI': '10.1073/pnas.1708800115',
#   'note': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
# ...
#  '7109337/JAXUAMNH': {'type': 'chapter',
#   'title': 'Epigraphy by numbers: Latin and the epigraphic culture in Sicily',
#   'container-title': 'Becoming Roman, writing Latin? Literacy and Epigraphy in the Roman West',
#   'publisher': 'Journal of Roman Archaeology',
#   'publisher-place': 'Portsmouth, Rhode Island',
#   'page': '15–31',
#   'event-place': 'Portsmouth, Rhode Island',
#   'author': [{'family': 'Prag', 'given': 'Jonathan'}],
#   'editor': [{'family': 'Cooley', 'given': 'Alison E.'}],
#   'issued': {'date-parts': [[2002]]}},
#  '7109337/TWB9XHFH': {'type': 'chapter',
#   'title': 'Christian and Late Antique Epigraphies',
#   'container-title': 'The Epigraphic Cultures of Late Antiquity',
#   'publisher': 'Franz Steiner Verlag',
#   'page': '503–514',
#   'ISBN': '978-3-515-11558-2',
#   'language': 'English',
#   'author': [{'family': 'Roueche', 'given': 'Charlotte Mary'},
#    {'family': 'Sotinel', 'given': 'Claire'}],
#   'editor': [{'family': 'Bolle', 'given': 'Katharina'},
#    {'family': 'Machado', 'given': 'Carlos'},
#    {'family': 'Witschel', 'given': 'Christian'}],
#   'issued': {'date-parts': [['2017', 3]]}},
#  '7109337/WLLWUZT7': {'type': 'article-journal',
#   'title': 'The Roman Brick-Stamps not Published in Volume XV 1 of the "Corpus Inscriptionum Latinarum"',
#   'container-title': 'Harvard Studies in Classical Philology',
#   'page': '1',
#   'volume': '56',
#   'URL': 'https://www.jstor.org/stable/310746?origin=crossref',
#   'DOI': '10.2307/310746',
#   'journalAbbreviation': 'Harvard Studies in Classical Philology',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1947]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '7109337/JCIXA2RJ': {'type': 'book',
#   'title': 'The Roman brick stamps not published in Vol. XI, 1 of the Corpus inscriptionum Latinarum, including Indices to the Roman brick-stamps.',
#   'publisher': '"L\'Erma" di Bretschneider',
#   'publisher-place': 'Roma',
#   'edition': 'Ed. anastat.',
#   'event-place': 'Roma',
#   'language': 'ita',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1967]]}},
#  '7109337/9J244TYE': {'type': 'book',
#   'title': 'EpiDoc Guidelines: Ancient documents in TEI XML',
#   'URL': 'https://epidoc.stoa.org/gl/latest/',
#   'language': 'eng',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Mylonas', 'given': 'Elli'},
#    {'family': 'Stoyanova', 'given': 'Simona'},
#    {'family': 'Tupman', 'given': 'Charlotte'},
#    {'family': 'Vanderbilt', 'given': 'Scott'}],
#   'issued': {'date-parts': [[2020]]}},
#  '7109337/EBFQEFW3': {'type': 'book',
#   'title': 'Conventions in editing : A suggested reformulation of the Leiden system.',
#   'collection-title': 'Greek, Roman and Byzantine scholarly Aids ; No. 2.',
#   'publisher': 'Duke University',
#   'publisher-place': 'Durham',
#   'event-place': 'Durham',
#   'language': 'eng',
#   'author': [{'family': 'Dow', 'given': 'Sterling'}],
#   'issued': {'date-parts': [[1969]]}},
#  '7109337/TXCY5XL8': {'type': 'book',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'publisher': 'Routledge',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'ISBN': '978-1-00-302530-6',
#   'note': 'DOI: 10.4324/9781003025306',
#   'language': 'en',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/AU6JTRIU': {'type': 'article-journal',
#   'title': 'Explaining the Epigraphic Habit in the Roman Empire: The Evidence of Epitaphs',
#   'container-title': 'Journal of Roman Studies',
#   'page': '74–96',
#   'volume': '80',
#   'abstract': "It is now notorious that the production of inscriptions in the Roman Empire was not constant over time, but rose over the first and second centuries A.D. and fell in the third. Ramsay MacMullen pointed this out more than five years ago, with conclusions more cautionary than explanatory: ‘history is not being written in the right way', he said, for historians have deduced Rome's decline from evidence that–since it appears only epigraphically–has merely disappeared for its own reasons, or have sought general explanations of decline in theories political, economic, or even demographic in nature, none of which can, in turn, explain the disappearance of epigraphy itself. Why this epigraphic habit rose and fell MacMullen left open to question, although he did postulate control by a ‘sense of audience'. The purpose of this paper is to propose that this ‘sense of audience' was not generalized or generic, but depended on a belief in the value of romanization, of which (as noted but not explained by MacMullen's article) the epigraphic habit is also a rough indicator. Epitaphs constitute the bulk of all provincial inscriptions and in form and number are (generally speaking) the consequence of a provincial imitation of characteristically Roman practices, an imitation that depended on the belief that Roman legal status and style were important, and that may indeed have ultimately depended, at least in North Africa, on the acquisition or prior possession of that status. Such status-based motivations for erecting an epitaph help to explain not only the chronological distribution of epitaphs but also the differences in the type and distribution of epitaphs in the western and eastern halves of the empire. They will be used here moreover to suggest an explanation for the epigraphic habit as a whole.",
#   'DOI': '10.2307/300281',
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'issued': {'date-parts': [[1990]]}},
#  '7109337/5W97HIK9': {'type': 'chapter',
#   'title': 'Epigraphy and Digital Resources',
#   'container-title': 'The Oxford Handbook of Roman Epigraphy',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford and New York',
#   'page': '78–85',
#   'event-place': 'Oxford and New York',
#   'author': [{'family': 'Elliot', 'given': 'Tom'}],
#   'editor': [{'family': 'Bruun', 'given': 'Christer'},
#    {'family': 'Edmondson', 'given': 'Jonathan'}],
#   'issued': {'date-parts': [[2015]]}},
#  '7109337/VDS8KTIA': {'type': 'book',
#   'title': 'Epigraphic evidence: ancient history from inscriptions',
#   'collection-number': '4',
#   'publisher': 'Routledge',
#   'publisher-place': 'London, New York',
#   'volume': '61',
#   'number-of-pages': '1019–1020',
#   'event-place': 'London, New York',
#   'abstract': 'Epigraphic Evidence is an accessible guide to the responsible use of Greek and Latin inscriptions as sources for ancient history. It introduces the types of historical information supplied by inscriptional texts and the methods with which they can be used. It outlines the limitations as well as the advantages of the different types of evidence covered. Epigraphic Evidence includes a general introduction, a guide to the arrangement of the standard corpora inscriptions and individual chapters on local languages and native cultures, epitaphs and the ancient economy amongst others.',
#   'note': 'ISSN: 0023-8856\nPublication Title: Latomus',
#   'author': [{'family': 'Duthoy', 'given': 'Robert'}],
#   'issued': {'date-parts': [[2002]]}},
#  '7109337/SBV9XF6H': {'type': 'book',
#   'title': 'An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan',
#   'publisher': 'The University of Michigan Press',
#   'publisher-place': 'Ann Arbor',
#   'event-place': 'Ann Arbor',
#   'note': 'Publication Title: An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan\nDOI: 10.3998/mpub.23012',
#   'author': [{'family': 'McLean', 'given': 'Bradley'}],
#   'issued': {'date-parts': [[2016]]}},
#  '7109337/C5QVR3SE': {'type': 'article-journal',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'container-title': 'The American Journal of Philology',
#   'page': '233',
#   'volume': '103',
#   'issue': '3',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'DOI': '10.2307/294470',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'issued': {'date-parts': [[1982]]}},
#  '7109337/A6W7Q3HZ': {'type': 'article-journal',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'container-title': 'Journal of Roman Studies',
#   'page': '22–39',
#   'volume': '86',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'DOI': '10.2307/300421',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'issued': {'date-parts': [[1996]]}},
#  '7109337/YWIASGX4': {'type': 'article-journal',
#   'title': 'Epigraphic Database Heidelberg – Data Reuse Options',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/26599',
#   'DOI': '10.11588/HEIDOK.00026599',
#   'note': 'Publisher: Heidelberg University Library',
#   'author': [{'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2019]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/MGBT6ZCX': {'type': 'article-journal',
#   'title': 'Digital Epigraphy am Scheideweg? / Digital Epigraphy at a crossroads?',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/22141',
#   'DOI': '10.11588/HEIDOK.00022141',
#   'note': 'Publisher: Heidelberg University Library',
#   'shortTitle': 'Digital Epigraphy am Scheideweg?',
#   'author': [{'family': 'Feraudi-Gruénais', 'given': 'Francisca'},
#    {'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2016]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/2WIJQZDC': {'type': 'book',
#   'title': 'The Epigraphic Cultures of Late Antiquity',
#   'collection-title': 'Alte Geschichte',
#   'publisher': 'Franz Steiner Verlag',
#   'URL': 'https://books.google.dk/books?id=iJBdMQAACAAJ',
#   'ISBN': '978-3-515-11558-2',
#   'author': [{'family': 'Bolle', 'given': 'K.'},
#    {'family': 'Machado', 'given': 'C.'},
#    {'family': 'Witschel', 'given': 'C.'}],
#   'issued': {'date-parts': [[2017]]}},
#  '7109337/N8YT927J': {'type': 'chapter',
#   'title': 'The “Epigraphic Habit” in the Roman World',
#   'container-title': 'The Oxford Handbook of Roman Epigraphy',
#   'collection-title': 'Oxford Handbooks',
#   'publisher': 'Oxford University Press',
#   'volume': '1',
#   'abstract': 'Since the 1980s scholars have ceased considering Roman inscriptions simply in functional terms—as sources of historical information—and started to treat them as a cultural phenomenon worthy of serious consideration. This change in perspective, as well as the realization that there was a permanent bond between text and monument, represents the most productive shift in approach in recent epigraphic scholarship. This chapter analyzes the “epigraphic habit” in order to explain why people wrote on stone throughout Italy and the provinces, linking its rise to the proliferation of urbanization, literacy, and the desire for self-representation.',
#   'ISBN': '0-19-533646-1',
#   'language': 'eng',
#   'author': [{'family': 'Beltrán Lloris', 'given': 'Francisco'}],
#   'issued': {'date-parts': [[2014]]}},
#  '7109337/KBJ7VEJ8': {'type': 'article-journal',
#   'title': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy: The End of a Habit?',
#   'container-title': 'Historia',
#   'page': '116-132',
#   'volume': '70',
#   'issue': '1',
#   'abstract': '<p>The political communities of western Asia Minor produced an enormous amount of inscriptions under Roman rule. For the period between AD 260 and 280, however, the epigraphic habit falls dramatically and this situation largely continues in the 4<sup>th</sup> and 5<sup>th</sup> centuries. The aim of this paper is to analyse the phenomenon in the transitional Tetrarchic age, when a notable increase in testimony, particularly milestones and texts related to the new regime (e. g. ‘Edict of Prices’), can be observed. My study of continuities and changes concludes that the propagandistic efforts under the Tetrarchs did not ultimately coincide with a full reactivation of civic epigraphic culture and this new scenario should remain fundamental for our assessment of Late Antiquity in the region.</p>',
#   'URL': 'https://elibrary.steiner-verlag.de/article/10.25162/historia-2021-0006',
#   'DOI': '10.25162/historia-2021-0006',
#   'shortTitle': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy',
#   'journalAbbreviation': 'historia',
#   'language': 'en',
#   'author': [{'family': 'Pérez', 'given': 'Aitor Blanco'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/RAG327R6': {'type': 'chapter',
#   'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#   'container-title': 'A Companion to Late Antiquity',
#   'publisher': 'John Wiley & Sons, Ltd',
#   'page': '170-186',
#   'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#   'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#   'ISBN': '978-1-4443-0610-1',
#   'note': 'DOI: 10.1002/9781444306101.ch12',
#   'shortTitle': 'Inscribing Identity',
#   'language': 'en',
#   'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}}}

# %%
# list all items within preselected collection:
url = "https://api.zotero.org/users/5925766/collections/" + collection_key + "/items?limit=1000"
collection_items_rawjson = requests.get(url, headers=headers).json()
collection_items_rawjson[:5]
# Out:
# [{'key': '5DKTH37I',
#   'version': 134,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/5DKTH37I',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/8C5W7WYE',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I/file/view',
#     'title': 'Lowndes et al. - 2017 - Our path to better science in less time using open.pdf',
#     'length': 412129}},
#   'meta': {'numChildren': False},
#   'data': {'key': '5DKTH37I',
#    'version': 134,
#    'parentItem': '8C5W7WYE',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-06-11T07:08:22Z',
#    'url': 'https://www.nature.com/articles/s41559-017-0160.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Lowndes et al. - 2017 - Our path to better science in less time using open.pdf',
#    'md5': '9df40be7f5764434c04e44af6fc2369a',
#    'mtime': 1623395302000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/NHJ9DBJB'},
#    'dateAdded': '2021-06-11T07:08:22Z',
#    'dateModified': '2021-06-11T07:08:22Z'}},
#  {'key': '8C5W7WYE',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/8C5W7WYE',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/8C5W7WYE',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 412129}},
#   'meta': {'creatorSummary': 'Lowndes et al.',
#    'parsedDate': '2017',
#    'numChildren': 1},
#   'data': {'key': '8C5W7WYE',
#    'version': 133,
#    'itemType': 'journalArticle',
#    'title': 'Our path to better science in less time using open data science tools',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Julia S. Stewart',
#      'lastName': 'Lowndes'},
#     {'creatorType': 'author', 'firstName': 'Benjamin D.', 'lastName': 'Best'},
#     {'creatorType': 'author',
#      'firstName': 'Courtney',
#      'lastName': 'Scarborough'},
#     {'creatorType': 'author',
#      'firstName': 'Jamie C.',
#      'lastName': 'Afflerbach'},
#     {'creatorType': 'author',
#      'firstName': 'Melanie R.',
#      'lastName': 'Frazier'},
#     {'creatorType': 'author', 'firstName': 'Casey C.', 'lastName': 'O’Hara'},
#     {'creatorType': 'author', 'firstName': 'Ning', 'lastName': 'Jiang'},
#     {'creatorType': 'author',
#      'firstName': 'Benjamin S.',
#      'lastName': 'Halpern'}],
#    'abstractNote': '',
#    'publicationTitle': 'Nature Ecology & Evolution',
#    'volume': '1',
#    'issue': '6',
#    'pages': '0160',
#    'date': '6/2017',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Nat Ecol Evol',
#    'language': 'en',
#    'DOI': '10.1038/s41559-017-0160',
#    'ISSN': '2397-334X',
#    'shortTitle': '',
#    'url': 'http://www.nature.com/articles/s41559-017-0160',
#    'accessDate': '2021-06-11T07:08:21Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/2IMKYASB'},
#    'dateAdded': '2021-06-11T07:08:21Z',
#    'dateModified': '2021-06-11T07:08:21Z'}},
#  {'key': '3J5XSHJ2',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3J5XSHJ2',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3J5XSHJ2',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Scheidel',
#    'parsedDate': '2018',
#    'numChildren': 0},
#   'data': {'key': '3J5XSHJ2',
#    'version': 133,
#    'itemType': 'book',
#    'title': 'The Great Leveler: Violence and the History of Inequality from the Stone Age to the Twenty-First Century',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Walter',
#      'lastName': 'Scheidel'}],
#    'abstractNote': '',
#    'series': 'The Princeton Economic History of the Western World',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Princeton University Press',
#    'date': '2018',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-691-18325-1',
#    'shortTitle': '',
#    'url': 'https://press.princeton.edu/books/paperback/9780691183251/the-great-leveler',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/5NVGQ6LK'},
#    'dateAdded': '2021-06-11T07:03:13Z',
#    'dateModified': '2021-06-11T07:04:19Z'}},
#  {'key': 'CY54CMQ9',
#   'version': 129,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/CY54CMQ9',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/CY54CMQ9',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Huggett',
#    'parsedDate': '2017-05-23',
#    'numChildren': 0},
#   'data': {'key': 'CY54CMQ9',
#    'version': 129,
#    'itemType': 'blogPost',
#    'title': 'Citing Data Reuse',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Jeremy',
#      'lastName': 'Huggett'}],
#    'abstractNote': '',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '23/05/2017',
#    'url': 'https://introspectivedigitalarchaeology.com/2017/05/23/citing-data-reuse/',
#    'accessDate': '',
#    'language': 'eng',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/RDNH84EL',
#      'http://zotero.org/groups/2784584/items/NRWZY682']},
#    'dateAdded': '2021-06-10T10:36:07Z',
#    'dateModified': '2021-06-10T10:36:48Z'}},
#  {'key': 'QZV4FHQ6',
#   'version': 129,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/QZV4FHQ6',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/QZV4FHQ6',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Huggett',
#    'parsedDate': '2016-06-29',
#    'numChildren': 0},
#   'data': {'key': 'QZV4FHQ6',
#    'version': 129,
#    'itemType': 'blogPost',
#    'title': 'Digital Data Realities',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Jeremy',
#      'lastName': 'Huggett'}],
#    'abstractNote': '',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '29/06/2016',
#    'url': 'https://introspectivedigitalarchaeology.com/2016/06/29/digital-data-realities/',
#    'accessDate': '',
#    'language': 'eng',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/X6C44E8B',
#      'http://zotero.org/groups/2784584/items/45PITQ5E']},
#    'dateAdded': '2021-06-10T10:34:48Z',
#    'dateModified': '2021-06-10T10:35:40Z'}}]

# %%
collection_items_dict = dict([(el["key"], el) for el in collection_items_rawjson])

# %%
collection_items_dict
# Out:
# {'5DKTH37I': {'key': '5DKTH37I',
#   'version': 134,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/5DKTH37I',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/8C5W7WYE',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I/file/view',
#     'title': 'Lowndes et al. - 2017 - Our path to better science in less time using open.pdf',
#     'length': 412129}},
#   'meta': {'numChildren': False},
#   'data': {'key': '5DKTH37I',
#    'version': 134,
#    'parentItem': '8C5W7WYE',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-06-11T07:08:22Z',
#    'url': 'https://www.nature.com/articles/s41559-017-0160.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Lowndes et al. - 2017 - Our path to better science in less time using open.pdf',
#    'md5': '9df40be7f5764434c04e44af6fc2369a',
#    'mtime': 1623395302000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/NHJ9DBJB'},
#    'dateAdded': '2021-06-11T07:08:22Z',
#    'dateModified': '2021-06-11T07:08:22Z'}},
#  '8C5W7WYE': {'key': '8C5W7WYE',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/8C5W7WYE',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/8C5W7WYE',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/5DKTH37I',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 412129}},
#   'meta': {'creatorSummary': 'Lowndes et al.',
#    'parsedDate': '2017',
#    'numChildren': 1},
#   'data': {'key': '8C5W7WYE',
#    'version': 133,
#    'itemType': 'journalArticle',
#    'title': 'Our path to better science in less time using open data science tools',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Julia S. Stewart',
#      'lastName': 'Lowndes'},
#     {'creatorType': 'author', 'firstName': 'Benjamin D.', 'lastName': 'Best'},
#     {'creatorType': 'author',
#      'firstName': 'Courtney',
#      'lastName': 'Scarborough'},
#     {'creatorType': 'author',
#      'firstName': 'Jamie C.',
#      'lastName': 'Afflerbach'},
#     {'creatorType': 'author',
#      'firstName': 'Melanie R.',
#      'lastName': 'Frazier'},
#     {'creatorType': 'author', 'firstName': 'Casey C.', 'lastName': 'O’Hara'},
#     {'creatorType': 'author', 'firstName': 'Ning', 'lastName': 'Jiang'},
#     {'creatorType': 'author',
#      'firstName': 'Benjamin S.',
#      'lastName': 'Halpern'}],
#    'abstractNote': '',
#    'publicationTitle': 'Nature Ecology & Evolution',
#    'volume': '1',
#    'issue': '6',
#    'pages': '0160',
#    'date': '6/2017',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Nat Ecol Evol',
#    'language': 'en',
#    'DOI': '10.1038/s41559-017-0160',
#    'ISSN': '2397-334X',
#    'shortTitle': '',
#    'url': 'http://www.nature.com/articles/s41559-017-0160',
#    'accessDate': '2021-06-11T07:08:21Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/2IMKYASB'},
#    'dateAdded': '2021-06-11T07:08:21Z',
#    'dateModified': '2021-06-11T07:08:21Z'}},
#  '3J5XSHJ2': {'key': '3J5XSHJ2',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3J5XSHJ2',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3J5XSHJ2',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Scheidel',
#    'parsedDate': '2018',
#    'numChildren': 0},
#   'data': {'key': '3J5XSHJ2',
#    'version': 133,
#    'itemType': 'book',
#    'title': 'The Great Leveler: Violence and the History of Inequality from the Stone Age to the Twenty-First Century',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Walter',
#      'lastName': 'Scheidel'}],
#    'abstractNote': '',
#    'series': 'The Princeton Economic History of the Western World',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Princeton University Press',
#    'date': '2018',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-691-18325-1',
#    'shortTitle': '',
#    'url': 'https://press.princeton.edu/books/paperback/9780691183251/the-great-leveler',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/5NVGQ6LK'},
#    'dateAdded': '2021-06-11T07:03:13Z',
#    'dateModified': '2021-06-11T07:04:19Z'}},
#  'CY54CMQ9': {'key': 'CY54CMQ9',
#   'version': 129,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/CY54CMQ9',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/CY54CMQ9',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Huggett',
#    'parsedDate': '2017-05-23',
#    'numChildren': 0},
#   'data': {'key': 'CY54CMQ9',
#    'version': 129,
#    'itemType': 'blogPost',
#    'title': 'Citing Data Reuse',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Jeremy',
#      'lastName': 'Huggett'}],
#    'abstractNote': '',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '23/05/2017',
#    'url': 'https://introspectivedigitalarchaeology.com/2017/05/23/citing-data-reuse/',
#    'accessDate': '',
#    'language': 'eng',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/RDNH84EL',
#      'http://zotero.org/groups/2784584/items/NRWZY682']},
#    'dateAdded': '2021-06-10T10:36:07Z',
#    'dateModified': '2021-06-10T10:36:48Z'}},
#  'QZV4FHQ6': {'key': 'QZV4FHQ6',
#   'version': 129,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/QZV4FHQ6',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/QZV4FHQ6',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Huggett',
#    'parsedDate': '2016-06-29',
#    'numChildren': 0},
#   'data': {'key': 'QZV4FHQ6',
#    'version': 129,
#    'itemType': 'blogPost',
#    'title': 'Digital Data Realities',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Jeremy',
#      'lastName': 'Huggett'}],
#    'abstractNote': '',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '29/06/2016',
#    'url': 'https://introspectivedigitalarchaeology.com/2016/06/29/digital-data-realities/',
#    'accessDate': '',
#    'language': 'eng',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/X6C44E8B',
#      'http://zotero.org/groups/2784584/items/45PITQ5E']},
#    'dateAdded': '2021-06-10T10:34:48Z',
#    'dateModified': '2021-06-10T10:35:40Z'}},
#  '3NH6EHMA': {'key': '3NH6EHMA',
#   'version': 126,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3NH6EHMA',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3NH6EHMA',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Raymond',
#    'parsedDate': '2001',
#    'numChildren': 0},
#   'data': {'key': '3NH6EHMA',
#    'version': 126,
#    'itemType': 'book',
#    'title': 'The Cathedral & the Bazaar',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Eric S.',
#      'lastName': 'Raymond'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': "O'Reilly Media",
#    'date': '2001',
#    'numPages': '',
#    'language': 'English',
#    'ISBN': '978-0-596-00108-7',
#    'shortTitle': '',
#    'url': 'https://www.oreilly.com/library/view/the-cathedral/0596001088/',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/GC8B39KI',
#      'http://zotero.org/groups/2784584/items/NHPHYMF9']},
#    'dateAdded': '2021-06-10T10:31:39Z',
#    'dateModified': '2021-06-10T10:33:26Z'}},
#  'CAJ8RP6I': {'key': 'CAJ8RP6I',
#   'version': 125,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/CAJ8RP6I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/CAJ8RP6I',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Iversen',
#    'parsedDate': '2007',
#    'numChildren': 0},
#   'data': {'key': 'CAJ8RP6I',
#    'version': 125,
#    'itemType': 'journalArticle',
#    'title': 'The Packard Humanities Institute (PHI) Greek Epigraphy Project and the Revolution in Greek Epigraphy',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Paul A.',
#      'lastName': 'Iversen'}],
#    'abstractNote': 'In this paper, the history, purpose and importance\nof the Packard Humanities Institute (PHI) Greek\nEpigraphy Project are discussed.',
#    'publicationTitle': 'Abgadiyat',
#    'volume': '2.1',
#    'issue': '',
#    'pages': '51-55',
#    'date': '2007',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'eng',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'https://journals.ekb.eg/article_62069_38414a2fca56893baf78323065072f95.pdf',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/PL944VJ3'},
#    'dateAdded': '2021-06-10T09:03:00Z',
#    'dateModified': '2021-06-10T09:03:00Z'}},
#  'GZXS5Q8K': {'key': 'GZXS5Q8K',
#   'version': 125,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/GZXS5Q8K',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/GZXS5Q8K',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/3ADCMC6C',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 424666}},
#   'meta': {'creatorSummary': 'Sherratt',
#    'parsedDate': '2019-10-29',
#    'numChildren': 1},
#   'data': {'key': 'GZXS5Q8K',
#    'version': 125,
#    'itemType': 'bookSection',
#    'title': 'Hacking heritage: Understanding the limits of online access',
#    'creators': [{'creatorType': 'editor',
#      'firstName': 'Hannah',
#      'lastName': 'Lewi'},
#     {'creatorType': 'editor', 'firstName': 'Wally', 'lastName': 'Smith'},
#     {'creatorType': 'editor', 'firstName': 'Dirk', 'lastName': 'vom Lehn'},
#     {'creatorType': 'editor', 'firstName': 'Steven', 'lastName': 'Cooke'},
#     {'creatorType': 'author', 'firstName': 'Tim', 'lastName': 'Sherratt'}],
#    'abstractNote': '',
#    'bookTitle': 'The Routledge International Handbook of New Digital Practices in Galleries, Libraries, Archives, Museums and Heritage Sites',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '1',
#    'place': '',
#    'publisher': 'Routledge',
#    'date': '2019-10-29',
#    'pages': '15',
#    'language': 'en',
#    'ISBN': '978-0-429-50676-5',
#    'shortTitle': '',
#    'url': 'https://www.taylorfrancis.com/books/9780429015304',
#    'accessDate': '2021-06-10T08:47:42Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.4324/9780429506765',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2784584/items/HL5NIEMG',
#      'http://zotero.org/groups/2366083/items/5IZH2L65']},
#    'dateAdded': '2021-06-10T08:47:42Z',
#    'dateModified': '2021-06-10T08:51:57Z'}},
#  '3ADCMC6C': {'key': '3ADCMC6C',
#   'version': 125,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/3ADCMC6C',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/3ADCMC6C',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/GZXS5Q8K',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/3ADCMC6C/file/view',
#     'title': 'Lewi et al. - 2019 - The Routledge International Handbook of New Digita.pdf',
#     'length': 424666}},
#   'meta': {'numChildren': False},
#   'data': {'key': '3ADCMC6C',
#    'version': 125,
#    'parentItem': 'GZXS5Q8K',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-06-10T08:47:49Z',
#    'url': 'https://dro.deakin.edu.au/eserv/DU:30122388/cooke-investigatingordinary-post-2019.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Lewi et al. - 2019 - The Routledge International Handbook of New Digita.pdf',
#    'md5': 'adec219e425056f1440b2c94e772921b',
#    'mtime': 1623314869000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/DPK3EJID'},
#    'dateAdded': '2021-06-10T08:47:49Z',
#    'dateModified': '2021-06-10T08:47:49Z'}},
#  'XDAURK5G': {'key': 'XDAURK5G',
#   'version': 136,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/XDAURK5G',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/XDAURK5G',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Madzharov',
#    'parsedDate': '2009',
#    'numChildren': 0},
#   'data': {'key': 'XDAURK5G',
#    'version': 136,
#    'itemType': 'book',
#    'title': 'Rimski patishta v Balgaria: prinos v razvitieto na rimskata patna sistema v provintsiite Mizia i Trakia',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Mitko',
#      'lastName': 'Madzharov'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'Veliko Turnovo',
#    'publisher': 'Faber Publisher',
#    'date': '2009',
#    'numPages': '',
#    'language': '',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/W5EPKGJU',
#      'http://zotero.org/groups/2784584/items/PTEB9H2F']},
#    'dateAdded': '2021-06-09T11:51:03Z',
#    'dateModified': '2021-06-09T11:51:03Z'}},
#  '7DY6HUZB': {'key': '7DY6HUZB',
#   'version': 133,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/7DY6HUZB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/7DY6HUZB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Hollenstein',
#    'parsedDate': '1975',
#    'numChildren': 0},
#   'data': {'key': '7DY6HUZB',
#    'version': 133,
#    'itemType': 'journalArticle',
#    'title': 'Zu den Meilensteinen der römischen Provinzen Thracia und Moesia Inferior',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Lorenz',
#      'lastName': 'Hollenstein'}],
#    'abstractNote': '',
#    'publicationTitle': 'Studia Balcanica',
#    'volume': '10',
#    'issue': '',
#    'pages': '23–44',
#    'date': '1975',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/RVP5YXG7',
#      'http://zotero.org/groups/2784584/items/YWEFPW8B']},
#    'dateAdded': '2021-06-09T11:50:52Z',
#    'dateModified': '2021-06-09T11:50:52Z'}},
#  'J6GWZWL4': {'key': 'J6GWZWL4',
#   'version': 115,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/J6GWZWL4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/J6GWZWL4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Duncan-Jones',
#    'parsedDate': '2018',
#    'numChildren': 0},
#   'data': {'key': 'J6GWZWL4',
#    'version': 115,
#    'itemType': 'journalArticle',
#    'title': 'The Antonine Plague Revisited',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Richard',
#      'lastName': 'Duncan-Jones'}],
#    'abstractNote': '',
#    'publicationTitle': 'Arctos',
#    'volume': '52',
#    'issue': '',
#    'pages': '41-72',
#    'date': '2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'eng',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/73AJRHE5'},
#    'dateAdded': '2021-06-04T14:17:06Z',
#    'dateModified': '2021-06-04T14:17:06Z'}},
#  'YFQQLVBK': {'key': 'YFQQLVBK',
#   'version': 114,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/YFQQLVBK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/YFQQLVBK',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Duncan-Jones',
#    'parsedDate': '1990-04-12',
#    'numChildren': 0},
#   'data': {'key': 'YFQQLVBK',
#    'version': 114,
#    'itemType': 'book',
#    'title': 'Structure and Scale in the Roman Economy',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Richard',
#      'lastName': 'Duncan-Jones'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '1',
#    'place': '',
#    'publisher': 'Cambridge University Press',
#    'date': '1990-04-12',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-521-35477-6 978-0-521-89289-6 978-0-511-55264-9',
#    'shortTitle': '',
#    'url': 'https://www.cambridge.org/core/product/identifier/9780511552649/type/book',
#    'accessDate': '2021-06-03T16:01:19Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1017/CBO9780511552649',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2784584/items/8GNR2ZUR',
#      'http://zotero.org/groups/2366083/items/6GH6YG72']},
#    'dateAdded': '2021-06-03T16:01:19Z',
#    'dateModified': '2021-06-03T16:01:19Z'}},
#  'HCU3WEJB': {'key': 'HCU3WEJB',
#   'version': 114,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/HCU3WEJB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/HCU3WEJB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Duncan-Jones',
#    'parsedDate': '1996',
#    'numChildren': 0},
#   'data': {'key': 'HCU3WEJB',
#    'version': 114,
#    'itemType': 'journalArticle',
#    'title': 'The impact of the Antonine plague',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'R. P.',
#      'lastName': 'Duncan-Jones'}],
#    'abstractNote': '',
#    'publicationTitle': 'Journal of Roman Archaeology',
#    'volume': '9',
#    'issue': '',
#    'pages': '108-136',
#    'date': '1996',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'J. Roman archaeol.',
#    'language': 'en',
#    'DOI': '10.1017/S1047759400016524',
#    'ISSN': '1047-7594, 2331-5709',
#    'shortTitle': '',
#    'url': 'https://www.cambridge.org/core/product/identifier/S1047759400016524/type/journal_article',
#    'accessDate': '2021-06-03T15:53:46Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2784584/items/PCA83JEZ',
#      'http://zotero.org/groups/2366083/items/LHLXI5ID']},
#    'dateAdded': '2021-06-03T15:53:46Z',
#    'dateModified': '2021-06-03T15:53:46Z'}},
#  'UH4L3837': {'key': 'UH4L3837',
#   'version': 137,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/UH4L3837',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/UH4L3837',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Tahmasebi and Hengchen',
#    'parsedDate': '2019',
#    'numChildren': 0},
#   'data': {'key': 'UH4L3837',
#    'version': 137,
#    'itemType': 'journalArticle',
#    'title': 'The Strengths and Pitfalls of Large-Scale Text Mining for Literary Studies',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Nina',
#      'lastName': 'Tahmasebi'},
#     {'creatorType': 'author', 'firstName': 'Simon', 'lastName': 'Hengchen'}],
#    'abstractNote': '',
#    'publicationTitle': 'Samlaren',
#    'volume': '140',
#    'issue': '',
#    'pages': '198–227',
#    'date': '2019',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'http://uu.diva-portal.org/smash/get/diva2:1415010/FULLTEXT01.pdf',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': ['http://zotero.org/groups/2366083/items/2CDUBU8M',
#      'http://zotero.org/groups/2784584/items/S8JAXRPN']},
#    'dateAdded': '2021-06-03T14:34:37Z',
#    'dateModified': '2021-06-03T14:34:37Z'}},
#  'TARVRY26': {'key': 'TARVRY26',
#   'version': 112,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/TARVRY26',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/TARVRY26',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Wilson', 'parsedDate': '2009', 'numChildren': 0},
#   'data': {'key': 'TARVRY26',
#    'version': 112,
#    'itemType': 'journalArticle',
#    'title': 'Indicators for Roman economic growth: a response to Walter Scheidel',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Andrew',
#      'lastName': 'Wilson'}],
#    'abstractNote': '',
#    'publicationTitle': 'Journal of Roman Archaeology',
#    'volume': '22',
#    'issue': '',
#    'pages': '71-82',
#    'date': '2009',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'J. Roman archaeol.',
#    'language': 'en',
#    'DOI': '10.1017/S1047759400020596',
#    'ISSN': '1047-7594, 2331-5709',
#    'shortTitle': 'Indicators for Roman economic growth',
#    'url': 'https://www.cambridge.org/core/product/identifier/S1047759400020596/type/journal_article',
#    'accessDate': '2021-06-01T10:30:08Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2784584/items/Z7J9QKJK'},
#    'dateAdded': '2021-06-03T13:54:57Z',
#    'dateModified': '2021-06-03T13:54:57Z'}},
#  'WRRYLBT4': {'key': 'WRRYLBT4',
#   'version': 111,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/WRRYLBT4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/WRRYLBT4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Liuzzo',
#    'parsedDate': '2019-10-17',
#    'numChildren': 0},
#   'data': {'key': 'WRRYLBT4',
#    'version': 111,
#    'itemType': 'book',
#    'title': 'Digital Approaches to Ethiopian and Eritrean Studies',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Pietro Maria',
#      'lastName': 'Liuzzo'}],
#    'abstractNote': '',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '1',
#    'place': '',
#    'publisher': 'Harrassowitz, O',
#    'date': '2019-10-17',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-3-447-19913-1 978-3-447-11291-8',
#    'shortTitle': '',
#    'url': 'http://www.jstor.org/stable/10.2307/j.ctvrnfr3q',
#    'accessDate': '2021-05-31T11:55:56Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.2307/j.ctvrnfr3q',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/TI2L8FYJ'},
#    'dateAdded': '2021-05-31T11:56:09Z',
#    'dateModified': '2021-05-31T11:56:09Z'}},
#  'DWGK7BKK': {'key': 'DWGK7BKK',
#   'version': 110,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/DWGK7BKK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/DWGK7BKK',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/5925766/items/VI7N28PJ',
#     'type': 'application/json'},
#    'enclosure': {'type': 'application/pdf',
#     'href': 'https://api.zotero.org/users/5925766/items/DWGK7BKK/file/view',
#     'title': 'Wilkinson et al. - 2016 - The FAIR Guiding Principles for scientific data ma.pdf',
#     'length': 254899}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'DWGK7BKK',
#    'version': 110,
#    'parentItem': 'VI7N28PJ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-31T11:49:28Z',
#    'url': 'https://www.nature.com/articles/sdata201618.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Wilkinson et al. - 2016 - The FAIR Guiding Principles for scientific data ma.pdf',
#    'md5': 'c673d5848f1e19b935c01eb7819e2b2c',
#    'mtime': 1622461788000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/58V6B494'},
#    'dateAdded': '2021-05-31T11:49:48Z',
#    'dateModified': '2021-05-31T11:49:48Z'}},
#  'VI7N28PJ': {'key': 'VI7N28PJ',
#   'version': 109,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/VI7N28PJ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/VI7N28PJ',
#     'type': 'text/html'},
#    'attachment': {'href': 'https://api.zotero.org/users/5925766/items/DWGK7BKK',
#     'type': 'application/json',
#     'attachmentType': 'application/pdf',
#     'attachmentSize': 254899}},
#   'meta': {'creatorSummary': 'Wilkinson et al.',
#    'parsedDate': '2016',
#    'numChildren': 1},
#   'data': {'key': 'VI7N28PJ',
#    'version': 109,
#    'itemType': 'journalArticle',
#    'title': 'The FAIR Guiding Principles for scientific data management and stewardship',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Mark D.',
#      'lastName': 'Wilkinson'},
#     {'creatorType': 'author', 'firstName': 'Michel', 'lastName': 'Dumontier'},
#     {'creatorType': 'author',
#      'firstName': 'IJsbrand Jan',
#      'lastName': 'Aalbersberg'},
#     {'creatorType': 'author',
#      'firstName': 'Gabrielle',
#      'lastName': 'Appleton'},
#     {'creatorType': 'author', 'firstName': 'Myles', 'lastName': 'Axton'},
#     {'creatorType': 'author', 'firstName': 'Arie', 'lastName': 'Baak'},
#     {'creatorType': 'author', 'firstName': 'Niklas', 'lastName': 'Blomberg'},
#     {'creatorType': 'author', 'firstName': 'Jan-Willem', 'lastName': 'Boiten'},
#     {'creatorType': 'author',
#      'firstName': 'Luiz Bonino',
#      'lastName': 'da Silva Santos'},
#     {'creatorType': 'author', 'firstName': 'Philip E.', 'lastName': 'Bourne'},
#     {'creatorType': 'author', 'firstName': 'Jildau', 'lastName': 'Bouwman'},
#     {'creatorType': 'author',
#      'firstName': 'Anthony J.',
#      'lastName': 'Brookes'},
#     {'creatorType': 'author', 'firstName': 'Tim', 'lastName': 'Clark'},
#     {'creatorType': 'author', 'firstName': 'Mercè', 'lastName': 'Crosas'},
#     {'creatorType': 'author', 'firstName': 'Ingrid', 'lastName': 'Dillo'},
#     {'creatorType': 'author', 'firstName': 'Olivier', 'lastName': 'Dumon'},
#     {'creatorType': 'author', 'firstName': 'Scott', 'lastName': 'Edmunds'},
#     {'creatorType': 'author', 'firstName': 'Chris T.', 'lastName': 'Evelo'},
#     {'creatorType': 'author', 'firstName': 'Richard', 'lastName': 'Finkers'},
#     {'creatorType': 'author',
#      'firstName': 'Alejandra',
#      'lastName': 'Gonzalez-Beltran'},
#     {'creatorType': 'author',
#      'firstName': 'Alasdair J.G.',
#      'lastName': 'Gray'},
#     {'creatorType': 'author', 'firstName': 'Paul', 'lastName': 'Groth'},
#     {'creatorType': 'author', 'firstName': 'Carole', 'lastName': 'Goble'},
#     {'creatorType': 'author', 'firstName': 'Jeffrey S.', 'lastName': 'Grethe'},
#     {'creatorType': 'author', 'firstName': 'Jaap', 'lastName': 'Heringa'},
#     {'creatorType': 'author', 'firstName': 'Peter A.C', 'lastName': '’t Hoen'},
#     {'creatorType': 'author', 'firstName': 'Rob', 'lastName': 'Hooft'},
#     {'creatorType': 'author', 'firstName': 'Tobias', 'lastName': 'Kuhn'},
#     {'creatorType': 'author', 'firstName': 'Ruben', 'lastName': 'Kok'},
#     {'creatorType': 'author', 'firstName': 'Joost', 'lastName': 'Kok'},
#     {'creatorType': 'author', 'firstName': 'Scott J.', 'lastName': 'Lusher'},
#     {'creatorType': 'author',
#      'firstName': 'Maryann E.',
#      'lastName': 'Martone'},
#     {'creatorType': 'author', 'firstName': 'Albert', 'lastName': 'Mons'},
#     {'creatorType': 'author', 'firstName': 'Abel L.', 'lastName': 'Packer'},
#     {'creatorType': 'author', 'firstName': 'Bengt', 'lastName': 'Persson'},
#     {'creatorType': 'author',
#      'firstName': 'Philippe',
#      'lastName': 'Rocca-Serra'},
#     {'creatorType': 'author', 'firstName': 'Marco', 'lastName': 'Roos'},
#     {'creatorType': 'author', 'firstName': 'Rene', 'lastName': 'van Schaik'},
#     {'creatorType': 'author',
#      'firstName': 'Susanna-Assunta',
#      'lastName': 'Sansone'},
#     {'creatorType': 'author', 'firstName': 'Erik', 'lastName': 'Schultes'},
#     {'creatorType': 'author', 'firstName': 'Thierry', 'lastName': 'Sengstag'},
#     {'creatorType': 'author', 'firstName': 'Ted', 'lastName': 'Slater'},
#     {'creatorType': 'author', 'firstName': 'George', 'lastName': 'Strawn'},
#     {'creatorType': 'author', 'firstName': 'Morris A.', 'lastName': 'Swertz'},
#     {'creatorType': 'author', 'firstName': 'Mark', 'lastName': 'Thompson'},
#     {'creatorType': 'author', 'firstName': 'Johan', 'lastName': 'van der Lei'},
#     {'creatorType': 'author', 'firstName': 'Erik', 'lastName': 'van Mulligen'},
#     {'creatorType': 'author', 'firstName': 'Jan', 'lastName': 'Velterop'},
#     {'creatorType': 'author', 'firstName': 'Andra', 'lastName': 'Waagmeester'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Wittenburg'},
#     {'creatorType': 'author',
#      'firstName': 'Katherine',
#      'lastName': 'Wolstencroft'},
#     {'creatorType': 'author', 'firstName': 'Jun', 'lastName': 'Zhao'},
#     {'creatorType': 'author', 'firstName': 'Barend', 'lastName': 'Mons'}],
#    'abstractNote': '',
#    'publicationTitle': 'Scientific Data',
#    'volume': '3',
#    'issue': '1',
#    'pages': '160018',
#    'date': '12/2016',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Sci Data',
#    'language': 'en',
#    'DOI': '10.1038/sdata.2016.18',
#    'ISSN': '2052-4463',
#    'shortTitle': '',
#    'url': 'http://www.nature.com/articles/sdata201618',
#    'accessDate': '2021-05-31T11:49:27Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/HUNSU4A3'},
#    'dateAdded': '2021-05-31T11:49:48Z',
#    'dateModified': '2021-05-31T11:49:48Z'}},
#  'KGBLD6FY': {'key': 'KGBLD6FY',
#   'version': 105,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/KGBLD6FY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/KGBLD6FY',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Ballsun-Stanton',
#    'parsedDate': '2020',
#    'numChildren': 0},
#   'data': {'key': 'KGBLD6FY',
#    'version': 105,
#    'itemType': 'computerProgram',
#    'title': 'Lat Epig 2.0',
#    'creators': [{'creatorType': 'programmer',
#      'firstName': 'Brian',
#      'lastName': 'Ballsun-Stanton'},
#     {'creatorType': 'contributor',
#      'firstName': 'Petra',
#      'lastName': 'Hermankova'},
#     {'creatorType': 'contributor',
#      'firstName': 'Ray',
#      'lastName': 'Laurence'}],
#    'abstractNote': '',
#    'seriesTitle': '',
#    'versionNumber': '',
#    'date': '2020',
#    'system': '',
#    'place': '',
#    'company': 'Macquarie University',
#    'programmingLanguage': 'python',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#    'rights': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'accessDate': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/84QIQ6VP'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  'MCUQLXCG': {'key': 'MCUQLXCG',
#   'version': 105,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/MCUQLXCG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/MCUQLXCG',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Kolb',
#    'parsedDate': '2019-06-17',
#    'numChildren': 0},
#   'data': {'key': 'MCUQLXCG',
#    'version': 105,
#    'itemType': 'bookSection',
#    'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Anne',
#      'lastName': 'Kolb'},
#     {'creatorType': 'editor', 'firstName': 'Anne', 'lastName': 'Kolb'}],
#    'abstractNote': '',
#    'bookTitle': 'Roman Roads: New Evidence - New Perspectives',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'De Gruyter',
#    'date': '2019-06-17',
#    'pages': '3-21',
#    'language': '',
#    'ISBN': '978-3-11-063833-2',
#    'shortTitle': '',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#    'accessDate': '2021-05-19T07:51:54Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1515/9783110638332',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WBXNR587'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  'RB28J3CE': {'key': 'RB28J3CE',
#   'version': 105,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/RB28J3CE',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/RB28J3CE',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Ober', 'parsedDate': '2015', 'numChildren': 0},
#   'data': {'key': 'RB28J3CE',
#    'version': 105,
#    'itemType': 'book',
#    'title': 'The rise and fall of classical Greece',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Josiah.',
#      'lastName': 'Ober'}],
#    'abstractNote': '"Lord Byron described Greece as great, fallen, and immortal, a characterization more apt than he knew. Through most of its long history, Greece was poor. But in the classical era, Greece was densely populated and highly urbanized. Many surprisingly healthy Greeks lived in remarkably big houses and worked for high wages at specialized occupations. Middle-class spending drove sustained economic growth. Classical wealth produced a stunning cultural efflorescence lasting hundreds of years. Why did Greece reach such heights in the classical period--and why only then? And how, after \'the Greek miracle\' had endured for centuries, did the Macedonians defeat the Greeks, seemingly bringing an end to their glory? Drawing on a massive body of newly available data and employing novel approaches to evidence, Josiah Ober offers a major new history of classical Greece and an unprecedented account of its rise and fall. Ober argues that Greece\'s rise was no miracle but rather the result of political breakthroughs and economic development. The extraordinary emergence of citizen-centered city-states transformed Greece into a society that defeated the mighty Persian Empire. Yet Philip and Alexander of Macedon were able to beat the Greeks in the Battle of Chaeronea in 338 BCE, a victory enabled by the Macedonians\' appropriation of Greek innovations. After Alexander\'s death, battle-hardened warlords fought ruthlessly over the remnants of his empire. But Greek cities remained populous and wealthy, their economy and culture surviving to be passed on to the Romans--and to us. A compelling narrative filled with uncanny modern parallels, this is a book for anyone interested in how great civilizations are born and die. This book is based on evidence available on a new interactive website. To learn more, please visit: http://polis.stanford.edu/"--',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': '',
#    'date': '2015',
#    'numPages': '',
#    'language': 'English',
#    'ISBN': '978-0-691-14091-9 0-691-14091-X',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '/z-wcorg/',
#    'archiveLocation': '',
#    'libraryCatalog': 'http://worldcat.org',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/R7SBJXLH'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  'TGQ9TAPF': {'key': 'TGQ9TAPF',
#   'version': 104,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/TGQ9TAPF',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/TGQ9TAPF',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2010', 'numChildren': 0},
#   'data': {'key': 'TGQ9TAPF',
#    'version': 104,
#    'itemType': 'book',
#    'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'New York',
#    'publisher': 'Farrar, Straus and Giroux',
#    'date': '2010',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '978-0-312-61169-9',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#    'tags': [{'tag': 'civilisationens historie'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WC3F7GTN'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  '93X7WDDV': {'key': '93X7WDDV',
#   'version': 104,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/93X7WDDV',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/93X7WDDV',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2013', 'numChildren': 0},
#   'data': {'key': '93X7WDDV',
#    'version': 104,
#    'itemType': 'book',
#    'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': 'Course Book',
#    'place': 'Princeton, NJ',
#    'publisher': 'Princeton University Press',
#    'date': '2013',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '1-299-14683-X',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'tags': [{'tag': 'Social structure'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/YTH8LCMQ'},
#    'dateAdded': '2021-05-25T09:50:01Z',
#    'dateModified': '2021-05-25T09:50:01Z'}},
#  'WZ6MD9YX': {'key': 'WZ6MD9YX',
#   'version': 104,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
# ...
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/A6W7Q3HZ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/A6W7Q3HZ',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Woolf', 'parsedDate': '1996', 'numChildren': 0},
#   'data': {'key': 'A6W7Q3HZ',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Greg',
#      'lastName': 'Woolf'}],
#    'abstractNote': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#    'publicationTitle': 'Journal of Roman Studies',
#    'volume': '86',
#    'issue': '',
#    'pages': '22–39',
#    'date': '1996',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.2307/300421',
#    'ISSN': '0075-4358',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'epigraphic habit'},
#     {'tag': 'epigraphy'},
#     {'tag': 'epipgaphic infrastructure'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/97CQ2NB2'},
#    'dateAdded': '2021-05-07T13:47:11Z',
#    'dateModified': '2021-05-07T13:47:11Z'}},
#  'YWIASGX4': {'key': 'YWIASGX4',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/YWIASGX4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/YWIASGX4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Grieshaber',
#    'parsedDate': '2019',
#    'numChildren': 0},
#   'data': {'key': 'YWIASGX4',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Epigraphic Database Heidelberg – Data Reuse Options',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Frank',
#      'lastName': 'Grieshaber'}],
#    'abstractNote': '',
#    'publicationTitle': '',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '2019',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.11588/HEIDOK.00026599',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/26599',
#    'accessDate': '2021-05-07T13:16:00Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Datacite)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Heidelberg University Library',
#    'tags': [{'tag': '470 Italic Latin', 'type': 1},
#     {'tag': '930 History of ancient world', 'type': 1}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/U6IWIHZP'},
#    'dateAdded': '2021-05-07T13:16:00Z',
#    'dateModified': '2021-05-07T13:16:00Z'}},
#  'MGBT6ZCX': {'key': 'MGBT6ZCX',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/MGBT6ZCX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/MGBT6ZCX',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Feraudi-Gruénais and Grieshaber',
#    'parsedDate': '2016',
#    'numChildren': 0},
#   'data': {'key': 'MGBT6ZCX',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Digital Epigraphy am Scheideweg? / Digital Epigraphy at a crossroads?',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Francisca',
#      'lastName': 'Feraudi-Gruénais'},
#     {'creatorType': 'author', 'firstName': 'Frank', 'lastName': 'Grieshaber'}],
#    'abstractNote': '',
#    'publicationTitle': '',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '2016',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.11588/HEIDOK.00022141',
#    'ISSN': '',
#    'shortTitle': 'Digital Epigraphy am Scheideweg?',
#    'url': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/22141',
#    'accessDate': '2021-05-07T13:11:36Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Datacite)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Heidelberg University Library',
#    'tags': [{'tag': '000 Generalities, Science', 'type': 1},
#     {'tag': '470 Italic Latin', 'type': 1},
#     {'tag': '480 Hellenic languages Classical Greek', 'type': 1}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/92AWXFTV'},
#    'dateAdded': '2021-05-07T13:11:36Z',
#    'dateModified': '2021-05-07T13:11:36Z'}},
#  '2WIJQZDC': {'key': '2WIJQZDC',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/2WIJQZDC',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/2WIJQZDC',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Bolle et al.',
#    'parsedDate': '2017',
#    'numChildren': 0},
#   'data': {'key': '2WIJQZDC',
#    'version': 99,
#    'itemType': 'book',
#    'title': 'The Epigraphic Cultures of Late Antiquity',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'K.',
#      'lastName': 'Bolle'},
#     {'creatorType': 'author', 'firstName': 'C.', 'lastName': 'Machado'},
#     {'creatorType': 'author', 'firstName': 'C.', 'lastName': 'Witschel'}],
#    'abstractNote': '',
#    'series': 'Alte Geschichte',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Franz Steiner Verlag',
#    'date': '2017',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-3-515-11558-2',
#    'shortTitle': '',
#    'url': 'https://books.google.dk/books?id=iJBdMQAACAAJ',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/VEGXDB34'},
#    'dateAdded': '2021-05-07T13:03:09Z',
#    'dateModified': '2021-05-07T13:03:09Z'}},
#  'N8YT927J': {'key': 'N8YT927J',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/N8YT927J',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/N8YT927J',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Beltrán Lloris',
#    'parsedDate': '2014',
#    'numChildren': 0},
#   'data': {'key': 'N8YT927J',
#    'version': 99,
#    'itemType': 'bookSection',
#    'title': 'The “Epigraphic Habit” in the Roman World',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Francisco',
#      'lastName': 'Beltrán Lloris'}],
#    'abstractNote': 'Since the 1980s scholars have ceased considering Roman inscriptions simply in functional terms—as sources of historical information—and started to treat them as a cultural phenomenon worthy of serious consideration. This change in perspective, as well as the realization that there was a permanent bond between text and monument, represents the most productive shift in approach in recent epigraphic scholarship. This chapter analyzes the “epigraphic habit” in order to explain why people wrote on stone throughout Italy and the provinces, linking its rise to the proliferation of urbanization, literacy, and the desire for self-representation.',
#    'bookTitle': 'The Oxford Handbook of Roman Epigraphy',
#    'series': 'Oxford Handbooks',
#    'seriesNumber': '',
#    'volume': '1',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Oxford University Press',
#    'date': '2014',
#    'pages': '',
#    'language': 'eng',
#    'ISBN': '0-19-533646-1',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Italy'},
#     {'tag': 'Principate'},
#     {'tag': 'Roman provinces'},
#     {'tag': 'Rome'},
#     {'tag': 'epigraphic habit'},
#     {'tag': 'epitaphs'},
#     {'tag': 'freedmen'},
#     {'tag': 'furor epigraphicus'},
#     {'tag': 'inscriptions'},
#     {'tag': 'urbanization'}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/MX4RX9KU'},
#    'dateAdded': '2021-05-07T12:39:58Z',
#    'dateModified': '2021-05-07T12:39:58Z'}},
#  'KBJ7VEJ8': {'key': 'KBJ7VEJ8',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/KBJ7VEJ8',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/KBJ7VEJ8',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Pérez', 'parsedDate': '2021', 'numChildren': 0},
#   'data': {'key': 'KBJ7VEJ8',
#    'version': 99,
#    'itemType': 'journalArticle',
#    'title': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy: The End of a Habit?',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Aitor Blanco',
#      'lastName': 'Pérez'}],
#    'abstractNote': '<p>The political communities of western Asia Minor produced an enormous amount of inscriptions under Roman rule. For the period between AD 260 and 280, however, the epigraphic habit falls dramatically and this situation largely continues in the 4<sup>th</sup> and 5<sup>th</sup> centuries. The aim of this paper is to analyse the phenomenon in the transitional Tetrarchic age, when a notable increase in testimony, particularly milestones and texts related to the new regime (e. g. ‘Edict of Prices’), can be observed. My study of continuities and changes concludes that the propagandistic efforts under the Tetrarchs did not ultimately coincide with a full reactivation of civic epigraphic culture and this new scenario should remain fundamental for our assessment of Late Antiquity in the region.</p>',
#    'publicationTitle': 'Historia',
#    'volume': '70',
#    'issue': '1',
#    'pages': '116-132',
#    'date': '2021',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'historia',
#    'language': 'en',
#    'DOI': '10.25162/historia-2021-0006',
#    'ISSN': '0018-2311',
#    'shortTitle': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy',
#    'url': 'https://elibrary.steiner-verlag.de/article/10.25162/historia-2021-0006',
#    'accessDate': '2021-05-07T12:22:35Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'elibrary.steiner-verlag.de',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/FZSBUKPJ'},
#    'dateAdded': '2021-05-07T12:22:36Z',
#    'dateModified': '2021-05-07T12:22:36Z'}},
#  'RAG327R6': {'key': 'RAG327R6',
#   'version': 99,
#   'library': {'type': 'user',
#    'id': 5925766,
#    'name': 'petrifiedvoices',
#    'links': {'alternate': {'href': 'https://www.zotero.org/petrifiedvoices',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/5925766/items/RAG327R6',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/petrifiedvoices/items/RAG327R6',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Trout', 'parsedDate': '2009', 'numChildren': 0},
#   'data': {'key': 'RAG327R6',
#    'version': 99,
#    'itemType': 'bookSection',
#    'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Dennis E.',
#      'lastName': 'Trout'}],
#    'abstractNote': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#    'bookTitle': 'A Companion to Late Antiquity',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'John Wiley & Sons, Ltd',
#    'date': '2009',
#    'pages': '170-186',
#    'language': 'en',
#    'ISBN': '978-1-4443-0610-1',
#    'shortTitle': 'Inscribing Identity',
#    'url': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#    'accessDate': '2021-05-07T12:15:20Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Wiley Online Library',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1002/9781444306101.ch12',
#    'tags': [{'tag': "Latin of Late Antiquity's non-elites", 'type': 1},
#     {'tag': 'civic history and public memory', 'type': 1},
#     {'tag': 'epigraphic corpora and epigraphic curves', 'type': 1},
#     {'tag': 'epigraphic horizons', 'type': 1},
#     {'tag': 'epigraphy of Christians', 'type': 1},
#     {'tag': 'evolution of Vulgar (or demotic) Latin toward Romance languages',
#      'type': 1},
#     {'tag': 'inscribing identity - Latin epigraphic habit', 'type': 1},
#     {'tag': 'inscriptions preserving unique images of late antique life and society',
#      'type': 1}],
#    'collections': ['LFPMLWZ2'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/H728XWCW'},
#    'dateAdded': '2021-05-07T12:15:20Z',
#    'dateModified': '2021-05-07T12:15:20Z'}}}

# %%
import re

# %%
re.match("(\d{4})-(\d+)\-(\d+)", "2018-07-08").groups()
# Out:
# ('2018', '07', '08')

# %%
re.sub(r"(\d{4})-(\d+)\-(\d+)", r"\1", "2018-07-08")
# Out:
# '2018'

# %%
# ids of items
citation_keys_pairs = {}
for key in citations.keys():
    if collection_items_dict[key.rpartition("/")[2]]["data"]["itemType"] != "attachment":
        try:
            item_dict = collection_items_dict[key.rpartition("/")[2]]
            item_key = item_dict["meta"]["creatorSummary"] + " " + item_dict["meta"]["parsedDate"]
        except: 
            try:
                item_key = item_dict["data"]["title"]
            except:
                item_key = ""
        item_key = re.sub(r"(\d{4})-(\d+)\-(\d+)", r"\1", item_key)
        citation_keys_pairs[item_key] = key

# %%
citation_keys_pairs
# Out:
# {'Lowndes et al. 2017': '7109337/8C5W7WYE',
#  'Scheidel 2018': '7109337/3J5XSHJ2',
#  'Huggett 2017': '7109337/CY54CMQ9',
#  'Huggett 2016': '7109337/QZV4FHQ6',
#  'Raymond 2001': '7109337/3NH6EHMA',
#  'Iversen 2007': '7109337/CAJ8RP6I',
#  'Sherratt 2019': '7109337/GZXS5Q8K',
#  'Madzharov 2009': '7109337/XDAURK5G',
#  'Hollenstein 1975': '7109337/7DY6HUZB',
#  'Duncan-Jones 2018': '7109337/J6GWZWL4',
#  'Duncan-Jones 1990': '7109337/YFQQLVBK',
#  'Duncan-Jones 1996': '7109337/HCU3WEJB',
#  'Tahmasebi and Hengchen 2019': '7109337/UH4L3837',
#  'Wilson 2009': '7109337/TARVRY26',
#  'Liuzzo 2019': '7109337/WRRYLBT4',
#  'Wilkinson et al. 2016': '7109337/VI7N28PJ',
#  'Ballsun-Stanton 2020': '7109337/KGBLD6FY',
#  'Kolb 2019': '7109337/MCUQLXCG',
#  'Ober 2015': '7109337/RB28J3CE',
#  'Morris 2010': '7109337/TGQ9TAPF',
#  'Morris 2013': '7109337/93X7WDDV',
#  'Hanson et al. 2017': '7109337/WZ6MD9YX',
#  'Mullins et al. 2018': '7109337/2ASLDCJP',
#  'Borgman 2015': '7109337/FBAWXZ3I',
#  'Cayless et al. 2010': '7109337/EYTI8IQA',
#  'Laurence 1999': '7109337/QSJYQVZZ',
#  'Bodard 2008': '7109337/KE9T4566',
#  'Bodard et al. 2021': '7109337/2KEXYJLP',
#  'Avanzini et al. 2018': '7109337/7EHKTWQD',
#  'Liuzzo 2018': '7109337/TKXWFLYN',
#  'de Ligt and Tacoma 2016': '7109337/75PC3E2A',
#  'Harper 2016': '7109337/SVYA23ZT',
#  'Littman and Littman 1973': '7109337/D2YZ7HDA',
#  'Verhagen 2019': '7109337/BG7SH7C4',
#  'De Santis and Rossi 2018': '7109337/NKKHMIDW',
#  'Wilson and Flohr 2016': '7109337/L73K2ZRY',
#  'Kemkes 2020': '7109337/TISH84GY',
#  'Hanel 2020': '7109337/ZESEJVF2',
#  'Bodel 2001': '7109337/82J5J52N',
#  'Verhagen et al. 2016': '7109337/FLW2G53N',
#  'Rabinowitz et al. 2018': '7109337/XLJYXMEV',
#  'Elliot et al. 2017': '7109337/T45AYTCM',
#  'Hartmann 2018': '7109337/EAY2DVSF',
#  'Oksanen and Lewis 2020': '7109337/YW3AIT6K',
#  'Hedrick 1999': '7109337/IRUVQAYJ',
#  'Wilson 2012': '7109337/BRZQ3MUL',
#  'Keppie 1991': '7109337/YMB2QZ7K',
#  'Cooley et al. 2007': '7109337/283Z83RT',
#  'Bowman and Wilson 2009': '7109337/QS4C5IAS',
#  'Turchin et al. 2018': '7109337/3L9BKAXW',
#  'Turchin and Scheidel 2009': '7109337/PE4PYNDX',
#  'Lotz 2020': '7109337/ARLWKWIA',
#  'Kaše 2021': '7109337/A38DT8IA',
#  'Johnson 2004': '7109337/T6MN4QSJ',
#  'Crema 2012': '7109337/A9IA3B55',
#  'Crema and Kobayashi 2020': '7109337/6GLRJFFY',
#  'Janouchová (Heřmánková) 2021': '7109337/AUPFZAAL',
#  'Prag 2013': '7109337/7U7NNBAA',
#  'Korhonen 2011': '7109337/7AA3T3HM',
#  'Prag 2002': '7109337/JAXUAMNH',
#  'Roueche and Sotinel 2017-03': '7109337/TWB9XHFH',
#  'Bloch 1947': '7109337/WLLWUZT7',
#  'Bloch 1967': '7109337/JCIXA2RJ',
#  'Elliot et al. 2020': '7109337/9J244TYE',
#  'Dow 1969': '7109337/EBFQEFW3',
#  'Nawotka 2021': '7109337/TXCY5XL8',
#  'Meyer 1990': '7109337/AU6JTRIU',
#  'Elliot 2015': '7109337/5W97HIK9',
#  'Duthoy 2002': '7109337/VDS8KTIA',
#  'McLean 2016': '7109337/SBV9XF6H',
#  'MacMullen 1982': '7109337/C5QVR3SE',
#  'Woolf 1996': '7109337/A6W7Q3HZ',
#  'Grieshaber 2019': '7109337/YWIASGX4',
#  'Feraudi-Gruénais and Grieshaber 2016': '7109337/MGBT6ZCX',
#  'Bolle et al. 2017': '7109337/2WIJQZDC',
#  'Beltrán Lloris 2014': '7109337/N8YT927J',
#  'Pérez 2021': '7109337/KBJ7VEJ8',
#  'Trout 2009': '7109337/RAG327R6'}

# %% [markdown]
# # Small test

# %% [markdown]
# this way, we can easily generate the data in the form produced by cite2c, combining **collection ID** and **item ID**.
#
# However, it seems that cite2c does not support group collection. We need to work with our personal collection instead.

# %% [markdown]
# Here we test how the citations work. We will use Wilson 2012 as an example. Let put it here <cite data-cite="1913534/SYSTIFZQ"></cite>. Another citation would be here <cite data-cite="1913534/627JE7WX"></cite> or here <cite data-cite="1913534/IFEXKMWT"></cite> (here should be Mullins et al. 2018 - but does not render automatically). <cite data-cite="1913534/MUKI9YSZ"></cite>

# %% [markdown]
# insert citation here <cite data-cite="undefined"></cite>.

# %% [markdown]
# <cite data-cite="1913534/U48VTMSM"></cite>

# %% [markdown]
# <div class="cite2c-biblio"></div>

# %% [markdown]
# # Read ipynb as text file

# %% [markdown]
# <cite data-cite="1913534/U48VTMSM"></cite>

# %%
notebook_text = open("Digital_epigraphy.ipynb").read()
notebook_text[:1000]
# Out:
# '{\n "cells": [\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "title"\n    ]\n   },\n   "source": [\n    "# Inscriptions as data: digital epigraphy in macro-historical perspective "\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Petra Hermankova\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6349-0540](https://orcid.org/0000-0002-6349-0540)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Vojtech Kase\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6601-1605](http://orcid.org/0000-0002-6601-1605)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Adela Sobotkova\\n",\n    "Author. Aarhus University, [ORCID:0000-0002-4541-3963](https://orcid.org/0000-0002-4541-3963)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n'

# %%
for key in citation_keys_pairs.keys():
    if key in notebook_text:
        print(key, citation_keys_pairs[key])
# Out:
# Lowndes et al. 2017 7109337/8C5W7WYE
# Scheidel 2018 7109337/3J5XSHJ2
# Huggett 2017 7109337/CY54CMQ9
# Raymond 2001 7109337/3NH6EHMA
# Iversen 2007 7109337/CAJ8RP6I
# Sherratt 2019 7109337/GZXS5Q8K
# Madzharov 2009 7109337/XDAURK5G
# Hollenstein 1975 7109337/7DY6HUZB
# Duncan-Jones 2018 7109337/J6GWZWL4
# Duncan-Jones 1990 7109337/YFQQLVBK
# Duncan-Jones 1996 7109337/HCU3WEJB
# Tahmasebi and Hengchen 2019 7109337/UH4L3837
# Wilson 2009 7109337/TARVRY26
# Liuzzo 2019 7109337/WRRYLBT4
# Wilkinson et al. 2016 7109337/VI7N28PJ
# Kolb 2019 7109337/MCUQLXCG
# Ober 2015 7109337/RB28J3CE
# Morris 2010 7109337/TGQ9TAPF
# Hanson et al. 2017 7109337/WZ6MD9YX
# Mullins et al. 2018 7109337/2ASLDCJP
# Borgman 2015 7109337/FBAWXZ3I
# Cayless et al. 2010 7109337/EYTI8IQA
# Laurence 1999 7109337/QSJYQVZZ
# Bodard 2008 7109337/KE9T4566
# Bodard et al. 2021 7109337/2KEXYJLP
# Avanzini et al. 2018 7109337/7EHKTWQD
# Liuzzo 2018 7109337/TKXWFLYN
# Harper 2016 7109337/SVYA23ZT
# Verhagen 2019 7109337/BG7SH7C4
# De Santis and Rossi 2018 7109337/NKKHMIDW
# Wilson and Flohr 2016 7109337/L73K2ZRY
# Kemkes 2020 7109337/TISH84GY
# Hanel 2020 7109337/ZESEJVF2
# Bodel 2001 7109337/82J5J52N
# Verhagen et al. 2016 7109337/FLW2G53N
# Rabinowitz et al. 2018 7109337/XLJYXMEV
# Hartmann 2018 7109337/EAY2DVSF
# Oksanen and Lewis 2020 7109337/YW3AIT6K
# Hedrick 1999 7109337/IRUVQAYJ
# Wilson 2012 7109337/BRZQ3MUL
# Bowman and Wilson 2009 7109337/QS4C5IAS
# Turchin et al. 2018 7109337/3L9BKAXW
# Turchin and Scheidel 2009 7109337/PE4PYNDX
# Lotz 2020 7109337/ARLWKWIA
# Kaše 2021 7109337/A38DT8IA
# Johnson 2004 7109337/T6MN4QSJ
# Crema 2012 7109337/A9IA3B55
# Crema and Kobayashi 2020 7109337/6GLRJFFY
# Prag 2002 7109337/JAXUAMNH
# Bloch 1947 7109337/WLLWUZT7
# Dow 1969 7109337/EBFQEFW3
# Nawotka 2021 7109337/TXCY5XL8
# Meyer 1990 7109337/AU6JTRIU
# MacMullen 1982 7109337/C5QVR3SE
# Woolf 1996 7109337/A6W7Q3HZ
# Grieshaber 2019 7109337/YWIASGX4
# Feraudi-Gruénais and Grieshaber 2016 7109337/MGBT6ZCX
# Trout 2009 7109337/RAG327R6

# %% [markdown]
# Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).

# %%
test_paragraph = "Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139)."
print(test_paragraph)
# Out:
# Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).

# %%
citations
# Out:
# {'7109337/5DKTH37I': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.nature.com/articles/s41559-017-0160.pdf',
#   'accessed': {'date-parts': [[2021, 6, 11]]}},
#  '7109337/8C5W7WYE': {'type': 'article-journal',
#   'title': 'Our path to better science in less time using open data science tools',
#   'container-title': 'Nature Ecology & Evolution',
#   'page': '0160',
#   'volume': '1',
#   'issue': '6',
#   'URL': 'http://www.nature.com/articles/s41559-017-0160',
#   'DOI': '10.1038/s41559-017-0160',
#   'journalAbbreviation': 'Nat Ecol Evol',
#   'language': 'en',
#   'author': [{'family': 'Lowndes', 'given': 'Julia S. Stewart'},
#    {'family': 'Best', 'given': 'Benjamin D.'},
#    {'family': 'Scarborough', 'given': 'Courtney'},
#    {'family': 'Afflerbach', 'given': 'Jamie C.'},
#    {'family': 'Frazier', 'given': 'Melanie R.'},
#    {'family': 'O’Hara', 'given': 'Casey C.'},
#    {'family': 'Jiang', 'given': 'Ning'},
#    {'family': 'Halpern', 'given': 'Benjamin S.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 6, 11]]}},
#  '7109337/3J5XSHJ2': {'type': 'book',
#   'title': 'The Great Leveler: Violence and the History of Inequality from the Stone Age to the Twenty-First Century',
#   'collection-title': 'The Princeton Economic History of the Western World',
#   'publisher': 'Princeton University Press',
#   'URL': 'https://press.princeton.edu/books/paperback/9780691183251/the-great-leveler',
#   'ISBN': '978-0-691-18325-1',
#   'author': [{'family': 'Scheidel', 'given': 'Walter'}],
#   'issued': {'date-parts': [[2018]]}},
#  '7109337/CY54CMQ9': {'type': 'post-weblog',
#   'title': 'Citing Data Reuse',
#   'URL': 'https://introspectivedigitalarchaeology.com/2017/05/23/citing-data-reuse/',
#   'language': 'eng',
#   'author': [{'family': 'Huggett', 'given': 'Jeremy'}],
#   'issued': {'date-parts': [[2017, 5, 23]]}},
#  '7109337/QZV4FHQ6': {'type': 'post-weblog',
#   'title': 'Digital Data Realities',
#   'URL': 'https://introspectivedigitalarchaeology.com/2016/06/29/digital-data-realities/',
#   'language': 'eng',
#   'author': [{'family': 'Huggett', 'given': 'Jeremy'}],
#   'issued': {'date-parts': [[2016, 6, 29]]}},
#  '7109337/3NH6EHMA': {'type': 'book',
#   'title': 'The Cathedral & the Bazaar',
#   'publisher': "O'Reilly Media",
#   'URL': 'https://www.oreilly.com/library/view/the-cathedral/0596001088/',
#   'ISBN': '978-0-596-00108-7',
#   'language': 'English',
#   'author': [{'family': 'Raymond', 'given': 'Eric S.'}],
#   'issued': {'date-parts': [[2001]]}},
#  '7109337/CAJ8RP6I': {'type': 'article-journal',
#   'title': 'The Packard Humanities Institute (PHI) Greek Epigraphy Project and the Revolution in Greek Epigraphy',
#   'container-title': 'Abgadiyat',
#   'page': '51-55',
#   'volume': '2.1',
#   'abstract': 'In this paper, the history, purpose and importance\nof the Packard Humanities Institute (PHI) Greek\nEpigraphy Project are discussed.',
#   'URL': 'https://journals.ekb.eg/article_62069_38414a2fca56893baf78323065072f95.pdf',
#   'language': 'eng',
#   'author': [{'family': 'Iversen', 'given': 'Paul A.'}],
#   'issued': {'date-parts': [[2007]]}},
#  '7109337/GZXS5Q8K': {'type': 'chapter',
#   'title': 'Hacking heritage: Understanding the limits of online access',
#   'container-title': 'The Routledge International Handbook of New Digital Practices in Galleries, Libraries, Archives, Museums and Heritage Sites',
#   'publisher': 'Routledge',
#   'page': '15',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9780429015304',
#   'ISBN': '978-0-429-50676-5',
#   'note': 'DOI: 10.4324/9780429506765',
#   'language': 'en',
#   'editor': [{'family': 'Lewi', 'given': 'Hannah'},
#    {'family': 'Smith', 'given': 'Wally'},
#    {'family': 'vom Lehn', 'given': 'Dirk'},
#    {'family': 'Cooke', 'given': 'Steven'}],
#   'author': [{'family': 'Sherratt', 'given': 'Tim'}],
#   'issued': {'date-parts': [[2019, 10, 29]]},
#   'accessed': {'date-parts': [[2021, 6, 10]]}},
#  '7109337/3ADCMC6C': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://dro.deakin.edu.au/eserv/DU:30122388/cooke-investigatingordinary-post-2019.pdf',
#   'accessed': {'date-parts': [[2021, 6, 10]]}},
#  '7109337/XDAURK5G': {'type': 'book',
#   'title': 'Rimski patishta v Balgaria: prinos v razvitieto na rimskata patna sistema v provintsiite Mizia i Trakia',
#   'publisher': 'Faber Publisher',
#   'publisher-place': 'Veliko Turnovo',
#   'event-place': 'Veliko Turnovo',
#   'author': [{'family': 'Madzharov', 'given': 'Mitko'}],
#   'issued': {'date-parts': [[2009]]}},
#  '7109337/7DY6HUZB': {'type': 'article-journal',
#   'title': 'Zu den Meilensteinen der römischen Provinzen Thracia und Moesia Inferior',
#   'container-title': 'Studia Balcanica',
#   'page': '23–44',
#   'volume': '10',
#   'author': [{'family': 'Hollenstein', 'given': 'Lorenz'}],
#   'issued': {'date-parts': [[1975]]}},
#  '7109337/J6GWZWL4': {'type': 'article-journal',
#   'title': 'The Antonine Plague Revisited',
#   'container-title': 'Arctos',
#   'page': '41-72',
#   'volume': '52',
#   'language': 'eng',
#   'author': [{'family': 'Duncan-Jones', 'given': 'Richard'}],
#   'issued': {'date-parts': [[2018]]}},
#  '7109337/YFQQLVBK': {'type': 'book',
#   'title': 'Structure and Scale in the Roman Economy',
#   'publisher': 'Cambridge University Press',
#   'edition': '1',
#   'URL': 'https://www.cambridge.org/core/product/identifier/9780511552649/type/book',
#   'ISBN': '978-0-521-35477-6 978-0-521-89289-6 978-0-511-55264-9',
#   'note': 'DOI: 10.1017/CBO9780511552649',
#   'author': [{'family': 'Duncan-Jones', 'given': 'Richard'}],
#   'issued': {'date-parts': [[1990, 4, 12]]},
#   'accessed': {'date-parts': [[2021, 6, 3]]}},
#  '7109337/HCU3WEJB': {'type': 'article-journal',
#   'title': 'The impact of the Antonine plague',
#   'container-title': 'Journal of Roman Archaeology',
#   'page': '108-136',
#   'volume': '9',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S1047759400016524/type/journal_article',
#   'DOI': '10.1017/S1047759400016524',
#   'journalAbbreviation': 'J. Roman archaeol.',
#   'language': 'en',
#   'author': [{'family': 'Duncan-Jones', 'given': 'R. P.'}],
#   'issued': {'date-parts': [[1996]]},
#   'accessed': {'date-parts': [[2021, 6, 3]]}},
#  '7109337/UH4L3837': {'type': 'article-journal',
#   'title': 'The Strengths and Pitfalls of Large-Scale Text Mining for Literary Studies',
#   'container-title': 'Samlaren',
#   'page': '198–227',
#   'volume': '140',
#   'URL': 'http://uu.diva-portal.org/smash/get/diva2:1415010/FULLTEXT01.pdf',
#   'author': [{'family': 'Tahmasebi', 'given': 'Nina'},
#    {'family': 'Hengchen', 'given': 'Simon'}],
#   'issued': {'date-parts': [[2019]]}},
#  '7109337/TARVRY26': {'type': 'article-journal',
#   'title': 'Indicators for Roman economic growth: a response to Walter Scheidel',
#   'container-title': 'Journal of Roman Archaeology',
#   'page': '71-82',
#   'volume': '22',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S1047759400020596/type/journal_article',
#   'DOI': '10.1017/S1047759400020596',
#   'shortTitle': 'Indicators for Roman economic growth',
#   'journalAbbreviation': 'J. Roman archaeol.',
#   'language': 'en',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 6, 1]]}},
#  '7109337/WRRYLBT4': {'type': 'book',
#   'title': 'Digital Approaches to Ethiopian and Eritrean Studies',
#   'publisher': 'Harrassowitz, O',
#   'edition': '1',
#   'URL': 'http://www.jstor.org/stable/10.2307/j.ctvrnfr3q',
#   'ISBN': '978-3-447-19913-1 978-3-447-11291-8',
#   'note': 'DOI: 10.2307/j.ctvrnfr3q',
#   'author': [{'family': 'Liuzzo', 'given': 'Pietro Maria'}],
#   'issued': {'date-parts': [[2019, 10, 17]]},
#   'accessed': {'date-parts': [[2021, 5, 31]]}},
#  '7109337/DWGK7BKK': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.nature.com/articles/sdata201618.pdf',
#   'accessed': {'date-parts': [[2021, 5, 31]]}},
#  '7109337/VI7N28PJ': {'type': 'article-journal',
#   'title': 'The FAIR Guiding Principles for scientific data management and stewardship',
#   'container-title': 'Scientific Data',
#   'page': '160018',
#   'volume': '3',
#   'issue': '1',
#   'URL': 'http://www.nature.com/articles/sdata201618',
#   'DOI': '10.1038/sdata.2016.18',
#   'journalAbbreviation': 'Sci Data',
#   'language': 'en',
#   'author': [{'family': 'Wilkinson', 'given': 'Mark D.'},
#    {'family': 'Dumontier', 'given': 'Michel'},
#    {'family': 'Aalbersberg', 'given': 'IJsbrand Jan'},
#    {'family': 'Appleton', 'given': 'Gabrielle'},
#    {'family': 'Axton', 'given': 'Myles'},
#    {'family': 'Baak', 'given': 'Arie'},
#    {'family': 'Blomberg', 'given': 'Niklas'},
#    {'family': 'Boiten', 'given': 'Jan-Willem'},
#    {'family': 'da Silva Santos', 'given': 'Luiz Bonino'},
#    {'family': 'Bourne', 'given': 'Philip E.'},
#    {'family': 'Bouwman', 'given': 'Jildau'},
#    {'family': 'Brookes', 'given': 'Anthony J.'},
#    {'family': 'Clark', 'given': 'Tim'},
#    {'family': 'Crosas', 'given': 'Mercè'},
#    {'family': 'Dillo', 'given': 'Ingrid'},
#    {'family': 'Dumon', 'given': 'Olivier'},
#    {'family': 'Edmunds', 'given': 'Scott'},
#    {'family': 'Evelo', 'given': 'Chris T.'},
#    {'family': 'Finkers', 'given': 'Richard'},
#    {'family': 'Gonzalez-Beltran', 'given': 'Alejandra'},
#    {'family': 'Gray', 'given': 'Alasdair J.G.'},
#    {'family': 'Groth', 'given': 'Paul'},
#    {'family': 'Goble', 'given': 'Carole'},
#    {'family': 'Grethe', 'given': 'Jeffrey S.'},
#    {'family': 'Heringa', 'given': 'Jaap'},
#    {'family': '’t Hoen', 'given': 'Peter A.C'},
#    {'family': 'Hooft', 'given': 'Rob'},
#    {'family': 'Kuhn', 'given': 'Tobias'},
#    {'family': 'Kok', 'given': 'Ruben'},
#    {'family': 'Kok', 'given': 'Joost'},
#    {'family': 'Lusher', 'given': 'Scott J.'},
#    {'family': 'Martone', 'given': 'Maryann E.'},
#    {'family': 'Mons', 'given': 'Albert'},
#    {'family': 'Packer', 'given': 'Abel L.'},
#    {'family': 'Persson', 'given': 'Bengt'},
#    {'family': 'Rocca-Serra', 'given': 'Philippe'},
#    {'family': 'Roos', 'given': 'Marco'},
#    {'family': 'van Schaik', 'given': 'Rene'},
#    {'family': 'Sansone', 'given': 'Susanna-Assunta'},
#    {'family': 'Schultes', 'given': 'Erik'},
#    {'family': 'Sengstag', 'given': 'Thierry'},
#    {'family': 'Slater', 'given': 'Ted'},
#    {'family': 'Strawn', 'given': 'George'},
#    {'family': 'Swertz', 'given': 'Morris A.'},
#    {'family': 'Thompson', 'given': 'Mark'},
#    {'family': 'van der Lei', 'given': 'Johan'},
#    {'family': 'van Mulligen', 'given': 'Erik'},
#    {'family': 'Velterop', 'given': 'Jan'},
#    {'family': 'Waagmeester', 'given': 'Andra'},
#    {'family': 'Wittenburg', 'given': 'Peter'},
#    {'family': 'Wolstencroft', 'given': 'Katherine'},
#    {'family': 'Zhao', 'given': 'Jun'},
#    {'family': 'Mons', 'given': 'Barend'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 31]]}},
#  '7109337/KGBLD6FY': {'type': 'book',
#   'title': 'Lat Epig 2.0',
#   'publisher': 'Macquarie University',
#   'URL': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#   'author': [{'family': 'Ballsun-Stanton', 'given': 'Brian'}],
#   'issued': {'date-parts': [[2020]]}},
#  '7109337/MCUQLXCG': {'type': 'chapter',
#   'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#   'container-title': 'Roman Roads: New Evidence - New Perspectives',
#   'publisher': 'De Gruyter',
#   'page': '3-21',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#   'ISBN': '978-3-11-063833-2',
#   'note': 'DOI: 10.1515/9783110638332',
#   'author': [{'family': 'Kolb', 'given': 'Anne'}],
#   'editor': [{'family': 'Kolb', 'given': 'Anne'}],
#   'issued': {'date-parts': [[2019, 6, 17]]},
#   'accessed': {'date-parts': [[2021, 5, 19]]}},
#  '7109337/RB28J3CE': {'type': 'book',
#   'title': 'The rise and fall of classical Greece',
#   'archive': '/z-wcorg/',
#   'abstract': '"Lord Byron described Greece as great, fallen, and immortal, a characterization more apt than he knew. Through most of its long history, Greece was poor. But in the classical era, Greece was densely populated and highly urbanized. Many surprisingly healthy Greeks lived in remarkably big houses and worked for high wages at specialized occupations. Middle-class spending drove sustained economic growth. Classical wealth produced a stunning cultural efflorescence lasting hundreds of years. Why did Greece reach such heights in the classical period--and why only then? And how, after \'the Greek miracle\' had endured for centuries, did the Macedonians defeat the Greeks, seemingly bringing an end to their glory? Drawing on a massive body of newly available data and employing novel approaches to evidence, Josiah Ober offers a major new history of classical Greece and an unprecedented account of its rise and fall. Ober argues that Greece\'s rise was no miracle but rather the result of political breakthroughs and economic development. The extraordinary emergence of citizen-centered city-states transformed Greece into a society that defeated the mighty Persian Empire. Yet Philip and Alexander of Macedon were able to beat the Greeks in the Battle of Chaeronea in 338 BCE, a victory enabled by the Macedonians\' appropriation of Greek innovations. After Alexander\'s death, battle-hardened warlords fought ruthlessly over the remnants of his empire. But Greek cities remained populous and wealthy, their economy and culture surviving to be passed on to the Romans--and to us. A compelling narrative filled with uncanny modern parallels, this is a book for anyone interested in how great civilizations are born and die. This book is based on evidence available on a new interactive website. To learn more, please visit: http://polis.stanford.edu/"--',
#   'ISBN': '978-0-691-14091-9 0-691-14091-X',
#   'language': 'English',
#   'author': [{'family': 'Ober', 'given': 'Josiah.'}],
#   'issued': {'date-parts': [[2015]]}},
#  '7109337/TGQ9TAPF': {'type': 'book',
#   'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#   'publisher': 'Farrar, Straus and Giroux',
#   'publisher-place': 'New York',
#   'event-place': 'New York',
#   'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#   'ISBN': '978-0-312-61169-9',
#   'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2010]]}},
#  '7109337/93X7WDDV': {'type': 'book',
#   'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'publisher': 'Princeton University Press',
#   'publisher-place': 'Princeton, NJ',
#   'edition': 'Course Book',
#   'event-place': 'Princeton, NJ',
#   'abstract': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#   'ISBN': '1-299-14683-X',
#   'note': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2013]]}},
#  '7109337/WZ6MD9YX': {'type': 'article-journal',
#   'title': 'Urbanism and the division of labour in the Roman Empire',
#   'container-title': 'Journal of The Royal Society Interface',
#   'page': '20170367',
#   'volume': '14',
#   'issue': '136',
#   'abstract': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#   'URL': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#   'DOI': '10.1098/rsif.2017.0367',
#   'journalAbbreviation': 'J. R. Soc. Interface.',
#   'language': 'en',
#   'author': [{'family': 'Hanson', 'given': 'J. W.'},
#    {'family': 'Ortman', 'given': 'S. G.'},
#    {'family': 'Lobo', 'given': 'J.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  '7109337/2ASLDCJP': {'type': 'article-journal',
#   'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#   'container-title': 'American Sociological Review',
#   'page': '596-626',
#   'volume': '83',
#   'issue': '3',
#   'abstract': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#   'URL': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#   'DOI': '10.1177/0003122418772567',
#   'journalAbbreviation': 'Am Sociol Rev',
#   'language': 'en',
#   'author': [{'family': 'Mullins', 'given': 'Daniel Austin'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Currie', 'given': 'Thomas'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Savage', 'given': 'Patrick E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'Turchin', 'given': 'Peter'}],
#   'issued': {'date-parts': [['2018']]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/FBAWXZ3I': {'type': 'book',
#   'title': 'Big Data, Little Data, No Data',
#   'publisher': 'The MIT Press',
#   'archive': 'JSTOR',
#   'abstract': '"Big Data" is on the covers of<em>Science, Nature</em>, the<em>Economist</em>, and<em>Wired</em>magazines, on the front pages of the<em>Wall Street Journal</em>and the<em>New York Times.</em>But despite the media hyperbole, as Christine Borgman points out in this examination of data and scholarly research, having the right data is usually better than having more data; little data can be just as valuable as big data. In many cases, there are no data -- because relevant data don\'t exist, cannot be found, or are not available. Moreover, data sharing is difficult, incentives to do so are minimal, and data practices vary widely across disciplines.Borgman, an often-cited authority on scholarly communication, argues that data have no value or meaning in isolation; they exist within a knowledge infrastructure -- an ecology of people, practices, technologies, institutions, material objects, and relationships. After laying out the premises of her investigation -- six "provocations" meant to inspire discussion about the uses of data in scholarship -- Borgman offers case studies of data practices in the sciences, the social sciences, and the humanities, and then considers the implications of her findings for scholarly practice and research policy. To manage and exploit data over the long term, Borgman argues, requires massive investment in knowledge infrastructures; at stake is the future of scholarship.',
#   'URL': 'http://www.jstor.org/stable/j.ctt17kk8n8',
#   'ISBN': '978-0-262-02856-1',
#   'author': [{'family': 'Borgman', 'given': 'Christine L.'}],
#   'issued': {'date-parts': [[2015]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/EYTI8IQA': {'type': 'chapter',
#   'title': 'EPIGRAPHY IN 2017',
#   'container-title': 'Changing the Center of Gravity',
#   'publisher': 'Gorgias Press',
#   'page': '203-222',
#   'URL': 'https://www.degruyter.com/document/doi/10.31826/9781463219222-012/html',
#   'ISBN': '978-1-4632-1922-2',
#   'note': 'DOI: 10.31826/9781463219222-012',
#   'editor': [{'family': 'Terras', 'given': 'Melissa'},
#    {'family': 'Crane', 'given': 'Gregory'}],
#   'author': [{'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Roueché', 'given': 'Charlotte'},
#    {'family': 'Elliott', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2010, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/QSJYQVZZ': {'type': 'book',
#   'title': 'The roads of Roman Italy: mobility and cultural change',
#   'publisher': 'Routledge',
#   'publisher-place': 'London; New York',
#   'archive': '/z-wcorg/',
#   'event-place': 'London; New York',
#   'abstract': '"The Roads of Roman Italy offers a complete re-evaluation of both the evidence for, and the interpretation of, Roman land transport. The book utilises archaeological, epigraphic and literary evidence for Roman communications, drawing on recent approaches to the human landscape developed by geographers. Among the topics considered are the relationship between the road and the human landscape, the administration and maintenance of the road system, the role of roads as imperial monuments, and the economics of road construction and urban development."--Jacket.',
#   'ISBN': '0-415-16616-0 978-0-415-16616-4',
#   'language': 'English',
#   'author': [{'family': 'Laurence', 'given': 'Ray'}],
#   'issued': {'date-parts': [[1999]]}},
#  '7109337/KE9T4566': {'type': 'article-journal',
#   'title': "The Inscriptions of Aphrodisias as electronic publication: A user's perspective and a proposed paradigm",
#   'container-title': 'Digital Medievalist',
#   'volume': '4',
#   'abstract': 'This paper discusses the value of the electronic medium of\npublication for one project in particular, Inscriptions of Aphrodisias\n(2007), and uses this one example to extrapolate and illustrate a\nuse-case paradigm of electronic publication and its advantages for\nresearch, pedagogy, and dissemination. The categories used in this\nstudy are: accessibility, scale, media, hypertext, updates, and\niterative research and transparency. Not all of these categories\napply equally to any given publication, and the discussion focuses\nDM 4 (2008) The Inscriptions of Aphrodisias as electronic publi... http://www.digitalmedievalist.org/journal/4/bodard/\n1 of 17 6/29/10 1:29 PM\non those that are the most appropriate to a digital publication of\ntagged epigraphic texts and images.',
#   'language': 'eng',
#   'author': [{'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2008]]}},
#  '7109337/2KEXYJLP': {'type': 'article-journal',
#   'title': 'Modeling Epigraphy with an Ontology',
#   'abstract': 'This document is maintained by the Ontology Working Group of Epigraphy.info. (https://epigraphy-info.github.io/epigraphy-info/) Any request or contribution should be made via the Epigraphic Ontology Mailing List of the Epigraphic Ontology WG &lt;epont@googlegroups.com&gt; Contributors are listed alphabetically. Not all listed contributors have confirmed.',
#   'URL': 'https://zenodo.org/record/4639507',
#   'DOI': '10.5281/ZENODO.4639507',
#   'note': 'Publisher: Zenodo\nVersion Number: 0.1',
#   'author': [{'family': 'Bodard', 'given': ''},
#    {'family': 'Cayless', 'given': ''},
#    {'family': 'Cenati', 'given': ''},
#    {'family': 'Cooley', 'given': ''},
#    {'family': 'Elliott', 'given': ''},
#    {'family': 'Evangelisti', 'given': ''},
#    {'family': 'Felicetti', 'given': ''},
#    {'family': 'Granados', 'given': ''},
#    {'family': 'Grieshaber', 'given': ''},
#    {'family': 'Gruber', 'given': ''},
#    {'family': 'Hershkowitz', 'given': ''},
#    {'family': 'Hill', 'given': ''},
#    {'family': 'Kiiskinen', 'given': ''},
#    {'family': 'Kollatz', 'given': ''},
#    {'family': 'Levivier', 'given': ''},
#    {'family': 'Liuzzo', 'given': ''},
#    {'family': 'Luciani', 'given': ''},
#    {'family': 'Mannocci', 'given': ''},
#    {'family': 'Mataix', 'given': ''},
#    {'family': 'Murano', 'given': ''},
#    {'family': 'Murphy', 'given': ''},
#    {'family': 'Mylonas', 'given': ''},
#    {'family': 'Prag', 'given': ''},
#    {'family': 'Razanajao', 'given': ''},
#    {'family': 'Stoyanova', 'given': ''},
#    {'family': 'Tsolakis', 'given': ''},
#    {'family': 'Tupman', 'given': ''},
#    {'family': 'Vagionakis', 'given': ''},
#    {'family': 'Vitale', 'given': ''},
#    {'family': 'Weise', 'given': ''}],
#   'issued': {'date-parts': [[2021, 3, 26]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/7EHKTWQD': {'type': 'chapter',
#   'title': 'Encoding, Interoperability, Lexicography: Digital Epigraphy Through the Lens of DASI Experience',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '1-18',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-002',
#   'shortTitle': '1 Encoding, Interoperability, Lexicography',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Avanzini', 'given': 'Alessandra'},
#    {'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/TKXWFLYN': {'type': 'chapter',
#   'title': 'EAGLE Continued: IDEA. The International Digital Epigraphy Association',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '216-230',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-018',
#   'shortTitle': '17 EAGLE Continued',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Liuzzo', 'given': 'Pietro M.'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/75PC3E2A': {'type': 'book',
#   'title': 'Migration and Mobility in the Early Roman Empire',
#   'publisher': 'BRILL',
#   'URL': 'https://brill.com/view/title/31880',
#   'ISBN': '978-90-04-30736-0 978-90-04-30737-7',
#   'note': 'DOI: 10.1163/9789004307377',
#   'author': [{'family': 'de Ligt', 'given': 'Luuk'},
#    {'family': 'Tacoma', 'given': 'Laurens Ernst'}],
#   'issued': {'date-parts': [[2016, 1, 19]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/SVYA23ZT': {'type': 'article-journal',
#   'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#   'container-title': 'The Journal of Economic History',
#   'page': '803-839',
#   'volume': '76',
#   'issue': '3',
#   'abstract': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0022050716000826/type/journal_article',
#   'DOI': '10.1017/S0022050716000826',
#   'shortTitle': 'People, Plagues, and Prices in the Roman World',
#   'journalAbbreviation': 'J. Econ. Hist.',
#   'language': 'en',
#   'author': [{'family': 'Harper', 'given': 'Kyle'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '7109337/D2YZ7HDA': {'type': 'article-journal',
#   'title': 'Galen and the Antonine Plague',
#   'container-title': 'The American Journal of Philology',
#   'page': '243–255',
#   'volume': '94',
#   'issue': '3',
#   'URL': 'http://www.jstor.org/stable/293979',
#   'note': 'Publisher: Johns Hopkins University Press',
#   'author': [{'family': 'Littman', 'given': 'R. J.'},
#    {'family': 'Littman', 'given': 'M. L.'}],
#   'issued': {'date-parts': [[1973]]}},
#  '7109337/BG7SH7C4': {'type': 'chapter',
#   'title': 'Modelling the Dynamics of Demography in the Dutch Roman Limes Zone: A Revised Model',
#   'container-title': 'Finding the Limits of the Limes: Modelling Demography, Economy and Transport on the Edge of the Roman Empire',
#   'publisher': 'Springer International Publishing',
#   'publisher-place': 'Cham',
#   'page': '43–59',
#   'event-place': 'Cham',
#   'abstract': 'In this chapter, a simulation model for better understanding the population dynamics of the limes zone is presented, building on our earlier study on the possible effects of recruitment of soldiers for the Roman army (Verhagen et al., Modelling the dynamics of demography in the Dutch limes zone. In: Multi-, inter- and transdisciplinary research in landscape archaeology. Proceedings of LAC 2014 Conference, Rome, 19–20 September 2014. Vrije Universiteit Amsterdam, Amsterdam. https://doi.org/10.5463/lac.2014.62, 2016a). In this earlier study, a number of questions were raised concerning the realism of using estimates from historical demographical sources for understanding the population dynamics of the region. In the current paper, the available data sets, approaches and hypotheses regarding fertility and mortality in the Roman period are re-assessed, together with the available archaeological evidence on the population dynamics of the region. A revised model is then presented that allows for more refined experimenting with various demographic scenarios, showing that a much larger number of parameters can be responsible for changes in population growth than is often assumed in archaeological studies. In particular, marriage strategies would seem to play an important role in regulating the number of births. The model remains a work in progress that can be further refined and linked to models of settlement and land use development.',
#   'URL': 'https://doi.org/10.1007/978-3-030-04576-0_3',
#   'ISBN': '978-3-030-04576-0',
#   'note': 'DOI: 10.1007/978-3-030-04576-0_3',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'}],
#   'editor': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Joyce', 'given': 'Jamie'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'}],
#   'issued': {'date-parts': [[2019]]}},
#  '7109337/NKKHMIDW': {'type': 'book',
#   'title': 'Crossing Experiences in Digital Epigraphy: From Practice to Discipline',
#   'publisher': 'De Gruyter',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208',
#   'shortTitle': 'Crossing Experiences in Digital Epigraphy',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/L73K2ZRY': {'type': 'book',
#   'title': 'Urban Craftsmen and Traders in the Roman World',
#   'publisher': 'Oxford University Press',
#   'URL': 'https://oxford.universitypressscholarship.com/view/10.1093/acprof:oso/9780198748489.001.0001/acprof-9780198748489',
#   'ISBN': '978-0-19-874848-9',
#   'note': 'DOI: 10.1093/acprof:oso/9780198748489.001.0001\nDOI: 10.1093/acprof:oso/9780198748489.001.0001',
#   'editor': [{'family': 'Wilson', 'given': 'Andrew'},
#    {'family': 'Flohr', 'given': 'Miko'}],
#   'issued': {'date-parts': [[2016, 1, 1]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '7109337/TISH84GY': {'type': 'chapter',
#   'title': 'The Limes',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '165-198',
#   'abstract': 'This chapter examines some important themes associated with research on the\n              limes\n              in Roman Germany, with particular emphasis on the ‘Upper German-Raetian\n              Limes\n              ’ and how the form and function of the outer frontiers of the Roman world were influenced by dynamic evolutionary processes. Before discussing how the\n              limes\n              took on a role as an ‘imperial/barbarian boundary’, the chapter considers the function of boundaries in general and the\n              limes\n              in particular. It then traces historic developments of the\n              limites\n              and their use in erecting frontier installations, watchtowers, and fortlets. It also looks at the crossing points through the\n              limes\n              that have survived in relatively high numbers in\n              Germania Superior\n              and\n              Raetia\n              ; the legions as the backbone of frontier defence; and auxiliary troops (\n              auxilia\n              ) that occupied the frontier along the Rhine in\n              Germania Inferior\n              and the Upper German-Raetian\n              Limes\n              during the second and third centuries AD.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-7',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.7',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '7109337/ZESEJVF2': {'type': 'chapter',
#   'title': 'Archaeology of Germania Inferior: Urbanization',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '91-115',
#   'abstract': 'This chapter focuses on the archaeology of the first urban settlements of Roman type found in\n              Germania Inferior\n              . It first describes\n              coloniae\n              such as the\n              Colonia Claudia Ara Agrippinensium\n              and\n              Colonia Ulpia Traiana\n              , along with the archaeological excavations carried out at the sites. It then turns to the vici, industrial settlements, and agricultural settlements, and concludes with a theoretical explanation of how various forms of urban centres arose in Lower Germany during the period between the Batavian revolt and the Gallic Empire.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-5',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.5',
#   'shortTitle': 'Archaeology of Germania Inferior',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '7109337/82J5J52N': {'type': 'book',
#   'title': 'Epigraphic Evidence: Ancient History from Inscriptions',
#   'collection-title': 'Approaching the ancient world',
#   'publisher': 'Routledge',
#   'URL': 'https://books.google.dk/books?id=Iz5GT7ZfxLsC',
#   'ISBN': '978-0-415-11623-7',
#   'note': 'LCCN: 00059202',
#   'author': [{'family': 'Bodel', 'given': 'J.P.'}],
#   'issued': {'date-parts': [[2001]]}},
#  '7109337/FLW2G53N': {'type': 'article-journal',
#   'title': "Now you see them, now you don't: Defining and using a flexible chronology of sites for spatial analysis of Roman settlement in the Dutch river area",
#   'container-title': 'Journal of Archaeological Science: Reports',
#   'page': '309-321',
#   'volume': '10',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S2352409X16303832',
#   'DOI': '10.1016/j.jasrep.2016.10.006',
#   'shortTitle': "Now you see them, now you don't",
#   'journalAbbreviation': 'Journal of Archaeological Science: Reports',
#   'language': 'en',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Vossen', 'given': 'Ivo'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'},
#    {'family': 'Joyce', 'given': 'Jamie'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '7109337/XLJYXMEV': {'type': 'chapter',
#   'title': 'Making up for Lost Time: Digital Epigraphy, Chronology, and the PeriodO Project',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '202-215',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-017',
#   'shortTitle': '16 Making up for Lost Time',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Rabinowitz', 'given': 'Adam'},
#    {'family': 'Shaw', 'given': 'Ryan'},
#    {'family': 'Golden', 'given': 'Patrick'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '7109337/T45AYTCM': {'type': 'book',
#   'title': 'EpiDoc Reference Stylesheets (version 9)',
#   'abstract': 'XSLT for transformation of EpiDoc XML files into HTML or text versions in Leiden. Includes various XML files containing parameters and other options.',
#   'URL': 'https://sourceforge.net/p/epidoc/wiki/Stylesheets/',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Au', 'given': 'Zaneta'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Lanz', 'given': 'Carmen'},
#    {'family': 'Lawrence', 'given': 'Faith'},
#    {'family': 'Vanderbilt', 'given': 'Scott'},
#    {'family': 'Viglianti', 'given': 'Raffaele'}],
#   'issued': {'date-parts': [[2017]]}},
#  '7109337/EAY2DVSF': {'type': 'article-journal',
#   'title': 'Rezension zu: Epigraphische Datenbank Heidelberg',
#   'container-title': 'H-Soz-Kult',
#   'URL': 'https://www.hsozkult.de/webreview/id/rezwww-179',
#   'language': 'ger',
#   'author': [{'family': 'Hartmann', 'given': 'Andreas'}],
#   'issued': {'date-parts': [[2018, 10, 13]]}},
#  '7109337/YW3AIT6K': {'type': 'article-journal',
#   'title': 'Medieval Commercial Sites: As Seen Through Portable Antiquities Scheme Data',
#   'container-title': 'The Antiquaries Journal',
#   'page': '109-140',
#   'volume': '100',
#   'abstract': 'This paper explores some 220,000 medieval objects recorded in the Portable Antiquities Scheme (PAS) online database of archaeological small finds through Geographic Information System analysis of their relationship with contemporary market sites. First, an overview of the contents of the PAS database is presented in terms of its spatial and ‘object type’ distribution. Second, the relationship of the medieval finds data against documentary evidence of commercial activity is investigated at a national level. Finally, PAS data is contextualised in its historical landscape context through case studies. It is argued that the distribution of PAS finds on the national scale can be linked with patterns of commercial activity, and that while rural and urban finds scatters have distinguishing trends, the countryside population enjoyed access to a range of sophisticated metalwork culture; also, that certain assemblages can be analysed statistically to yield new data and perspectives on local historical development.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0003581520000165/type/journal_article',
#   'DOI': '10.1017/S0003581520000165',
#   'shortTitle': 'MEDIEVAL COMMERCIAL SITES',
#   'journalAbbreviation': 'Antiq. J.',
#   'language': 'en',
#   'author': [{'family': 'Oksanen', 'given': 'Eljas'},
#    {'family': 'Lewis', 'given': 'Michael'}],
#   'issued': {'date-parts': [['2020']]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '7109337/IRUVQAYJ': {'type': 'article-journal',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'container-title': 'Hesperia',
#   'page': '387-439',
#   'volume': '68',
#   'issue': '3',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'DOI': '10.2307/148494',
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'issued': {'date-parts': [[1999]]},
#   'accessed': {'date-parts': [[2019, 11, 21]]}},
#  '7109337/BRZQ3MUL': {'type': 'chapter',
#   'title': 'City Sizes and Urbanization in the Roman Empire',
#   'container-title': 'Settlement, Urbanization and Population',
#   'collection-title': 'Oxford Studies in the Roman Economy',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'page': '161–195',
#   'event-place': 'Oxford - New York',
#   'ISBN': '0-19-960235-2',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2012]]}},
#  '7109337/YMB2QZ7K': {'type': 'webpage',
#   'title': 'Understanding Roman inscriptions',
#   'abstract': 'This is the first comprehensive treatment in English to provide an explanation of not only the language of inscriptions but also the context in which they were produced.',
#   'URL': 'http://site.ebrary.com/id/10062897',
#   'note': 'Archive: /z-wcorg/\nISBN: 0203084675 9780203084670 9780203707357 0203707354 9781134746125 1134746121 9781134746163 1134746164 9781134746170 1134746172 9781138142923 1138142921 9780415151436 0415151430 9786610539277 6610539278 1280539275 9781280539275\nLibrary Catalog: http://worldcat.org\nPlace: Baltimore\nPublisher: Johns Hopkins University Press',
#   'language': 'English.',
#   'author': [{'family': 'Keppie', 'given': 'L. J. F.'}],
#   'issued': {'date-parts': [[1991]]}},
#  '7109337/283Z83RT': {'type': 'article-journal',
#   'title': 'Roman Inscriptions 2001-2005',
#   'container-title': 'The Journal of Roman Studies',
#   'page': '176–263',
#   'volume': '97',
#   'URL': 'http://www.jstor.org/stable/20430576',
#   'note': 'Publisher: [Society for the Promotion of Roman Studies, Cambridge University Press]',
#   'author': [{'family': 'Cooley', 'given': 'Alison E.'},
#    {'family': 'Mitchell', 'given': 'Stephen'},
#    {'family': 'Salway', 'given': 'Benet'}],
#   'issued': {'date-parts': [[2007]]}},
#  '7109337/QS4C5IAS': {'type': 'book',
#   'title': 'Quantifying the Roman Economy: Methods and Problems',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'event-place': 'Oxford - New York',
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2009]]}},
#  '7109337/3L9BKAXW': {'type': 'article-journal',
#   'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'page': 'E144-E151',
#   'volume': '115',
#   'issue': '2',
#   'abstract': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#   'DOI': '10.1073/pnas.1708800115',
#   'note': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
# ...
#  '7109337/JAXUAMNH': {'type': 'chapter',
#   'title': 'Epigraphy by numbers: Latin and the epigraphic culture in Sicily',
#   'container-title': 'Becoming Roman, writing Latin? Literacy and Epigraphy in the Roman West',
#   'publisher': 'Journal of Roman Archaeology',
#   'publisher-place': 'Portsmouth, Rhode Island',
#   'page': '15–31',
#   'event-place': 'Portsmouth, Rhode Island',
#   'author': [{'family': 'Prag', 'given': 'Jonathan'}],
#   'editor': [{'family': 'Cooley', 'given': 'Alison E.'}],
#   'issued': {'date-parts': [[2002]]}},
#  '7109337/TWB9XHFH': {'type': 'chapter',
#   'title': 'Christian and Late Antique Epigraphies',
#   'container-title': 'The Epigraphic Cultures of Late Antiquity',
#   'publisher': 'Franz Steiner Verlag',
#   'page': '503–514',
#   'ISBN': '978-3-515-11558-2',
#   'language': 'English',
#   'author': [{'family': 'Roueche', 'given': 'Charlotte Mary'},
#    {'family': 'Sotinel', 'given': 'Claire'}],
#   'editor': [{'family': 'Bolle', 'given': 'Katharina'},
#    {'family': 'Machado', 'given': 'Carlos'},
#    {'family': 'Witschel', 'given': 'Christian'}],
#   'issued': {'date-parts': [['2017', 3]]}},
#  '7109337/WLLWUZT7': {'type': 'article-journal',
#   'title': 'The Roman Brick-Stamps not Published in Volume XV 1 of the "Corpus Inscriptionum Latinarum"',
#   'container-title': 'Harvard Studies in Classical Philology',
#   'page': '1',
#   'volume': '56',
#   'URL': 'https://www.jstor.org/stable/310746?origin=crossref',
#   'DOI': '10.2307/310746',
#   'journalAbbreviation': 'Harvard Studies in Classical Philology',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1947]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '7109337/JCIXA2RJ': {'type': 'book',
#   'title': 'The Roman brick stamps not published in Vol. XI, 1 of the Corpus inscriptionum Latinarum, including Indices to the Roman brick-stamps.',
#   'publisher': '"L\'Erma" di Bretschneider',
#   'publisher-place': 'Roma',
#   'edition': 'Ed. anastat.',
#   'event-place': 'Roma',
#   'language': 'ita',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1967]]}},
#  '7109337/9J244TYE': {'type': 'book',
#   'title': 'EpiDoc Guidelines: Ancient documents in TEI XML',
#   'URL': 'https://epidoc.stoa.org/gl/latest/',
#   'language': 'eng',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Mylonas', 'given': 'Elli'},
#    {'family': 'Stoyanova', 'given': 'Simona'},
#    {'family': 'Tupman', 'given': 'Charlotte'},
#    {'family': 'Vanderbilt', 'given': 'Scott'}],
#   'issued': {'date-parts': [[2020]]}},
#  '7109337/EBFQEFW3': {'type': 'book',
#   'title': 'Conventions in editing : A suggested reformulation of the Leiden system.',
#   'collection-title': 'Greek, Roman and Byzantine scholarly Aids ; No. 2.',
#   'publisher': 'Duke University',
#   'publisher-place': 'Durham',
#   'event-place': 'Durham',
#   'language': 'eng',
#   'author': [{'family': 'Dow', 'given': 'Sterling'}],
#   'issued': {'date-parts': [[1969]]}},
#  '7109337/TXCY5XL8': {'type': 'book',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'publisher': 'Routledge',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'ISBN': '978-1-00-302530-6',
#   'note': 'DOI: 10.4324/9781003025306',
#   'language': 'en',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/AU6JTRIU': {'type': 'article-journal',
#   'title': 'Explaining the Epigraphic Habit in the Roman Empire: The Evidence of Epitaphs',
#   'container-title': 'Journal of Roman Studies',
#   'page': '74–96',
#   'volume': '80',
#   'abstract': "It is now notorious that the production of inscriptions in the Roman Empire was not constant over time, but rose over the first and second centuries A.D. and fell in the third. Ramsay MacMullen pointed this out more than five years ago, with conclusions more cautionary than explanatory: ‘history is not being written in the right way', he said, for historians have deduced Rome's decline from evidence that–since it appears only epigraphically–has merely disappeared for its own reasons, or have sought general explanations of decline in theories political, economic, or even demographic in nature, none of which can, in turn, explain the disappearance of epigraphy itself. Why this epigraphic habit rose and fell MacMullen left open to question, although he did postulate control by a ‘sense of audience'. The purpose of this paper is to propose that this ‘sense of audience' was not generalized or generic, but depended on a belief in the value of romanization, of which (as noted but not explained by MacMullen's article) the epigraphic habit is also a rough indicator. Epitaphs constitute the bulk of all provincial inscriptions and in form and number are (generally speaking) the consequence of a provincial imitation of characteristically Roman practices, an imitation that depended on the belief that Roman legal status and style were important, and that may indeed have ultimately depended, at least in North Africa, on the acquisition or prior possession of that status. Such status-based motivations for erecting an epitaph help to explain not only the chronological distribution of epitaphs but also the differences in the type and distribution of epitaphs in the western and eastern halves of the empire. They will be used here moreover to suggest an explanation for the epigraphic habit as a whole.",
#   'DOI': '10.2307/300281',
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'issued': {'date-parts': [[1990]]}},
#  '7109337/5W97HIK9': {'type': 'chapter',
#   'title': 'Epigraphy and Digital Resources',
#   'container-title': 'The Oxford Handbook of Roman Epigraphy',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford and New York',
#   'page': '78–85',
#   'event-place': 'Oxford and New York',
#   'author': [{'family': 'Elliot', 'given': 'Tom'}],
#   'editor': [{'family': 'Bruun', 'given': 'Christer'},
#    {'family': 'Edmondson', 'given': 'Jonathan'}],
#   'issued': {'date-parts': [[2015]]}},
#  '7109337/VDS8KTIA': {'type': 'book',
#   'title': 'Epigraphic evidence: ancient history from inscriptions',
#   'collection-number': '4',
#   'publisher': 'Routledge',
#   'publisher-place': 'London, New York',
#   'volume': '61',
#   'number-of-pages': '1019–1020',
#   'event-place': 'London, New York',
#   'abstract': 'Epigraphic Evidence is an accessible guide to the responsible use of Greek and Latin inscriptions as sources for ancient history. It introduces the types of historical information supplied by inscriptional texts and the methods with which they can be used. It outlines the limitations as well as the advantages of the different types of evidence covered. Epigraphic Evidence includes a general introduction, a guide to the arrangement of the standard corpora inscriptions and individual chapters on local languages and native cultures, epitaphs and the ancient economy amongst others.',
#   'note': 'ISSN: 0023-8856\nPublication Title: Latomus',
#   'author': [{'family': 'Duthoy', 'given': 'Robert'}],
#   'issued': {'date-parts': [[2002]]}},
#  '7109337/SBV9XF6H': {'type': 'book',
#   'title': 'An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan',
#   'publisher': 'The University of Michigan Press',
#   'publisher-place': 'Ann Arbor',
#   'event-place': 'Ann Arbor',
#   'note': 'Publication Title: An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan\nDOI: 10.3998/mpub.23012',
#   'author': [{'family': 'McLean', 'given': 'Bradley'}],
#   'issued': {'date-parts': [[2016]]}},
#  '7109337/C5QVR3SE': {'type': 'article-journal',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'container-title': 'The American Journal of Philology',
#   'page': '233',
#   'volume': '103',
#   'issue': '3',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'DOI': '10.2307/294470',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'issued': {'date-parts': [[1982]]}},
#  '7109337/A6W7Q3HZ': {'type': 'article-journal',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'container-title': 'Journal of Roman Studies',
#   'page': '22–39',
#   'volume': '86',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'DOI': '10.2307/300421',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'issued': {'date-parts': [[1996]]}},
#  '7109337/YWIASGX4': {'type': 'article-journal',
#   'title': 'Epigraphic Database Heidelberg – Data Reuse Options',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/26599',
#   'DOI': '10.11588/HEIDOK.00026599',
#   'note': 'Publisher: Heidelberg University Library',
#   'author': [{'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2019]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/MGBT6ZCX': {'type': 'article-journal',
#   'title': 'Digital Epigraphy am Scheideweg? / Digital Epigraphy at a crossroads?',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/22141',
#   'DOI': '10.11588/HEIDOK.00022141',
#   'note': 'Publisher: Heidelberg University Library',
#   'shortTitle': 'Digital Epigraphy am Scheideweg?',
#   'author': [{'family': 'Feraudi-Gruénais', 'given': 'Francisca'},
#    {'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2016]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/2WIJQZDC': {'type': 'book',
#   'title': 'The Epigraphic Cultures of Late Antiquity',
#   'collection-title': 'Alte Geschichte',
#   'publisher': 'Franz Steiner Verlag',
#   'URL': 'https://books.google.dk/books?id=iJBdMQAACAAJ',
#   'ISBN': '978-3-515-11558-2',
#   'author': [{'family': 'Bolle', 'given': 'K.'},
#    {'family': 'Machado', 'given': 'C.'},
#    {'family': 'Witschel', 'given': 'C.'}],
#   'issued': {'date-parts': [[2017]]}},
#  '7109337/N8YT927J': {'type': 'chapter',
#   'title': 'The “Epigraphic Habit” in the Roman World',
#   'container-title': 'The Oxford Handbook of Roman Epigraphy',
#   'collection-title': 'Oxford Handbooks',
#   'publisher': 'Oxford University Press',
#   'volume': '1',
#   'abstract': 'Since the 1980s scholars have ceased considering Roman inscriptions simply in functional terms—as sources of historical information—and started to treat them as a cultural phenomenon worthy of serious consideration. This change in perspective, as well as the realization that there was a permanent bond between text and monument, represents the most productive shift in approach in recent epigraphic scholarship. This chapter analyzes the “epigraphic habit” in order to explain why people wrote on stone throughout Italy and the provinces, linking its rise to the proliferation of urbanization, literacy, and the desire for self-representation.',
#   'ISBN': '0-19-533646-1',
#   'language': 'eng',
#   'author': [{'family': 'Beltrán Lloris', 'given': 'Francisco'}],
#   'issued': {'date-parts': [[2014]]}},
#  '7109337/KBJ7VEJ8': {'type': 'article-journal',
#   'title': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy: The End of a Habit?',
#   'container-title': 'Historia',
#   'page': '116-132',
#   'volume': '70',
#   'issue': '1',
#   'abstract': '<p>The political communities of western Asia Minor produced an enormous amount of inscriptions under Roman rule. For the period between AD 260 and 280, however, the epigraphic habit falls dramatically and this situation largely continues in the 4<sup>th</sup> and 5<sup>th</sup> centuries. The aim of this paper is to analyse the phenomenon in the transitional Tetrarchic age, when a notable increase in testimony, particularly milestones and texts related to the new regime (e. g. ‘Edict of Prices’), can be observed. My study of continuities and changes concludes that the propagandistic efforts under the Tetrarchs did not ultimately coincide with a full reactivation of civic epigraphic culture and this new scenario should remain fundamental for our assessment of Late Antiquity in the region.</p>',
#   'URL': 'https://elibrary.steiner-verlag.de/article/10.25162/historia-2021-0006',
#   'DOI': '10.25162/historia-2021-0006',
#   'shortTitle': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy',
#   'journalAbbreviation': 'historia',
#   'language': 'en',
#   'author': [{'family': 'Pérez', 'given': 'Aitor Blanco'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/RAG327R6': {'type': 'chapter',
#   'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#   'container-title': 'A Companion to Late Antiquity',
#   'publisher': 'John Wiley & Sons, Ltd',
#   'page': '170-186',
#   'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#   'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#   'ISBN': '978-1-4443-0610-1',
#   'note': 'DOI: 10.1002/9781444306101.ch12',
#   'shortTitle': 'Inscribing Identity',
#   'language': 'en',
#   'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}}}

# %%
test_paragraph = "Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139)."
citations_used = {}
for key in citation_keys_pairs.keys():
    if key in test_paragraph:
        print(key)
        citations_used[citation_keys_pairs[key]] = citations[citation_keys_pairs[key]]
        test_paragraph = test_paragraph.replace(key, '<cite data-cite="' + citation_keys_pairs[key] + '"></cite>')
# Out:
# Hedrick 1999
# Nawotka 2021
# Meyer 1990
# MacMullen 1982
# Woolf 1996
# Trout 2009

# %%
citations_used
# Out:
# {'7109337/IRUVQAYJ': {'type': 'article-journal',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'container-title': 'Hesperia',
#   'page': '387-439',
#   'volume': '68',
#   'issue': '3',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'DOI': '10.2307/148494',
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'issued': {'date-parts': [[1999]]},
#   'accessed': {'date-parts': [[2019, 11, 21]]}},
#  '7109337/TXCY5XL8': {'type': 'book',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'publisher': 'Routledge',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'ISBN': '978-1-00-302530-6',
#   'note': 'DOI: 10.4324/9781003025306',
#   'language': 'en',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '7109337/AU6JTRIU': {'type': 'article-journal',
#   'title': 'Explaining the Epigraphic Habit in the Roman Empire: The Evidence of Epitaphs',
#   'container-title': 'Journal of Roman Studies',
#   'page': '74–96',
#   'volume': '80',
#   'abstract': "It is now notorious that the production of inscriptions in the Roman Empire was not constant over time, but rose over the first and second centuries A.D. and fell in the third. Ramsay MacMullen pointed this out more than five years ago, with conclusions more cautionary than explanatory: ‘history is not being written in the right way', he said, for historians have deduced Rome's decline from evidence that–since it appears only epigraphically–has merely disappeared for its own reasons, or have sought general explanations of decline in theories political, economic, or even demographic in nature, none of which can, in turn, explain the disappearance of epigraphy itself. Why this epigraphic habit rose and fell MacMullen left open to question, although he did postulate control by a ‘sense of audience'. The purpose of this paper is to propose that this ‘sense of audience' was not generalized or generic, but depended on a belief in the value of romanization, of which (as noted but not explained by MacMullen's article) the epigraphic habit is also a rough indicator. Epitaphs constitute the bulk of all provincial inscriptions and in form and number are (generally speaking) the consequence of a provincial imitation of characteristically Roman practices, an imitation that depended on the belief that Roman legal status and style were important, and that may indeed have ultimately depended, at least in North Africa, on the acquisition or prior possession of that status. Such status-based motivations for erecting an epitaph help to explain not only the chronological distribution of epitaphs but also the differences in the type and distribution of epitaphs in the western and eastern halves of the empire. They will be used here moreover to suggest an explanation for the epigraphic habit as a whole.",
#   'DOI': '10.2307/300281',
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'issued': {'date-parts': [[1990]]}},
#  '7109337/C5QVR3SE': {'type': 'article-journal',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'container-title': 'The American Journal of Philology',
#   'page': '233',
#   'volume': '103',
#   'issue': '3',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'DOI': '10.2307/294470',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'issued': {'date-parts': [[1982]]}},
#  '7109337/A6W7Q3HZ': {'type': 'article-journal',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'container-title': 'Journal of Roman Studies',
#   'page': '22–39',
#   'volume': '86',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'DOI': '10.2307/300421',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'issued': {'date-parts': [[1996]]}},
#  '7109337/RAG327R6': {'type': 'chapter',
#   'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#   'container-title': 'A Companion to Late Antiquity',
#   'publisher': 'John Wiley & Sons, Ltd',
#   'page': '170-186',
#   'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#   'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#   'ISBN': '978-1-4443-0610-1',
#   'note': 'DOI: 10.1002/9781444306101.ch12',
#   'shortTitle': 'Inscribing Identity',
#   'language': 'en',
#   'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}}}

# %%
test_paragraph
# Out:
# 'Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (<cite data-cite="7109337/C5QVR3SE"></cite>; Meyer 1991; <cite data-cite="7109337/A6W7Q3HZ"></cite>). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (<cite data-cite="7109337/AU6JTRIU"></cite>, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., <cite data-cite="7109337/IRUVQAYJ"></cite>; <cite data-cite="7109337/RAG327R6"></cite>; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; <cite data-cite="7109337/TXCY5XL8"></cite>; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).'

# %% [markdown]
# Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (<cite data-cite="1913534/BGNB6HUT"></cite>; Meyer 1991; <cite data-cite="1913534/HBPZKHXT"></cite>). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (<cite data-cite="1913534/MUKI9YSZ"></cite>, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., <cite data-cite="1913534/2LT8WIGC"></cite>; <cite data-cite="1913534/F3Y2FVVY"></cite>; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; <cite data-cite="1913534/NEGLBLPH"></cite>; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).

# %%
import json

# %%
notebook_dict = json.loads(notebook_text)
notebook_dict["metadata"]["cite2c"]["citations"]
# Out:
# {'7109337/2ASLDCJP': {'DOI': '10.1177/0003122418772567',
#   'URL': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#   'abstract': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#   'accessed': {'day': 17, 'month': 5, 'year': 2021},
#   'author': [{'family': 'Mullins', 'given': 'Daniel Austin'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Currie', 'given': 'Thomas'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Savage', 'given': 'Patrick E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'Turchin', 'given': 'Peter'}],
#   'container-title': 'American Sociological Review',
#   'container-title-short': 'Am Sociol Rev',
#   'id': '7109337/2ASLDCJP',
#   'issue': '3',
#   'issued': {'year': 2018},
#   'journalAbbreviation': 'Am Sociol Rev',
#   'language': 'en',
#   'page': '596-626',
#   'page-first': '596',
#   'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#   'type': 'article-journal',
#   'volume': '83'},
#  '7109337/3L9BKAXW': {'DOI': '10.1073/pnas.1708800115',
#   'abstract': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Currie', 'given': 'Thomas E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'Mullins', 'given': 'Daniel'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Grohmann', 'given': 'Stephanie'},
#    {'family': 'Savage', 'given': 'Patrick'},
#    {'family': 'Mendel-Gleason', 'given': 'Gavin'},
#    {'family': 'Turner', 'given': 'Edward'},
#    {'family': 'Dupeyron', 'given': 'Agathe'},
#    {'family': 'Cioni', 'given': 'Enrico'},
#    {'family': 'Reddish', 'given': 'Jenny'},
#    {'family': 'Levine', 'given': 'Jill'},
#    {'family': 'Jordan', 'given': 'Greine'},
#    {'family': 'Brandl', 'given': 'Eva'},
#    {'family': 'Williams', 'given': 'Alice'},
#    {'family': 'Cesaretti', 'given': 'Rudolf'},
#    {'family': 'Krueger', 'given': 'Marta'},
#    {'family': 'Ceccarelli', 'given': 'Alessandro'},
#    {'family': 'Figliulo-Rosswurm', 'given': 'Joe'},
#    {'family': 'Tuan', 'given': 'Po-Ju'},
#    {'family': 'Peregrine', 'given': 'Peter'},
#    {'family': 'Marciniak', 'given': 'Arkadiusz'},
#    {'family': 'Preiser-Kapeller', 'given': 'Johannes'},
#    {'family': 'Kradin', 'given': 'Nikolay'},
#    {'family': 'Korotayev', 'given': 'Andrey'},
#    {'family': 'Palmisano', 'given': 'Alessio'},
#    {'family': 'Baker', 'given': 'David'},
#    {'family': 'Bidmead', 'given': 'Julye'},
#    {'family': 'Bol', 'given': 'Peter'},
#    {'family': 'Christian', 'given': 'David'},
#    {'family': 'Cook', 'given': 'Connie'},
#    {'family': 'Covey', 'given': 'Alan'},
#    {'family': 'Feinman', 'given': 'Gary'},
#    {'family': 'Júlíusson', 'given': 'Árni Daníel'},
#    {'family': 'Kristinsson', 'given': 'Axel'},
#    {'family': 'Miksic', 'given': 'John'},
#    {'family': 'Mostern', 'given': 'Ruth'},
#    {'family': 'Petrie', 'given': 'Cameron'},
#    {'family': 'Rudiak-Gould', 'given': 'Peter'},
#    {'family': 'ter Haar', 'given': 'Barend'},
#    {'family': 'Wallace', 'given': 'Vesna'},
#    {'family': 'Mair', 'given': 'Victor'},
#    {'family': 'Xie', 'given': 'Liye'},
#    {'family': 'Baines', 'given': 'John'},
#    {'family': 'Bridges', 'given': 'Elizabeth'},
#    {'family': 'Manning', 'given': 'Joseph'},
#    {'family': 'Lockhart', 'given': 'Bruce'},
#    {'family': 'Bogaard', 'given': 'Amy'},
#    {'family': 'Spencer', 'given': 'Charles'}],
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'id': '7109337/3L9BKAXW',
#   'issue': '2',
#   'issued': {'year': 2018},
#   'note': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#   'page': 'E144-E151',
#   'page-first': 'E144',
#   'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#   'type': 'article-journal',
#   'volume': '115'},
#  '7109337/75PC3E2A': {'ISBN': '978-90-04-30736-0 978-90-04-30737-7',
#   'URL': 'https://brill.com/view/title/31880',
#   'accessed': {'day': 17, 'month': 5, 'year': 2021},
#   'author': [{'family': 'de Ligt', 'given': 'Luuk'},
#    {'family': 'Tacoma', 'given': 'Laurens Ernst'}],
#   'id': '7109337/75PC3E2A',
#   'issued': {'day': 19, 'month': 1, 'year': 2016},
#   'note': 'DOI: 10.1163/9789004307377',
#   'publisher': 'BRILL',
#   'title': 'Migration and Mobility in the Early Roman Empire',
#   'type': 'book'},
#  '7109337/93X7WDDV': {'ISBN': '1-299-14683-X',
#   'abstract': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'edition': 'Course Book',
#   'event-place': 'Princeton, NJ',
#   'id': '7109337/93X7WDDV',
#   'issued': {'year': 2013},
#   'language': 'eng',
#   'note': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'publisher': 'Princeton University Press',
#   'publisher-place': 'Princeton, NJ',
#   'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'type': 'book'},
#  '7109337/A6W7Q3HZ': {'DOI': '10.2307/300421',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'container-title': 'Journal of Roman Studies',
#   'id': '7109337/A6W7Q3HZ',
#   'issued': {'year': 1996},
#   'page': '22–39',
#   'page-first': '22',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'type': 'article-journal',
#   'volume': '86'},
#  '7109337/AU6JTRIU': {'DOI': '10.2307/300281',
#   'abstract': "It is now notorious that the production of inscriptions in the Roman Empire was not constant over time, but rose over the first and second centuries A.D. and fell in the third. Ramsay MacMullen pointed this out more than five years ago, with conclusions more cautionary than explanatory: ‘history is not being written in the right way', he said, for historians have deduced Rome's decline from evidence that–since it appears only epigraphically–has merely disappeared for its own reasons, or have sought general explanations of decline in theories political, economic, or even demographic in nature, none of which can, in turn, explain the disappearance of epigraphy itself. Why this epigraphic habit rose and fell MacMullen left open to question, although he did postulate control by a ‘sense of audience'. The purpose of this paper is to propose that this ‘sense of audience' was not generalized or generic, but depended on a belief in the value of romanization, of which (as noted but not explained by MacMullen's article) the epigraphic habit is also a rough indicator. Epitaphs constitute the bulk of all provincial inscriptions and in form and number are (generally speaking) the consequence of a provincial imitation of characteristically Roman practices, an imitation that depended on the belief that Roman legal status and style were important, and that may indeed have ultimately depended, at least in North Africa, on the acquisition or prior possession of that status. Such status-based motivations for erecting an epitaph help to explain not only the chronological distribution of epitaphs but also the differences in the type and distribution of epitaphs in the western and eastern halves of the empire. They will be used here moreover to suggest an explanation for the epigraphic habit as a whole.",
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'container-title': 'Journal of Roman Studies',
#   'id': '7109337/AU6JTRIU',
#   'issued': {'year': 1990},
#   'page': '74–96',
#   'page-first': '74',
#   'title': 'Explaining the Epigraphic Habit in the Roman Empire: The Evidence of Epitaphs',
#   'type': 'article-journal',
#   'volume': '80'},
#  '7109337/BRZQ3MUL': {'ISBN': '0-19-960235-2',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'collection-title': 'Oxford Studies in the Roman Economy',
#   'container-title': 'Settlement, Urbanization and Population',
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'event-place': 'Oxford - New York',
#   'id': '7109337/BRZQ3MUL',
#   'issued': {'year': 2012},
#   'page': '161–195',
#   'page-first': '161',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'title': 'City Sizes and Urbanization in the Roman Empire',
#   'type': 'chapter'},
#  '7109337/C5QVR3SE': {'DOI': '10.2307/294470',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'container-title': 'The American Journal of Philology',
#   'id': '7109337/C5QVR3SE',
#   'issue': '3',
#   'issued': {'year': 1982},
#   'page': '233',
#   'page-first': '233',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'type': 'article-journal',
#   'volume': '103'},
#  '7109337/IRUVQAYJ': {'DOI': '10.2307/148494',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'accessed': {'day': 21, 'month': 11, 'year': 2019},
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'container-title': 'Hesperia',
#   'container-title-short': 'Hesperia',
#   'id': '7109337/IRUVQAYJ',
#   'issue': '3',
#   'issued': {'year': 1999},
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'page': '387-439',
#   'page-first': '387',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'type': 'article-journal',
#   'volume': '68'},
#  '7109337/L73K2ZRY': {'ISBN': '978-0-19-874848-9',
#   'URL': 'https://oxford.universitypressscholarship.com/view/10.1093/acprof:oso/9780198748489.001.0001/acprof-9780198748489',
#   'accessed': {'day': 17, 'month': 5, 'year': 2021},
#   'editor': [{'family': 'Wilson', 'given': 'Andrew'},
#    {'family': 'Flohr', 'given': 'Miko'}],
#   'id': '7109337/L73K2ZRY',
#   'issued': {'day': 1, 'month': 1, 'year': 2016},
#   'note': 'DOI: 10.1093/acprof:oso/9780198748489.001.0001\nDOI: 10.1093/acprof:oso/9780198748489.001.0001',
#   'publisher': 'Oxford University Press',
#   'title': 'Urban Craftsmen and Traders in the Roman World',
#   'type': 'book'},
#  '7109337/PE4PYNDX': {'DOI': '10.1073/pnas.0904576106',
#   'abstract': 'In times of violence, people tend to hide their valuables, which are later recovered unless the owners had been killed or driven away. Thus, the temporal distribution of unrecovered coin hoards is an excellent proxy for the intensity of internal warfare. We use this relationship to resolve a long-standing controversy in Roman history. Depending on who was counted in the early Imperial censuses (adult males or the entire citizenry including women and minors), the Roman citizen population of Italy either declined, or more than doubled, during the first century BCE. This period was characterized by a series of civil wars, and historical evidence indicates that high levels of sociopolitical instability are associated with demographic contractions. We fitted a simple model quantifying the effect of instability (proxied by hoard frequency) on population dynamics to the data before 100 BCE. The model predicts declining population after 100 BCE. This suggests that the vigorous growth scenario is highly implausible.',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Scheidel', 'given': 'Walter'}],
#   'container-title': 'Proceedings of the National Academy of Sciences of the United States of America',
#   'id': '7109337/PE4PYNDX',
#   'issued': {'year': 2009},
#   'note': 'PMID: 19805043',
#   'page': '17276–17279',
#   'page-first': '17276',
#   'title': 'Coin Hoards Speak of Population Declines in Ancient Rome',
#   'type': 'article-journal',
#   'volume': '106'},
#  '7109337/RB28J3CE': {'ISBN': '978-0-691-14091-9 0-691-14091-X',
#   'abstract': '"Lord Byron described Greece as great, fallen, and immortal, a characterization more apt than he knew. Through most of its long history, Greece was poor. But in the classical era, Greece was densely populated and highly urbanized. Many surprisingly healthy Greeks lived in remarkably big houses and worked for high wages at specialized occupations. Middle-class spending drove sustained economic growth. Classical wealth produced a stunning cultural efflorescence lasting hundreds of years. Why did Greece reach such heights in the classical period--and why only then? And how, after \'the Greek miracle\' had endured for centuries, did the Macedonians defeat the Greeks, seemingly bringing an end to their glory? Drawing on a massive body of newly available data and employing novel approaches to evidence, Josiah Ober offers a major new history of classical Greece and an unprecedented account of its rise and fall. Ober argues that Greece\'s rise was no miracle but rather the result of political breakthroughs and economic development. The extraordinary emergence of citizen-centered city-states transformed Greece into a society that defeated the mighty Persian Empire. Yet Philip and Alexander of Macedon were able to beat the Greeks in the Battle of Chaeronea in 338 BCE, a victory enabled by the Macedonians\' appropriation of Greek innovations. After Alexander\'s death, battle-hardened warlords fought ruthlessly over the remnants of his empire. But Greek cities remained populous and wealthy, their economy and culture surviving to be passed on to the Romans--and to us. A compelling narrative filled with uncanny modern parallels, this is a book for anyone interested in how great civilizations are born and die. This book is based on evidence available on a new interactive website. To learn more, please visit: http://polis.stanford.edu/"--',
#   'archive': '/z-wcorg/',
#   'author': [{'family': 'Ober', 'given': 'Josiah.'}],
#   'id': '7109337/RB28J3CE',
#   'issued': {'year': 2015},
#   'language': 'English',
#   'title': 'The rise and fall of classical Greece',
#   'type': 'book'},
#  '7109337/TGQ9TAPF': {'ISBN': '978-0-312-61169-9',
#   'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'event-place': 'New York',
#   'id': '7109337/TGQ9TAPF',
#   'issued': {'year': 2010},
#   'language': 'eng',
#   'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#   'publisher': 'Farrar, Straus and Giroux',
#   'publisher-place': 'New York',
#   'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#   'type': 'book'},
#  '7109337/TXCY5XL8': {'ISBN': '978-1-00-302530-6',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'accessed': {'day': 7, 'month': 5, 'year': 2021},
#   'edition': '1',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'id': '7109337/TXCY5XL8',
#   'issued': {'year': 2021},
#   'language': 'en',
#   'note': 'DOI: 10.4324/9781003025306',
#   'publisher': 'Routledge',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'type': 'book'},
#  '7109337/VDS8KTIA': {'abstract': 'Epigraphic Evidence is an accessible guide to the responsible use of Greek and Latin inscriptions as sources for ancient history. It introduces the types of historical information supplied by inscriptional texts and the methods with which they can be used. It outlines the limitations as well as the advantages of the different types of evidence covered. Epigraphic Evidence includes a general introduction, a guide to the arrangement of the standard corpora inscriptions and individual chapters on local languages and native cultures, epitaphs and the ancient economy amongst others.',
#   'author': [{'family': 'Duthoy', 'given': 'Robert'}],
#   'collection-number': '4',
#   'event-place': 'London, New York',
#   'issued': {'date-parts': [[2002]]},
#   'note': 'ISSN: 0023-8856\nPublication Title: Latomus',
#   'number-of-pages': '1019–1020',
#   'publisher': 'Routledge',
#   'publisher-place': 'London, New York',
#   'title': 'Epigraphic evidence: ancient history from inscriptions',
#   'type': 'book',
#   'volume': '61'},
#  '7109337/WZ6MD9YX': {'DOI': '10.1098/rsif.2017.0367',
#   'URL': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#   'abstract': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#   'accessed': {'day': 18, 'month': 5, 'year': 2021},
#   'author': [{'family': 'Hanson', 'given': 'J. W.'},
#    {'family': 'Ortman', 'given': 'S. G.'},
#    {'family': 'Lobo', 'given': 'J.'}],
#   'container-title': 'Journal of The Royal Society Interface',
#   'container-title-short': 'J. R. Soc. Interface.',
#   'id': '7109337/WZ6MD9YX',
#   'issue': '136',
#   'issued': {'year': 2017},
#   'journalAbbreviation': 'J. R. Soc. Interface.',
#   'language': 'en',
#   'page': '20170367',
#   'page-first': '20170367',
#   'title': 'Urbanism and the division of labour in the Roman Empire',
#   'type': 'article-journal',
#   'volume': '14'}}

# %%
notebook_dict["cells"][10:20]
# Out:
# [{'cell_type': 'code',
#   'execution_count': 3,
#   'metadata': {'tags': ['configuration', 'Python', 'hermeneutics']},
#   'outputs': [{'name': 'stderr',
#     'output_type': 'stream',
#     'text': ['Matplotlib is building the font cache; this may take a moment.\n']}],
#   'source': ['import geopandas as gpd\n',
#    'import cite2c\n',
#    'import requests\n',
#    'import seaborn as sns\n',
#    'import matplotlib.colors as mcolors\n',
#    'import matplotlib.pyplot as plt\n',
#    'from scipy.stats import trapz\n',
#    'import scipy\n',
#    'import nltk\n',
#    'import json\n',
#    'import tempun\n',
#    'import sddk\n',
#    'import numpy as np\n',
#    'import pandas as pd\n',
#    'pd.options.display.max_columns = 1000  # to see all columns']},
#  {'cell_type': 'code',
#   'execution_count': 4,
#   'metadata': {'tags': ['configuration', 'hermeneutics']},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['Requirement already satisfied: cite2c in /opt/conda/lib/python3.7/site-packages (0.2.1)\n',
#      'Requirement already satisfied: rauth in /opt/conda/lib/python3.7/site-packages (from cite2c) (0.7.3)\n',
#      'Requirement already satisfied: tornado in /opt/conda/lib/python3.7/site-packages (from cite2c) (6.0.4)\n',
#      'Requirement already satisfied: notebook in /opt/conda/lib/python3.7/site-packages (from cite2c) (6.1.3)\n',
#      'Requirement already satisfied: requests>=1.2.3 in /opt/conda/lib/python3.7/site-packages (from rauth->cite2c) (2.24.0)\n',
#      'Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (4.3.3)\n',
#      'Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (0.2.0)\n',
#      'Requirement already satisfied: nbformat in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (5.0.7)\n',
#      'Requirement already satisfied: jupyter-core>=4.6.1 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (4.6.3)\n',
#      'Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (0.8.3)\n',
#      'Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (19.0.2)\n',
#      'Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (2.11.2)\n',
#      'Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (6.1.6)\n',
#      'Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (5.3.4)\n',
#      'Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (5.6.1)\n',
#      'Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (0.8.0)\n',
#      'Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (1.5.0)\n',
#      'Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (20.1.0)\n',
#      'Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (3.0.4)\n',
#      'Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (1.25.10)\n',
#      'Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (2020.6.20)\n',
#      'Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (2.10)\n',
#      'Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook->cite2c) (4.4.2)\n',
#      'Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook->cite2c) (1.15.0)\n',
#      'Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat->notebook->cite2c) (3.2.0)\n',
#      'Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->notebook->cite2c) (1.1.1)\n',
#      'Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook->cite2c) (2.8.1)\n',
#      'Requirement already satisfied: ipython>=5.0.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook->cite2c) (7.17.0)\n',
#      'Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (3.1.5)\n',
#      'Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (2.6.1)\n',
#      'Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.8.4)\n',
#      'Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.3)\n',
#      'Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.6.0)\n',
#      'Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (1.4.2)\n',
#      'Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.4.4)\n',
#      'Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook->cite2c) (1.14.1)\n',
#      'Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (1.7.0)\n',
#      'Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (0.16.0)\n',
#      'Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (20.1.0)\n',
#      'Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (49.6.0.post20200814)\n',
#      'Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (0.15.2)\n',
#      'Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (3.0.6)\n',
#      'Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (0.2.0)\n',
#      'Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (0.7.5)\n',
#      'Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (4.8.0)\n',
#      'Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook->cite2c) (0.5.1)\n',
#      'Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook->cite2c) (20.4)\n',
#      'Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->cite2c) (2.20)\n',
#      'Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (3.1.0)\n',
#      'Requirement already satisfied: parso>=0.5.2 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook->cite2c) (0.7.1)\n',
#      'Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook->cite2c) (0.2.5)\n',
#      'Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook->cite2c) (0.6.0)\n',
#      'Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook->cite2c) (2.4.7)\n',
#      'Installing nbextension ...\n',
#      'Enabling the nbextension ...\n',
#      'Enabling the server extension ...\n',
#      'Done.\n']}],
#   'source': ['# cite2c module for bibliographies\n',
#    '\n',
#    '!pip install cite2c\n',
#    '!python3 -m cite2c.install']},
#  {'cell_type': 'markdown',
#   'metadata': {'tags': ['narrative']},
#   'source': ['## Introduction\n',
#    'Ancient inscriptions represent an idiosyncratic category of evidence on past societies, straddling the divide between textual accounts and archaeological artefacts. Close-reading methods dominated early studies of inscriptions, with the aim to reconstruct the text, date and interpret the inscriptions. As the body of evidence grew, synthetic analyses started to emerge to investigate larger-scale patterns (MacMullen 1982; Meyer 1990; Woolf 1996; Hedrick 1999; Nawotka 2021). Digitized epigraphic data made it possible to tackle topics such as the evolution of demographic trends, economic development, migration patterns, changes of the socio-political organization and cultural development using distant-reading and other computational techniques (Wilson 2012; Wilson and Flohr 2016; de Light and Tacoma 2016; Hanson et al. 2017; Liuzzo 2019). While these computational studies underscore the potential of epigraphic evidence, they rarely use a dataset larger than several thousand records. Greek and Latin inscriptions, however, count hundreds of thousands spanning the Roman Empire spatially and temporally. In this respect, epigraphic datasets can inform large-scale comparative studies of the dynamics of past societies (Morris 2010; 2013; Turchin and Scheidel 2009; Mullins et al. 2018; Turchin et al. 2018; Ober 2015).']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['Currently, such a large-scale study has been beyond the reach of any individual researcher because of the gargantuan efforts of aggregating and streamlining the thousands of inscriptions to make analysis feasible. Even the exact number of ancient inscriptions, dating between 800 BC and 800 AD, currently estimated at 600,000 surviving Latin and Greek ones, remains elusive (Bodel 2001, 4; Beltran Lloris 2014, 135). Although numerous analogue and digital corpora exist, their contents and structure overlap to a variable degree and are not straightforward to combine. Some collections focus on specific language, mostly Latin- or Greek-language inscriptions, or collate all inscriptions from a distinct modern or ancient geographic area regardless of language. Others focus on a particular chronological period. While the challenge of technical data wrangling and distant-reading the inscriptions may be beyond a single researcher, a collaborative team equipped with both the necessary computational tools and domain-specific skill set may get further. Working from established digital repositories and building our digital toolkit on the go, we try to address the variability and fluctuation of epigraphic production in different times and places of the Roman Empire and the dependency of comparative research on the state of modern-day research infrastructure.']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['## Epigraphic Habit(s) 40 years later: can we do any better?\n',
#    'Inscriptions vary significantly in form and contents, touching almost all aspects of life in an ancient society. Commissioning an inscription was part of a long-term cultural practice that served as a physical response to a change of circumstances, i.e. death, birth, change of legal status, social rank, physical appearance or they can serve as a reminder or reflection of historical events. The inscribed texts range from short private messages on objects of daily use to extensive regulations and codes issued by a political authority, to monumental inscriptions helping to create a public image and build social prestige. In contrast with literary texts, which survived via multiple copying and editing, the text of inscription has the original unaltered form with original typographical and grammatical errors, being an ideal study subject for historical linguists and historians. The information preserved via inscriptions has potentially broader demographic coverage than literary texts, as social groups producing inscriptions were of more diverse socio-economic and cultural background than those of literary texts (Bodard 2008). Inscriptions aggregated into empire-wide collections can thus serve as a proxy for state power, economic health, building productivity, or population trends or as complementary evidence to coin hoards, shipwrecks and other proxies (Bowman and Wilson 2009; Duncan-Jones 1990).\n']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["Working at the province level with a couple of thousand inscriptions, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly at the beginning of the third century AD (MacMullen 1982; Meyer 1990; Woolf 1996). Researchers started exploring different drivers for such convergence, from the role of funerary habits to the popularity of public status display to the democratization of citizenship. Elizabeth Meyer, for example, saw the *Constitutio Antoniniana* in AD 212 as the turning point for epitaph production. Once all inhabitants of the Roman Empire had been granted Roman citizenship, being a Roman citizen lost its prestige and the incentive to commission funerary inscriptions to mark one's status vanished (Meyer 1990, 78-81). Such explanations, however, were based on a few regional datasets and of one category of inscriptions. Since the time of Meyer or Macmullen, many scholars have attempted to study epigraphic production at the scale of the Roman Empire but found that such efforts were technically entailed (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). First, constraints on interoperability hindered the integration of numerous digital datasets. Second, the volume and diversity of epigraphic data proved challenging to handle and reconcile. Third, analysis was hampered by the inability to quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139; Elliott 2014, 80-83; De Santis and Rossi 2018)."]},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ["Although the analysis of a large body of digitized texts may seem relatively straightforward from an outsider's point of view, epigraphic datasets pose numerous technological, methodological and even ethical challenges to digital research. What are these constraints, and how do they shift as we move from a thousand inscriptions to several hundred thousand? For large-scale analysis, datasets need to include information on the chronological period and the findspot of each monument in a compatible format to be readily combined. The aggregated datasets should provide representative coverage for a project study area (Wilson 2009, 75). The final aggregate needs to be machine-readable and consistent across columns. The problem with computers is that they do not readily understand `120AD` and `AD120` and `AD 120` to be the same thing. These differences need to be normalized (unified into one canonical form) else the analysis halts, or worse, yields misleading results. When handling a dataset of thousand records, the few variants that occur can be cleaned manually. When handling tens of thousands of records from multiple sources with different formatting, the number of variations becomes so high that it is tractable only with Regular Expressions and other automated validation tools. For spatio-temporal patterns, temporal and spatial attributes often need validation and modelling to account for uncertainty, which is a more entailed process than streamlining the spelling of vocabularies in a list of standardized descriptors. Concepts and meanings need to be mapped and related among datasets to make meaningful analysis possible. Computer-assisted analysis (e.g. distant reading) of fragmented texts hinges on the reconciliation of alterations to the Leiden editorial standard, see ([hermeneutics, Step 2.3](LINK TBA)). Furthermore, researchers need to develop their tools and pipelines to tackle the idiosyncrasies of epigraphic monuments as standard Natural Language Processing pipelines trained on literary data do not work on the texts of inscriptions. "]},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['After the initial - primarily technical - obstacles of wrangling a large quantity of epigraphic evidence into a compatible machine-readable format, conceptual obstacles emerge. The most common obstacle, which affects most historical and archaeological data, yet the hardest one to tackle, is the paucity of high-resolution dates and the need to inventively work with chronological assignment.']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['We take two well-established digital resources and develop a pipeline that allows us and others to combine and reconcile differences between them. These datasets come from two distinct projects: [Epigraphic Database Heidelberg](https://edh-www.adw.uni-heidelberg.de/) (EDH), a flagship resource for Latin epigraphers and a pioneering initiative in the field of open and FAIR epigraphy with over 35 years of development; and [Epigraphic Database Clauss-Slaby](http://www.manfredclauss.de/) (EDCS), the most extensive digital catalogue of Latin inscriptions, with over 500,000 texts. Before we tap the potential of inscriptions, however, we need to understand the strengths and weaknesses of this class of evidence and be aware of its biases. We, therefore, focus on the distribution of inscription data across the Empire, to decouple the data from social phenomena it may correlate with and build a foundation for other interpretive studies. We inspect inscription frequencies through time and across space and evaluate the representativeness and suitability of each dataset for different research designs.']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['Following the open science practices (Stewart-Lowndes et al. 2017), we use reproducible programmatic methods throughout the data aggregation and analysis. Each step in the data collection and streamlining is transparent and documented. All project stages are accessible via public repositories on the Social Dynamics in the Ancient Mediterranean Project [(SDAM) GitHub](https://github.com/sdam-au) and Zenodo under CC-BY-SA 4.0 International license.  ']}]

# %%
notebook_text = open("Digital_epigraphy.ipynb").read()
notebook_text[:1000]
# Out:
# '{\n "cells": [\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "title"\n    ]\n   },\n   "source": [\n    "# Inscriptions as data: digital epigraphy in macro-historical perspective "\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Petra Hermankova\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6349-0540](https://orcid.org/0000-0002-6349-0540)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Vojtech Kase\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6601-1605](http://orcid.org/0000-0002-6601-1605)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Adela Sobotkova\\n",\n    "Author. Aarhus University, [ORCID:0000-0002-4541-3963](https://orcid.org/0000-0002-4541-3963)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n'

# %%
citations_used = {}
for key in citation_keys_pairs.keys():
    if key in notebook_text:
        citations_used[citation_keys_pairs[key]] = citations[citation_keys_pairs[key]]
        notebook_text = notebook_text.replace(key, "<cite data-cite=\'" + citation_keys_pairs[key] + "\'></cite>")

# %%
notebook_dict = json.loads(notebook_text)
notebook_dict["metadata"]["cite2c"]["citations"] = citations_used

# %%
with open("Digital_epigraphy_cite2c_test_2.ipynb", "w") as f:
    json.dump(notebook_dict, f)
