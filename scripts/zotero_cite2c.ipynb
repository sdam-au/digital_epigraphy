# %%
#!pip install pyzotero
import requests
import sddk
import getpass

# %% [markdown]
# # Zotero API configuration
#
# 1. find your zotero user ID and insert it interactively in the cell below (you can find it e.g. from https://www.zotero.org/settings/keys)

# %%
userID = input("Paste your Zotero user ID: ")
# Out:
# Paste your Zotero user ID: 2132694

# %% [markdown]
# 2. go to https://www.zotero.org/settings/keys
# 3. `Create new private key`
# 4. name your key in `Key description`, e.g. `pyzot`.
# 5. click at `Save Key`
# 6. copy the generated key into clipboard
# 7 insert it in the cell below

# %%
api_key =  getpass.getpass("Paste your key: ")
# Out:
# Paste your key: ········

# %%
# prepare the authorization
base_url = "https://api.zotero.org/users/" + str(userID) + "/"
headers ={"Authorization": "Bearer " + api_key}

# %%
# list all personal collections
url = "https://api.zotero.org/users/2132694/collections"
resp = requests.get(url, headers=headers)
resp.json()
# Out:
# [{'key': 'P55PUAIK',
#   'version': 2818,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/collections/P55PUAIK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/collections/P55PUAIK',
#     'type': 'text/html'}},
#   'meta': {'numCollections': 0, 'numItems': 62},
#   'data': {'key': 'P55PUAIK',
#    'version': 2818,
#    'name': 'JDH_article',
#    'parentCollection': False,
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/collections/QR9UH9RG'}}}]

# %% [markdown]
# Among these collections, find the one you want to use and copy its `key` (i.e. the value of the `key` attribute.

# %%
collection_key = input("your collection key: ")
# Out:
# your collection key: P55PUAIK

# %%
# list all items within preselected collection:
url = "https://api.zotero.org/users/2132694/collections/" + collection_key + "/items?limit=1000"
collection_items_json = requests.get(url, headers=headers).json()

# %%
# inspect the items
collection_items_json
# Out:
# [{'key': '4DU2BY28',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/4DU2BY28',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/4DU2BY28',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/C2MUHDNG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '4DU2BY28',
#    'version': 2829,
#    'parentItem': 'C2MUHDNG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-18T11:04:52Z',
#    'url': 'https://royalsocietypublishing.org/doi/pdf/10.1098/rsif.2017.0367',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Hanson et al. - 2017 - Urbanism and the division of labour in the Roman E.pdf',
#    'md5': '79b6036c9ae46b01d4220a030d53d267',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/XIXVPIM6'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'FTDUBX6P',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/FTDUBX6P',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/FTDUBX6P',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/IFEXKMWT',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'FTDUBX6P',
#    'version': 2829,
#    'parentItem': 'IFEXKMWT',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Accepted Version',
#    'accessDate': '2021-05-17T13:56:04Z',
#    'url': 'https://ore.exeter.ac.uk/repository/bitstream/10871/36086/2/deleted_FINAL_submission.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Mullins et al. - 2018 - A Systematic Assessment of “Axial Age” Proposals U.pdf',
#    'md5': 'adf11660ed230bc904e56dca26ad60bb',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/DCMSZNZ4'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'L47JEQBH',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/L47JEQBH',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/L47JEQBH',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/4WT5APEZ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'L47JEQBH',
#    'version': 2829,
#    'parentItem': '4WT5APEZ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:20:02Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 17 EAGLE Continued IDEA. The International Digita.pdf',
#    'md5': 'a541ac0949a58b0e2463f1be9532a54f',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/TMVXV8KZ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '7JEU5M89',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/7JEU5M89',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/7JEU5M89',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/N8MU7LGT',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '7JEU5M89',
#    'version': 2829,
#    'parentItem': 'N8MU7LGT',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-14T09:57:31Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 16 Making up for Lost Time Digital Epigraphy, Chr.pdf',
#    'md5': '23080e24a3216c4047d3ad49fe242528',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/NDQPHA65'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'AGSJ79AY',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/AGSJ79AY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/AGSJ79AY',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/SYSTIFZQ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'AGSJ79AY',
#    'version': 2829,
#    'parentItem': 'SYSTIFZQ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf',
#    'md5': '361eb415ef014d66f52bd62a750bdbc7',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/53ISVBX3'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '3LU29L3J',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/3LU29L3J',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/3LU29L3J',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/LFKD595C',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '3LU29L3J',
#    'version': 2829,
#    'parentItem': 'LFKD595C',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:27:40Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 1 Encoding, Interoperability, Lexicography Digita.pdf',
#    'md5': '1d2b5a559c816e6ed22b8abe3a135882',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/66R9JXZI'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '49AE839R',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/49AE839R',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/49AE839R',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/37N8YE3I',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '49AE839R',
#    'version': 2829,
#    'parentItem': '37N8YE3I',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:10:37Z',
#    'url': 'https://zenodo.org/record/2593547/files/DeSantis_Rossi_2018_Digital_Epigraphy_book.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - Crossing Experiences in Digital Epigraphy From Pr.pdf',
#    'md5': '89dafc461cca554441d0f0bde48bea38',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/5NQCCQJV'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'V36QKWVK',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/V36QKWVK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/V36QKWVK',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/U48VTMSM',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'V36QKWVK',
#    'version': 2829,
#    'parentItem': 'U48VTMSM',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Turchin, Scheidel - 2009 - Coin Hoards Speak of Population Declines in Ancient Rome.pdf',
#    'md5': '216bae77c5778834695351cf72c2e4b5',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/RSDIDT42'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'TVCGWGMN',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/TVCGWGMN',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/TVCGWGMN',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/2LT8WIGC',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'TVCGWGMN',
#    'version': 2828,
#    'parentItem': '2LT8WIGC',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Hedrick - 1999 - Democracy and the Athenian Epigraphical Habit.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Hedrick - 1999 - Democracy and the Athenian Epigraphical Habit.pdf',
#    'md5': '351291b72289761a5776a2dc11b24deb',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/375MJWAQ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'MG4AUE6B',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/MG4AUE6B',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/MG4AUE6B',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/DF62R52E',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'MG4AUE6B',
#    'version': 2828,
#    'parentItem': 'DF62R52E',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Crema2020_JomonPopulationDynamics.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Crema2020_JomonPopulationDynamics.pdf',
#    'md5': 'fafcfe9f56b9f2154529290743f4aa2a',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/PUGS2NNW'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'I4SY879G',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/I4SY879G',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/I4SY879G',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/HGSQZDS4',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'I4SY879G',
#    'version': 2828,
#    'parentItem': 'HGSQZDS4',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Accepted Version',
#    'accessDate': '2021-05-10T13:50:55Z',
#    'url': 'https://helda.helsinki.fi/bitstream/10138/329293/1/Oksanen_and_Lewis_PAS_and_medieval_markets_AJ_100.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Oksanen and Lewis - 2020 - MEDIEVAL COMMERCIAL SITES AS SEEN THROUGH PORTABL.pdf',
#    'md5': 'f0ed9df6f6be4d68e00046054580364a',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/S73ZB82A'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'Z8JVQ5FX',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/Z8JVQ5FX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/Z8JVQ5FX',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/5ALKMMVG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'Z8JVQ5FX',
#    'version': 2828,
#    'parentItem': '5ALKMMVG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'PDF',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Turchin et al. - 2018 - Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in h.pdf',
#    'md5': '1df9a98c175bde2398461a0b23095cdc',
#    'mtime': 1622099543000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/BMH24W79'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'VDPSKXF2',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/VDPSKXF2',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/VDPSKXF2',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/UTITLKQZ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'VDPSKXF2',
#    'version': 2828,
#    'parentItem': 'UTITLKQZ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Crema - 2012 - Modelling Temporal Uncertainty in Archaeological A.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Crema - 2012 - Modelling Temporal Uncertainty in Archaeological A.pdf',
#    'md5': '62e0029a560ced451027ca3c1b5f9f7f',
#    'mtime': 1622099543000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/GSUL5APN'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'K5B59T6I',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/K5B59T6I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/K5B59T6I',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/U48VTMSM',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'K5B59T6I',
#    'version': 2828,
#    'parentItem': 'U48VTMSM',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Turchin_Scheidel_2009_Coin Hoards Speak of Population Declines in Ancient Rome.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Turchin_Scheidel_2009_Coin Hoards Speak of Population Declines in Ancient Rome.pdf',
#    'md5': '216bae77c5778834695351cf72c2e4b5',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/UL6SNGC7'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'J2H5P8TD',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/J2H5P8TD',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/J2H5P8TD',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/6HXR6GAN',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'J2H5P8TD',
#    'version': 2828,
#    'parentItem': '6HXR6GAN',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Korhonen - 2011 - Language and Identity in the Roman Colonies of Sicily.pdf',
#    'md5': 'c8ae053b8e010f4402b60d79bf234eb4',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/CKMLTI64'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'HGK83TQN',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/HGK83TQN',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/HGK83TQN',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/CALUBQFC',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'HGK83TQN',
#    'version': 2828,
#    'parentItem': 'CALUBQFC',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Prag - 2002 - Epigraphy by numbers Latin and the epigraphic culture in Sicily.pdf',
#    'md5': '8a9549c8999989ef7449038376c9f987',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/9U6NZ7RP'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'YAFN5N27',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/YAFN5N27',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/YAFN5N27',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/NX2YYEWH',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'YAFN5N27',
#    'version': 2828,
#    'parentItem': 'NX2YYEWH',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Prag - 2013 - Epigraphy in the western Mediterranean a Hellenistic phenomenon.pdf',
#    'md5': 'd1a0dafcbb662713ff38646839c683b1',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/W79EFH49'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'IJPUN3PC',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/IJPUN3PC',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/IJPUN3PC',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/5ALKMMVG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'IJPUN3PC',
#    'version': 2828,
#    'parentItem': '5ALKMMVG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'turchin-et-al_2018_quantitative-historical-analysis.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'turchin-et-al_2018_quantitative-historical-analysis.pdf',
#    'md5': 'e69e3dc350a2697a81a7b4a069af71e0',
#    'mtime': 1622099543000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/RCV5B276'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '5MY4KSUI',
#   'version': 2825,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/5MY4KSUI',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/5MY4KSUI',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Ballsun-Stanton',
#    'parsedDate': '2020',
#    'numChildren': 0},
#   'data': {'key': '5MY4KSUI',
#    'version': 2825,
#    'itemType': 'computerProgram',
#    'title': 'Lat Epig 2.0',
#    'creators': [{'creatorType': 'programmer',
#      'firstName': 'Brian',
#      'lastName': 'Ballsun-Stanton'},
#     {'creatorType': 'contributor',
#      'firstName': 'Petra',
#      'lastName': 'Hermankova'},
#     {'creatorType': 'contributor',
#      'firstName': 'Ray',
#      'lastName': 'Laurence'}],
#    'abstractNote': '',
#    'seriesTitle': '',
#    'versionNumber': '',
#    'date': '2020',
#    'system': '',
#    'place': '',
#    'company': 'Macquarie University',
#    'programmingLanguage': 'python',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#    'rights': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'accessDate': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/84QIQ6VP'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'SYSTIFZQ',
#   'version': 2825,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/SYSTIFZQ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/SYSTIFZQ',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Wilson', 'parsedDate': '2012', 'numChildren': 1},
#   'data': {'key': 'SYSTIFZQ',
#    'version': 2825,
#    'itemType': 'bookSection',
#    'title': 'City Sizes and Urbanization in the Roman Empire',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Andrew',
#      'lastName': 'Wilson'},
#     {'creatorType': 'editor', 'firstName': 'Alan', 'lastName': 'Bowman'},
#     {'creatorType': 'editor', 'firstName': 'Andrew', 'lastName': 'Wilson'}],
#    'abstractNote': '',
#    'bookTitle': 'Settlement, Urbanization and Population',
#    'series': 'Oxford Studies in the Roman Economy',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'Oxford - New York',
#    'publisher': 'Oxford University Press',
#    'date': '2012',
#    'pages': '161–195',
#    'language': '',
#    'ISBN': '0-19-960235-2',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'pdf'}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/MYBKPFWP'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'C2MUHDNG',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/C2MUHDNG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/C2MUHDNG',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Hanson et al.',
#    'parsedDate': '2017',
#    'numChildren': 1},
#   'data': {'key': 'C2MUHDNG',
#    'version': 2824,
#    'itemType': 'journalArticle',
#    'title': 'Urbanism and the division of labour in the Roman Empire',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'J. W.',
#      'lastName': 'Hanson'},
#     {'creatorType': 'author', 'firstName': 'S. G.', 'lastName': 'Ortman'},
#     {'creatorType': 'author', 'firstName': 'J.', 'lastName': 'Lobo'}],
#    'abstractNote': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#    'publicationTitle': 'Journal of The Royal Society Interface',
#    'volume': '14',
#    'issue': '136',
#    'pages': '20170367',
#    'date': '11/2017',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'J. R. Soc. Interface.',
#    'language': 'en',
#    'DOI': '10.1098/rsif.2017.0367',
#    'ISSN': '1742-5689, 1742-5662',
#    'shortTitle': '',
#    'url': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#    'accessDate': '2021-05-18T11:04:50Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/G855HU3P'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '9YX6ZS7N',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/9YX6ZS7N',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/9YX6ZS7N',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2013', 'numChildren': 0},
#   'data': {'key': '9YX6ZS7N',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': 'Course Book',
#    'place': 'Princeton, NJ',
#    'publisher': 'Princeton University Press',
#    'date': '2013',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '1-299-14683-X',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'tags': [{'tag': 'Social structure'}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/YTH8LCMQ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '627JE7WX',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/627JE7WX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/627JE7WX',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2010', 'numChildren': 0},
#   'data': {'key': '627JE7WX',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'New York',
#    'publisher': 'Farrar, Straus and Giroux',
#    'date': '2010',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '978-0-312-61169-9',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#    'tags': [{'tag': 'civilisationens historie'}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WC3F7GTN'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'IFEXKMWT',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/IFEXKMWT',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/IFEXKMWT',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Mullins et al.',
#    'parsedDate': '2018',
#    'numChildren': 1},
#   'data': {'key': 'IFEXKMWT',
#    'version': 2824,
#    'itemType': 'journalArticle',
#    'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Daniel Austin',
#      'lastName': 'Mullins'},
#     {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Hoyer'},
#     {'creatorType': 'author', 'firstName': 'Christina', 'lastName': 'Collins'},
#     {'creatorType': 'author', 'firstName': 'Thomas', 'lastName': 'Currie'},
#     {'creatorType': 'author', 'firstName': 'Kevin', 'lastName': 'Feeney'},
#     {'creatorType': 'author', 'firstName': 'Pieter', 'lastName': 'François'},
#     {'creatorType': 'author', 'firstName': 'Patrick E.', 'lastName': 'Savage'},
#     {'creatorType': 'author', 'firstName': 'Harvey', 'lastName': 'Whitehouse'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Turchin'}],
#    'abstractNote': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#    'publicationTitle': 'American Sociological Review',
#    'volume': '83',
#    'issue': '3',
#    'pages': '596-626',
#    'date': '06/2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Am Sociol Rev',
#    'language': 'en',
#    'DOI': '10.1177/0003122418772567',
#    'ISSN': '0003-1224, 1939-8271',
#    'shortTitle': '',
#    'url': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#    'accessDate': '2021-05-17T13:55:59Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/YP4EWP6Y'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'C5MFASAY',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/C5MFASAY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/C5MFASAY',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Harper', 'parsedDate': '2016', 'numChildren': 0},
#   'data': {'key': 'C5MFASAY',
#    'version': 2824,
#    'itemType': 'journalArticle',
#    'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Kyle',
#      'lastName': 'Harper'}],
#    'abstractNote': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#    'publicationTitle': 'The Journal of Economic History',
#    'volume': '76',
#    'issue': '3',
#    'pages': '803-839',
#    'date': '2016',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.1017/S0022050716000826',
#    'ISSN': '1471-6372',
#    'shortTitle': '',
#    'url': 'https://www.cambridge.org/core/article/people-plagues-and-prices-in-the-roman-world-the-evidence-from-egypt/50D27EAD5045D12C1573DFFB5D5C029C',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/XB3S54U6'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '95I2Q54Z',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/95I2Q54Z',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/95I2Q54Z',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Kolb',
#    'parsedDate': '2019-06-17',
#    'numChildren': 0},
#   'data': {'key': '95I2Q54Z',
#    'version': 2824,
#    'itemType': 'bookSection',
#    'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Anne',
#      'lastName': 'Kolb'},
#     {'creatorType': 'editor', 'firstName': 'Anne', 'lastName': 'Kolb'}],
#    'abstractNote': '',
#    'bookTitle': 'Roman Roads: New Evidence - New Perspectives',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'De Gruyter',
#    'date': '2019-06-17',
#    'pages': '3-21',
#    'language': '',
#    'ISBN': '978-3-11-063833-2',
#    'shortTitle': '',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#    'accessDate': '2021-05-19T07:51:54Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1515/9783110638332',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WBXNR587'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'GSAVHWAN',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/GSAVHWAN',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/GSAVHWAN',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Borgman',
#    'parsedDate': '2015',
#    'numChildren': 0},
#   'data': {'key': 'GSAVHWAN',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'Big Data, Little Data, No Data',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Christine L.',
#      'lastName': 'Borgman'}],
#    'abstractNote': '"Big Data" is on the covers of<em>Science, Nature</em>, the<em>Economist</em>, and<em>Wired</em>magazines, on the front pages of the<em>Wall Street Journal</em>and the<em>New York Times.</em>But despite the media hyperbole, as Christine Borgman points out in this examination of data and scholarly research, having the right data is usually better than having more data; little data can be just as valuable as big data. In many cases, there are no data -- because relevant data don\'t exist, cannot be found, or are not available. Moreover, data sharing is difficult, incentives to do so are minimal, and data practices vary widely across disciplines.Borgman, an often-cited authority on scholarly communication, argues that data have no value or meaning in isolation; they exist within a knowledge infrastructure -- an ecology of people, practices, technologies, institutions, material objects, and relationships. After laying out the premises of her investigation -- six "provocations" meant to inspire discussion about the uses of data in scholarship -- Borgman offers case studies of data practices in the sciences, the social sciences, and the humanities, and then considers the implications of her findings for scholarly practice and research policy. To manage and exploit data over the long term, Borgman argues, requires massive investment in knowledge infrastructures; at stake is the future of scholarship.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'The MIT Press',
#    'date': '2015',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-262-02856-1',
#    'shortTitle': '',
#    'url': 'http://www.jstor.org/stable/j.ctt17kk8n8',
#    'accessDate': '2021-05-17',
#    'archive': 'JSTOR',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/R6GC6RM2'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'KRXAF9YL',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/KRXAF9YL',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/KRXAF9YL',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Cayless et al.',
#    'parsedDate': '2010-12-31',
#    'numChildren': 0},
#   'data': {'key': 'KRXAF9YL',
#    'version': 2824,
#    'itemType': 'bookSection',
#    'title': 'EPIGRAPHY IN 2017',
#    'creators': [{'creatorType': 'editor',
#      'firstName': 'Melissa',
#      'lastName': 'Terras'},
#     {'creatorType': 'editor', 'firstName': 'Gregory', 'lastName': 'Crane'},
#     {'creatorType': 'author', 'firstName': 'Hugh', 'lastName': 'Cayless'},
#     {'creatorType': 'author', 'firstName': 'Charlotte', 'lastName': 'Roueché'},
#     {'creatorType': 'author', 'firstName': 'Tom', 'lastName': 'Elliott'},
#     {'creatorType': 'author', 'firstName': 'Gabriel', 'lastName': 'Bodard'}],
#    'abstractNote': '',
#    'bookTitle': 'Changing the Center of Gravity',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Gorgias Press',
#    'date': '2010-12-31',
#    'pages': '203-222',
#    'language': '',
#    'ISBN': '978-1-4632-1922-2',
#    'shortTitle': '',
#    'url': 'https://www.degruyter.com/document/doi/10.31826/9781463219222-012/html',
#    'accessDate': '2021-05-17T10:30:40Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.31826/9781463219222-012',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/2TRX7DVQ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'AW6LP4AP',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/AW6LP4AP',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/AW6LP4AP',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Laurence',
#    'parsedDate': '1999',
#    'numChildren': 0},
#   'data': {'key': 'AW6LP4AP',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'The roads of Roman Italy: mobility and cultural change',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ray',
#      'lastName': 'Laurence'}],
# ...
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Datacite)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Universitätsbibliothek Tübingen',
#    'tags': [{'tag': '930', 'type': 1}, {'tag': 'Archäoinformatik', 'type': 1}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/V669MYBG'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'NR7KMK97',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/NR7KMK97',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/NR7KMK97',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Roueche and Sotinel',
#    'parsedDate': '2017-03',
#    'numChildren': 0},
#   'data': {'key': 'NR7KMK97',
#    'version': 2819,
#    'itemType': 'bookSection',
#    'title': 'Christian and Late Antique Epigraphies',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Charlotte Mary',
#      'lastName': 'Roueche'},
#     {'creatorType': 'author', 'firstName': 'Claire', 'lastName': 'Sotinel'},
#     {'creatorType': 'editor', 'firstName': 'Katharina', 'lastName': 'Bolle'},
#     {'creatorType': 'editor', 'firstName': 'Carlos', 'lastName': 'Machado'},
#     {'creatorType': 'editor',
#      'firstName': 'Christian',
#      'lastName': 'Witschel'}],
#    'abstractNote': '',
#    'bookTitle': 'The Epigraphic Cultures of Late Antiquity',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Franz Steiner Verlag',
#    'date': 'March 2017',
#    'pages': '503–514',
#    'language': 'English',
#    'ISBN': '978-3-515-11558-2',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Christian antiquities', 'type': 1},
#     {'tag': 'Epigraphy', 'type': 1},
#     {'tag': 'Late Antiquity', 'type': 1}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/ZRE798N5'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'HGSQZDS4',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/HGSQZDS4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/HGSQZDS4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Oksanen and Lewis',
#    'parsedDate': '2020',
#    'numChildren': 1},
#   'data': {'key': 'HGSQZDS4',
#    'version': 2819,
#    'itemType': 'journalArticle',
#    'title': 'Medieval Commercial Sites: As Seen Through Portable Antiquities Scheme Data',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Eljas',
#      'lastName': 'Oksanen'},
#     {'creatorType': 'author', 'firstName': 'Michael', 'lastName': 'Lewis'}],
#    'abstractNote': 'This paper explores some 220,000 medieval objects recorded in the Portable Antiquities Scheme (PAS) online database of archaeological small finds through Geographic Information System analysis of their relationship with contemporary market sites. First, an overview of the contents of the PAS database is presented in terms of its spatial and ‘object type’ distribution. Second, the relationship of the medieval finds data against documentary evidence of commercial activity is investigated at a national level. Finally, PAS data is contextualised in its historical landscape context through case studies. It is argued that the distribution of PAS finds on the national scale can be linked with patterns of commercial activity, and that while rural and urban finds scatters have distinguishing trends, the countryside population enjoyed access to a range of sophisticated metalwork culture; also, that certain assemblages can be analysed statistically to yield new data and perspectives on local historical development.',
#    'publicationTitle': 'The Antiquaries Journal',
#    'volume': '100',
#    'issue': '',
#    'pages': '109-140',
#    'date': '09/2020',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Antiq. J.',
#    'language': 'en',
#    'DOI': '10.1017/S0003581520000165',
#    'ISSN': '0003-5815, 1758-5309',
#    'shortTitle': 'MEDIEVAL COMMERCIAL SITES',
#    'url': 'https://www.cambridge.org/core/product/identifier/S0003581520000165/type/journal_article',
#    'accessDate': '2021-05-10T13:50:54Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/HKR5H6PK'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'YS8ZN82H',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/YS8ZN82H',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/YS8ZN82H',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Hartmann',
#    'parsedDate': '2018-10-13',
#    'numChildren': 0},
#   'data': {'key': 'YS8ZN82H',
#    'version': 2819,
#    'itemType': 'journalArticle',
#    'title': 'Rezension zu: Epigraphische Datenbank Heidelberg',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Andreas',
#      'lastName': 'Hartmann'}],
#    'abstractNote': '',
#    'publicationTitle': 'H-Soz-Kult',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '13/10/2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'ger',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'https://www.hsozkult.de/webreview/id/rezwww-179',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/6TY2F79A'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'WNGG6SYB',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/WNGG6SYB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/WNGG6SYB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Elliot et al.',
#    'parsedDate': '2017',
#    'numChildren': 0},
#   'data': {'key': 'WNGG6SYB',
#    'version': 2819,
#    'itemType': 'computerProgram',
#    'title': 'EpiDoc Reference Stylesheets (version 9)',
#    'creators': [{'creatorType': 'programmer',
#      'firstName': 'Tom',
#      'lastName': 'Elliot'},
#     {'creatorType': 'programmer', 'firstName': 'Zaneta', 'lastName': 'Au'},
#     {'creatorType': 'programmer',
#      'firstName': 'Gabriel',
#      'lastName': 'Bodard'},
#     {'creatorType': 'programmer', 'firstName': 'Hugh', 'lastName': 'Cayless'},
#     {'creatorType': 'programmer', 'firstName': 'Carmen', 'lastName': 'Lanz'},
#     {'creatorType': 'programmer',
#      'firstName': 'Faith',
#      'lastName': 'Lawrence'},
#     {'creatorType': 'programmer',
#      'firstName': 'Scott',
#      'lastName': 'Vanderbilt'},
#     {'creatorType': 'programmer',
#      'firstName': 'Raffaele',
#      'lastName': 'Viglianti'}],
#    'abstractNote': 'XSLT for transformation of EpiDoc XML files into HTML or text versions in Leiden. Includes various XML files containing parameters and other options.',
#    'seriesTitle': '',
#    'versionNumber': '',
#    'date': '2017',
#    'system': '',
#    'place': '',
#    'company': '',
#    'programmingLanguage': 'XSLT 2.0',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': 'https://sourceforge.net/p/epidoc/wiki/Stylesheets/',
#    'rights': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'accessDate': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/7VS4BH25'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '5ALKMMVG',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/5ALKMMVG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/5ALKMMVG',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Turchin et al.',
#    'parsedDate': '2018',
#    'numChildren': 2},
#   'data': {'key': '5ALKMMVG',
#    'version': 2819,
#    'itemType': 'journalArticle',
#    'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Peter',
#      'lastName': 'Turchin'},
#     {'creatorType': 'author', 'firstName': 'Thomas E.', 'lastName': 'Currie'},
#     {'creatorType': 'author', 'firstName': 'Harvey', 'lastName': 'Whitehouse'},
#     {'creatorType': 'author', 'firstName': 'Pieter', 'lastName': 'François'},
#     {'creatorType': 'author', 'firstName': 'Kevin', 'lastName': 'Feeney'},
#     {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Mullins'},
#     {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Hoyer'},
#     {'creatorType': 'author', 'firstName': 'Christina', 'lastName': 'Collins'},
#     {'creatorType': 'author',
#      'firstName': 'Stephanie',
#      'lastName': 'Grohmann'},
#     {'creatorType': 'author', 'firstName': 'Patrick', 'lastName': 'Savage'},
#     {'creatorType': 'author',
#      'firstName': 'Gavin',
#      'lastName': 'Mendel-Gleason'},
#     {'creatorType': 'author', 'firstName': 'Edward', 'lastName': 'Turner'},
#     {'creatorType': 'author', 'firstName': 'Agathe', 'lastName': 'Dupeyron'},
#     {'creatorType': 'author', 'firstName': 'Enrico', 'lastName': 'Cioni'},
#     {'creatorType': 'author', 'firstName': 'Jenny', 'lastName': 'Reddish'},
#     {'creatorType': 'author', 'firstName': 'Jill', 'lastName': 'Levine'},
#     {'creatorType': 'author', 'firstName': 'Greine', 'lastName': 'Jordan'},
#     {'creatorType': 'author', 'firstName': 'Eva', 'lastName': 'Brandl'},
#     {'creatorType': 'author', 'firstName': 'Alice', 'lastName': 'Williams'},
#     {'creatorType': 'author', 'firstName': 'Rudolf', 'lastName': 'Cesaretti'},
#     {'creatorType': 'author', 'firstName': 'Marta', 'lastName': 'Krueger'},
#     {'creatorType': 'author',
#      'firstName': 'Alessandro',
#      'lastName': 'Ceccarelli'},
#     {'creatorType': 'author',
#      'firstName': 'Joe',
#      'lastName': 'Figliulo-Rosswurm'},
#     {'creatorType': 'author', 'firstName': 'Po-Ju', 'lastName': 'Tuan'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Peregrine'},
#     {'creatorType': 'author',
#      'firstName': 'Arkadiusz',
#      'lastName': 'Marciniak'},
#     {'creatorType': 'author',
#      'firstName': 'Johannes',
#      'lastName': 'Preiser-Kapeller'},
#     {'creatorType': 'author', 'firstName': 'Nikolay', 'lastName': 'Kradin'},
#     {'creatorType': 'author', 'firstName': 'Andrey', 'lastName': 'Korotayev'},
#     {'creatorType': 'author', 'firstName': 'Alessio', 'lastName': 'Palmisano'},
#     {'creatorType': 'author', 'firstName': 'David', 'lastName': 'Baker'},
#     {'creatorType': 'author', 'firstName': 'Julye', 'lastName': 'Bidmead'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Bol'},
#     {'creatorType': 'author', 'firstName': 'David', 'lastName': 'Christian'},
#     {'creatorType': 'author', 'firstName': 'Connie', 'lastName': 'Cook'},
#     {'creatorType': 'author', 'firstName': 'Alan', 'lastName': 'Covey'},
#     {'creatorType': 'author', 'firstName': 'Gary', 'lastName': 'Feinman'},
#     {'creatorType': 'author',
#      'firstName': 'Árni Daníel',
#      'lastName': 'Júlíusson'},
#     {'creatorType': 'author', 'firstName': 'Axel', 'lastName': 'Kristinsson'},
#     {'creatorType': 'author', 'firstName': 'John', 'lastName': 'Miksic'},
#     {'creatorType': 'author', 'firstName': 'Ruth', 'lastName': 'Mostern'},
#     {'creatorType': 'author', 'firstName': 'Cameron', 'lastName': 'Petrie'},
#     {'creatorType': 'author',
#      'firstName': 'Peter',
#      'lastName': 'Rudiak-Gould'},
#     {'creatorType': 'author', 'firstName': 'Barend', 'lastName': 'ter Haar'},
#     {'creatorType': 'author', 'firstName': 'Vesna', 'lastName': 'Wallace'},
#     {'creatorType': 'author', 'firstName': 'Victor', 'lastName': 'Mair'},
#     {'creatorType': 'author', 'firstName': 'Liye', 'lastName': 'Xie'},
#     {'creatorType': 'author', 'firstName': 'John', 'lastName': 'Baines'},
#     {'creatorType': 'author', 'firstName': 'Elizabeth', 'lastName': 'Bridges'},
#     {'creatorType': 'author', 'firstName': 'Joseph', 'lastName': 'Manning'},
#     {'creatorType': 'author', 'firstName': 'Bruce', 'lastName': 'Lockhart'},
#     {'creatorType': 'author', 'firstName': 'Amy', 'lastName': 'Bogaard'},
#     {'creatorType': 'author', 'firstName': 'Charles', 'lastName': 'Spencer'}],
#    'abstractNote': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#    'publicationTitle': 'Proceedings of the National Academy of Sciences',
#    'volume': '115',
#    'issue': '2',
#    'pages': 'E144-E151',
#    'date': '2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.1073/pnas.1708800115',
#    'ISSN': '0027-8424',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/JNS83J8R'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}}]

# %%
# ids of items
citation_keys_pairs = {}
for item in collection_items_json:
    if item["data"]["itemType"] != "attachment":
        try:
            item_key = item["meta"]["creatorSummary"] + " " + item["meta"]["parsedDate"]
        except: 
            try:
                item_key = item["data"]["title"]
            except:
                item_key = ""
        citation_keys_pairs[item_key] = item["data"]["key"]

# %%
citation_keys_pairs
# Out:
# {'Ballsun-Stanton 2020': '5MY4KSUI',
#  'Wilson 2012': 'SYSTIFZQ',
#  'Hanson et al. 2017': 'C2MUHDNG',
#  'Morris 2013': '9YX6ZS7N',
#  'Morris 2010': '627JE7WX',
#  'Mullins et al. 2018': 'IFEXKMWT',
#  'Harper 2016': '33TNUAZ3',
#  'Kolb 2019-06-17': '95I2Q54Z',
#  'Borgman 2015': 'GSAVHWAN',
#  'Cayless et al. 2010-12-31': 'KRXAF9YL',
#  'Laurence 1999': 'AW6LP4AP',
#  'Bodard 2008': '66WIWW57',
#  'Liuzzo 2018-12-31': '4WT5APEZ',
#  'de Ligt and Tacoma 2016-01-19': '6ZEVHLM6',
#  'Wilson and Flohr 2016-01-01': 'B99689HI',
#  'Verhagen 2019': 'A2U4FIKT',
#  'Hanel 2020-03-24': 'CLBZUHJ7',
#  'Bodard et al. 2021-03-26': 'AHA9EWZL',
#  'Avanzini et al. 2018-12-31': 'LFKD595C',
#  'De Santis and Rossi 2018-12-31': '37N8YE3I',
#  'Littman and Littman 1973': 'UZDY7HD7',
#  'Rabinowitz et al. 2018-12-31': 'N8MU7LGT',
#  'Bodel 2001': '4YVYEDQD',
#  'Crema and Kobayashi 2020': 'DF62R52E',
#  'Kaše 2021-03-31': 'MT2ZRZBH',
#  'Kemkes 2020-03-24': 'AIJX7C5S',
#  'Verhagen et al. 2016': 'XJBYYW4X',
#  'Keppie 1991': 'V9UVGQX2',
#  'Bowman and Wilson 2009': '6YVHFFUJ',
#  'Turchin and Scheidel 2009': 'U48VTMSM',
#  'Hedrick 1999': '2LT8WIGC',
#  'Beltrán Lloris 2014': '6CHTC3L7',
#  'Nawotka 2021': 'NEGLBLPH',
#  'Bolle et al. 2017': 'GDRQEX9Z',
#  'Lotz 2020-10-07': 'XUF75FS9',
#  'MacMullen 1982': 'BGNB6HUT',
#  'Pérez 2021': '8AAUR7HD',
#  'Trout 2009': 'F3Y2FVVY',
#  'Feraudi-Gruénais and Grieshaber 2016': '7KH8X6PB',
#  'Grieshaber 2019': 'DBL5UIX2',
#  'Woolf 1996': 'HBPZKHXT',
#  'Elliot et al. 2020': 'BADWX5AX',
#  'Duthoy 2002': 'ARJNJ286',
#  'Elliot 2015': 'VH243883',
#  'Meyer 1990': 'MUKI9YSZ',
#  'Dow 1969': 'WRT7VI6X',
#  'Bloch 1967': '5GAQW7DV',
#  'Bloch 1947': 'T9TGS9S6',
#  'McLean 2016': 'H7KAA2TH',
#  'Korhonen 2011': '6HXR6GAN',
#  'Janouchová (Heřmánková) 2021': 'MNRERH36',
#  'Prag 2002': 'CALUBQFC',
#  'Prag 2013': 'NX2YYEWH',
#  'Cooley et al. 2007': 'XQGJDGFJ',
#  'Crema 2012': 'UTITLKQZ',
#  'Johnson 2004': 'EIU8NCUL',
#  'Roueche and Sotinel 2017-03': 'NR7KMK97',
#  'Oksanen and Lewis 2020': 'HGSQZDS4',
#  'Hartmann 2018-10-13': 'YS8ZN82H',
#  'Elliot et al. 2017': 'WNGG6SYB',
#  'Turchin et al. 2018': '5ALKMMVG'}

# %% [markdown]
# # Test with one item

# %%
item_id = "627JE7WX"
url = "https://api.zotero.org/users/2132694/items/" + item_id + "?format=csljson"
item_json = requests.get(url, headers=headers).json()
item_json
# Out:
# {'items': [{'id': '1913534/627JE7WX',
#    'type': 'book',
#    'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#    'publisher': 'Farrar, Straus and Giroux',
#    'publisher-place': 'New York',
#    'event-place': 'New York',
#    'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#    'ISBN': '978-0-312-61169-9',
#    'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#    'language': 'eng',
#    'author': [{'family': 'Morris', 'given': 'Ian'}],
#    'issued': {'date-parts': [[2010]]}}]}

# %%
# list all items within preselected collection:
url = "https://api.zotero.org/users/2132694/collections/" + collection_key + "/items?limit=1000&format=csljson"
collection_items_csljson = requests.get(url, headers=headers).json()
collection_items_csljson["items"][:5]
# Out:
# [{'id': '1913534/4DU2BY28',
#   'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://royalsocietypublishing.org/doi/pdf/10.1098/rsif.2017.0367',
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  {'id': '1913534/FTDUBX6P',
#   'type': 'article',
#   'title': 'Accepted Version',
#   'URL': 'https://ore.exeter.ac.uk/repository/bitstream/10871/36086/2/deleted_FINAL_submission.pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  {'id': '1913534/L47JEQBH',
#   'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  {'id': '1913534/7JEU5M89',
#   'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/pdf',
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  {'id': '1913534/AGSJ79AY',
#   'type': 'article',
#   'title': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf'}]

# %%
citations = {}
for item in collection_items_csljson["items"]:
    try:
        citations[item["id"]] = item
        citations[item["id"]].pop("id", None)
    except:
        pass

# %%
citations
# Out:
# {'1913534/4DU2BY28': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://royalsocietypublishing.org/doi/pdf/10.1098/rsif.2017.0367',
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  '1913534/FTDUBX6P': {'type': 'article',
#   'title': 'Accepted Version',
#   'URL': 'https://ore.exeter.ac.uk/repository/bitstream/10871/36086/2/deleted_FINAL_submission.pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/L47JEQBH': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/7JEU5M89': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/pdf',
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '1913534/AGSJ79AY': {'type': 'article',
#   'title': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf'},
#  '1913534/3LU29L3J': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/49AE839R': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://zenodo.org/record/2593547/files/DeSantis_Rossi_2018_Digital_Epigraphy_book.pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/V36QKWVK': {'type': 'article', 'title': 'Attachment'},
#  '1913534/TVCGWGMN': {'type': 'article',
#   'title': 'Hedrick - 1999 - Democracy and the Athenian Epigraphical Habit.pdf'},
#  '1913534/MG4AUE6B': {'type': 'article',
#   'title': 'Crema2020_JomonPopulationDynamics.pdf'},
#  '1913534/I4SY879G': {'type': 'article',
#   'title': 'Accepted Version',
#   'URL': 'https://helda.helsinki.fi/bitstream/10138/329293/1/Oksanen_and_Lewis_PAS_and_medieval_markets_AJ_100.pdf',
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/Z8JVQ5FX': {'type': 'article', 'title': 'PDF'},
#  '1913534/VDPSKXF2': {'type': 'article',
#   'title': 'Crema - 2012 - Modelling Temporal Uncertainty in Archaeological A.pdf'},
#  '1913534/K5B59T6I': {'type': 'article',
#   'title': 'Turchin_Scheidel_2009_Coin Hoards Speak of Population Declines in Ancient Rome.pdf'},
#  '1913534/J2H5P8TD': {'type': 'article', 'title': 'Attachment'},
#  '1913534/HGK83TQN': {'type': 'article', 'title': 'Attachment'},
#  '1913534/YAFN5N27': {'type': 'article', 'title': 'Attachment'},
#  '1913534/IJPUN3PC': {'type': 'article',
#   'title': 'turchin-et-al_2018_quantitative-historical-analysis.pdf'},
#  '1913534/5MY4KSUI': {'type': 'book',
#   'title': 'Lat Epig 2.0',
#   'publisher': 'Macquarie University',
#   'URL': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#   'author': [{'family': 'Ballsun-Stanton', 'given': 'Brian'}],
#   'issued': {'date-parts': [[2020]]}},
#  '1913534/SYSTIFZQ': {'type': 'chapter',
#   'title': 'City Sizes and Urbanization in the Roman Empire',
#   'container-title': 'Settlement, Urbanization and Population',
#   'collection-title': 'Oxford Studies in the Roman Economy',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'page': '161–195',
#   'event-place': 'Oxford - New York',
#   'ISBN': '0-19-960235-2',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2012]]}},
#  '1913534/C2MUHDNG': {'type': 'article-journal',
#   'title': 'Urbanism and the division of labour in the Roman Empire',
#   'container-title': 'Journal of The Royal Society Interface',
#   'page': '20170367',
#   'volume': '14',
#   'issue': '136',
#   'abstract': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#   'URL': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#   'DOI': '10.1098/rsif.2017.0367',
#   'journalAbbreviation': 'J. R. Soc. Interface.',
#   'language': 'en',
#   'author': [{'family': 'Hanson', 'given': 'J. W.'},
#    {'family': 'Ortman', 'given': 'S. G.'},
#    {'family': 'Lobo', 'given': 'J.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  '1913534/9YX6ZS7N': {'type': 'book',
#   'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'publisher': 'Princeton University Press',
#   'publisher-place': 'Princeton, NJ',
#   'edition': 'Course Book',
#   'event-place': 'Princeton, NJ',
#   'abstract': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#   'ISBN': '1-299-14683-X',
#   'note': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2013]]}},
#  '1913534/627JE7WX': {'type': 'book',
#   'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#   'publisher': 'Farrar, Straus and Giroux',
#   'publisher-place': 'New York',
#   'event-place': 'New York',
#   'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#   'ISBN': '978-0-312-61169-9',
#   'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2010]]}},
#  '1913534/IFEXKMWT': {'type': 'article-journal',
#   'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#   'container-title': 'American Sociological Review',
#   'page': '596-626',
#   'volume': '83',
#   'issue': '3',
#   'abstract': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#   'URL': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#   'DOI': '10.1177/0003122418772567',
#   'journalAbbreviation': 'Am Sociol Rev',
#   'language': 'en',
#   'author': [{'family': 'Mullins', 'given': 'Daniel Austin'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Currie', 'given': 'Thomas'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Savage', 'given': 'Patrick E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'Turchin', 'given': 'Peter'}],
#   'issued': {'date-parts': [['2018']]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/C5MFASAY': {'type': 'article-journal',
#   'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#   'container-title': 'The Journal of Economic History',
#   'page': '803-839',
#   'volume': '76',
#   'issue': '3',
#   'abstract': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#   'URL': 'https://www.cambridge.org/core/article/people-plagues-and-prices-in-the-roman-world-the-evidence-from-egypt/50D27EAD5045D12C1573DFFB5D5C029C',
#   'DOI': '10.1017/S0022050716000826',
#   'author': [{'family': 'Harper', 'given': 'Kyle'}],
#   'issued': {'date-parts': [[2016]]}},
#  '1913534/95I2Q54Z': {'type': 'chapter',
#   'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#   'container-title': 'Roman Roads: New Evidence - New Perspectives',
#   'publisher': 'De Gruyter',
#   'page': '3-21',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#   'ISBN': '978-3-11-063833-2',
#   'note': 'DOI: 10.1515/9783110638332',
#   'author': [{'family': 'Kolb', 'given': 'Anne'}],
#   'editor': [{'family': 'Kolb', 'given': 'Anne'}],
#   'issued': {'date-parts': [[2019, 6, 17]]},
#   'accessed': {'date-parts': [[2021, 5, 19]]}},
#  '1913534/GSAVHWAN': {'type': 'book',
#   'title': 'Big Data, Little Data, No Data',
#   'publisher': 'The MIT Press',
#   'archive': 'JSTOR',
#   'abstract': '"Big Data" is on the covers of<em>Science, Nature</em>, the<em>Economist</em>, and<em>Wired</em>magazines, on the front pages of the<em>Wall Street Journal</em>and the<em>New York Times.</em>But despite the media hyperbole, as Christine Borgman points out in this examination of data and scholarly research, having the right data is usually better than having more data; little data can be just as valuable as big data. In many cases, there are no data -- because relevant data don\'t exist, cannot be found, or are not available. Moreover, data sharing is difficult, incentives to do so are minimal, and data practices vary widely across disciplines.Borgman, an often-cited authority on scholarly communication, argues that data have no value or meaning in isolation; they exist within a knowledge infrastructure -- an ecology of people, practices, technologies, institutions, material objects, and relationships. After laying out the premises of her investigation -- six "provocations" meant to inspire discussion about the uses of data in scholarship -- Borgman offers case studies of data practices in the sciences, the social sciences, and the humanities, and then considers the implications of her findings for scholarly practice and research policy. To manage and exploit data over the long term, Borgman argues, requires massive investment in knowledge infrastructures; at stake is the future of scholarship.',
#   'URL': 'http://www.jstor.org/stable/j.ctt17kk8n8',
#   'ISBN': '978-0-262-02856-1',
#   'author': [{'family': 'Borgman', 'given': 'Christine L.'}],
#   'issued': {'date-parts': [[2015]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/KRXAF9YL': {'type': 'chapter',
#   'title': 'EPIGRAPHY IN 2017',
#   'container-title': 'Changing the Center of Gravity',
#   'publisher': 'Gorgias Press',
#   'page': '203-222',
#   'URL': 'https://www.degruyter.com/document/doi/10.31826/9781463219222-012/html',
#   'ISBN': '978-1-4632-1922-2',
#   'note': 'DOI: 10.31826/9781463219222-012',
#   'editor': [{'family': 'Terras', 'given': 'Melissa'},
#    {'family': 'Crane', 'given': 'Gregory'}],
#   'author': [{'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Roueché', 'given': 'Charlotte'},
#    {'family': 'Elliott', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2010, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/AW6LP4AP': {'type': 'book',
#   'title': 'The roads of Roman Italy: mobility and cultural change',
#   'publisher': 'Routledge',
#   'publisher-place': 'London; New York',
#   'archive': '/z-wcorg/',
#   'event-place': 'London; New York',
#   'abstract': '"The Roads of Roman Italy offers a complete re-evaluation of both the evidence for, and the interpretation of, Roman land transport. The book utilises archaeological, epigraphic and literary evidence for Roman communications, drawing on recent approaches to the human landscape developed by geographers. Among the topics considered are the relationship between the road and the human landscape, the administration and maintenance of the road system, the role of roads as imperial monuments, and the economics of road construction and urban development."--Jacket.',
#   'ISBN': '0-415-16616-0 978-0-415-16616-4',
#   'language': 'English',
#   'author': [{'family': 'Laurence', 'given': 'Ray'}],
#   'issued': {'date-parts': [[1999]]}},
#  '1913534/66WIWW57': {'type': 'article-journal',
#   'title': "The Inscriptions of Aphrodisias as electronic publication: A user's perspective and a proposed paradigm",
#   'container-title': 'Digital Medievalist',
#   'volume': '4',
#   'abstract': 'This paper discusses the value of the electronic medium of\npublication for one project in particular, Inscriptions of Aphrodisias\n(2007), and uses this one example to extrapolate and illustrate a\nuse-case paradigm of electronic publication and its advantages for\nresearch, pedagogy, and dissemination. The categories used in this\nstudy are: accessibility, scale, media, hypertext, updates, and\niterative research and transparency. Not all of these categories\napply equally to any given publication, and the discussion focuses\nDM 4 (2008) The Inscriptions of Aphrodisias as electronic publi... http://www.digitalmedievalist.org/journal/4/bodard/\n1 of 17 6/29/10 1:29 PM\non those that are the most appropriate to a digital publication of\ntagged epigraphic texts and images.',
#   'language': 'eng',
#   'author': [{'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2008]]}},
#  '1913534/4WT5APEZ': {'type': 'chapter',
#   'title': 'EAGLE Continued: IDEA. The International Digital Epigraphy Association',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '216-230',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-018',
#   'shortTitle': '17 EAGLE Continued',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Liuzzo', 'given': 'Pietro M.'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/6ZEVHLM6': {'type': 'book',
#   'title': 'Migration and Mobility in the Early Roman Empire',
#   'publisher': 'BRILL',
#   'URL': 'https://brill.com/view/title/31880',
#   'ISBN': '978-90-04-30736-0 978-90-04-30737-7',
#   'note': 'DOI: 10.1163/9789004307377',
#   'author': [{'family': 'de Ligt', 'given': 'Luuk'},
#    {'family': 'Tacoma', 'given': 'Laurens Ernst'}],
#   'issued': {'date-parts': [[2016, 1, 19]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/B99689HI': {'type': 'book',
#   'title': 'Urban Craftsmen and Traders in the Roman World',
#   'publisher': 'Oxford University Press',
#   'URL': 'https://oxford.universitypressscholarship.com/view/10.1093/acprof:oso/9780198748489.001.0001/acprof-9780198748489',
#   'ISBN': '978-0-19-874848-9',
#   'note': 'DOI: 10.1093/acprof:oso/9780198748489.001.0001\nDOI: 10.1093/acprof:oso/9780198748489.001.0001',
#   'editor': [{'family': 'Wilson', 'given': 'Andrew'},
#    {'family': 'Flohr', 'given': 'Miko'}],
#   'issued': {'date-parts': [[2016, 1, 1]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/A2U4FIKT': {'type': 'chapter',
#   'title': 'Modelling the Dynamics of Demography in the Dutch Roman Limes Zone: A Revised Model',
#   'container-title': 'Finding the Limits of the Limes: Modelling Demography, Economy and Transport on the Edge of the Roman Empire',
#   'publisher': 'Springer International Publishing',
#   'publisher-place': 'Cham',
#   'page': '43–59',
#   'event-place': 'Cham',
#   'abstract': 'In this chapter, a simulation model for better understanding the population dynamics of the limes zone is presented, building on our earlier study on the possible effects of recruitment of soldiers for the Roman army (Verhagen et al., Modelling the dynamics of demography in the Dutch limes zone. In: Multi-, inter- and transdisciplinary research in landscape archaeology. Proceedings of LAC 2014 Conference, Rome, 19–20 September 2014. Vrije Universiteit Amsterdam, Amsterdam. https://doi.org/10.5463/lac.2014.62, 2016a). In this earlier study, a number of questions were raised concerning the realism of using estimates from historical demographical sources for understanding the population dynamics of the region. In the current paper, the available data sets, approaches and hypotheses regarding fertility and mortality in the Roman period are re-assessed, together with the available archaeological evidence on the population dynamics of the region. A revised model is then presented that allows for more refined experimenting with various demographic scenarios, showing that a much larger number of parameters can be responsible for changes in population growth than is often assumed in archaeological studies. In particular, marriage strategies would seem to play an important role in regulating the number of births. The model remains a work in progress that can be further refined and linked to models of settlement and land use development.',
#   'URL': 'https://doi.org/10.1007/978-3-030-04576-0_3',
#   'ISBN': '978-3-030-04576-0',
#   'note': 'DOI: 10.1007/978-3-030-04576-0_3',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'}],
#   'editor': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Joyce', 'given': 'Jamie'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'}],
#   'issued': {'date-parts': [[2019]]}},
#  '1913534/CLBZUHJ7': {'type': 'chapter',
#   'title': 'Archaeology of Germania Inferior: Urbanization',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '91-115',
#   'abstract': 'This chapter focuses on the archaeology of the first urban settlements of Roman type found in\n              Germania Inferior\n              . It first describes\n              coloniae\n              such as the\n              Colonia Claudia Ara Agrippinensium\n              and\n              Colonia Ulpia Traiana\n              , along with the archaeological excavations carried out at the sites. It then turns to the vici, industrial settlements, and agricultural settlements, and concludes with a theoretical explanation of how various forms of urban centres arose in Lower Germany during the period between the Batavian revolt and the Gallic Empire.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-5',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.5',
#   'shortTitle': 'Archaeology of Germania Inferior',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '1913534/AHA9EWZL': {'type': 'article-journal',
#   'title': 'Modeling Epigraphy with an Ontology',
#   'abstract': 'This document is maintained by the Ontology Working Group of Epigraphy.info. (https://epigraphy-info.github.io/epigraphy-info/) Any request or contribution should be made via the Epigraphic Ontology Mailing List of the Epigraphic Ontology WG &lt;epont@googlegroups.com&gt; Contributors are listed alphabetically. Not all listed contributors have confirmed.',
#   'URL': 'https://zenodo.org/record/4639507',
#   'DOI': '10.5281/ZENODO.4639507',
#   'note': 'Publisher: Zenodo\nVersion Number: 0.1',
#   'author': [{'family': 'Bodard', 'given': ''},
#    {'family': 'Cayless', 'given': ''},
#    {'family': 'Cenati', 'given': ''},
#    {'family': 'Cooley', 'given': ''},
#    {'family': 'Elliott', 'given': ''},
#    {'family': 'Evangelisti', 'given': ''},
#    {'family': 'Felicetti', 'given': ''},
#    {'family': 'Granados', 'given': ''},
#    {'family': 'Grieshaber', 'given': ''},
#    {'family': 'Gruber', 'given': ''},
#    {'family': 'Hershkowitz', 'given': ''},
#    {'family': 'Hill', 'given': ''},
#    {'family': 'Kiiskinen', 'given': ''},
#    {'family': 'Kollatz', 'given': ''},
#    {'family': 'Levivier', 'given': ''},
#    {'family': 'Liuzzo', 'given': ''},
#    {'family': 'Luciani', 'given': ''},
#    {'family': 'Mannocci', 'given': ''},
#    {'family': 'Mataix', 'given': ''},
#    {'family': 'Murano', 'given': ''},
#    {'family': 'Murphy', 'given': ''},
#    {'family': 'Mylonas', 'given': ''},
#    {'family': 'Prag', 'given': ''},
#    {'family': 'Razanajao', 'given': ''},
#    {'family': 'Stoyanova', 'given': ''},
#    {'family': 'Tsolakis', 'given': ''},
#    {'family': 'Tupman', 'given': ''},
#    {'family': 'Vagionakis', 'given': ''},
#    {'family': 'Vitale', 'given': ''},
#    {'family': 'Weise', 'given': ''}],
#   'issued': {'date-parts': [[2021, 3, 26]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/LFKD595C': {'type': 'chapter',
#   'title': 'Encoding, Interoperability, Lexicography: Digital Epigraphy Through the Lens of DASI Experience',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '1-18',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-002',
#   'shortTitle': '1 Encoding, Interoperability, Lexicography',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Avanzini', 'given': 'Alessandra'},
#    {'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/37N8YE3I': {'type': 'book',
#   'title': 'Crossing Experiences in Digital Epigraphy: From Practice to Discipline',
#   'publisher': 'De Gruyter',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208',
#   'shortTitle': 'Crossing Experiences in Digital Epigraphy',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/UZDY7HD7': {'type': 'article-journal',
#   'title': 'Galen and the Antonine Plague',
#   'container-title': 'The American Journal of Philology',
#   'page': '243–255',
#   'volume': '94',
#   'issue': '3',
#   'URL': 'http://www.jstor.org/stable/293979',
#   'note': 'Publisher: Johns Hopkins University Press',
#   'author': [{'family': 'Littman', 'given': 'R. J.'},
#    {'family': 'Littman', 'given': 'M. L.'}],
#   'issued': {'date-parts': [[1973]]}},
#  '1913534/33TNUAZ3': {'type': 'article-journal',
#   'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#   'container-title': 'The Journal of Economic History',
#   'page': '803-839',
#   'volume': '76',
#   'issue': '3',
#   'abstract': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0022050716000826/type/journal_article',
#   'DOI': '10.1017/S0022050716000826',
#   'shortTitle': 'People, Plagues, and Prices in the Roman World',
#   'journalAbbreviation': 'J. Econ. Hist.',
#   'language': 'en',
#   'author': [{'family': 'Harper', 'given': 'Kyle'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '1913534/N8MU7LGT': {'type': 'chapter',
#   'title': 'Making up for Lost Time: Digital Epigraphy, Chronology, and the PeriodO Project',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '202-215',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-017',
#   'shortTitle': '16 Making up for Lost Time',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Rabinowitz', 'given': 'Adam'},
#    {'family': 'Shaw', 'given': 'Ryan'},
#    {'family': 'Golden', 'given': 'Patrick'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '1913534/4YVYEDQD': {'type': 'book',
#   'title': 'Epigraphic Evidence: Ancient History from Inscriptions',
#   'collection-title': 'Approaching the ancient world',
#   'publisher': 'Routledge',
#   'URL': 'https://books.google.dk/books?id=Iz5GT7ZfxLsC',
#   'ISBN': '978-0-415-11623-7',
#   'note': 'LCCN: 00059202',
#   'author': [{'family': 'Bodel', 'given': 'J.P.'}],
#   'issued': {'date-parts': [[2001]]}},
#  '1913534/DF62R52E': {'type': 'article-journal',
#   'title': 'A multi-proxy inference of Jōmon population dynamics using bayesian phase models, residential data, and summed probability distribution of 14C dates',
#   'container-title': 'Journal of Archaeological Science',
#   'page': '105136',
#   'volume': '117',
#   'abstract': 'We introduce a new workflow for analysing archaeological frequency data associated with relative rather than absolute chronological time-stamps. Our approach takes into account multiple sources of uncertainty by combining Bayesian chronological models and Monte-Carlo simulation to sample possible calendar dates for each archaeological entity. We argue that when applied to settlement data, this combination of methods can bring new life to demographic proxies that are currently under-used due to their lack of chronological accuracy and pre\xad cision, and provide grounds for further exploring the limits and the potential of the so-called “dates as data” approach based on the temporal frequency of radiocarbon dates. Here we employ this new workflow by reexamining a legacy dataset that has been used to describe a major population rise-and-fall that occurred in central Japan during the Jo�mon period (16,000–2,800 cal BP), focusing on the temporal window between 8,000 and 3,000 cal BP. To achieve this goal we: 1) construct the first Bayesian model of forty-two Jo�mon ceramic typology based cultural phases using a sample of 2,120 radiocarbon dates; 2) apply the proposed workflow on a dataset of 9,612 Jo�mon pit-dwellings; and 3) compare the output to a Summed Probability Distribution (SPD) of 1,550 radiocarbon dates from the same region. Our results provide new estimates on the timing of major de\xad mographic fluctuations during the Jo�mon period and reveal a generally good correlation between the two proxies, although with some notable discrepancies potentially related to changes in settlement pattern.',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0305440320300583',
#   'DOI': '10.1016/j.jas.2020.105136',
#   'journalAbbreviation': 'Journal of Archaeological Science',
#   'language': 'en',
#   'author': [{'family': 'Crema', 'given': 'Enrico R.'},
#    {'family': 'Kobayashi', 'given': "Ken'ichi"}],
#   'issued': {'date-parts': [['2020']]},
#   'accessed': {'date-parts': [[2020, 5, 14]]}},
#  '1913534/MT2ZRZBH': {'type': 'book',
#   'title': 'tempun',
#   'publisher': 'Zenodo',
#   'version': 'v0.1',
#   'abstract': 'No description provided.',
#   'URL': 'https://zenodo.org/record/4650989',
#   'note': 'DOI: 10.5281/ZENODO.4650989',
#   'author': [{'family': 'Kaše', 'given': 'Vojtěch'}],
#   'issued': {'date-parts': [[2021, 3, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/AIJX7C5S': {'type': 'chapter',
#   'title': 'The Limes',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '165-198',
#   'abstract': 'This chapter examines some important themes associated with research on the\n              limes\n              in Roman Germany, with particular emphasis on the ‘Upper German-Raetian\n              Limes\n              ’ and how the form and function of the outer frontiers of the Roman world were influenced by dynamic evolutionary processes. Before discussing how the\n              limes\n              took on a role as an ‘imperial/barbarian boundary’, the chapter considers the function of boundaries in general and the\n              limes\n              in particular. It then traces historic developments of the\n              limites\n              and their use in erecting frontier installations, watchtowers, and fortlets. It also looks at the crossing points through the\n              limes\n              that have survived in relatively high numbers in\n              Germania Superior\n              and\n              Raetia\n              ; the legions as the backbone of frontier defence; and auxiliary troops (\n              auxilia\n              ) that occupied the frontier along the Rhine in\n              Germania Inferior\n              and the Upper German-Raetian\n              Limes\n              during the second and third centuries AD.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-7',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.7',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '1913534/XJBYYW4X': {'type': 'article-journal',
#   'title': "Now you see them, now you don't: Defining and using a flexible chronology of sites for spatial analysis of Roman settlement in the Dutch river area",
#   'container-title': 'Journal of Archaeological Science: Reports',
#   'page': '309-321',
#   'volume': '10',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S2352409X16303832',
#   'DOI': '10.1016/j.jasrep.2016.10.006',
#   'shortTitle': "Now you see them, now you don't",
#   'journalAbbreviation': 'Journal of Archaeological Science: Reports',
#   'language': 'en',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Vossen', 'given': 'Ivo'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'},
#    {'family': 'Joyce', 'given': 'Jamie'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '1913534/V9UVGQX2': {'type': 'webpage',
#   'title': 'Understanding Roman inscriptions',
#   'abstract': 'This is the first comprehensive treatment in English to provide an explanation of not only the language of inscriptions but also the context in which they were produced.',
#   'URL': 'http://site.ebrary.com/id/10062897',
#   'note': 'Archive: /z-wcorg/\nISBN: 0203084675 9780203084670 9780203707357 0203707354 9781134746125 1134746121 9781134746163 1134746164 9781134746170 1134746172 9781138142923 1138142921 9780415151436 0415151430 9786610539277 6610539278 1280539275 9781280539275\nLibrary Catalog: http://worldcat.org\nPlace: Baltimore\nPublisher: Johns Hopkins University Press',
#   'language': 'English.',
#   'author': [{'family': 'Keppie', 'given': 'L. J. F.'}],
#   'issued': {'date-parts': [[1991]]}},
#  '1913534/6YVHFFUJ': {'type': 'book',
#   'title': 'Quantifying the Roman Economy: Methods and Problems',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'event-place': 'Oxford - New York',
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2009]]}},
#  '1913534/U48VTMSM': {'type': 'article-journal',
#   'title': 'Coin Hoards Speak of Population Declines in Ancient Rome',
#   'container-title': 'Proceedings of the National Academy of Sciences of the United States of America',
#   'page': '17276–17279',
#   'volume': '106',
#   'abstract': 'In times of violence, people tend to hide their valuables, which are later recovered unless the owners had been killed or driven away. Thus, the temporal distribution of unrecovered coin hoards is an excellent proxy for the intensity of internal warfare. We use this relationship to resolve a long-standing controversy in Roman history. Depending on who was counted in the early Imperial censuses (adult males or the entire citizenry including women and minors), the Roman citizen population of Italy either declined, or more than doubled, during the first century BCE. This period was characterized by a series of civil wars, and historical evidence indicates that high levels of sociopolitical instability are associated with demographic contractions. We fitted a simple model quantifying the effect of instability (proxied by hoard frequency) on population dynamics to the data before 100 BCE. The model predicts declining population after 100 BCE. This suggests that the vigorous growth scenario is highly implausible.',
#   'DOI': '10.1073/pnas.0904576106',
#   'note': 'PMID: 19805043',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Scheidel', 'given': 'Walter'}],
#   'issued': {'date-parts': [[2009]]}},
#  '1913534/2LT8WIGC': {'type': 'article-journal',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'container-title': 'Hesperia',
#   'page': '387-439',
#   'volume': '68',
#   'issue': '3',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'DOI': '10.2307/148494',
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'issued': {'date-parts': [[1999]]},
#   'accessed': {'date-parts': [[2019, 11, 21]]}},
#  '1913534/6CHTC3L7': {'type': 'chapter',
#   'title': 'The “Epigraphic Habit” in the Roman World',
#   'container-title': 'The Oxford Handbook of Roman Epigraphy',
#   'collection-title': 'Oxford Handbooks',
#   'publisher': 'Oxford University Press',
#   'volume': '1',
#   'abstract': 'Since the 1980s scholars have ceased considering Roman inscriptions simply in functional terms—as sources of historical information—and started to treat them as a cultural phenomenon worthy of serious consideration. This change in perspective, as well as the realization that there was a permanent bond between text and monument, represents the most productive shift in approach in recent epigraphic scholarship. This chapter analyzes the “epigraphic habit” in order to explain why people wrote on stone throughout Italy and the provinces, linking its rise to the proliferation of urbanization, literacy, and the desire for self-representation.',
#   'ISBN': '0-19-533646-1',
#   'language': 'eng',
#   'author': [{'family': 'Beltrán Lloris', 'given': 'Francisco'}],
#   'issued': {'date-parts': [[2014]]}},
#  '1913534/NEGLBLPH': {'type': 'book',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'publisher': 'Routledge',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'ISBN': '978-1-00-302530-6',
#   'note': 'DOI: 10.4324/9781003025306',
#   'language': 'en',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/GDRQEX9Z': {'type': 'book',
#   'title': 'The Epigraphic Cultures of Late Antiquity',
#   'collection-title': 'Alte Geschichte',
#   'publisher': 'Franz Steiner Verlag',
#   'URL': 'https://books.google.dk/books?id=iJBdMQAACAAJ',
#   'ISBN': '978-3-515-11558-2',
#   'author': [{'family': 'Bolle', 'given': 'K.'},
#    {'family': 'Machado', 'given': 'C.'},
#    {'family': 'Witschel', 'given': 'C.'}],
#   'issued': {'date-parts': [[2017]]}},
#  '1913534/XUF75FS9': {'type': 'post-weblog',
#   'title': 'Working with databases: The case of the Epigraphik-Datenbank Clauss/Slaby (EDCS)',
#   'container-title': 'DOCTORAL TRAINING UNIT “DIGITAL HISTORY & HERMENEUTICS”',
#   'genre': 'Université du Luxembourg',
#   'URL': 'https://dhh.uni.lu/2020/07/10/working-with-databases-the-case-of-the-epigraphik-datenbank-clauss-slaby-edcs/',
#   'language': 'English',
#   'author': [{'family': 'Lotz', 'given': 'Jan'}],
#   'issued': {'date-parts': [[2020, 10, 7]]},
#   'accessed': {'date-parts': [[2021, 7, 5]]}},
#  '1913534/BGNB6HUT': {'type': 'article-journal',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'container-title': 'The American Journal of Philology',
#   'page': '233',
#   'volume': '103',
#   'issue': '3',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'DOI': '10.2307/294470',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'issued': {'date-parts': [[1982]]}},
#  '1913534/8AAUR7HD': {'type': 'article-journal',
#   'title': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy: The End of a Habit?',
#   'container-title': 'Historia',
#   'page': '116-132',
#   'volume': '70',
#   'issue': '1',
#   'abstract': '<p>The political communities of western Asia Minor produced an enormous amount of inscriptions under Roman rule. For the period between AD 260 and 280, however, the epigraphic habit falls dramatically and this situation largely continues in the 4<sup>th</sup> and 5<sup>th</sup> centuries. The aim of this paper is to analyse the phenomenon in the transitional Tetrarchic age, when a notable increase in testimony, particularly milestones and texts related to the new regime (e. g. ‘Edict of Prices’), can be observed. My study of continuities and changes concludes that the propagandistic efforts under the Tetrarchs did not ultimately coincide with a full reactivation of civic epigraphic culture and this new scenario should remain fundamental for our assessment of Late Antiquity in the region.</p>',
#   'URL': 'https://elibrary.steiner-verlag.de/article/10.25162/historia-2021-0006',
#   'DOI': '10.25162/historia-2021-0006',
#   'shortTitle': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy',
#   'journalAbbreviation': 'historia',
#   'language': 'en',
#   'author': [{'family': 'Pérez', 'given': 'Aitor Blanco'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/F3Y2FVVY': {'type': 'chapter',
#   'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#   'container-title': 'A Companion to Late Antiquity',
#   'publisher': 'John Wiley & Sons, Ltd',
#   'page': '170-186',
#   'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#   'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#   'ISBN': '978-1-4443-0610-1',
#   'note': 'DOI: 10.1002/9781444306101.ch12',
#   'shortTitle': 'Inscribing Identity',
#   'language': 'en',
#   'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/7KH8X6PB': {'type': 'article-journal',
#   'title': 'Digital Epigraphy am Scheideweg? / Digital Epigraphy at a crossroads?',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/22141',
#   'DOI': '10.11588/HEIDOK.00022141',
#   'note': 'Publisher: Heidelberg University Library',
#   'shortTitle': 'Digital Epigraphy am Scheideweg?',
#   'author': [{'family': 'Feraudi-Gruénais', 'given': 'Francisca'},
#    {'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2016]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/DBL5UIX2': {'type': 'article-journal',
#   'title': 'Epigraphic Database Heidelberg – Data Reuse Options',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/26599',
#   'DOI': '10.11588/HEIDOK.00026599',
#   'note': 'Publisher: Heidelberg University Library',
#   'author': [{'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2019]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/HBPZKHXT': {'type': 'article-journal',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'container-title': 'Journal of Roman Studies',
#   'page': '22–39',
#   'volume': '86',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'DOI': '10.2307/300421',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'issued': {'date-parts': [[1996]]}},
#  '1913534/BADWX5AX': {'type': 'book',
#   'title': 'EpiDoc Guidelines: Ancient documents in TEI XML',
#   'URL': 'https://epidoc.stoa.org/gl/latest/',
#   'language': 'eng',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Mylonas', 'given': 'Elli'},
#    {'family': 'Stoyanova', 'given': 'Simona'},
#    {'family': 'Tupman', 'given': 'Charlotte'},
#    {'family': 'Vanderbilt', 'given': 'Scott'}],
#   'issued': {'date-parts': [[2020]]}},
#  '1913534/ARJNJ286': {'type': 'book',
#   'title': 'Epigraphic evidence: ancient history from inscriptions',
#   'collection-number': '4',
#   'publisher': 'Routledge',
#   'publisher-place': 'London, New York',
#   'volume': '61',
#   'number-of-pages': '1019–1020',
# ...
#   'DOI': '10.2307/300281',
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'issued': {'date-parts': [[1990]]}},
#  '1913534/WRT7VI6X': {'type': 'book',
#   'title': 'Conventions in editing : A suggested reformulation of the Leiden system.',
#   'collection-title': 'Greek, Roman and Byzantine scholarly Aids ; No. 2.',
#   'publisher': 'Duke University',
#   'publisher-place': 'Durham',
#   'event-place': 'Durham',
#   'language': 'eng',
#   'author': [{'family': 'Dow', 'given': 'Sterling'}],
#   'issued': {'date-parts': [[1969]]}},
#  '1913534/5GAQW7DV': {'type': 'book',
#   'title': 'The Roman brick stamps not published in Vol. XI, 1 of the Corpus inscriptionum Latinarum, including Indices to the Roman brick-stamps.',
#   'publisher': '"L\'Erma" di Bretschneider',
#   'publisher-place': 'Roma',
#   'edition': 'Ed. anastat.',
#   'event-place': 'Roma',
#   'language': 'ita',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1967]]}},
#  '1913534/T9TGS9S6': {'type': 'article-journal',
#   'title': 'The Roman Brick-Stamps not Published in Volume XV 1 of the "Corpus Inscriptionum Latinarum"',
#   'container-title': 'Harvard Studies in Classical Philology',
#   'page': '1',
#   'volume': '56',
#   'URL': 'https://www.jstor.org/stable/310746?origin=crossref',
#   'DOI': '10.2307/310746',
#   'journalAbbreviation': 'Harvard Studies in Classical Philology',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1947]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/H7KAA2TH': {'type': 'book',
#   'title': 'An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan',
#   'publisher': 'The University of Michigan Press',
#   'publisher-place': 'Ann Arbor',
#   'event-place': 'Ann Arbor',
#   'note': 'Publication Title: An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan\nDOI: 10.3998/mpub.23012',
#   'author': [{'family': 'McLean', 'given': 'Bradley'}],
#   'issued': {'date-parts': [[2016]]}},
#  '1913534/6HXR6GAN': {'type': 'chapter',
#   'title': 'Language and Identity in the Roman Colonies of Sicily',
#   'container-title': 'Roman Colonies in the First Century of their Foundation',
#   'publisher': 'Oxbow Books',
#   'publisher-place': 'Oxford',
#   'page': '7–31',
#   'event-place': 'Oxford',
#   'ISBN': '978-1-84217-974-1',
#   'author': [{'family': 'Korhonen', 'given': 'Kalle'}],
#   'editor': [{'family': 'Sweetman', 'given': 'Rebecca J'}],
#   'issued': {'date-parts': [[2011]]}},
#  '1913534/MNRERH36': {'type': 'chapter',
#   'title': 'Quantitative approaches to epigraphy: Epigraphic production in Thrace as a mirror of social organization',
#   'container-title': 'Peoples in the Black Sea Region from the Archaic to the Roman Period, Proceedings of the 3rd International Workshop on the Black Sea in Antiquity “ Thessaloniki, 21-23 September 2018',
#   'publisher': 'Archaeopress',
#   'publisher-place': 'Oxford',
#   'page': '83–93',
#   'event-place': 'Oxford',
#   'author': [{'family': 'Janouchová (Heřmánková)', 'given': 'Petra'}],
#   'editor': [{'family': 'Manoledakis', 'given': 'Manolis'}],
#   'issued': {'date-parts': [[2021]]}},
#  '1913534/CALUBQFC': {'type': 'chapter',
#   'title': 'Epigraphy by numbers: Latin and the epigraphic culture in Sicily',
#   'container-title': 'Becoming Roman, writing Latin? Literacy and Epigraphy in the Roman West',
#   'publisher': 'Journal of Roman Archaeology',
#   'publisher-place': 'Portsmouth, Rhode Island',
#   'page': '15–31',
#   'event-place': 'Portsmouth, Rhode Island',
#   'author': [{'family': 'Prag', 'given': 'Jonathan'}],
#   'editor': [{'family': 'Cooley', 'given': 'Alison E.'}],
#   'issued': {'date-parts': [[2002]]}},
#  '1913534/NX2YYEWH': {'type': 'chapter',
#   'title': 'Epigraphy in the western Mediterranean: a Hellenistic phenomenon?',
#   'container-title': 'The Hellenistic West: Rethinking the Ancient Mediterranean',
#   'publisher': 'Cambridge University Press',
#   'publisher-place': 'Cambridge, New York',
#   'page': '320–347',
#   'event-place': 'Cambridge, New York',
#   'abstract': "Although the Hellenistic period has become increasingly popular in research and teaching in recent years, the western Mediterranean is rarely considered part of the 'Hellenistic world'; instead the cities, peoples and kingdoms of the West are usually only discussed insofar as they relate to Rome. This book contends that the rift between the 'Greek East' and the 'Roman West' is more a product of the traditional separation of Roman and Greek history than a reflection of the Hellenistic-period Mediterranean, which was a strongly interconnected cultural and economic zone, with the rising Roman republic just one among many powers in the region, east and west. The contributors argue for a dynamic reading of the economy, politics and history of the central and western Mediterranean beyond Rome, and in doing so problematise the concepts of 'East', 'West' and 'Hellenistic' itself.",
#   'author': [{'family': 'Prag', 'given': 'Jonathan'}],
#   'editor': [{'family': 'Prag', 'given': 'Jonathan R. W.'},
#    {'family': 'Quinn', 'given': 'Josephine Crawley'}],
#   'issued': {'date-parts': [[2013]]}},
#  '1913534/XQGJDGFJ': {'type': 'article-journal',
#   'title': 'Roman Inscriptions 2001-2005',
#   'container-title': 'The Journal of Roman Studies',
#   'page': '176–263',
#   'volume': '97',
#   'URL': 'http://www.jstor.org/stable/20430576',
#   'note': 'Publisher: [Society for the Promotion of Roman Studies, Cambridge University Press]',
#   'author': [{'family': 'Cooley', 'given': 'Alison E.'},
#    {'family': 'Mitchell', 'given': 'Stephen'},
#    {'family': 'Salway', 'given': 'Benet'}],
#   'issued': {'date-parts': [[2007]]}},
#  '1913534/UTITLKQZ': {'type': 'article-journal',
#   'title': 'Modelling Temporal Uncertainty in Archaeological Analysis',
#   'container-title': 'Journal of Archaeological Method and Theory',
#   'page': '440-461',
#   'volume': '19',
#   'issue': '3',
#   'abstract': 'This paper discusses the problem of temporal uncertainty in archaeological analysis and how it affects archaeological interpretation. A probabilistic method is proposed as a potential solution for modelling and quantifying time when high levels of uncertainty restricts temporal knowledge and scientific datings are unavailable, while Monte Carlo simulation is suggested as a means to formally integrate such knowledge into actual analysis. A case study focusing on counts of prehistoric hunter–gatherer pithouses in Mid-Holocene Japan provides an example of how uncertainty can be problematic and bias the results of the most straightforward archaeological analysis and how the coupling of a probabilistic and simulation-based approach nonetheless offers a useful solution. The discussion that follows also addresses the need for more robust and quantifiable ways to illustrate the chronological flow of our archaeological narratives.',
#   'URL': 'http://link.springer.com/10.1007/s10816-011-9122-3',
#   'DOI': '10.1007/s10816-011-9122-3',
#   'journalAbbreviation': 'J Archaeol Method Theory',
#   'language': 'en',
#   'author': [{'family': 'Crema', 'given': 'Enrico R.'}],
#   'issued': {'date-parts': [['2012']]},
#   'accessed': {'date-parts': [[2019, 11, 20]]}},
#  '1913534/EIU8NCUL': {'type': 'article-journal',
#   'title': 'Aoristic Analysis: Seeds of a New Approach to Mapping Archaeological Distributions through Time',
#   'container-title': 'Computer Applications in Archaeology',
#   'page': '448-452',
#   'volume': '2003',
#   'URL': 'https://publikationen.uni-tuebingen.de/xmlui/handle/10900/60663',
#   'DOI': '10.15496/PUBLIKATION-2085',
#   'note': 'Publisher: Universitätsbibliothek Tübingen',
#   'shortTitle': 'Aoristic Analysis',
#   'language': 'en',
#   'author': [{'family': 'Johnson', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2004]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/NR7KMK97': {'type': 'chapter',
#   'title': 'Christian and Late Antique Epigraphies',
#   'container-title': 'The Epigraphic Cultures of Late Antiquity',
#   'publisher': 'Franz Steiner Verlag',
#   'page': '503–514',
#   'ISBN': '978-3-515-11558-2',
#   'language': 'English',
#   'author': [{'family': 'Roueche', 'given': 'Charlotte Mary'},
#    {'family': 'Sotinel', 'given': 'Claire'}],
#   'editor': [{'family': 'Bolle', 'given': 'Katharina'},
#    {'family': 'Machado', 'given': 'Carlos'},
#    {'family': 'Witschel', 'given': 'Christian'}],
#   'issued': {'date-parts': [['2017', 3]]}},
#  '1913534/HGSQZDS4': {'type': 'article-journal',
#   'title': 'Medieval Commercial Sites: As Seen Through Portable Antiquities Scheme Data',
#   'container-title': 'The Antiquaries Journal',
#   'page': '109-140',
#   'volume': '100',
#   'abstract': 'This paper explores some 220,000 medieval objects recorded in the Portable Antiquities Scheme (PAS) online database of archaeological small finds through Geographic Information System analysis of their relationship with contemporary market sites. First, an overview of the contents of the PAS database is presented in terms of its spatial and ‘object type’ distribution. Second, the relationship of the medieval finds data against documentary evidence of commercial activity is investigated at a national level. Finally, PAS data is contextualised in its historical landscape context through case studies. It is argued that the distribution of PAS finds on the national scale can be linked with patterns of commercial activity, and that while rural and urban finds scatters have distinguishing trends, the countryside population enjoyed access to a range of sophisticated metalwork culture; also, that certain assemblages can be analysed statistically to yield new data and perspectives on local historical development.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0003581520000165/type/journal_article',
#   'DOI': '10.1017/S0003581520000165',
#   'shortTitle': 'MEDIEVAL COMMERCIAL SITES',
#   'journalAbbreviation': 'Antiq. J.',
#   'language': 'en',
#   'author': [{'family': 'Oksanen', 'given': 'Eljas'},
#    {'family': 'Lewis', 'given': 'Michael'}],
#   'issued': {'date-parts': [['2020']]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/YS8ZN82H': {'type': 'article-journal',
#   'title': 'Rezension zu: Epigraphische Datenbank Heidelberg',
#   'container-title': 'H-Soz-Kult',
#   'URL': 'https://www.hsozkult.de/webreview/id/rezwww-179',
#   'language': 'ger',
#   'author': [{'family': 'Hartmann', 'given': 'Andreas'}],
#   'issued': {'date-parts': [[2018, 10, 13]]}},
#  '1913534/WNGG6SYB': {'type': 'book',
#   'title': 'EpiDoc Reference Stylesheets (version 9)',
#   'abstract': 'XSLT for transformation of EpiDoc XML files into HTML or text versions in Leiden. Includes various XML files containing parameters and other options.',
#   'URL': 'https://sourceforge.net/p/epidoc/wiki/Stylesheets/',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Au', 'given': 'Zaneta'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Lanz', 'given': 'Carmen'},
#    {'family': 'Lawrence', 'given': 'Faith'},
#    {'family': 'Vanderbilt', 'given': 'Scott'},
#    {'family': 'Viglianti', 'given': 'Raffaele'}],
#   'issued': {'date-parts': [[2017]]}},
#  '1913534/5ALKMMVG': {'type': 'article-journal',
#   'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'page': 'E144-E151',
#   'volume': '115',
#   'issue': '2',
#   'abstract': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#   'DOI': '10.1073/pnas.1708800115',
#   'note': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Currie', 'given': 'Thomas E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'Mullins', 'given': 'Daniel'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Grohmann', 'given': 'Stephanie'},
#    {'family': 'Savage', 'given': 'Patrick'},
#    {'family': 'Mendel-Gleason', 'given': 'Gavin'},
#    {'family': 'Turner', 'given': 'Edward'},
#    {'family': 'Dupeyron', 'given': 'Agathe'},
#    {'family': 'Cioni', 'given': 'Enrico'},
#    {'family': 'Reddish', 'given': 'Jenny'},
#    {'family': 'Levine', 'given': 'Jill'},
#    {'family': 'Jordan', 'given': 'Greine'},
#    {'family': 'Brandl', 'given': 'Eva'},
#    {'family': 'Williams', 'given': 'Alice'},
#    {'family': 'Cesaretti', 'given': 'Rudolf'},
#    {'family': 'Krueger', 'given': 'Marta'},
#    {'family': 'Ceccarelli', 'given': 'Alessandro'},
#    {'family': 'Figliulo-Rosswurm', 'given': 'Joe'},
#    {'family': 'Tuan', 'given': 'Po-Ju'},
#    {'family': 'Peregrine', 'given': 'Peter'},
#    {'family': 'Marciniak', 'given': 'Arkadiusz'},
#    {'family': 'Preiser-Kapeller', 'given': 'Johannes'},
#    {'family': 'Kradin', 'given': 'Nikolay'},
#    {'family': 'Korotayev', 'given': 'Andrey'},
#    {'family': 'Palmisano', 'given': 'Alessio'},
#    {'family': 'Baker', 'given': 'David'},
#    {'family': 'Bidmead', 'given': 'Julye'},
#    {'family': 'Bol', 'given': 'Peter'},
#    {'family': 'Christian', 'given': 'David'},
#    {'family': 'Cook', 'given': 'Connie'},
#    {'family': 'Covey', 'given': 'Alan'},
#    {'family': 'Feinman', 'given': 'Gary'},
#    {'family': 'Júlíusson', 'given': 'Árni Daníel'},
#    {'family': 'Kristinsson', 'given': 'Axel'},
#    {'family': 'Miksic', 'given': 'John'},
#    {'family': 'Mostern', 'given': 'Ruth'},
#    {'family': 'Petrie', 'given': 'Cameron'},
#    {'family': 'Rudiak-Gould', 'given': 'Peter'},
#    {'family': 'ter Haar', 'given': 'Barend'},
#    {'family': 'Wallace', 'given': 'Vesna'},
#    {'family': 'Mair', 'given': 'Victor'},
#    {'family': 'Xie', 'given': 'Liye'},
#    {'family': 'Baines', 'given': 'John'},
#    {'family': 'Bridges', 'given': 'Elizabeth'},
#    {'family': 'Manning', 'given': 'Joseph'},
#    {'family': 'Lockhart', 'given': 'Bruce'},
#    {'family': 'Bogaard', 'given': 'Amy'},
#    {'family': 'Spencer', 'given': 'Charles'}],
#   'issued': {'date-parts': [[2018]]}}}

# %%
# list all items within preselected collection:
url = "https://api.zotero.org/users/2132694/collections/" + collection_key + "/items?limit=1000"
collection_items_rawjson = requests.get(url, headers=headers).json()
collection_items_rawjson[:5]
# Out:
# [{'key': '4DU2BY28',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/4DU2BY28',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/4DU2BY28',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/C2MUHDNG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '4DU2BY28',
#    'version': 2829,
#    'parentItem': 'C2MUHDNG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-18T11:04:52Z',
#    'url': 'https://royalsocietypublishing.org/doi/pdf/10.1098/rsif.2017.0367',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Hanson et al. - 2017 - Urbanism and the division of labour in the Roman E.pdf',
#    'md5': '79b6036c9ae46b01d4220a030d53d267',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/XIXVPIM6'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'FTDUBX6P',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/FTDUBX6P',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/FTDUBX6P',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/IFEXKMWT',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'FTDUBX6P',
#    'version': 2829,
#    'parentItem': 'IFEXKMWT',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Accepted Version',
#    'accessDate': '2021-05-17T13:56:04Z',
#    'url': 'https://ore.exeter.ac.uk/repository/bitstream/10871/36086/2/deleted_FINAL_submission.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Mullins et al. - 2018 - A Systematic Assessment of “Axial Age” Proposals U.pdf',
#    'md5': 'adf11660ed230bc904e56dca26ad60bb',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/DCMSZNZ4'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'L47JEQBH',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/L47JEQBH',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/L47JEQBH',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/4WT5APEZ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'L47JEQBH',
#    'version': 2829,
#    'parentItem': '4WT5APEZ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:20:02Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 17 EAGLE Continued IDEA. The International Digita.pdf',
#    'md5': 'a541ac0949a58b0e2463f1be9532a54f',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/TMVXV8KZ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': '7JEU5M89',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/7JEU5M89',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/7JEU5M89',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/N8MU7LGT',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '7JEU5M89',
#    'version': 2829,
#    'parentItem': 'N8MU7LGT',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-14T09:57:31Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 16 Making up for Lost Time Digital Epigraphy, Chr.pdf',
#    'md5': '23080e24a3216c4047d3ad49fe242528',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/NDQPHA65'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  {'key': 'AGSJ79AY',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/AGSJ79AY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/AGSJ79AY',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/SYSTIFZQ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'AGSJ79AY',
#    'version': 2829,
#    'parentItem': 'SYSTIFZQ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf',
#    'md5': '361eb415ef014d66f52bd62a750bdbc7',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/53ISVBX3'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}}]

# %%
collection_items_dict = dict([(el["key"], el) for el in collection_items_rawjson])

# %%
collection_items_dict
# Out:
# {'4DU2BY28': {'key': '4DU2BY28',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/4DU2BY28',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/4DU2BY28',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/C2MUHDNG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '4DU2BY28',
#    'version': 2829,
#    'parentItem': 'C2MUHDNG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-18T11:04:52Z',
#    'url': 'https://royalsocietypublishing.org/doi/pdf/10.1098/rsif.2017.0367',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Hanson et al. - 2017 - Urbanism and the division of labour in the Roman E.pdf',
#    'md5': '79b6036c9ae46b01d4220a030d53d267',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/XIXVPIM6'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'FTDUBX6P': {'key': 'FTDUBX6P',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/FTDUBX6P',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/FTDUBX6P',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/IFEXKMWT',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'FTDUBX6P',
#    'version': 2829,
#    'parentItem': 'IFEXKMWT',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Accepted Version',
#    'accessDate': '2021-05-17T13:56:04Z',
#    'url': 'https://ore.exeter.ac.uk/repository/bitstream/10871/36086/2/deleted_FINAL_submission.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Mullins et al. - 2018 - A Systematic Assessment of “Axial Age” Proposals U.pdf',
#    'md5': 'adf11660ed230bc904e56dca26ad60bb',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/DCMSZNZ4'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'L47JEQBH': {'key': 'L47JEQBH',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/L47JEQBH',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/L47JEQBH',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/4WT5APEZ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'L47JEQBH',
#    'version': 2829,
#    'parentItem': '4WT5APEZ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:20:02Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 17 EAGLE Continued IDEA. The International Digita.pdf',
#    'md5': 'a541ac0949a58b0e2463f1be9532a54f',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/TMVXV8KZ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '7JEU5M89': {'key': '7JEU5M89',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/7JEU5M89',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/7JEU5M89',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/N8MU7LGT',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '7JEU5M89',
#    'version': 2829,
#    'parentItem': 'N8MU7LGT',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-14T09:57:31Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 16 Making up for Lost Time Digital Epigraphy, Chr.pdf',
#    'md5': '23080e24a3216c4047d3ad49fe242528',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/NDQPHA65'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'AGSJ79AY': {'key': 'AGSJ79AY',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/AGSJ79AY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/AGSJ79AY',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/SYSTIFZQ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'AGSJ79AY',
#    'version': 2829,
#    'parentItem': 'SYSTIFZQ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf',
#    'md5': '361eb415ef014d66f52bd62a750bdbc7',
#    'mtime': 1622099548000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/53ISVBX3'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '3LU29L3J': {'key': '3LU29L3J',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/3LU29L3J',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/3LU29L3J',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/LFKD595C',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '3LU29L3J',
#    'version': 2829,
#    'parentItem': 'LFKD595C',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:27:40Z',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - 1 Encoding, Interoperability, Lexicography Digita.pdf',
#    'md5': '1d2b5a559c816e6ed22b8abe3a135882',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/66R9JXZI'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '49AE839R': {'key': '49AE839R',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/49AE839R',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/49AE839R',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/37N8YE3I',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': '49AE839R',
#    'version': 2829,
#    'parentItem': '37N8YE3I',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Full Text',
#    'accessDate': '2021-05-17T09:10:37Z',
#    'url': 'https://zenodo.org/record/2593547/files/DeSantis_Rossi_2018_Digital_Epigraphy_book.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'De Santis and Rossi - 2018 - Crossing Experiences in Digital Epigraphy From Pr.pdf',
#    'md5': '89dafc461cca554441d0f0bde48bea38',
#    'mtime': 1622099547000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/5NQCCQJV'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'V36QKWVK': {'key': 'V36QKWVK',
#   'version': 2829,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/V36QKWVK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/V36QKWVK',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/U48VTMSM',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'V36QKWVK',
#    'version': 2829,
#    'parentItem': 'U48VTMSM',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Turchin, Scheidel - 2009 - Coin Hoards Speak of Population Declines in Ancient Rome.pdf',
#    'md5': '216bae77c5778834695351cf72c2e4b5',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/RSDIDT42'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'TVCGWGMN': {'key': 'TVCGWGMN',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/TVCGWGMN',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/TVCGWGMN',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/2LT8WIGC',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'TVCGWGMN',
#    'version': 2828,
#    'parentItem': '2LT8WIGC',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Hedrick - 1999 - Democracy and the Athenian Epigraphical Habit.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Hedrick - 1999 - Democracy and the Athenian Epigraphical Habit.pdf',
#    'md5': '351291b72289761a5776a2dc11b24deb',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/375MJWAQ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'MG4AUE6B': {'key': 'MG4AUE6B',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/MG4AUE6B',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/MG4AUE6B',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/DF62R52E',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'MG4AUE6B',
#    'version': 2828,
#    'parentItem': 'DF62R52E',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Crema2020_JomonPopulationDynamics.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Crema2020_JomonPopulationDynamics.pdf',
#    'md5': 'fafcfe9f56b9f2154529290743f4aa2a',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/PUGS2NNW'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'I4SY879G': {'key': 'I4SY879G',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/I4SY879G',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/I4SY879G',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/HGSQZDS4',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'I4SY879G',
#    'version': 2828,
#    'parentItem': 'HGSQZDS4',
#    'itemType': 'attachment',
#    'linkMode': 'imported_url',
#    'title': 'Accepted Version',
#    'accessDate': '2021-05-10T13:50:55Z',
#    'url': 'https://helda.helsinki.fi/bitstream/10138/329293/1/Oksanen_and_Lewis_PAS_and_medieval_markets_AJ_100.pdf',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Oksanen and Lewis - 2020 - MEDIEVAL COMMERCIAL SITES AS SEEN THROUGH PORTABL.pdf',
#    'md5': 'f0ed9df6f6be4d68e00046054580364a',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/S73ZB82A'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'Z8JVQ5FX': {'key': 'Z8JVQ5FX',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/Z8JVQ5FX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/Z8JVQ5FX',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/5ALKMMVG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'Z8JVQ5FX',
#    'version': 2828,
#    'parentItem': '5ALKMMVG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'PDF',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Turchin et al. - 2018 - Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in h.pdf',
#    'md5': '1df9a98c175bde2398461a0b23095cdc',
#    'mtime': 1622099543000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/BMH24W79'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'VDPSKXF2': {'key': 'VDPSKXF2',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/VDPSKXF2',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/VDPSKXF2',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/UTITLKQZ',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'VDPSKXF2',
#    'version': 2828,
#    'parentItem': 'UTITLKQZ',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Crema - 2012 - Modelling Temporal Uncertainty in Archaeological A.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Crema - 2012 - Modelling Temporal Uncertainty in Archaeological A.pdf',
#    'md5': '62e0029a560ced451027ca3c1b5f9f7f',
#    'mtime': 1622099543000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/GSUL5APN'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'K5B59T6I': {'key': 'K5B59T6I',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/K5B59T6I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/K5B59T6I',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/U48VTMSM',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'K5B59T6I',
#    'version': 2828,
#    'parentItem': 'U48VTMSM',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Turchin_Scheidel_2009_Coin Hoards Speak of Population Declines in Ancient Rome.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Turchin_Scheidel_2009_Coin Hoards Speak of Population Declines in Ancient Rome.pdf',
#    'md5': '216bae77c5778834695351cf72c2e4b5',
#    'mtime': 1622099545000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/UL6SNGC7'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'J2H5P8TD': {'key': 'J2H5P8TD',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/J2H5P8TD',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/J2H5P8TD',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/6HXR6GAN',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'J2H5P8TD',
#    'version': 2828,
#    'parentItem': '6HXR6GAN',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Korhonen - 2011 - Language and Identity in the Roman Colonies of Sicily.pdf',
#    'md5': 'c8ae053b8e010f4402b60d79bf234eb4',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/CKMLTI64'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'HGK83TQN': {'key': 'HGK83TQN',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/HGK83TQN',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/HGK83TQN',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/CALUBQFC',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'HGK83TQN',
#    'version': 2828,
#    'parentItem': 'CALUBQFC',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Prag - 2002 - Epigraphy by numbers Latin and the epigraphic culture in Sicily.pdf',
#    'md5': '8a9549c8999989ef7449038376c9f987',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/9U6NZ7RP'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'YAFN5N27': {'key': 'YAFN5N27',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/YAFN5N27',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/YAFN5N27',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/NX2YYEWH',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'YAFN5N27',
#    'version': 2828,
#    'parentItem': 'NX2YYEWH',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'Attachment',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'Prag - 2013 - Epigraphy in the western Mediterranean a Hellenistic phenomenon.pdf',
#    'md5': 'd1a0dafcbb662713ff38646839c683b1',
#    'mtime': 1622099544000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/W79EFH49'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'IJPUN3PC': {'key': 'IJPUN3PC',
#   'version': 2828,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/IJPUN3PC',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/IJPUN3PC',
#     'type': 'text/html'},
#    'up': {'href': 'https://api.zotero.org/users/2132694/items/5ALKMMVG',
#     'type': 'application/json'}},
#   'meta': {'numChildren': False},
#   'data': {'key': 'IJPUN3PC',
#    'version': 2828,
#    'parentItem': '5ALKMMVG',
#    'itemType': 'attachment',
#    'linkMode': 'imported_file',
#    'title': 'turchin-et-al_2018_quantitative-historical-analysis.pdf',
#    'accessDate': '',
#    'url': '',
#    'note': '',
#    'contentType': 'application/pdf',
#    'charset': '',
#    'filename': 'turchin-et-al_2018_quantitative-historical-analysis.pdf',
#    'md5': 'e69e3dc350a2697a81a7b4a069af71e0',
#    'mtime': 1622099543000,
#    'tags': [],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/RCV5B276'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '5MY4KSUI': {'key': '5MY4KSUI',
#   'version': 2825,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/5MY4KSUI',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/5MY4KSUI',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Ballsun-Stanton',
#    'parsedDate': '2020',
#    'numChildren': 0},
#   'data': {'key': '5MY4KSUI',
#    'version': 2825,
#    'itemType': 'computerProgram',
#    'title': 'Lat Epig 2.0',
#    'creators': [{'creatorType': 'programmer',
#      'firstName': 'Brian',
#      'lastName': 'Ballsun-Stanton'},
#     {'creatorType': 'contributor',
#      'firstName': 'Petra',
#      'lastName': 'Hermankova'},
#     {'creatorType': 'contributor',
#      'firstName': 'Ray',
#      'lastName': 'Laurence'}],
#    'abstractNote': '',
#    'seriesTitle': '',
#    'versionNumber': '',
#    'date': '2020',
#    'system': '',
#    'place': '',
#    'company': 'Macquarie University',
#    'programmingLanguage': 'python',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#    'rights': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'accessDate': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/84QIQ6VP'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'SYSTIFZQ': {'key': 'SYSTIFZQ',
#   'version': 2825,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/SYSTIFZQ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/SYSTIFZQ',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Wilson', 'parsedDate': '2012', 'numChildren': 1},
#   'data': {'key': 'SYSTIFZQ',
#    'version': 2825,
#    'itemType': 'bookSection',
#    'title': 'City Sizes and Urbanization in the Roman Empire',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Andrew',
#      'lastName': 'Wilson'},
#     {'creatorType': 'editor', 'firstName': 'Alan', 'lastName': 'Bowman'},
#     {'creatorType': 'editor', 'firstName': 'Andrew', 'lastName': 'Wilson'}],
#    'abstractNote': '',
#    'bookTitle': 'Settlement, Urbanization and Population',
#    'series': 'Oxford Studies in the Roman Economy',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'Oxford - New York',
#    'publisher': 'Oxford University Press',
#    'date': '2012',
#    'pages': '161–195',
#    'language': '',
#    'ISBN': '0-19-960235-2',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'pdf'}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/MYBKPFWP'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'C2MUHDNG': {'key': 'C2MUHDNG',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/C2MUHDNG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/C2MUHDNG',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Hanson et al.',
#    'parsedDate': '2017',
#    'numChildren': 1},
#   'data': {'key': 'C2MUHDNG',
#    'version': 2824,
#    'itemType': 'journalArticle',
#    'title': 'Urbanism and the division of labour in the Roman Empire',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'J. W.',
#      'lastName': 'Hanson'},
#     {'creatorType': 'author', 'firstName': 'S. G.', 'lastName': 'Ortman'},
#     {'creatorType': 'author', 'firstName': 'J.', 'lastName': 'Lobo'}],
#    'abstractNote': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#    'publicationTitle': 'Journal of The Royal Society Interface',
#    'volume': '14',
#    'issue': '136',
#    'pages': '20170367',
#    'date': '11/2017',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'J. R. Soc. Interface.',
#    'language': 'en',
#    'DOI': '10.1098/rsif.2017.0367',
#    'ISSN': '1742-5689, 1742-5662',
#    'shortTitle': '',
#    'url': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#    'accessDate': '2021-05-18T11:04:50Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/G855HU3P'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '9YX6ZS7N': {'key': '9YX6ZS7N',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/9YX6ZS7N',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/9YX6ZS7N',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2013', 'numChildren': 0},
#   'data': {'key': '9YX6ZS7N',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': 'Course Book',
#    'place': 'Princeton, NJ',
#    'publisher': 'Princeton University Press',
#    'date': '2013',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '1-299-14683-X',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#    'tags': [{'tag': 'Social structure'}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/YTH8LCMQ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '627JE7WX': {'key': '627JE7WX',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/627JE7WX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/627JE7WX',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Morris', 'parsedDate': '2010', 'numChildren': 0},
#   'data': {'key': '627JE7WX',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ian',
#      'lastName': 'Morris'}],
#    'abstractNote': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': 'New York',
#    'publisher': 'Farrar, Straus and Giroux',
#    'date': '2010',
#    'numPages': '',
#    'language': 'eng',
#    'ISBN': '978-0-312-61169-9',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#    'tags': [{'tag': 'civilisationens historie'}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WC3F7GTN'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'IFEXKMWT': {'key': 'IFEXKMWT',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/IFEXKMWT',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/IFEXKMWT',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Mullins et al.',
#    'parsedDate': '2018',
#    'numChildren': 1},
#   'data': {'key': 'IFEXKMWT',
#    'version': 2824,
#    'itemType': 'journalArticle',
#    'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Daniel Austin',
#      'lastName': 'Mullins'},
#     {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Hoyer'},
#     {'creatorType': 'author', 'firstName': 'Christina', 'lastName': 'Collins'},
#     {'creatorType': 'author', 'firstName': 'Thomas', 'lastName': 'Currie'},
#     {'creatorType': 'author', 'firstName': 'Kevin', 'lastName': 'Feeney'},
#     {'creatorType': 'author', 'firstName': 'Pieter', 'lastName': 'François'},
#     {'creatorType': 'author', 'firstName': 'Patrick E.', 'lastName': 'Savage'},
#     {'creatorType': 'author', 'firstName': 'Harvey', 'lastName': 'Whitehouse'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Turchin'}],
#    'abstractNote': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#    'publicationTitle': 'American Sociological Review',
#    'volume': '83',
#    'issue': '3',
#    'pages': '596-626',
#    'date': '06/2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Am Sociol Rev',
#    'language': 'en',
#    'DOI': '10.1177/0003122418772567',
#    'ISSN': '0003-1224, 1939-8271',
#    'shortTitle': '',
#    'url': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#    'accessDate': '2021-05-17T13:55:59Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/YP4EWP6Y'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'C5MFASAY': {'key': 'C5MFASAY',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/C5MFASAY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/C5MFASAY',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Harper', 'parsedDate': '2016', 'numChildren': 0},
#   'data': {'key': 'C5MFASAY',
#    'version': 2824,
#    'itemType': 'journalArticle',
#    'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Kyle',
#      'lastName': 'Harper'}],
#    'abstractNote': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#    'publicationTitle': 'The Journal of Economic History',
#    'volume': '76',
#    'issue': '3',
#    'pages': '803-839',
#    'date': '2016',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.1017/S0022050716000826',
#    'ISSN': '1471-6372',
#    'shortTitle': '',
#    'url': 'https://www.cambridge.org/core/article/people-plagues-and-prices-in-the-roman-world-the-evidence-from-egypt/50D27EAD5045D12C1573DFFB5D5C029C',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/XB3S54U6'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '95I2Q54Z': {'key': '95I2Q54Z',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/95I2Q54Z',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/95I2Q54Z',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Kolb',
#    'parsedDate': '2019-06-17',
#    'numChildren': 0},
#   'data': {'key': '95I2Q54Z',
#    'version': 2824,
#    'itemType': 'bookSection',
#    'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Anne',
#      'lastName': 'Kolb'},
#     {'creatorType': 'editor', 'firstName': 'Anne', 'lastName': 'Kolb'}],
#    'abstractNote': '',
#    'bookTitle': 'Roman Roads: New Evidence - New Perspectives',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'De Gruyter',
#    'date': '2019-06-17',
#    'pages': '3-21',
#    'language': '',
#    'ISBN': '978-3-11-063833-2',
#    'shortTitle': '',
#    'url': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#    'accessDate': '2021-05-19T07:51:54Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.1515/9783110638332',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/WBXNR587'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'GSAVHWAN': {'key': 'GSAVHWAN',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/GSAVHWAN',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/GSAVHWAN',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Borgman',
#    'parsedDate': '2015',
#    'numChildren': 0},
#   'data': {'key': 'GSAVHWAN',
#    'version': 2824,
#    'itemType': 'book',
#    'title': 'Big Data, Little Data, No Data',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Christine L.',
#      'lastName': 'Borgman'}],
#    'abstractNote': '"Big Data" is on the covers of<em>Science, Nature</em>, the<em>Economist</em>, and<em>Wired</em>magazines, on the front pages of the<em>Wall Street Journal</em>and the<em>New York Times.</em>But despite the media hyperbole, as Christine Borgman points out in this examination of data and scholarly research, having the right data is usually better than having more data; little data can be just as valuable as big data. In many cases, there are no data -- because relevant data don\'t exist, cannot be found, or are not available. Moreover, data sharing is difficult, incentives to do so are minimal, and data practices vary widely across disciplines.Borgman, an often-cited authority on scholarly communication, argues that data have no value or meaning in isolation; they exist within a knowledge infrastructure -- an ecology of people, practices, technologies, institutions, material objects, and relationships. After laying out the premises of her investigation -- six "provocations" meant to inspire discussion about the uses of data in scholarship -- Borgman offers case studies of data practices in the sciences, the social sciences, and the humanities, and then considers the implications of her findings for scholarly practice and research policy. To manage and exploit data over the long term, Borgman argues, requires massive investment in knowledge infrastructures; at stake is the future of scholarship.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'The MIT Press',
#    'date': '2015',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-262-02856-1',
#    'shortTitle': '',
#    'url': 'http://www.jstor.org/stable/j.ctt17kk8n8',
#    'accessDate': '2021-05-17',
#    'archive': 'JSTOR',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/R6GC6RM2'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'KRXAF9YL': {'key': 'KRXAF9YL',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/KRXAF9YL',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/KRXAF9YL',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Cayless et al.',
#    'parsedDate': '2010-12-31',
#    'numChildren': 0},
#   'data': {'key': 'KRXAF9YL',
#    'version': 2824,
#    'itemType': 'bookSection',
#    'title': 'EPIGRAPHY IN 2017',
#    'creators': [{'creatorType': 'editor',
#      'firstName': 'Melissa',
#      'lastName': 'Terras'},
#     {'creatorType': 'editor', 'firstName': 'Gregory', 'lastName': 'Crane'},
#     {'creatorType': 'author', 'firstName': 'Hugh', 'lastName': 'Cayless'},
#     {'creatorType': 'author', 'firstName': 'Charlotte', 'lastName': 'Roueché'},
#     {'creatorType': 'author', 'firstName': 'Tom', 'lastName': 'Elliott'},
#     {'creatorType': 'author', 'firstName': 'Gabriel', 'lastName': 'Bodard'}],
#    'abstractNote': '',
#    'bookTitle': 'Changing the Center of Gravity',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Gorgias Press',
#    'date': '2010-12-31',
#    'pages': '203-222',
#    'language': '',
#    'ISBN': '978-1-4632-1922-2',
#    'shortTitle': '',
#    'url': 'https://www.degruyter.com/document/doi/10.31826/9781463219222-012/html',
#    'accessDate': '2021-05-17T10:30:40Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.31826/9781463219222-012',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/2TRX7DVQ'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'AW6LP4AP': {'key': 'AW6LP4AP',
#   'version': 2824,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/AW6LP4AP',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/AW6LP4AP',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Laurence',
#    'parsedDate': '1999',
#    'numChildren': 0},
# ...
#    'libraryCatalog': 'DOI.org (Datacite)',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Universitätsbibliothek Tübingen',
#    'tags': [{'tag': '930', 'type': 1}, {'tag': 'Archäoinformatik', 'type': 1}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/V669MYBG'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'NR7KMK97': {'key': 'NR7KMK97',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/NR7KMK97',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/NR7KMK97',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Roueche and Sotinel',
#    'parsedDate': '2017-03',
#    'numChildren': 0},
#   'data': {'key': 'NR7KMK97',
#    'version': 2819,
#    'itemType': 'bookSection',
#    'title': 'Christian and Late Antique Epigraphies',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Charlotte Mary',
#      'lastName': 'Roueche'},
#     {'creatorType': 'author', 'firstName': 'Claire', 'lastName': 'Sotinel'},
#     {'creatorType': 'editor', 'firstName': 'Katharina', 'lastName': 'Bolle'},
#     {'creatorType': 'editor', 'firstName': 'Carlos', 'lastName': 'Machado'},
#     {'creatorType': 'editor',
#      'firstName': 'Christian',
#      'lastName': 'Witschel'}],
#    'abstractNote': '',
#    'bookTitle': 'The Epigraphic Cultures of Late Antiquity',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'Franz Steiner Verlag',
#    'date': 'March 2017',
#    'pages': '503–514',
#    'language': 'English',
#    'ISBN': '978-3-515-11558-2',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Christian antiquities', 'type': 1},
#     {'tag': 'Epigraphy', 'type': 1},
#     {'tag': 'Late Antiquity', 'type': 1}],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/ZRE798N5'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'HGSQZDS4': {'key': 'HGSQZDS4',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/HGSQZDS4',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/HGSQZDS4',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Oksanen and Lewis',
#    'parsedDate': '2020',
#    'numChildren': 1},
#   'data': {'key': 'HGSQZDS4',
#    'version': 2819,
#    'itemType': 'journalArticle',
#    'title': 'Medieval Commercial Sites: As Seen Through Portable Antiquities Scheme Data',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Eljas',
#      'lastName': 'Oksanen'},
#     {'creatorType': 'author', 'firstName': 'Michael', 'lastName': 'Lewis'}],
#    'abstractNote': 'This paper explores some 220,000 medieval objects recorded in the Portable Antiquities Scheme (PAS) online database of archaeological small finds through Geographic Information System analysis of their relationship with contemporary market sites. First, an overview of the contents of the PAS database is presented in terms of its spatial and ‘object type’ distribution. Second, the relationship of the medieval finds data against documentary evidence of commercial activity is investigated at a national level. Finally, PAS data is contextualised in its historical landscape context through case studies. It is argued that the distribution of PAS finds on the national scale can be linked with patterns of commercial activity, and that while rural and urban finds scatters have distinguishing trends, the countryside population enjoyed access to a range of sophisticated metalwork culture; also, that certain assemblages can be analysed statistically to yield new data and perspectives on local historical development.',
#    'publicationTitle': 'The Antiquaries Journal',
#    'volume': '100',
#    'issue': '',
#    'pages': '109-140',
#    'date': '09/2020',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Antiq. J.',
#    'language': 'en',
#    'DOI': '10.1017/S0003581520000165',
#    'ISSN': '0003-5815, 1758-5309',
#    'shortTitle': 'MEDIEVAL COMMERCIAL SITES',
#    'url': 'https://www.cambridge.org/core/product/identifier/S0003581520000165/type/journal_article',
#    'accessDate': '2021-05-10T13:50:54Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'DOI.org (Crossref)',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/HKR5H6PK'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'YS8ZN82H': {'key': 'YS8ZN82H',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/YS8ZN82H',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/YS8ZN82H',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Hartmann',
#    'parsedDate': '2018-10-13',
#    'numChildren': 0},
#   'data': {'key': 'YS8ZN82H',
#    'version': 2819,
#    'itemType': 'journalArticle',
#    'title': 'Rezension zu: Epigraphische Datenbank Heidelberg',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Andreas',
#      'lastName': 'Hartmann'}],
#    'abstractNote': '',
#    'publicationTitle': 'H-Soz-Kult',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '13/10/2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'ger',
#    'DOI': '',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': 'https://www.hsozkult.de/webreview/id/rezwww-179',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/6TY2F79A'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  'WNGG6SYB': {'key': 'WNGG6SYB',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/WNGG6SYB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/WNGG6SYB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Elliot et al.',
#    'parsedDate': '2017',
#    'numChildren': 0},
#   'data': {'key': 'WNGG6SYB',
#    'version': 2819,
#    'itemType': 'computerProgram',
#    'title': 'EpiDoc Reference Stylesheets (version 9)',
#    'creators': [{'creatorType': 'programmer',
#      'firstName': 'Tom',
#      'lastName': 'Elliot'},
#     {'creatorType': 'programmer', 'firstName': 'Zaneta', 'lastName': 'Au'},
#     {'creatorType': 'programmer',
#      'firstName': 'Gabriel',
#      'lastName': 'Bodard'},
#     {'creatorType': 'programmer', 'firstName': 'Hugh', 'lastName': 'Cayless'},
#     {'creatorType': 'programmer', 'firstName': 'Carmen', 'lastName': 'Lanz'},
#     {'creatorType': 'programmer',
#      'firstName': 'Faith',
#      'lastName': 'Lawrence'},
#     {'creatorType': 'programmer',
#      'firstName': 'Scott',
#      'lastName': 'Vanderbilt'},
#     {'creatorType': 'programmer',
#      'firstName': 'Raffaele',
#      'lastName': 'Viglianti'}],
#    'abstractNote': 'XSLT for transformation of EpiDoc XML files into HTML or text versions in Leiden. Includes various XML files containing parameters and other options.',
#    'seriesTitle': '',
#    'versionNumber': '',
#    'date': '2017',
#    'system': '',
#    'place': '',
#    'company': '',
#    'programmingLanguage': 'XSLT 2.0',
#    'ISBN': '',
#    'shortTitle': '',
#    'url': 'https://sourceforge.net/p/epidoc/wiki/Stylesheets/',
#    'rights': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'accessDate': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/7VS4BH25'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}},
#  '5ALKMMVG': {'key': '5ALKMMVG',
#   'version': 2819,
#   'library': {'type': 'user',
#    'id': 2132694,
#    'name': 'vojtech.kase',
#    'links': {'alternate': {'href': 'https://www.zotero.org/vojtech.kase',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/2132694/items/5ALKMMVG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/vojtech.kase/items/5ALKMMVG',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Turchin et al.',
#    'parsedDate': '2018',
#    'numChildren': 2},
#   'data': {'key': '5ALKMMVG',
#    'version': 2819,
#    'itemType': 'journalArticle',
#    'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Peter',
#      'lastName': 'Turchin'},
#     {'creatorType': 'author', 'firstName': 'Thomas E.', 'lastName': 'Currie'},
#     {'creatorType': 'author', 'firstName': 'Harvey', 'lastName': 'Whitehouse'},
#     {'creatorType': 'author', 'firstName': 'Pieter', 'lastName': 'François'},
#     {'creatorType': 'author', 'firstName': 'Kevin', 'lastName': 'Feeney'},
#     {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Mullins'},
#     {'creatorType': 'author', 'firstName': 'Daniel', 'lastName': 'Hoyer'},
#     {'creatorType': 'author', 'firstName': 'Christina', 'lastName': 'Collins'},
#     {'creatorType': 'author',
#      'firstName': 'Stephanie',
#      'lastName': 'Grohmann'},
#     {'creatorType': 'author', 'firstName': 'Patrick', 'lastName': 'Savage'},
#     {'creatorType': 'author',
#      'firstName': 'Gavin',
#      'lastName': 'Mendel-Gleason'},
#     {'creatorType': 'author', 'firstName': 'Edward', 'lastName': 'Turner'},
#     {'creatorType': 'author', 'firstName': 'Agathe', 'lastName': 'Dupeyron'},
#     {'creatorType': 'author', 'firstName': 'Enrico', 'lastName': 'Cioni'},
#     {'creatorType': 'author', 'firstName': 'Jenny', 'lastName': 'Reddish'},
#     {'creatorType': 'author', 'firstName': 'Jill', 'lastName': 'Levine'},
#     {'creatorType': 'author', 'firstName': 'Greine', 'lastName': 'Jordan'},
#     {'creatorType': 'author', 'firstName': 'Eva', 'lastName': 'Brandl'},
#     {'creatorType': 'author', 'firstName': 'Alice', 'lastName': 'Williams'},
#     {'creatorType': 'author', 'firstName': 'Rudolf', 'lastName': 'Cesaretti'},
#     {'creatorType': 'author', 'firstName': 'Marta', 'lastName': 'Krueger'},
#     {'creatorType': 'author',
#      'firstName': 'Alessandro',
#      'lastName': 'Ceccarelli'},
#     {'creatorType': 'author',
#      'firstName': 'Joe',
#      'lastName': 'Figliulo-Rosswurm'},
#     {'creatorType': 'author', 'firstName': 'Po-Ju', 'lastName': 'Tuan'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Peregrine'},
#     {'creatorType': 'author',
#      'firstName': 'Arkadiusz',
#      'lastName': 'Marciniak'},
#     {'creatorType': 'author',
#      'firstName': 'Johannes',
#      'lastName': 'Preiser-Kapeller'},
#     {'creatorType': 'author', 'firstName': 'Nikolay', 'lastName': 'Kradin'},
#     {'creatorType': 'author', 'firstName': 'Andrey', 'lastName': 'Korotayev'},
#     {'creatorType': 'author', 'firstName': 'Alessio', 'lastName': 'Palmisano'},
#     {'creatorType': 'author', 'firstName': 'David', 'lastName': 'Baker'},
#     {'creatorType': 'author', 'firstName': 'Julye', 'lastName': 'Bidmead'},
#     {'creatorType': 'author', 'firstName': 'Peter', 'lastName': 'Bol'},
#     {'creatorType': 'author', 'firstName': 'David', 'lastName': 'Christian'},
#     {'creatorType': 'author', 'firstName': 'Connie', 'lastName': 'Cook'},
#     {'creatorType': 'author', 'firstName': 'Alan', 'lastName': 'Covey'},
#     {'creatorType': 'author', 'firstName': 'Gary', 'lastName': 'Feinman'},
#     {'creatorType': 'author',
#      'firstName': 'Árni Daníel',
#      'lastName': 'Júlíusson'},
#     {'creatorType': 'author', 'firstName': 'Axel', 'lastName': 'Kristinsson'},
#     {'creatorType': 'author', 'firstName': 'John', 'lastName': 'Miksic'},
#     {'creatorType': 'author', 'firstName': 'Ruth', 'lastName': 'Mostern'},
#     {'creatorType': 'author', 'firstName': 'Cameron', 'lastName': 'Petrie'},
#     {'creatorType': 'author',
#      'firstName': 'Peter',
#      'lastName': 'Rudiak-Gould'},
#     {'creatorType': 'author', 'firstName': 'Barend', 'lastName': 'ter Haar'},
#     {'creatorType': 'author', 'firstName': 'Vesna', 'lastName': 'Wallace'},
#     {'creatorType': 'author', 'firstName': 'Victor', 'lastName': 'Mair'},
#     {'creatorType': 'author', 'firstName': 'Liye', 'lastName': 'Xie'},
#     {'creatorType': 'author', 'firstName': 'John', 'lastName': 'Baines'},
#     {'creatorType': 'author', 'firstName': 'Elizabeth', 'lastName': 'Bridges'},
#     {'creatorType': 'author', 'firstName': 'Joseph', 'lastName': 'Manning'},
#     {'creatorType': 'author', 'firstName': 'Bruce', 'lastName': 'Lockhart'},
#     {'creatorType': 'author', 'firstName': 'Amy', 'lastName': 'Bogaard'},
#     {'creatorType': 'author', 'firstName': 'Charles', 'lastName': 'Spencer'}],
#    'abstractNote': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#    'publicationTitle': 'Proceedings of the National Academy of Sciences',
#    'volume': '115',
#    'issue': '2',
#    'pages': 'E144-E151',
#    'date': '2018',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.1073/pnas.1708800115',
#    'ISSN': '0027-8424',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#    'tags': [],
#    'collections': ['P55PUAIK'],
#    'relations': {'owl:sameAs': 'http://zotero.org/groups/2366083/items/JNS83J8R'},
#    'dateAdded': '2021-05-27T07:12:23Z',
#    'dateModified': '2021-05-27T07:12:23Z'}}}

# %%
import re

# %%
re.match("(\d{4})-(\d+)\-(\d+)", "2018-07-08").groups()
# Out:
# ('2018', '07', '08')

# %%
re.sub(r"(\d{4})-(\d+)\-(\d+)", r"\1", "2018-07-08")
# Out:
# '2018'

# %%
# ids of items
citation_keys_pairs = {}
for key in citations.keys():
    if collection_items_dict[key.rpartition("/")[2]]["data"]["itemType"] != "attachment":
        try:
            item_dict = collection_items_dict[key.rpartition("/")[2]]
            item_key = item_dict["meta"]["creatorSummary"] + " " + item_dict["meta"]["parsedDate"]
        except: 
            try:
                item_key = item_dict["data"]["title"]
            except:
                item_key = ""
        item_key = re.sub(r"(\d{4})-(\d+)\-(\d+)", r"\1", item_key)
        citation_keys_pairs[item_key] = key

# %%
citation_keys_pairs
# Out:
# {'Ballsun-Stanton 2020': '1913534/5MY4KSUI',
#  'Wilson 2012': '1913534/SYSTIFZQ',
#  'Hanson et al. 2017': '1913534/C2MUHDNG',
#  'Morris 2013': '1913534/9YX6ZS7N',
#  'Morris 2010': '1913534/627JE7WX',
#  'Mullins et al. 2018': '1913534/IFEXKMWT',
#  'Harper 2016': '1913534/33TNUAZ3',
#  'Kolb 2019': '1913534/95I2Q54Z',
#  'Borgman 2015': '1913534/GSAVHWAN',
#  'Cayless et al. 2010': '1913534/KRXAF9YL',
#  'Laurence 1999': '1913534/AW6LP4AP',
#  'Bodard 2008': '1913534/66WIWW57',
#  'Liuzzo 2018': '1913534/4WT5APEZ',
#  'de Ligt and Tacoma 2016': '1913534/6ZEVHLM6',
#  'Wilson and Flohr 2016': '1913534/B99689HI',
#  'Verhagen 2019': '1913534/A2U4FIKT',
#  'Hanel 2020': '1913534/CLBZUHJ7',
#  'Bodard et al. 2021': '1913534/AHA9EWZL',
#  'Avanzini et al. 2018': '1913534/LFKD595C',
#  'De Santis and Rossi 2018': '1913534/37N8YE3I',
#  'Littman and Littman 1973': '1913534/UZDY7HD7',
#  'Rabinowitz et al. 2018': '1913534/N8MU7LGT',
#  'Bodel 2001': '1913534/4YVYEDQD',
#  'Crema and Kobayashi 2020': '1913534/DF62R52E',
#  'Kaše 2021': '1913534/MT2ZRZBH',
#  'Kemkes 2020': '1913534/AIJX7C5S',
#  'Verhagen et al. 2016': '1913534/XJBYYW4X',
#  'Keppie 1991': '1913534/V9UVGQX2',
#  'Bowman and Wilson 2009': '1913534/6YVHFFUJ',
#  'Turchin and Scheidel 2009': '1913534/U48VTMSM',
#  'Hedrick 1999': '1913534/2LT8WIGC',
#  'Beltrán Lloris 2014': '1913534/6CHTC3L7',
#  'Nawotka 2021': '1913534/NEGLBLPH',
#  'Bolle et al. 2017': '1913534/GDRQEX9Z',
#  'Lotz 2020': '1913534/XUF75FS9',
#  'MacMullen 1982': '1913534/BGNB6HUT',
#  'Pérez 2021': '1913534/8AAUR7HD',
#  'Trout 2009': '1913534/F3Y2FVVY',
#  'Feraudi-Gruénais and Grieshaber 2016': '1913534/7KH8X6PB',
#  'Grieshaber 2019': '1913534/DBL5UIX2',
#  'Woolf 1996': '1913534/HBPZKHXT',
#  'Elliot et al. 2020': '1913534/BADWX5AX',
#  'Duthoy 2002': '1913534/ARJNJ286',
#  'Elliot 2015': '1913534/VH243883',
#  'Meyer 1990': '1913534/MUKI9YSZ',
#  'Dow 1969': '1913534/WRT7VI6X',
#  'Bloch 1967': '1913534/5GAQW7DV',
#  'Bloch 1947': '1913534/T9TGS9S6',
#  'McLean 2016': '1913534/H7KAA2TH',
#  'Korhonen 2011': '1913534/6HXR6GAN',
#  'Janouchová (Heřmánková) 2021': '1913534/MNRERH36',
#  'Prag 2002': '1913534/CALUBQFC',
#  'Prag 2013': '1913534/NX2YYEWH',
#  'Cooley et al. 2007': '1913534/XQGJDGFJ',
#  'Crema 2012': '1913534/UTITLKQZ',
#  'Johnson 2004': '1913534/EIU8NCUL',
#  'Roueche and Sotinel 2017-03': '1913534/NR7KMK97',
#  'Oksanen and Lewis 2020': '1913534/HGSQZDS4',
#  'Hartmann 2018': '1913534/YS8ZN82H',
#  'Elliot et al. 2017': '1913534/WNGG6SYB',
#  'Turchin et al. 2018': '1913534/5ALKMMVG'}

# %% [markdown]
# # Small test

# %% [markdown]
# this way, we can easily generate the data in the form produced by cite2c, combining **collection ID** and **item ID**.
#
# However, it seems that cite2c does not support group collection. We need to work with our personal collection instead.

# %% [markdown]
# Here we test how the citations work. We will use Wilson 2012 as an example. Let put it here <cite data-cite="1913534/SYSTIFZQ"></cite>. Another citation would be here <cite data-cite="1913534/627JE7WX"></cite> or here <cite data-cite="1913534/IFEXKMWT"></cite> (here should be Mullins et al. 2018 - but does not render automatically). <cite data-cite="1913534/MUKI9YSZ"></cite>

# %% [markdown]
# insert citation here <cite data-cite="undefined"></cite>.

# %% [markdown]
# <cite data-cite="1913534/U48VTMSM"></cite>

# %% [markdown]
# <div class="cite2c-biblio"></div>

# %% [markdown]
# # Read ipynb as text file

# %% [markdown]
# <cite data-cite="1913534/U48VTMSM"></cite>

# %%
notebook_text = open("Digital_epigraphy.ipynb").read()
notebook_text[:1000]
# Out:
# '{\n "cells": [\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "title"\n    ]\n   },\n   "source": [\n    "# Inscriptions as data: digital epigraphy in macro-historical perspective "\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Petra Hermankova\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6349-0540](https://orcid.org/0000-0002-6349-0540)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Vojtech Kase\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6601-1605](http://orcid.org/0000-0002-6601-1605)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Adela Sobotkova\\n",\n    "Author. Aarhus University, [ORCID:0000-0002-4541-3963](https://orcid.org/0000-0002-4541-3963)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n'

# %%
for key in citation_keys_pairs.keys():
    if key in notebook_text:
        print(key, citation_keys_pairs[key])
# Out:
# Wilson 2012 1913534/SYSTIFZQ
# Hanson et al. 2017 1913534/C2MUHDNG
# Mullins et al. 2018 1913534/IFEXKMWT
# Harper 2016 1913534/33TNUAZ3
# Kolb 2019 1913534/95I2Q54Z
# Borgman 2015 1913534/GSAVHWAN
# Cayless et al. 2010 1913534/KRXAF9YL
# Laurence 1999 1913534/AW6LP4AP
# Bodard 2008 1913534/66WIWW57
# Liuzzo 2018 1913534/4WT5APEZ
# Wilson and Flohr 2016 1913534/B99689HI
# Verhagen 2019 1913534/A2U4FIKT
# Hanel 2020 1913534/CLBZUHJ7
# Bodard et al. 2021 1913534/AHA9EWZL
# Avanzini et al. 2018 1913534/LFKD595C
# De Santis and Rossi 2018 1913534/37N8YE3I
# Rabinowitz et al. 2018 1913534/N8MU7LGT
# Bodel 2001 1913534/4YVYEDQD
# Crema and Kobayashi 2020 1913534/DF62R52E
# Kaše 2021 1913534/MT2ZRZBH
# Kemkes 2020 1913534/AIJX7C5S
# Verhagen et al. 2016 1913534/XJBYYW4X
# Bowman and Wilson 2009 1913534/6YVHFFUJ
# Turchin and Scheidel 2009 1913534/U48VTMSM
# Hedrick 1999 1913534/2LT8WIGC
# Nawotka 2021 1913534/NEGLBLPH
# Lotz 2020 1913534/XUF75FS9
# MacMullen 1982 1913534/BGNB6HUT
# Trout 2009 1913534/F3Y2FVVY
# Feraudi-Gruénais and Grieshaber 2016 1913534/7KH8X6PB
# Grieshaber 2019 1913534/DBL5UIX2
# Woolf 1996 1913534/HBPZKHXT
# Meyer 1990 1913534/MUKI9YSZ
# Dow 1969 1913534/WRT7VI6X
# Bloch 1947 1913534/T9TGS9S6
# Prag 2002 1913534/CALUBQFC
# Crema 2012 1913534/UTITLKQZ
# Johnson 2004 1913534/EIU8NCUL
# Oksanen and Lewis 2020 1913534/HGSQZDS4
# Hartmann 2018 1913534/YS8ZN82H
# Turchin et al. 2018 1913534/5ALKMMVG

# %% [markdown]
# Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).

# %%
test_paragraph = "Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139)."
print(test_paragraph)
# Out:
# Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).

# %%
citations
# Out:
# {'1913534/4DU2BY28': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://royalsocietypublishing.org/doi/pdf/10.1098/rsif.2017.0367',
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  '1913534/FTDUBX6P': {'type': 'article',
#   'title': 'Accepted Version',
#   'URL': 'https://ore.exeter.ac.uk/repository/bitstream/10871/36086/2/deleted_FINAL_submission.pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/L47JEQBH': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/7JEU5M89': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/pdf',
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '1913534/AGSJ79AY': {'type': 'article',
#   'title': 'Wilson_2012_City Sizes and Urbanization in the Roman Empire.pdf'},
#  '1913534/3LU29L3J': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/49AE839R': {'type': 'article',
#   'title': 'Full Text',
#   'URL': 'https://zenodo.org/record/2593547/files/DeSantis_Rossi_2018_Digital_Epigraphy_book.pdf',
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/V36QKWVK': {'type': 'article', 'title': 'Attachment'},
#  '1913534/TVCGWGMN': {'type': 'article',
#   'title': 'Hedrick - 1999 - Democracy and the Athenian Epigraphical Habit.pdf'},
#  '1913534/MG4AUE6B': {'type': 'article',
#   'title': 'Crema2020_JomonPopulationDynamics.pdf'},
#  '1913534/I4SY879G': {'type': 'article',
#   'title': 'Accepted Version',
#   'URL': 'https://helda.helsinki.fi/bitstream/10138/329293/1/Oksanen_and_Lewis_PAS_and_medieval_markets_AJ_100.pdf',
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/Z8JVQ5FX': {'type': 'article', 'title': 'PDF'},
#  '1913534/VDPSKXF2': {'type': 'article',
#   'title': 'Crema - 2012 - Modelling Temporal Uncertainty in Archaeological A.pdf'},
#  '1913534/K5B59T6I': {'type': 'article',
#   'title': 'Turchin_Scheidel_2009_Coin Hoards Speak of Population Declines in Ancient Rome.pdf'},
#  '1913534/J2H5P8TD': {'type': 'article', 'title': 'Attachment'},
#  '1913534/HGK83TQN': {'type': 'article', 'title': 'Attachment'},
#  '1913534/YAFN5N27': {'type': 'article', 'title': 'Attachment'},
#  '1913534/IJPUN3PC': {'type': 'article',
#   'title': 'turchin-et-al_2018_quantitative-historical-analysis.pdf'},
#  '1913534/5MY4KSUI': {'type': 'book',
#   'title': 'Lat Epig 2.0',
#   'publisher': 'Macquarie University',
#   'URL': 'https://github.com/mqAncientHistory/EpigraphyScraperNotebook',
#   'author': [{'family': 'Ballsun-Stanton', 'given': 'Brian'}],
#   'issued': {'date-parts': [[2020]]}},
#  '1913534/SYSTIFZQ': {'type': 'chapter',
#   'title': 'City Sizes and Urbanization in the Roman Empire',
#   'container-title': 'Settlement, Urbanization and Population',
#   'collection-title': 'Oxford Studies in the Roman Economy',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'page': '161–195',
#   'event-place': 'Oxford - New York',
#   'ISBN': '0-19-960235-2',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2012]]}},
#  '1913534/C2MUHDNG': {'type': 'article-journal',
#   'title': 'Urbanism and the division of labour in the Roman Empire',
#   'container-title': 'Journal of The Royal Society Interface',
#   'page': '20170367',
#   'volume': '14',
#   'issue': '136',
#   'abstract': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#   'URL': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#   'DOI': '10.1098/rsif.2017.0367',
#   'journalAbbreviation': 'J. R. Soc. Interface.',
#   'language': 'en',
#   'author': [{'family': 'Hanson', 'given': 'J. W.'},
#    {'family': 'Ortman', 'given': 'S. G.'},
#    {'family': 'Lobo', 'given': 'J.'}],
#   'issued': {'date-parts': [['2017']]},
#   'accessed': {'date-parts': [[2021, 5, 18]]}},
#  '1913534/9YX6ZS7N': {'type': 'book',
#   'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'publisher': 'Princeton University Press',
#   'publisher-place': 'Princeton, NJ',
#   'edition': 'Course Book',
#   'event-place': 'Princeton, NJ',
#   'abstract': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#   'ISBN': '1-299-14683-X',
#   'note': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2013]]}},
#  '1913534/627JE7WX': {'type': 'book',
#   'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#   'publisher': 'Farrar, Straus and Giroux',
#   'publisher-place': 'New York',
#   'event-place': 'New York',
#   'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#   'ISBN': '978-0-312-61169-9',
#   'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#   'language': 'eng',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2010]]}},
#  '1913534/IFEXKMWT': {'type': 'article-journal',
#   'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#   'container-title': 'American Sociological Review',
#   'page': '596-626',
#   'volume': '83',
#   'issue': '3',
#   'abstract': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#   'URL': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#   'DOI': '10.1177/0003122418772567',
#   'journalAbbreviation': 'Am Sociol Rev',
#   'language': 'en',
#   'author': [{'family': 'Mullins', 'given': 'Daniel Austin'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Currie', 'given': 'Thomas'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Savage', 'given': 'Patrick E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'Turchin', 'given': 'Peter'}],
#   'issued': {'date-parts': [['2018']]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/C5MFASAY': {'type': 'article-journal',
#   'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#   'container-title': 'The Journal of Economic History',
#   'page': '803-839',
#   'volume': '76',
#   'issue': '3',
#   'abstract': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#   'URL': 'https://www.cambridge.org/core/article/people-plagues-and-prices-in-the-roman-world-the-evidence-from-egypt/50D27EAD5045D12C1573DFFB5D5C029C',
#   'DOI': '10.1017/S0022050716000826',
#   'author': [{'family': 'Harper', 'given': 'Kyle'}],
#   'issued': {'date-parts': [[2016]]}},
#  '1913534/95I2Q54Z': {'type': 'chapter',
#   'title': 'Via ducta – Roman Road Building: An Introduction to Its Significance, the Sources and the State of Research',
#   'container-title': 'Roman Roads: New Evidence - New Perspectives',
#   'publisher': 'De Gruyter',
#   'page': '3-21',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110638332/html',
#   'ISBN': '978-3-11-063833-2',
#   'note': 'DOI: 10.1515/9783110638332',
#   'author': [{'family': 'Kolb', 'given': 'Anne'}],
#   'editor': [{'family': 'Kolb', 'given': 'Anne'}],
#   'issued': {'date-parts': [[2019, 6, 17]]},
#   'accessed': {'date-parts': [[2021, 5, 19]]}},
#  '1913534/GSAVHWAN': {'type': 'book',
#   'title': 'Big Data, Little Data, No Data',
#   'publisher': 'The MIT Press',
#   'archive': 'JSTOR',
#   'abstract': '"Big Data" is on the covers of<em>Science, Nature</em>, the<em>Economist</em>, and<em>Wired</em>magazines, on the front pages of the<em>Wall Street Journal</em>and the<em>New York Times.</em>But despite the media hyperbole, as Christine Borgman points out in this examination of data and scholarly research, having the right data is usually better than having more data; little data can be just as valuable as big data. In many cases, there are no data -- because relevant data don\'t exist, cannot be found, or are not available. Moreover, data sharing is difficult, incentives to do so are minimal, and data practices vary widely across disciplines.Borgman, an often-cited authority on scholarly communication, argues that data have no value or meaning in isolation; they exist within a knowledge infrastructure -- an ecology of people, practices, technologies, institutions, material objects, and relationships. After laying out the premises of her investigation -- six "provocations" meant to inspire discussion about the uses of data in scholarship -- Borgman offers case studies of data practices in the sciences, the social sciences, and the humanities, and then considers the implications of her findings for scholarly practice and research policy. To manage and exploit data over the long term, Borgman argues, requires massive investment in knowledge infrastructures; at stake is the future of scholarship.',
#   'URL': 'http://www.jstor.org/stable/j.ctt17kk8n8',
#   'ISBN': '978-0-262-02856-1',
#   'author': [{'family': 'Borgman', 'given': 'Christine L.'}],
#   'issued': {'date-parts': [[2015]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/KRXAF9YL': {'type': 'chapter',
#   'title': 'EPIGRAPHY IN 2017',
#   'container-title': 'Changing the Center of Gravity',
#   'publisher': 'Gorgias Press',
#   'page': '203-222',
#   'URL': 'https://www.degruyter.com/document/doi/10.31826/9781463219222-012/html',
#   'ISBN': '978-1-4632-1922-2',
#   'note': 'DOI: 10.31826/9781463219222-012',
#   'editor': [{'family': 'Terras', 'given': 'Melissa'},
#    {'family': 'Crane', 'given': 'Gregory'}],
#   'author': [{'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Roueché', 'given': 'Charlotte'},
#    {'family': 'Elliott', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2010, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/AW6LP4AP': {'type': 'book',
#   'title': 'The roads of Roman Italy: mobility and cultural change',
#   'publisher': 'Routledge',
#   'publisher-place': 'London; New York',
#   'archive': '/z-wcorg/',
#   'event-place': 'London; New York',
#   'abstract': '"The Roads of Roman Italy offers a complete re-evaluation of both the evidence for, and the interpretation of, Roman land transport. The book utilises archaeological, epigraphic and literary evidence for Roman communications, drawing on recent approaches to the human landscape developed by geographers. Among the topics considered are the relationship between the road and the human landscape, the administration and maintenance of the road system, the role of roads as imperial monuments, and the economics of road construction and urban development."--Jacket.',
#   'ISBN': '0-415-16616-0 978-0-415-16616-4',
#   'language': 'English',
#   'author': [{'family': 'Laurence', 'given': 'Ray'}],
#   'issued': {'date-parts': [[1999]]}},
#  '1913534/66WIWW57': {'type': 'article-journal',
#   'title': "The Inscriptions of Aphrodisias as electronic publication: A user's perspective and a proposed paradigm",
#   'container-title': 'Digital Medievalist',
#   'volume': '4',
#   'abstract': 'This paper discusses the value of the electronic medium of\npublication for one project in particular, Inscriptions of Aphrodisias\n(2007), and uses this one example to extrapolate and illustrate a\nuse-case paradigm of electronic publication and its advantages for\nresearch, pedagogy, and dissemination. The categories used in this\nstudy are: accessibility, scale, media, hypertext, updates, and\niterative research and transparency. Not all of these categories\napply equally to any given publication, and the discussion focuses\nDM 4 (2008) The Inscriptions of Aphrodisias as electronic publi... http://www.digitalmedievalist.org/journal/4/bodard/\n1 of 17 6/29/10 1:29 PM\non those that are the most appropriate to a digital publication of\ntagged epigraphic texts and images.',
#   'language': 'eng',
#   'author': [{'family': 'Bodard', 'given': 'Gabriel'}],
#   'issued': {'date-parts': [[2008]]}},
#  '1913534/4WT5APEZ': {'type': 'chapter',
#   'title': 'EAGLE Continued: IDEA. The International Digital Epigraphy Association',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '216-230',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-018/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-018',
#   'shortTitle': '17 EAGLE Continued',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Liuzzo', 'given': 'Pietro M.'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/6ZEVHLM6': {'type': 'book',
#   'title': 'Migration and Mobility in the Early Roman Empire',
#   'publisher': 'BRILL',
#   'URL': 'https://brill.com/view/title/31880',
#   'ISBN': '978-90-04-30736-0 978-90-04-30737-7',
#   'note': 'DOI: 10.1163/9789004307377',
#   'author': [{'family': 'de Ligt', 'given': 'Luuk'},
#    {'family': 'Tacoma', 'given': 'Laurens Ernst'}],
#   'issued': {'date-parts': [[2016, 1, 19]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/B99689HI': {'type': 'book',
#   'title': 'Urban Craftsmen and Traders in the Roman World',
#   'publisher': 'Oxford University Press',
#   'URL': 'https://oxford.universitypressscholarship.com/view/10.1093/acprof:oso/9780198748489.001.0001/acprof-9780198748489',
#   'ISBN': '978-0-19-874848-9',
#   'note': 'DOI: 10.1093/acprof:oso/9780198748489.001.0001\nDOI: 10.1093/acprof:oso/9780198748489.001.0001',
#   'editor': [{'family': 'Wilson', 'given': 'Andrew'},
#    {'family': 'Flohr', 'given': 'Miko'}],
#   'issued': {'date-parts': [[2016, 1, 1]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/A2U4FIKT': {'type': 'chapter',
#   'title': 'Modelling the Dynamics of Demography in the Dutch Roman Limes Zone: A Revised Model',
#   'container-title': 'Finding the Limits of the Limes: Modelling Demography, Economy and Transport on the Edge of the Roman Empire',
#   'publisher': 'Springer International Publishing',
#   'publisher-place': 'Cham',
#   'page': '43–59',
#   'event-place': 'Cham',
#   'abstract': 'In this chapter, a simulation model for better understanding the population dynamics of the limes zone is presented, building on our earlier study on the possible effects of recruitment of soldiers for the Roman army (Verhagen et al., Modelling the dynamics of demography in the Dutch limes zone. In: Multi-, inter- and transdisciplinary research in landscape archaeology. Proceedings of LAC 2014 Conference, Rome, 19–20 September 2014. Vrije Universiteit Amsterdam, Amsterdam. https://doi.org/10.5463/lac.2014.62, 2016a). In this earlier study, a number of questions were raised concerning the realism of using estimates from historical demographical sources for understanding the population dynamics of the region. In the current paper, the available data sets, approaches and hypotheses regarding fertility and mortality in the Roman period are re-assessed, together with the available archaeological evidence on the population dynamics of the region. A revised model is then presented that allows for more refined experimenting with various demographic scenarios, showing that a much larger number of parameters can be responsible for changes in population growth than is often assumed in archaeological studies. In particular, marriage strategies would seem to play an important role in regulating the number of births. The model remains a work in progress that can be further refined and linked to models of settlement and land use development.',
#   'URL': 'https://doi.org/10.1007/978-3-030-04576-0_3',
#   'ISBN': '978-3-030-04576-0',
#   'note': 'DOI: 10.1007/978-3-030-04576-0_3',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'}],
#   'editor': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Joyce', 'given': 'Jamie'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'}],
#   'issued': {'date-parts': [[2019]]}},
#  '1913534/CLBZUHJ7': {'type': 'chapter',
#   'title': 'Archaeology of Germania Inferior: Urbanization',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '91-115',
#   'abstract': 'This chapter focuses on the archaeology of the first urban settlements of Roman type found in\n              Germania Inferior\n              . It first describes\n              coloniae\n              such as the\n              Colonia Claudia Ara Agrippinensium\n              and\n              Colonia Ulpia Traiana\n              , along with the archaeological excavations carried out at the sites. It then turns to the vici, industrial settlements, and agricultural settlements, and concludes with a theoretical explanation of how various forms of urban centres arose in Lower Germany during the period between the Batavian revolt and the Gallic Empire.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-5',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.5',
#   'shortTitle': 'Archaeology of Germania Inferior',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'author': [{'family': 'Hanel', 'given': 'Norbert'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '1913534/AHA9EWZL': {'type': 'article-journal',
#   'title': 'Modeling Epigraphy with an Ontology',
#   'abstract': 'This document is maintained by the Ontology Working Group of Epigraphy.info. (https://epigraphy-info.github.io/epigraphy-info/) Any request or contribution should be made via the Epigraphic Ontology Mailing List of the Epigraphic Ontology WG &lt;epont@googlegroups.com&gt; Contributors are listed alphabetically. Not all listed contributors have confirmed.',
#   'URL': 'https://zenodo.org/record/4639507',
#   'DOI': '10.5281/ZENODO.4639507',
#   'note': 'Publisher: Zenodo\nVersion Number: 0.1',
#   'author': [{'family': 'Bodard', 'given': ''},
#    {'family': 'Cayless', 'given': ''},
#    {'family': 'Cenati', 'given': ''},
#    {'family': 'Cooley', 'given': ''},
#    {'family': 'Elliott', 'given': ''},
#    {'family': 'Evangelisti', 'given': ''},
#    {'family': 'Felicetti', 'given': ''},
#    {'family': 'Granados', 'given': ''},
#    {'family': 'Grieshaber', 'given': ''},
#    {'family': 'Gruber', 'given': ''},
#    {'family': 'Hershkowitz', 'given': ''},
#    {'family': 'Hill', 'given': ''},
#    {'family': 'Kiiskinen', 'given': ''},
#    {'family': 'Kollatz', 'given': ''},
#    {'family': 'Levivier', 'given': ''},
#    {'family': 'Liuzzo', 'given': ''},
#    {'family': 'Luciani', 'given': ''},
#    {'family': 'Mannocci', 'given': ''},
#    {'family': 'Mataix', 'given': ''},
#    {'family': 'Murano', 'given': ''},
#    {'family': 'Murphy', 'given': ''},
#    {'family': 'Mylonas', 'given': ''},
#    {'family': 'Prag', 'given': ''},
#    {'family': 'Razanajao', 'given': ''},
#    {'family': 'Stoyanova', 'given': ''},
#    {'family': 'Tsolakis', 'given': ''},
#    {'family': 'Tupman', 'given': ''},
#    {'family': 'Vagionakis', 'given': ''},
#    {'family': 'Vitale', 'given': ''},
#    {'family': 'Weise', 'given': ''}],
#   'issued': {'date-parts': [[2021, 3, 26]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/LFKD595C': {'type': 'chapter',
#   'title': 'Encoding, Interoperability, Lexicography: Digital Epigraphy Through the Lens of DASI Experience',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '1-18',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-002/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-002',
#   'shortTitle': '1 Encoding, Interoperability, Lexicography',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Avanzini', 'given': 'Alessandra'},
#    {'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/37N8YE3I': {'type': 'book',
#   'title': 'Crossing Experiences in Digital Epigraphy: From Practice to Discipline',
#   'publisher': 'De Gruyter',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208',
#   'shortTitle': 'Crossing Experiences in Digital Epigraphy',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 17]]}},
#  '1913534/UZDY7HD7': {'type': 'article-journal',
#   'title': 'Galen and the Antonine Plague',
#   'container-title': 'The American Journal of Philology',
#   'page': '243–255',
#   'volume': '94',
#   'issue': '3',
#   'URL': 'http://www.jstor.org/stable/293979',
#   'note': 'Publisher: Johns Hopkins University Press',
#   'author': [{'family': 'Littman', 'given': 'R. J.'},
#    {'family': 'Littman', 'given': 'M. L.'}],
#   'issued': {'date-parts': [[1973]]}},
#  '1913534/33TNUAZ3': {'type': 'article-journal',
#   'title': 'People, Plagues, and Prices in the Roman World: The Evidence from Egypt',
#   'container-title': 'The Journal of Economic History',
#   'page': '803-839',
#   'volume': '76',
#   'issue': '3',
#   'abstract': 'The papyri of Roman Egypt provide some of the most important quantifiable data from a first-millennium economy. This paper builds a new dataset of wheat prices, land prices, rents, and wages over the entire period of Roman control in Egypt. Movements in both nominal and real prices over these centuries suggest periods of intensive and extensive economic growth as well as contraction. Across a timeframe that covers several severe mortality shocks, demographic changes appear to be an important, but by no means the only, force behind changes in factor prices.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0022050716000826/type/journal_article',
#   'DOI': '10.1017/S0022050716000826',
#   'shortTitle': 'People, Plagues, and Prices in the Roman World',
#   'journalAbbreviation': 'J. Econ. Hist.',
#   'language': 'en',
#   'author': [{'family': 'Harper', 'given': 'Kyle'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '1913534/N8MU7LGT': {'type': 'chapter',
#   'title': 'Making up for Lost Time: Digital Epigraphy, Chronology, and the PeriodO Project',
#   'container-title': 'Crossing Experiences in Digital Epigraphy',
#   'publisher': 'De Gruyter Open Poland',
#   'page': '202-215',
#   'URL': 'https://www.degruyter.com/document/doi/10.1515/9783110607208-017/html',
#   'ISBN': '978-3-11-060720-8',
#   'note': 'DOI: 10.1515/9783110607208-017',
#   'shortTitle': '16 Making up for Lost Time',
#   'editor': [{'family': 'De Santis', 'given': 'Annamaria'},
#    {'family': 'Rossi', 'given': 'Irene'}],
#   'author': [{'family': 'Rabinowitz', 'given': 'Adam'},
#    {'family': 'Shaw', 'given': 'Ryan'},
#    {'family': 'Golden', 'given': 'Patrick'}],
#   'issued': {'date-parts': [[2018, 12, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '1913534/4YVYEDQD': {'type': 'book',
#   'title': 'Epigraphic Evidence: Ancient History from Inscriptions',
#   'collection-title': 'Approaching the ancient world',
#   'publisher': 'Routledge',
#   'URL': 'https://books.google.dk/books?id=Iz5GT7ZfxLsC',
#   'ISBN': '978-0-415-11623-7',
#   'note': 'LCCN: 00059202',
#   'author': [{'family': 'Bodel', 'given': 'J.P.'}],
#   'issued': {'date-parts': [[2001]]}},
#  '1913534/DF62R52E': {'type': 'article-journal',
#   'title': 'A multi-proxy inference of Jōmon population dynamics using bayesian phase models, residential data, and summed probability distribution of 14C dates',
#   'container-title': 'Journal of Archaeological Science',
#   'page': '105136',
#   'volume': '117',
#   'abstract': 'We introduce a new workflow for analysing archaeological frequency data associated with relative rather than absolute chronological time-stamps. Our approach takes into account multiple sources of uncertainty by combining Bayesian chronological models and Monte-Carlo simulation to sample possible calendar dates for each archaeological entity. We argue that when applied to settlement data, this combination of methods can bring new life to demographic proxies that are currently under-used due to their lack of chronological accuracy and pre\xad cision, and provide grounds for further exploring the limits and the potential of the so-called “dates as data” approach based on the temporal frequency of radiocarbon dates. Here we employ this new workflow by reexamining a legacy dataset that has been used to describe a major population rise-and-fall that occurred in central Japan during the Jo�mon period (16,000–2,800 cal BP), focusing on the temporal window between 8,000 and 3,000 cal BP. To achieve this goal we: 1) construct the first Bayesian model of forty-two Jo�mon ceramic typology based cultural phases using a sample of 2,120 radiocarbon dates; 2) apply the proposed workflow on a dataset of 9,612 Jo�mon pit-dwellings; and 3) compare the output to a Summed Probability Distribution (SPD) of 1,550 radiocarbon dates from the same region. Our results provide new estimates on the timing of major de\xad mographic fluctuations during the Jo�mon period and reveal a generally good correlation between the two proxies, although with some notable discrepancies potentially related to changes in settlement pattern.',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S0305440320300583',
#   'DOI': '10.1016/j.jas.2020.105136',
#   'journalAbbreviation': 'Journal of Archaeological Science',
#   'language': 'en',
#   'author': [{'family': 'Crema', 'given': 'Enrico R.'},
#    {'family': 'Kobayashi', 'given': "Ken'ichi"}],
#   'issued': {'date-parts': [['2020']]},
#   'accessed': {'date-parts': [[2020, 5, 14]]}},
#  '1913534/MT2ZRZBH': {'type': 'book',
#   'title': 'tempun',
#   'publisher': 'Zenodo',
#   'version': 'v0.1',
#   'abstract': 'No description provided.',
#   'URL': 'https://zenodo.org/record/4650989',
#   'note': 'DOI: 10.5281/ZENODO.4650989',
#   'author': [{'family': 'Kaše', 'given': 'Vojtěch'}],
#   'issued': {'date-parts': [[2021, 3, 31]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/AIJX7C5S': {'type': 'chapter',
#   'title': 'The Limes',
#   'container-title': 'The Oxford Handbook of the Archaeology of Roman Germany',
#   'publisher': 'Oxford University Press',
#   'page': '165-198',
#   'abstract': 'This chapter examines some important themes associated with research on the\n              limes\n              in Roman Germany, with particular emphasis on the ‘Upper German-Raetian\n              Limes\n              ’ and how the form and function of the outer frontiers of the Roman world were influenced by dynamic evolutionary processes. Before discussing how the\n              limes\n              took on a role as an ‘imperial/barbarian boundary’, the chapter considers the function of boundaries in general and the\n              limes\n              in particular. It then traces historic developments of the\n              limites\n              and their use in erecting frontier installations, watchtowers, and fortlets. It also looks at the crossing points through the\n              limes\n              that have survived in relatively high numbers in\n              Germania Superior\n              and\n              Raetia\n              ; the legions as the backbone of frontier defence; and auxiliary troops (\n              auxilia\n              ) that occupied the frontier along the Rhine in\n              Germania Inferior\n              and the Upper German-Raetian\n              Limes\n              during the second and third centuries AD.',
#   'URL': 'http://oxfordhandbooks.com/view/10.1093/oxfordhb/9780199665730.001.0001/oxfordhb-9780199665730-e-7',
#   'ISBN': '978-0-19-966573-0',
#   'note': 'DOI: 10.1093/oxfordhb/9780199665730.013.7',
#   'language': 'en',
#   'editor': [{'family': 'James', 'given': 'Simon'},
#    {'family': 'Krmnicek', 'given': 'Stefan'}],
#   'container-author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'author': [{'family': 'Kemkes', 'given': 'Martin'}],
#   'issued': {'date-parts': [[2020, 3, 24]]},
#   'accessed': {'date-parts': [[2021, 5, 15]]}},
#  '1913534/XJBYYW4X': {'type': 'article-journal',
#   'title': "Now you see them, now you don't: Defining and using a flexible chronology of sites for spatial analysis of Roman settlement in the Dutch river area",
#   'container-title': 'Journal of Archaeological Science: Reports',
#   'page': '309-321',
#   'volume': '10',
#   'URL': 'https://linkinghub.elsevier.com/retrieve/pii/S2352409X16303832',
#   'DOI': '10.1016/j.jasrep.2016.10.006',
#   'shortTitle': "Now you see them, now you don't",
#   'journalAbbreviation': 'Journal of Archaeological Science: Reports',
#   'language': 'en',
#   'author': [{'family': 'Verhagen', 'given': 'Philip'},
#    {'family': 'Vossen', 'given': 'Ivo'},
#    {'family': 'Groenhuijzen', 'given': 'Mark R.'},
#    {'family': 'Joyce', 'given': 'Jamie'}],
#   'issued': {'date-parts': [['2016']]},
#   'accessed': {'date-parts': [[2021, 5, 14]]}},
#  '1913534/V9UVGQX2': {'type': 'webpage',
#   'title': 'Understanding Roman inscriptions',
#   'abstract': 'This is the first comprehensive treatment in English to provide an explanation of not only the language of inscriptions but also the context in which they were produced.',
#   'URL': 'http://site.ebrary.com/id/10062897',
#   'note': 'Archive: /z-wcorg/\nISBN: 0203084675 9780203084670 9780203707357 0203707354 9781134746125 1134746121 9781134746163 1134746164 9781134746170 1134746172 9781138142923 1138142921 9780415151436 0415151430 9786610539277 6610539278 1280539275 9781280539275\nLibrary Catalog: http://worldcat.org\nPlace: Baltimore\nPublisher: Johns Hopkins University Press',
#   'language': 'English.',
#   'author': [{'family': 'Keppie', 'given': 'L. J. F.'}],
#   'issued': {'date-parts': [[1991]]}},
#  '1913534/6YVHFFUJ': {'type': 'book',
#   'title': 'Quantifying the Roman Economy: Methods and Problems',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'event-place': 'Oxford - New York',
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'issued': {'date-parts': [[2009]]}},
#  '1913534/U48VTMSM': {'type': 'article-journal',
#   'title': 'Coin Hoards Speak of Population Declines in Ancient Rome',
#   'container-title': 'Proceedings of the National Academy of Sciences of the United States of America',
#   'page': '17276–17279',
#   'volume': '106',
#   'abstract': 'In times of violence, people tend to hide their valuables, which are later recovered unless the owners had been killed or driven away. Thus, the temporal distribution of unrecovered coin hoards is an excellent proxy for the intensity of internal warfare. We use this relationship to resolve a long-standing controversy in Roman history. Depending on who was counted in the early Imperial censuses (adult males or the entire citizenry including women and minors), the Roman citizen population of Italy either declined, or more than doubled, during the first century BCE. This period was characterized by a series of civil wars, and historical evidence indicates that high levels of sociopolitical instability are associated with demographic contractions. We fitted a simple model quantifying the effect of instability (proxied by hoard frequency) on population dynamics to the data before 100 BCE. The model predicts declining population after 100 BCE. This suggests that the vigorous growth scenario is highly implausible.',
#   'DOI': '10.1073/pnas.0904576106',
#   'note': 'PMID: 19805043',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Scheidel', 'given': 'Walter'}],
#   'issued': {'date-parts': [[2009]]}},
#  '1913534/2LT8WIGC': {'type': 'article-journal',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'container-title': 'Hesperia',
#   'page': '387-439',
#   'volume': '68',
#   'issue': '3',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'DOI': '10.2307/148494',
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'issued': {'date-parts': [[1999]]},
#   'accessed': {'date-parts': [[2019, 11, 21]]}},
#  '1913534/6CHTC3L7': {'type': 'chapter',
#   'title': 'The “Epigraphic Habit” in the Roman World',
#   'container-title': 'The Oxford Handbook of Roman Epigraphy',
#   'collection-title': 'Oxford Handbooks',
#   'publisher': 'Oxford University Press',
#   'volume': '1',
#   'abstract': 'Since the 1980s scholars have ceased considering Roman inscriptions simply in functional terms—as sources of historical information—and started to treat them as a cultural phenomenon worthy of serious consideration. This change in perspective, as well as the realization that there was a permanent bond between text and monument, represents the most productive shift in approach in recent epigraphic scholarship. This chapter analyzes the “epigraphic habit” in order to explain why people wrote on stone throughout Italy and the provinces, linking its rise to the proliferation of urbanization, literacy, and the desire for self-representation.',
#   'ISBN': '0-19-533646-1',
#   'language': 'eng',
#   'author': [{'family': 'Beltrán Lloris', 'given': 'Francisco'}],
#   'issued': {'date-parts': [[2014]]}},
#  '1913534/NEGLBLPH': {'type': 'book',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'publisher': 'Routledge',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'ISBN': '978-1-00-302530-6',
#   'note': 'DOI: 10.4324/9781003025306',
#   'language': 'en',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/GDRQEX9Z': {'type': 'book',
#   'title': 'The Epigraphic Cultures of Late Antiquity',
#   'collection-title': 'Alte Geschichte',
#   'publisher': 'Franz Steiner Verlag',
#   'URL': 'https://books.google.dk/books?id=iJBdMQAACAAJ',
#   'ISBN': '978-3-515-11558-2',
#   'author': [{'family': 'Bolle', 'given': 'K.'},
#    {'family': 'Machado', 'given': 'C.'},
#    {'family': 'Witschel', 'given': 'C.'}],
#   'issued': {'date-parts': [[2017]]}},
#  '1913534/XUF75FS9': {'type': 'post-weblog',
#   'title': 'Working with databases: The case of the Epigraphik-Datenbank Clauss/Slaby (EDCS)',
#   'container-title': 'DOCTORAL TRAINING UNIT “DIGITAL HISTORY & HERMENEUTICS”',
#   'genre': 'Université du Luxembourg',
#   'URL': 'https://dhh.uni.lu/2020/07/10/working-with-databases-the-case-of-the-epigraphik-datenbank-clauss-slaby-edcs/',
#   'language': 'English',
#   'author': [{'family': 'Lotz', 'given': 'Jan'}],
#   'issued': {'date-parts': [[2020, 10, 7]]},
#   'accessed': {'date-parts': [[2021, 7, 5]]}},
#  '1913534/BGNB6HUT': {'type': 'article-journal',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'container-title': 'The American Journal of Philology',
#   'page': '233',
#   'volume': '103',
#   'issue': '3',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'DOI': '10.2307/294470',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'issued': {'date-parts': [[1982]]}},
#  '1913534/8AAUR7HD': {'type': 'article-journal',
#   'title': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy: The End of a Habit?',
#   'container-title': 'Historia',
#   'page': '116-132',
#   'volume': '70',
#   'issue': '1',
#   'abstract': '<p>The political communities of western Asia Minor produced an enormous amount of inscriptions under Roman rule. For the period between AD 260 and 280, however, the epigraphic habit falls dramatically and this situation largely continues in the 4<sup>th</sup> and 5<sup>th</sup> centuries. The aim of this paper is to analyse the phenomenon in the transitional Tetrarchic age, when a notable increase in testimony, particularly milestones and texts related to the new regime (e. g. ‘Edict of Prices’), can be observed. My study of continuities and changes concludes that the propagandistic efforts under the Tetrarchs did not ultimately coincide with a full reactivation of civic epigraphic culture and this new scenario should remain fundamental for our assessment of Late Antiquity in the region.</p>',
#   'URL': 'https://elibrary.steiner-verlag.de/article/10.25162/historia-2021-0006',
#   'DOI': '10.25162/historia-2021-0006',
#   'shortTitle': 'Western Asia Minor and its Epigraphic Sources under the Tetrarchy',
#   'journalAbbreviation': 'historia',
#   'language': 'en',
#   'author': [{'family': 'Pérez', 'given': 'Aitor Blanco'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/F3Y2FVVY': {'type': 'chapter',
#   'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#   'container-title': 'A Companion to Late Antiquity',
#   'publisher': 'John Wiley & Sons, Ltd',
#   'page': '170-186',
#   'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#   'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#   'ISBN': '978-1-4443-0610-1',
#   'note': 'DOI: 10.1002/9781444306101.ch12',
#   'shortTitle': 'Inscribing Identity',
#   'language': 'en',
#   'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/7KH8X6PB': {'type': 'article-journal',
#   'title': 'Digital Epigraphy am Scheideweg? / Digital Epigraphy at a crossroads?',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/22141',
#   'DOI': '10.11588/HEIDOK.00022141',
#   'note': 'Publisher: Heidelberg University Library',
#   'shortTitle': 'Digital Epigraphy am Scheideweg?',
#   'author': [{'family': 'Feraudi-Gruénais', 'given': 'Francisca'},
#    {'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2016]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/DBL5UIX2': {'type': 'article-journal',
#   'title': 'Epigraphic Database Heidelberg – Data Reuse Options',
#   'URL': 'http://archiv.ub.uni-heidelberg.de/volltextserver/id/eprint/26599',
#   'DOI': '10.11588/HEIDOK.00026599',
#   'note': 'Publisher: Heidelberg University Library',
#   'author': [{'family': 'Grieshaber', 'given': 'Frank'}],
#   'issued': {'date-parts': [[2019]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/HBPZKHXT': {'type': 'article-journal',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'container-title': 'Journal of Roman Studies',
#   'page': '22–39',
#   'volume': '86',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'DOI': '10.2307/300421',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'issued': {'date-parts': [[1996]]}},
#  '1913534/BADWX5AX': {'type': 'book',
#   'title': 'EpiDoc Guidelines: Ancient documents in TEI XML',
#   'URL': 'https://epidoc.stoa.org/gl/latest/',
#   'language': 'eng',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Mylonas', 'given': 'Elli'},
#    {'family': 'Stoyanova', 'given': 'Simona'},
#    {'family': 'Tupman', 'given': 'Charlotte'},
#    {'family': 'Vanderbilt', 'given': 'Scott'}],
#   'issued': {'date-parts': [[2020]]}},
#  '1913534/ARJNJ286': {'type': 'book',
#   'title': 'Epigraphic evidence: ancient history from inscriptions',
#   'collection-number': '4',
#   'publisher': 'Routledge',
#   'publisher-place': 'London, New York',
#   'volume': '61',
#   'number-of-pages': '1019–1020',
# ...
#   'DOI': '10.2307/300281',
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'issued': {'date-parts': [[1990]]}},
#  '1913534/WRT7VI6X': {'type': 'book',
#   'title': 'Conventions in editing : A suggested reformulation of the Leiden system.',
#   'collection-title': 'Greek, Roman and Byzantine scholarly Aids ; No. 2.',
#   'publisher': 'Duke University',
#   'publisher-place': 'Durham',
#   'event-place': 'Durham',
#   'language': 'eng',
#   'author': [{'family': 'Dow', 'given': 'Sterling'}],
#   'issued': {'date-parts': [[1969]]}},
#  '1913534/5GAQW7DV': {'type': 'book',
#   'title': 'The Roman brick stamps not published in Vol. XI, 1 of the Corpus inscriptionum Latinarum, including Indices to the Roman brick-stamps.',
#   'publisher': '"L\'Erma" di Bretschneider',
#   'publisher-place': 'Roma',
#   'edition': 'Ed. anastat.',
#   'event-place': 'Roma',
#   'language': 'ita',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1967]]}},
#  '1913534/T9TGS9S6': {'type': 'article-journal',
#   'title': 'The Roman Brick-Stamps not Published in Volume XV 1 of the "Corpus Inscriptionum Latinarum"',
#   'container-title': 'Harvard Studies in Classical Philology',
#   'page': '1',
#   'volume': '56',
#   'URL': 'https://www.jstor.org/stable/310746?origin=crossref',
#   'DOI': '10.2307/310746',
#   'journalAbbreviation': 'Harvard Studies in Classical Philology',
#   'author': [{'family': 'Bloch', 'given': 'Herbert'}],
#   'issued': {'date-parts': [[1947]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/H7KAA2TH': {'type': 'book',
#   'title': 'An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan',
#   'publisher': 'The University of Michigan Press',
#   'publisher-place': 'Ann Arbor',
#   'event-place': 'Ann Arbor',
#   'note': 'Publication Title: An Introduction to Greek Epigraphy of the Hellenistic and Roman Periods from Alexan\nDOI: 10.3998/mpub.23012',
#   'author': [{'family': 'McLean', 'given': 'Bradley'}],
#   'issued': {'date-parts': [[2016]]}},
#  '1913534/6HXR6GAN': {'type': 'chapter',
#   'title': 'Language and Identity in the Roman Colonies of Sicily',
#   'container-title': 'Roman Colonies in the First Century of their Foundation',
#   'publisher': 'Oxbow Books',
#   'publisher-place': 'Oxford',
#   'page': '7–31',
#   'event-place': 'Oxford',
#   'ISBN': '978-1-84217-974-1',
#   'author': [{'family': 'Korhonen', 'given': 'Kalle'}],
#   'editor': [{'family': 'Sweetman', 'given': 'Rebecca J'}],
#   'issued': {'date-parts': [[2011]]}},
#  '1913534/MNRERH36': {'type': 'chapter',
#   'title': 'Quantitative approaches to epigraphy: Epigraphic production in Thrace as a mirror of social organization',
#   'container-title': 'Peoples in the Black Sea Region from the Archaic to the Roman Period, Proceedings of the 3rd International Workshop on the Black Sea in Antiquity “ Thessaloniki, 21-23 September 2018',
#   'publisher': 'Archaeopress',
#   'publisher-place': 'Oxford',
#   'page': '83–93',
#   'event-place': 'Oxford',
#   'author': [{'family': 'Janouchová (Heřmánková)', 'given': 'Petra'}],
#   'editor': [{'family': 'Manoledakis', 'given': 'Manolis'}],
#   'issued': {'date-parts': [[2021]]}},
#  '1913534/CALUBQFC': {'type': 'chapter',
#   'title': 'Epigraphy by numbers: Latin and the epigraphic culture in Sicily',
#   'container-title': 'Becoming Roman, writing Latin? Literacy and Epigraphy in the Roman West',
#   'publisher': 'Journal of Roman Archaeology',
#   'publisher-place': 'Portsmouth, Rhode Island',
#   'page': '15–31',
#   'event-place': 'Portsmouth, Rhode Island',
#   'author': [{'family': 'Prag', 'given': 'Jonathan'}],
#   'editor': [{'family': 'Cooley', 'given': 'Alison E.'}],
#   'issued': {'date-parts': [[2002]]}},
#  '1913534/NX2YYEWH': {'type': 'chapter',
#   'title': 'Epigraphy in the western Mediterranean: a Hellenistic phenomenon?',
#   'container-title': 'The Hellenistic West: Rethinking the Ancient Mediterranean',
#   'publisher': 'Cambridge University Press',
#   'publisher-place': 'Cambridge, New York',
#   'page': '320–347',
#   'event-place': 'Cambridge, New York',
#   'abstract': "Although the Hellenistic period has become increasingly popular in research and teaching in recent years, the western Mediterranean is rarely considered part of the 'Hellenistic world'; instead the cities, peoples and kingdoms of the West are usually only discussed insofar as they relate to Rome. This book contends that the rift between the 'Greek East' and the 'Roman West' is more a product of the traditional separation of Roman and Greek history than a reflection of the Hellenistic-period Mediterranean, which was a strongly interconnected cultural and economic zone, with the rising Roman republic just one among many powers in the region, east and west. The contributors argue for a dynamic reading of the economy, politics and history of the central and western Mediterranean beyond Rome, and in doing so problematise the concepts of 'East', 'West' and 'Hellenistic' itself.",
#   'author': [{'family': 'Prag', 'given': 'Jonathan'}],
#   'editor': [{'family': 'Prag', 'given': 'Jonathan R. W.'},
#    {'family': 'Quinn', 'given': 'Josephine Crawley'}],
#   'issued': {'date-parts': [[2013]]}},
#  '1913534/XQGJDGFJ': {'type': 'article-journal',
#   'title': 'Roman Inscriptions 2001-2005',
#   'container-title': 'The Journal of Roman Studies',
#   'page': '176–263',
#   'volume': '97',
#   'URL': 'http://www.jstor.org/stable/20430576',
#   'note': 'Publisher: [Society for the Promotion of Roman Studies, Cambridge University Press]',
#   'author': [{'family': 'Cooley', 'given': 'Alison E.'},
#    {'family': 'Mitchell', 'given': 'Stephen'},
#    {'family': 'Salway', 'given': 'Benet'}],
#   'issued': {'date-parts': [[2007]]}},
#  '1913534/UTITLKQZ': {'type': 'article-journal',
#   'title': 'Modelling Temporal Uncertainty in Archaeological Analysis',
#   'container-title': 'Journal of Archaeological Method and Theory',
#   'page': '440-461',
#   'volume': '19',
#   'issue': '3',
#   'abstract': 'This paper discusses the problem of temporal uncertainty in archaeological analysis and how it affects archaeological interpretation. A probabilistic method is proposed as a potential solution for modelling and quantifying time when high levels of uncertainty restricts temporal knowledge and scientific datings are unavailable, while Monte Carlo simulation is suggested as a means to formally integrate such knowledge into actual analysis. A case study focusing on counts of prehistoric hunter–gatherer pithouses in Mid-Holocene Japan provides an example of how uncertainty can be problematic and bias the results of the most straightforward archaeological analysis and how the coupling of a probabilistic and simulation-based approach nonetheless offers a useful solution. The discussion that follows also addresses the need for more robust and quantifiable ways to illustrate the chronological flow of our archaeological narratives.',
#   'URL': 'http://link.springer.com/10.1007/s10816-011-9122-3',
#   'DOI': '10.1007/s10816-011-9122-3',
#   'journalAbbreviation': 'J Archaeol Method Theory',
#   'language': 'en',
#   'author': [{'family': 'Crema', 'given': 'Enrico R.'}],
#   'issued': {'date-parts': [['2012']]},
#   'accessed': {'date-parts': [[2019, 11, 20]]}},
#  '1913534/EIU8NCUL': {'type': 'article-journal',
#   'title': 'Aoristic Analysis: Seeds of a New Approach to Mapping Archaeological Distributions through Time',
#   'container-title': 'Computer Applications in Archaeology',
#   'page': '448-452',
#   'volume': '2003',
#   'URL': 'https://publikationen.uni-tuebingen.de/xmlui/handle/10900/60663',
#   'DOI': '10.15496/PUBLIKATION-2085',
#   'note': 'Publisher: Universitätsbibliothek Tübingen',
#   'shortTitle': 'Aoristic Analysis',
#   'language': 'en',
#   'author': [{'family': 'Johnson', 'given': 'Ian'}],
#   'issued': {'date-parts': [[2004]]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/NR7KMK97': {'type': 'chapter',
#   'title': 'Christian and Late Antique Epigraphies',
#   'container-title': 'The Epigraphic Cultures of Late Antiquity',
#   'publisher': 'Franz Steiner Verlag',
#   'page': '503–514',
#   'ISBN': '978-3-515-11558-2',
#   'language': 'English',
#   'author': [{'family': 'Roueche', 'given': 'Charlotte Mary'},
#    {'family': 'Sotinel', 'given': 'Claire'}],
#   'editor': [{'family': 'Bolle', 'given': 'Katharina'},
#    {'family': 'Machado', 'given': 'Carlos'},
#    {'family': 'Witschel', 'given': 'Christian'}],
#   'issued': {'date-parts': [['2017', 3]]}},
#  '1913534/HGSQZDS4': {'type': 'article-journal',
#   'title': 'Medieval Commercial Sites: As Seen Through Portable Antiquities Scheme Data',
#   'container-title': 'The Antiquaries Journal',
#   'page': '109-140',
#   'volume': '100',
#   'abstract': 'This paper explores some 220,000 medieval objects recorded in the Portable Antiquities Scheme (PAS) online database of archaeological small finds through Geographic Information System analysis of their relationship with contemporary market sites. First, an overview of the contents of the PAS database is presented in terms of its spatial and ‘object type’ distribution. Second, the relationship of the medieval finds data against documentary evidence of commercial activity is investigated at a national level. Finally, PAS data is contextualised in its historical landscape context through case studies. It is argued that the distribution of PAS finds on the national scale can be linked with patterns of commercial activity, and that while rural and urban finds scatters have distinguishing trends, the countryside population enjoyed access to a range of sophisticated metalwork culture; also, that certain assemblages can be analysed statistically to yield new data and perspectives on local historical development.',
#   'URL': 'https://www.cambridge.org/core/product/identifier/S0003581520000165/type/journal_article',
#   'DOI': '10.1017/S0003581520000165',
#   'shortTitle': 'MEDIEVAL COMMERCIAL SITES',
#   'journalAbbreviation': 'Antiq. J.',
#   'language': 'en',
#   'author': [{'family': 'Oksanen', 'given': 'Eljas'},
#    {'family': 'Lewis', 'given': 'Michael'}],
#   'issued': {'date-parts': [['2020']]},
#   'accessed': {'date-parts': [[2021, 5, 10]]}},
#  '1913534/YS8ZN82H': {'type': 'article-journal',
#   'title': 'Rezension zu: Epigraphische Datenbank Heidelberg',
#   'container-title': 'H-Soz-Kult',
#   'URL': 'https://www.hsozkult.de/webreview/id/rezwww-179',
#   'language': 'ger',
#   'author': [{'family': 'Hartmann', 'given': 'Andreas'}],
#   'issued': {'date-parts': [[2018, 10, 13]]}},
#  '1913534/WNGG6SYB': {'type': 'book',
#   'title': 'EpiDoc Reference Stylesheets (version 9)',
#   'abstract': 'XSLT for transformation of EpiDoc XML files into HTML or text versions in Leiden. Includes various XML files containing parameters and other options.',
#   'URL': 'https://sourceforge.net/p/epidoc/wiki/Stylesheets/',
#   'author': [{'family': 'Elliot', 'given': 'Tom'},
#    {'family': 'Au', 'given': 'Zaneta'},
#    {'family': 'Bodard', 'given': 'Gabriel'},
#    {'family': 'Cayless', 'given': 'Hugh'},
#    {'family': 'Lanz', 'given': 'Carmen'},
#    {'family': 'Lawrence', 'given': 'Faith'},
#    {'family': 'Vanderbilt', 'given': 'Scott'},
#    {'family': 'Viglianti', 'given': 'Raffaele'}],
#   'issued': {'date-parts': [[2017]]}},
#  '1913534/5ALKMMVG': {'type': 'article-journal',
#   'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'page': 'E144-E151',
#   'volume': '115',
#   'issue': '2',
#   'abstract': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#   'DOI': '10.1073/pnas.1708800115',
#   'note': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Currie', 'given': 'Thomas E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'Mullins', 'given': 'Daniel'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Grohmann', 'given': 'Stephanie'},
#    {'family': 'Savage', 'given': 'Patrick'},
#    {'family': 'Mendel-Gleason', 'given': 'Gavin'},
#    {'family': 'Turner', 'given': 'Edward'},
#    {'family': 'Dupeyron', 'given': 'Agathe'},
#    {'family': 'Cioni', 'given': 'Enrico'},
#    {'family': 'Reddish', 'given': 'Jenny'},
#    {'family': 'Levine', 'given': 'Jill'},
#    {'family': 'Jordan', 'given': 'Greine'},
#    {'family': 'Brandl', 'given': 'Eva'},
#    {'family': 'Williams', 'given': 'Alice'},
#    {'family': 'Cesaretti', 'given': 'Rudolf'},
#    {'family': 'Krueger', 'given': 'Marta'},
#    {'family': 'Ceccarelli', 'given': 'Alessandro'},
#    {'family': 'Figliulo-Rosswurm', 'given': 'Joe'},
#    {'family': 'Tuan', 'given': 'Po-Ju'},
#    {'family': 'Peregrine', 'given': 'Peter'},
#    {'family': 'Marciniak', 'given': 'Arkadiusz'},
#    {'family': 'Preiser-Kapeller', 'given': 'Johannes'},
#    {'family': 'Kradin', 'given': 'Nikolay'},
#    {'family': 'Korotayev', 'given': 'Andrey'},
#    {'family': 'Palmisano', 'given': 'Alessio'},
#    {'family': 'Baker', 'given': 'David'},
#    {'family': 'Bidmead', 'given': 'Julye'},
#    {'family': 'Bol', 'given': 'Peter'},
#    {'family': 'Christian', 'given': 'David'},
#    {'family': 'Cook', 'given': 'Connie'},
#    {'family': 'Covey', 'given': 'Alan'},
#    {'family': 'Feinman', 'given': 'Gary'},
#    {'family': 'Júlíusson', 'given': 'Árni Daníel'},
#    {'family': 'Kristinsson', 'given': 'Axel'},
#    {'family': 'Miksic', 'given': 'John'},
#    {'family': 'Mostern', 'given': 'Ruth'},
#    {'family': 'Petrie', 'given': 'Cameron'},
#    {'family': 'Rudiak-Gould', 'given': 'Peter'},
#    {'family': 'ter Haar', 'given': 'Barend'},
#    {'family': 'Wallace', 'given': 'Vesna'},
#    {'family': 'Mair', 'given': 'Victor'},
#    {'family': 'Xie', 'given': 'Liye'},
#    {'family': 'Baines', 'given': 'John'},
#    {'family': 'Bridges', 'given': 'Elizabeth'},
#    {'family': 'Manning', 'given': 'Joseph'},
#    {'family': 'Lockhart', 'given': 'Bruce'},
#    {'family': 'Bogaard', 'given': 'Amy'},
#    {'family': 'Spencer', 'given': 'Charles'}],
#   'issued': {'date-parts': [[2018]]}}}

# %%
test_paragraph = "Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139)."
citations_used = {}
for key in citation_keys_pairs.keys():
    if key in test_paragraph:
        print(key)
        citations_used[citation_keys_pairs[key]] = citations[citation_keys_pairs[key]]
        test_paragraph = test_paragraph.replace(key, '<cite data-cite="' + citation_keys_pairs[key] + '"></cite>')
# Out:
# Hedrick 1999
# Nawotka 2021
# MacMullen 1982
# Trout 2009
# Woolf 1996
# Meyer 1990

# %%
citations_used
# Out:
# {'1913534/2LT8WIGC': {'type': 'article-journal',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'container-title': 'Hesperia',
#   'page': '387-439',
#   'volume': '68',
#   'issue': '3',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'DOI': '10.2307/148494',
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'issued': {'date-parts': [[1999]]},
#   'accessed': {'date-parts': [[2019, 11, 21]]}},
#  '1913534/NEGLBLPH': {'type': 'book',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'publisher': 'Routledge',
#   'edition': '1',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'ISBN': '978-1-00-302530-6',
#   'note': 'DOI: 10.4324/9781003025306',
#   'language': 'en',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'issued': {'date-parts': [[2021]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/BGNB6HUT': {'type': 'article-journal',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'container-title': 'The American Journal of Philology',
#   'page': '233',
#   'volume': '103',
#   'issue': '3',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'DOI': '10.2307/294470',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'issued': {'date-parts': [[1982]]}},
#  '1913534/F3Y2FVVY': {'type': 'chapter',
#   'title': 'Inscribing Identity: The Latin Epigraphic Habit in Late Antiquity',
#   'container-title': 'A Companion to Late Antiquity',
#   'publisher': 'John Wiley & Sons, Ltd',
#   'page': '170-186',
#   'abstract': 'This chapter contains sections titled: Epigraphic Corpora and Epigraphic Curves An Epigraphy of Christians Epigraphic Horizons Civic History and Public Memory Crossing Divides Bibliographical Note',
#   'URL': 'https://onlinelibrary.wiley.com/doi/abs/10.1002/9781444306101.ch12',
#   'ISBN': '978-1-4443-0610-1',
#   'note': 'DOI: 10.1002/9781444306101.ch12',
#   'shortTitle': 'Inscribing Identity',
#   'language': 'en',
#   'author': [{'family': 'Trout', 'given': 'Dennis E.'}],
#   'issued': {'date-parts': [[2009]]},
#   'accessed': {'date-parts': [[2021, 5, 7]]}},
#  '1913534/HBPZKHXT': {'type': 'article-journal',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'container-title': 'Journal of Roman Studies',
#   'page': '22–39',
#   'volume': '86',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'DOI': '10.2307/300421',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'issued': {'date-parts': [[1996]]}},
#  '1913534/MUKI9YSZ': {'type': 'article-journal',
#   'title': 'Explaining the Epigraphic Habit in the Roman Empire: The Evidence of Epitaphs',
#   'container-title': 'Journal of Roman Studies',
#   'page': '74–96',
#   'volume': '80',
#   'abstract': "It is now notorious that the production of inscriptions in the Roman Empire was not constant over time, but rose over the first and second centuries A.D. and fell in the third. Ramsay MacMullen pointed this out more than five years ago, with conclusions more cautionary than explanatory: ‘history is not being written in the right way', he said, for historians have deduced Rome's decline from evidence that–since it appears only epigraphically–has merely disappeared for its own reasons, or have sought general explanations of decline in theories political, economic, or even demographic in nature, none of which can, in turn, explain the disappearance of epigraphy itself. Why this epigraphic habit rose and fell MacMullen left open to question, although he did postulate control by a ‘sense of audience'. The purpose of this paper is to propose that this ‘sense of audience' was not generalized or generic, but depended on a belief in the value of romanization, of which (as noted but not explained by MacMullen's article) the epigraphic habit is also a rough indicator. Epitaphs constitute the bulk of all provincial inscriptions and in form and number are (generally speaking) the consequence of a provincial imitation of characteristically Roman practices, an imitation that depended on the belief that Roman legal status and style were important, and that may indeed have ultimately depended, at least in North Africa, on the acquisition or prior possession of that status. Such status-based motivations for erecting an epitaph help to explain not only the chronological distribution of epitaphs but also the differences in the type and distribution of epitaphs in the western and eastern halves of the empire. They will be used here moreover to suggest an explanation for the epigraphic habit as a whole.",
#   'DOI': '10.2307/300281',
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'issued': {'date-parts': [[1990]]}}}

# %%
test_paragraph
# Out:
# 'Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (<cite data-cite="1913534/BGNB6HUT"></cite>; Meyer 1991; <cite data-cite="1913534/HBPZKHXT"></cite>). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (<cite data-cite="1913534/MUKI9YSZ"></cite>, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., <cite data-cite="1913534/2LT8WIGC"></cite>; <cite data-cite="1913534/F3Y2FVVY"></cite>; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; <cite data-cite="1913534/NEGLBLPH"></cite>; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).'

# %% [markdown]
# Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (<cite data-cite="1913534/BGNB6HUT"></cite>; Meyer 1991; <cite data-cite="1913534/HBPZKHXT"></cite>). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (<cite data-cite="1913534/MUKI9YSZ"></cite>, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., <cite data-cite="1913534/2LT8WIGC"></cite>; <cite data-cite="1913534/F3Y2FVVY"></cite>; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; <cite data-cite="1913534/NEGLBLPH"></cite>; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).

# %%
import json

# %%
notebook_dict = json.loads(notebook_text)
notebook_dict["metadata"]["cite2c"]["citations"]
# Out:
# {'7109337/2ASLDCJP': {'DOI': '10.1177/0003122418772567',
#   'URL': 'http://journals.sagepub.com/doi/10.1177/0003122418772567',
#   'abstract': 'Proponents of the Axial Age contend that parallel cultural developments between 800 and 200 BCE in what is today China, Greece, India, Iran, and Israel-Palestine constitute the global historical turning point toward modernity. The Axial Age concept is well-known and influential, but deficiencies in the historical evidence and sociological analysis available have thwarted efforts to evaluate the concept’s major global contentions. As a result, the Axial Age concept remains controversial. Seshat: Global History Databank provides new tools for examining this topic in social formations across Afro-Eurasia during the first two millennia BCE and first millennium CE, allowing scholars to empirically evaluate the varied and contrasting claims researchers have put forward. Results undercut the notion of a specific “age” of axiality limited to a specific geo-temporal localization. Critical traits offered as evidence of an axial transformation by proponents of the Axial Age concept appeared across Afro-Eurasia hundreds, and in some cases thousands, of years prior to the proposed Axial Age. Our analysis raises important questions for future evaluations of this period and points the way toward empirically-led, historical-sociological investigations of the ideological and institutional foundations of complex societies.',
#   'accessed': {'day': 17, 'month': 5, 'year': 2021},
#   'author': [{'family': 'Mullins', 'given': 'Daniel Austin'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Currie', 'given': 'Thomas'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Savage', 'given': 'Patrick E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'Turchin', 'given': 'Peter'}],
#   'container-title': 'American Sociological Review',
#   'container-title-short': 'Am Sociol Rev',
#   'id': '7109337/2ASLDCJP',
#   'issue': '3',
#   'issued': {'year': 2018},
#   'journalAbbreviation': 'Am Sociol Rev',
#   'language': 'en',
#   'page': '596-626',
#   'page-first': '596',
#   'title': 'A Systematic Assessment of “Axial Age” Proposals Using Global Comparative Historical Evidence',
#   'type': 'article-journal',
#   'volume': '83'},
#  '7109337/3L9BKAXW': {'DOI': '10.1073/pnas.1708800115',
#   'abstract': 'Do human societies from around the world exhibit similarities in the way that they are structured, and show commonalities in the ways that they have evolved? These are long-standing questions that have proven difficult to answer. To test between competing hypotheses, we constructed a massive repository of historical and archaeological information known as "Seshat: Global History Databank." We systematically coded data on 414 societies from 30 regions around the world spanning the last 10,000 years. We were able to capture information on 51 variables reflecting nine characteristics of human societies, such as social scale, economy, features of governance, and information systems. Our analyses revealed that these different characteristics show strong relationships with each other and that a single principal component captures around three-quarters of the observed variation. Furthermore, we found that different characteristics of social complexity are highly predictable across different world regions. These results suggest that key aspects of social organization are functionally related and do indeed coevolve in predictable ways. Our findings highlight the power of the sciences and humanities working together to rigorously test hypotheses about general rules that may have shaped human history.',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Currie', 'given': 'Thomas E.'},
#    {'family': 'Whitehouse', 'given': 'Harvey'},
#    {'family': 'François', 'given': 'Pieter'},
#    {'family': 'Feeney', 'given': 'Kevin'},
#    {'family': 'Mullins', 'given': 'Daniel'},
#    {'family': 'Hoyer', 'given': 'Daniel'},
#    {'family': 'Collins', 'given': 'Christina'},
#    {'family': 'Grohmann', 'given': 'Stephanie'},
#    {'family': 'Savage', 'given': 'Patrick'},
#    {'family': 'Mendel-Gleason', 'given': 'Gavin'},
#    {'family': 'Turner', 'given': 'Edward'},
#    {'family': 'Dupeyron', 'given': 'Agathe'},
#    {'family': 'Cioni', 'given': 'Enrico'},
#    {'family': 'Reddish', 'given': 'Jenny'},
#    {'family': 'Levine', 'given': 'Jill'},
#    {'family': 'Jordan', 'given': 'Greine'},
#    {'family': 'Brandl', 'given': 'Eva'},
#    {'family': 'Williams', 'given': 'Alice'},
#    {'family': 'Cesaretti', 'given': 'Rudolf'},
#    {'family': 'Krueger', 'given': 'Marta'},
#    {'family': 'Ceccarelli', 'given': 'Alessandro'},
#    {'family': 'Figliulo-Rosswurm', 'given': 'Joe'},
#    {'family': 'Tuan', 'given': 'Po-Ju'},
#    {'family': 'Peregrine', 'given': 'Peter'},
#    {'family': 'Marciniak', 'given': 'Arkadiusz'},
#    {'family': 'Preiser-Kapeller', 'given': 'Johannes'},
#    {'family': 'Kradin', 'given': 'Nikolay'},
#    {'family': 'Korotayev', 'given': 'Andrey'},
#    {'family': 'Palmisano', 'given': 'Alessio'},
#    {'family': 'Baker', 'given': 'David'},
#    {'family': 'Bidmead', 'given': 'Julye'},
#    {'family': 'Bol', 'given': 'Peter'},
#    {'family': 'Christian', 'given': 'David'},
#    {'family': 'Cook', 'given': 'Connie'},
#    {'family': 'Covey', 'given': 'Alan'},
#    {'family': 'Feinman', 'given': 'Gary'},
#    {'family': 'Júlíusson', 'given': 'Árni Daníel'},
#    {'family': 'Kristinsson', 'given': 'Axel'},
#    {'family': 'Miksic', 'given': 'John'},
#    {'family': 'Mostern', 'given': 'Ruth'},
#    {'family': 'Petrie', 'given': 'Cameron'},
#    {'family': 'Rudiak-Gould', 'given': 'Peter'},
#    {'family': 'ter Haar', 'given': 'Barend'},
#    {'family': 'Wallace', 'given': 'Vesna'},
#    {'family': 'Mair', 'given': 'Victor'},
#    {'family': 'Xie', 'given': 'Liye'},
#    {'family': 'Baines', 'given': 'John'},
#    {'family': 'Bridges', 'given': 'Elizabeth'},
#    {'family': 'Manning', 'given': 'Joseph'},
#    {'family': 'Lockhart', 'given': 'Bruce'},
#    {'family': 'Bogaard', 'given': 'Amy'},
#    {'family': 'Spencer', 'given': 'Charles'}],
#   'container-title': 'Proceedings of the National Academy of Sciences',
#   'id': '7109337/3L9BKAXW',
#   'issue': '2',
#   'issued': {'year': 2018},
#   'note': 'PMID: 29269395\nCitation Key: Turchin2018\nISBN: 1708800115',
#   'page': 'E144-E151',
#   'page-first': 'E144',
#   'title': 'Quantitative historical analysis uncovers a single dimension of complexity that structures global variation in human social organization',
#   'type': 'article-journal',
#   'volume': '115'},
#  '7109337/75PC3E2A': {'ISBN': '978-90-04-30736-0 978-90-04-30737-7',
#   'URL': 'https://brill.com/view/title/31880',
#   'accessed': {'day': 17, 'month': 5, 'year': 2021},
#   'author': [{'family': 'de Ligt', 'given': 'Luuk'},
#    {'family': 'Tacoma', 'given': 'Laurens Ernst'}],
#   'id': '7109337/75PC3E2A',
#   'issued': {'day': 19, 'month': 1, 'year': 2016},
#   'note': 'DOI: 10.1163/9789004307377',
#   'publisher': 'BRILL',
#   'title': 'Migration and Mobility in the Early Roman Empire',
#   'type': 'book'},
#  '7109337/93X7WDDV': {'ISBN': '1-299-14683-X',
#   'abstract': "In the last thirty years, there have been fierce debates over how civilizations develop and why the West became so powerful. The Measure of Civilization presents a brand-new way of investigating these questions and provides new tools for assessing the long-term growth of societies. Using a groundbreaking numerical index of social development that compares societies in different times and places, award-winning author Ian Morris sets forth a sweeping examination of Eastern and Western development across 15,000 years since the end of the last ice age. He offers surprising conclusions about when and why the West came to dominate the world and fresh perspectives for thinking about the twenty-first century. Adapting the United Nations' approach for measuring human development, Morris's index breaks social development into four traits–energy capture per capita, organization, information technology, and war-making capacity–and he uses archaeological, historical, and current government data to quantify patterns. Morris reveals that for 90 percent of the time since the last ice age, the world's most advanced region has been at the western end of Eurasia, but contrary to what many historians once believed, there were roughly 1,200 years–from about 550 to 1750 CE–when an East Asian region was more advanced. Only in the late eighteenth century CE, when northwest Europeans tapped into the energy trapped in fossil fuels, did the West leap ahead. Resolving some of the biggest debates in global history, The Measure of Civilization puts forth innovative tools for determining past, present, and future economic and social trends.",
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'edition': 'Course Book',
#   'event-place': 'Princeton, NJ',
#   'id': '7109337/93X7WDDV',
#   'issued': {'year': 2013},
#   'language': 'eng',
#   'note': 'Publication Title: The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'publisher': 'Princeton University Press',
#   'publisher-place': 'Princeton, NJ',
#   'title': 'The Measure of Civilization : How Social Development Decides the Fate of Nations',
#   'type': 'book'},
#  '7109337/A6W7Q3HZ': {'DOI': '10.2307/300421',
#   'abstract': 'The vast majority of surviving Roman inscriptions originated in a cultural phenomenon that is characteristic of, and in some senses defines, the early Roman Empire. At the end of the last century B.C. — roughly co-incident, then, with the transition to autocracy, the Roman cultural revolution, and the formative period of provincial cultures throughout the Empire — an epigraphic boom occurred, in Italy and in every province of the Empire. That explosion of new inscriptions, and the subsequent rise and fall of an epigraphic culture, was experienced by eastern and western provinces alike, in Greek as well as in Latin epigraphy. Many regional epigraphies remain to be characterized in terms of their chronology, but such local studies as have been done strongly suggest that, although there was certainly some inter-regional variation in the scale, rate, and timing of this phenomenon, in its broad outlines this pattern was very widespread. Across the entire Empire, the number of inscriptions set up each year began to rise from the Augustan period and increased more and more steeply through the second century. In every region that has been examined in detail, the majority of extant inscriptions were produced in the late second and early third centuries. The peak or turning-point seems to have been reached at slightly different times in each area. But everywhere the subsequent decline was much faster than the original rise, reaching a new low between the middle and the end of the third century A.D. Epigraphy does survive into the fourth century — in most areas of the Empire, if not in most cities — but late imperial inscriptions are very much rarer and differ markedly from early imperial examples in genre, form, and style.',
#   'author': [{'family': 'Woolf', 'given': 'Greg'}],
#   'container-title': 'Journal of Roman Studies',
#   'id': '7109337/A6W7Q3HZ',
#   'issued': {'year': 1996},
#   'page': '22–39',
#   'page-first': '22',
#   'title': 'Monumental Writing and the Expansion of Roman Society in the Early Empire',
#   'type': 'article-journal',
#   'volume': '86'},
#  '7109337/AU6JTRIU': {'DOI': '10.2307/300281',
#   'abstract': "It is now notorious that the production of inscriptions in the Roman Empire was not constant over time, but rose over the first and second centuries A.D. and fell in the third. Ramsay MacMullen pointed this out more than five years ago, with conclusions more cautionary than explanatory: ‘history is not being written in the right way', he said, for historians have deduced Rome's decline from evidence that–since it appears only epigraphically–has merely disappeared for its own reasons, or have sought general explanations of decline in theories political, economic, or even demographic in nature, none of which can, in turn, explain the disappearance of epigraphy itself. Why this epigraphic habit rose and fell MacMullen left open to question, although he did postulate control by a ‘sense of audience'. The purpose of this paper is to propose that this ‘sense of audience' was not generalized or generic, but depended on a belief in the value of romanization, of which (as noted but not explained by MacMullen's article) the epigraphic habit is also a rough indicator. Epitaphs constitute the bulk of all provincial inscriptions and in form and number are (generally speaking) the consequence of a provincial imitation of characteristically Roman practices, an imitation that depended on the belief that Roman legal status and style were important, and that may indeed have ultimately depended, at least in North Africa, on the acquisition or prior possession of that status. Such status-based motivations for erecting an epitaph help to explain not only the chronological distribution of epitaphs but also the differences in the type and distribution of epitaphs in the western and eastern halves of the empire. They will be used here moreover to suggest an explanation for the epigraphic habit as a whole.",
#   'author': [{'family': 'Meyer', 'given': 'Elizabeth A.'}],
#   'container-title': 'Journal of Roman Studies',
#   'id': '7109337/AU6JTRIU',
#   'issued': {'year': 1990},
#   'page': '74–96',
#   'page-first': '74',
#   'title': 'Explaining the Epigraphic Habit in the Roman Empire: The Evidence of Epitaphs',
#   'type': 'article-journal',
#   'volume': '80'},
#  '7109337/BRZQ3MUL': {'ISBN': '0-19-960235-2',
#   'author': [{'family': 'Wilson', 'given': 'Andrew'}],
#   'collection-title': 'Oxford Studies in the Roman Economy',
#   'container-title': 'Settlement, Urbanization and Population',
#   'editor': [{'family': 'Bowman', 'given': 'Alan'},
#    {'family': 'Wilson', 'given': 'Andrew'}],
#   'event-place': 'Oxford - New York',
#   'id': '7109337/BRZQ3MUL',
#   'issued': {'year': 2012},
#   'page': '161–195',
#   'page-first': '161',
#   'publisher': 'Oxford University Press',
#   'publisher-place': 'Oxford - New York',
#   'title': 'City Sizes and Urbanization in the Roman Empire',
#   'type': 'chapter'},
#  '7109337/C5QVR3SE': {'DOI': '10.2307/294470',
#   'abstract': 'Epigraphy, or the study of inscriptions, is critical for anyone seeking to understand the Roman world, whether they regard themselves as literary scholars, historians, archaeologists, anthropologists, religious scholars or work in a field that touches on the Roman world from c. 500 BCE to 500 CE and beyond. The Oxford Handbook of Roman Epigraphy is the fullest collection of scholarship on the study and history of Latin epigraphy produced to date. Rather that just a collection of inscriptions, however, this volume seeks to show why inscriptions matter and demonstrate to classicists and ancient historians how to work with the sources. To that end, the 35 chapters, written by senior and rising scholars in Roman history, classics, and epigraphy, cover everything from typograph to the importance of inscriptions for understanding many aspects of Roman culture, from Roman public life, to slavery, to the roles and lives of women, to the military, and to life in the provinces. Students and scholars alike will find the Handbook a crritical tool for expanding their knowledge of the Roman world.',
#   'author': [{'family': 'MacMullen', 'given': 'Ramsay'}],
#   'container-title': 'The American Journal of Philology',
#   'id': '7109337/C5QVR3SE',
#   'issue': '3',
#   'issued': {'year': 1982},
#   'page': '233',
#   'page-first': '233',
#   'title': 'The Epigraphic Habit in the Roman Empire',
#   'type': 'article-journal',
#   'volume': '103'},
#  '7109337/IRUVQAYJ': {'DOI': '10.2307/148494',
#   'URL': 'http://links.jstor.org/sici?sici=0018-098X%28199907%2F09%2968%3A3%3C387%3ADATAEH%3E2.0.CO%3B2-J&origin=crossref',
#   'accessed': {'day': 21, 'month': 11, 'year': 2019},
#   'author': [{'family': 'Hedrick', 'given': 'Charles W. Jr.'}],
#   'container-title': 'Hesperia',
#   'container-title-short': 'Hesperia',
#   'id': '7109337/IRUVQAYJ',
#   'issue': '3',
#   'issued': {'year': 1999},
#   'journalAbbreviation': 'Hesperia',
#   'language': 'en',
#   'page': '387-439',
#   'page-first': '387',
#   'title': 'Democracy and the Athenian Epigraphical Habit',
#   'type': 'article-journal',
#   'volume': '68'},
#  '7109337/L73K2ZRY': {'ISBN': '978-0-19-874848-9',
#   'URL': 'https://oxford.universitypressscholarship.com/view/10.1093/acprof:oso/9780198748489.001.0001/acprof-9780198748489',
#   'accessed': {'day': 17, 'month': 5, 'year': 2021},
#   'editor': [{'family': 'Wilson', 'given': 'Andrew'},
#    {'family': 'Flohr', 'given': 'Miko'}],
#   'id': '7109337/L73K2ZRY',
#   'issued': {'day': 1, 'month': 1, 'year': 2016},
#   'note': 'DOI: 10.1093/acprof:oso/9780198748489.001.0001\nDOI: 10.1093/acprof:oso/9780198748489.001.0001',
#   'publisher': 'Oxford University Press',
#   'title': 'Urban Craftsmen and Traders in the Roman World',
#   'type': 'book'},
#  '7109337/PE4PYNDX': {'DOI': '10.1073/pnas.0904576106',
#   'abstract': 'In times of violence, people tend to hide their valuables, which are later recovered unless the owners had been killed or driven away. Thus, the temporal distribution of unrecovered coin hoards is an excellent proxy for the intensity of internal warfare. We use this relationship to resolve a long-standing controversy in Roman history. Depending on who was counted in the early Imperial censuses (adult males or the entire citizenry including women and minors), the Roman citizen population of Italy either declined, or more than doubled, during the first century BCE. This period was characterized by a series of civil wars, and historical evidence indicates that high levels of sociopolitical instability are associated with demographic contractions. We fitted a simple model quantifying the effect of instability (proxied by hoard frequency) on population dynamics to the data before 100 BCE. The model predicts declining population after 100 BCE. This suggests that the vigorous growth scenario is highly implausible.',
#   'author': [{'family': 'Turchin', 'given': 'Peter'},
#    {'family': 'Scheidel', 'given': 'Walter'}],
#   'container-title': 'Proceedings of the National Academy of Sciences of the United States of America',
#   'id': '7109337/PE4PYNDX',
#   'issued': {'year': 2009},
#   'note': 'PMID: 19805043',
#   'page': '17276–17279',
#   'page-first': '17276',
#   'title': 'Coin Hoards Speak of Population Declines in Ancient Rome',
#   'type': 'article-journal',
#   'volume': '106'},
#  '7109337/RB28J3CE': {'ISBN': '978-0-691-14091-9 0-691-14091-X',
#   'abstract': '"Lord Byron described Greece as great, fallen, and immortal, a characterization more apt than he knew. Through most of its long history, Greece was poor. But in the classical era, Greece was densely populated and highly urbanized. Many surprisingly healthy Greeks lived in remarkably big houses and worked for high wages at specialized occupations. Middle-class spending drove sustained economic growth. Classical wealth produced a stunning cultural efflorescence lasting hundreds of years. Why did Greece reach such heights in the classical period--and why only then? And how, after \'the Greek miracle\' had endured for centuries, did the Macedonians defeat the Greeks, seemingly bringing an end to their glory? Drawing on a massive body of newly available data and employing novel approaches to evidence, Josiah Ober offers a major new history of classical Greece and an unprecedented account of its rise and fall. Ober argues that Greece\'s rise was no miracle but rather the result of political breakthroughs and economic development. The extraordinary emergence of citizen-centered city-states transformed Greece into a society that defeated the mighty Persian Empire. Yet Philip and Alexander of Macedon were able to beat the Greeks in the Battle of Chaeronea in 338 BCE, a victory enabled by the Macedonians\' appropriation of Greek innovations. After Alexander\'s death, battle-hardened warlords fought ruthlessly over the remnants of his empire. But Greek cities remained populous and wealthy, their economy and culture surviving to be passed on to the Romans--and to us. A compelling narrative filled with uncanny modern parallels, this is a book for anyone interested in how great civilizations are born and die. This book is based on evidence available on a new interactive website. To learn more, please visit: http://polis.stanford.edu/"--',
#   'archive': '/z-wcorg/',
#   'author': [{'family': 'Ober', 'given': 'Josiah.'}],
#   'id': '7109337/RB28J3CE',
#   'issued': {'year': 2015},
#   'language': 'English',
#   'title': 'The rise and fall of classical Greece',
#   'type': 'book'},
#  '7109337/TGQ9TAPF': {'ISBN': '978-0-312-61169-9',
#   'abstract': 'Summary: Archaeologist and historian Ian Morris explains that Western dominance is largely the result of the effects of geography on the everyday efforts of ordinary people as they deal with crises of resources, disease, migration, and climate. As geography and human ingenuity continue to interact, however, the world over the next hundred years will subsequently change in astonishing ways, transforming Western rule in the process.',
#   'author': [{'family': 'Morris', 'given': 'Ian'}],
#   'event-place': 'New York',
#   'id': '7109337/TGQ9TAPF',
#   'issued': {'year': 2010},
#   'language': 'eng',
#   'note': 'Publication Title: Why the west rules - for now : the patterns of history, and what they reveal about the future /',
#   'publisher': 'Farrar, Straus and Giroux',
#   'publisher-place': 'New York',
#   'title': 'Why the west rules - for now : the patterns of history, and what they reveal about the future',
#   'type': 'book'},
#  '7109337/TXCY5XL8': {'ISBN': '978-1-00-302530-6',
#   'URL': 'https://www.taylorfrancis.com/books/9781000164800',
#   'accessed': {'day': 7, 'month': 5, 'year': 2021},
#   'edition': '1',
#   'editor': [{'family': 'Nawotka', 'given': 'Krzysztof'}],
#   'id': '7109337/TXCY5XL8',
#   'issued': {'year': 2021},
#   'language': 'en',
#   'note': 'DOI: 10.4324/9781003025306',
#   'publisher': 'Routledge',
#   'title': 'Epigraphic Culture in the Eastern Mediterranean in Antiquity',
#   'type': 'book'},
#  '7109337/VDS8KTIA': {'abstract': 'Epigraphic Evidence is an accessible guide to the responsible use of Greek and Latin inscriptions as sources for ancient history. It introduces the types of historical information supplied by inscriptional texts and the methods with which they can be used. It outlines the limitations as well as the advantages of the different types of evidence covered. Epigraphic Evidence includes a general introduction, a guide to the arrangement of the standard corpora inscriptions and individual chapters on local languages and native cultures, epitaphs and the ancient economy amongst others.',
#   'author': [{'family': 'Duthoy', 'given': 'Robert'}],
#   'collection-number': '4',
#   'event-place': 'London, New York',
#   'issued': {'date-parts': [[2002]]},
#   'note': 'ISSN: 0023-8856\nPublication Title: Latomus',
#   'number-of-pages': '1019–1020',
#   'publisher': 'Routledge',
#   'publisher-place': 'London, New York',
#   'title': 'Epigraphic evidence: ancient history from inscriptions',
#   'type': 'book',
#   'volume': '61'},
#  '7109337/WZ6MD9YX': {'DOI': '10.1098/rsif.2017.0367',
#   'URL': 'https://royalsocietypublishing.org/doi/10.1098/rsif.2017.0367',
#   'abstract': 'One of the hallmarks of human agglomeration is an increase in the division of labour, but the exact nature of this relationship has been debated among anthropologists, sociologists, economists, and historians and archaeologists. Over the last decade, researchers investigating contemporary urban systems have suggested a novel explanation for the links between the numbers of inhabitants in settlements and many of their most important characteristics, which is grounded in a view of settlements as social networks embedded in built environments. One of the remarkable aspects of this approach is that it is not based on the specific conditions of the modern world (such as capitalism or industrialization), which raises the issue of whether the relationships observed in contemporary urban systems can also be detected in pre-modern urban or even non-urban systems. Here, we present a general model for the relationship between the population and functional diversity of settlements, where the latter is viewed as an indicator of the division of labour. We then explore the applicability of this model to pre-modern contexts, focusing on cities in the Roman Empire, using estimates of their numbers of inhabitants, numbers of documented professional associations, and numbers of recorded inscriptions to develop an index of functional diversity. Our results are consistent with theoretical expectations, adding further support to the view that urban systems in both contemporary and pre-modern contexts reflect a common set of generative processes.',
#   'accessed': {'day': 18, 'month': 5, 'year': 2021},
#   'author': [{'family': 'Hanson', 'given': 'J. W.'},
#    {'family': 'Ortman', 'given': 'S. G.'},
#    {'family': 'Lobo', 'given': 'J.'}],
#   'container-title': 'Journal of The Royal Society Interface',
#   'container-title-short': 'J. R. Soc. Interface.',
#   'id': '7109337/WZ6MD9YX',
#   'issue': '136',
#   'issued': {'year': 2017},
#   'journalAbbreviation': 'J. R. Soc. Interface.',
#   'language': 'en',
#   'page': '20170367',
#   'page-first': '20170367',
#   'title': 'Urbanism and the division of labour in the Roman Empire',
#   'type': 'article-journal',
#   'volume': '14'}}

# %%
notebook_dict["cells"][10:20]
# Out:
# [{'cell_type': 'code',
#   'execution_count': 54,
#   'metadata': {'tags': ['configuration', 'Python']},
#   'outputs': [],
#   'source': ['%%capture\n',
#    '# install Python libraries\n',
#    '!pip install sddk tempun scipy seaborn nltk rpy2 cite2c geopandas cite2c\n',
#    '# alternatively:\n',
#    '#!pip install -r requirements.txt (eventually we can load reqs via requirements)']},
#  {'cell_type': 'code',
#   'execution_count': 55,
#   'metadata': {'tags': ['configuration', 'Python']},
#   'outputs': [],
#   'source': ['import geopandas as gpd\n',
#    'import cite2c\n',
#    'import requests\n',
#    'import seaborn as sns\n',
#    'import matplotlib.colors as mcolors\n',
#    'import matplotlib.pyplot as plt\n',
#    'from scipy.stats import trapz\n',
#    'import scipy\n',
#    'import nltk\n',
#    'import json\n',
#    'import tempun\n',
#    'import sddk\n',
#    'import numpy as np\n',
#    'import pandas as pd\n',
#    'pd.options.display.max_columns = 1000  # to see all columns']},
#  {'cell_type': 'code',
#   'execution_count': 56,
#   'metadata': {'tags': ['configuration']},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ['Requirement already satisfied: cite2c in /opt/conda/lib/python3.7/site-packages (0.2.1)\n',
#      'Requirement already satisfied: notebook in /opt/conda/lib/python3.7/site-packages (from cite2c) (6.1.3)\n',
#      'Requirement already satisfied: rauth in /opt/conda/lib/python3.7/site-packages (from cite2c) (0.7.3)\n',
#      'Requirement already satisfied: tornado in /opt/conda/lib/python3.7/site-packages (from cite2c) (6.0.4)\n',
#      'Requirement already satisfied: jupyter-core>=4.6.1 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (4.6.3)\n',
#      'Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (20.1.0)\n',
#      'Requirement already satisfied: traitlets>=4.2.1 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (4.3.3)\n',
#      'Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (0.8.0)\n',
#      'Requirement already satisfied: nbformat in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (5.0.7)\n',
#      'Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (1.5.0)\n',
#      'Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (0.2.0)\n',
#      'Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (5.3.4)\n',
#      'Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (0.8.3)\n',
#      'Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (5.6.1)\n',
#      'Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (19.0.2)\n',
#      'Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (2.11.2)\n',
#      'Requirement already satisfied: jupyter-client>=5.3.4 in /opt/conda/lib/python3.7/site-packages (from notebook->cite2c) (6.1.6)\n',
#      'Requirement already satisfied: requests>=1.2.3 in /opt/conda/lib/python3.7/site-packages (from rauth->cite2c) (2.24.0)\n',
#      'Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook->cite2c) (1.14.1)\n',
#      'Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook->cite2c) (1.15.0)\n',
#      'Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2.1->notebook->cite2c) (4.4.2)\n',
#      'Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat->notebook->cite2c) (3.2.0)\n',
#      'Requirement already satisfied: ipython>=5.0.0 in /opt/conda/lib/python3.7/site-packages (from ipykernel->notebook->cite2c) (7.17.0)\n',
#      'Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (3.1.5)\n',
#      'Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (2.6.1)\n',
#      'Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.8.4)\n',
#      'Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.3)\n',
#      'Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.4.4)\n',
#      'Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (0.6.0)\n',
#      'Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->notebook->cite2c) (1.4.2)\n',
#      'Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.7/site-packages (from jinja2->notebook->cite2c) (1.1.1)\n',
#      'Requirement already satisfied: python-dateutil>=2.1 in /opt/conda/lib/python3.7/site-packages (from jupyter-client>=5.3.4->notebook->cite2c) (2.8.1)\n',
#      'Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (2020.6.20)\n',
#      'Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (2.10)\n',
#      'Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (1.25.10)\n',
#      'Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests>=1.2.3->rauth->cite2c) (3.0.4)\n',
#      'Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->cite2c) (2.20)\n',
#      'Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (0.16.0)\n',
#      'Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (49.6.0.post20200814)\n',
#      'Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (20.1.0)\n',
#      'Requirement already satisfied: importlib-metadata; python_version < "3.8" in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (1.7.0)\n',
#      'Requirement already satisfied: pexpect; sys_platform != "win32" in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (4.8.0)\n',
#      'Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (3.0.6)\n',
#      'Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (0.2.0)\n',
#      'Requirement already satisfied: jedi>=0.10 in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (0.15.2)\n',
#      'Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython>=5.0.0->ipykernel->notebook->cite2c) (0.7.5)\n',
#      'Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook->cite2c) (0.5.1)\n',
#      'Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->notebook->cite2c) (20.4)\n',
#      'Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata; python_version < "3.8"->jsonschema!=2.5.0,>=2.4->nbformat->notebook->cite2c) (3.1.0)\n',
#      'Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect; sys_platform != "win32"->ipython>=5.0.0->ipykernel->notebook->cite2c) (0.6.0)\n',
#      'Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook->cite2c) (0.2.5)\n',
#      'Requirement already satisfied: parso>=0.5.2 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook->cite2c) (0.7.1)\n',
#      'Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.7/site-packages (from packaging->bleach->nbconvert->notebook->cite2c) (2.4.7)\n',
#      'Installing nbextension ...\n',
#      'Enabling the nbextension ...\n',
#      'Enabling the server extension ...\n',
#      'Done.\n']}],
#   'source': ['# cite2c module for bibliographies\n',
#    '\n',
#    '!pip install cite2c\n',
#    '!python3 -m cite2c.install']},
#  {'cell_type': 'markdown',
#   'metadata': {'tags': ['narrative']},
#   'source': ['## Introduction\n',
#    'Ancient inscriptions form an idiosyncratic category of evidence on past societies, straddling the divide between textual accounts and archaeological artefacts. Close-reading methods dominated early studies of inscriptions, with the aim to reconstruct the text, date and interpret the inscriptions. As the body of evidence grew, synthetic analyses started to emerge with the aim to investigate larger-scale patterns <cite data-cite="7109337/C5QVR3SE"></cite> <cite data-cite="7109337/AU6JTRIU"></cite> <cite data-cite="7109337/A6W7Q3HZ"></cite> <cite data-cite="7109337/IRUVQAYJ"></cite> <cite data-cite="7109337/TXCY5XL8"></cite>. **REF check: (MacMullen 1982; Meyer 1990; Woolf 1996; Hedrick 1999; Nawotka 2021)** Digitized epigraphic data made it possible to tackle topics such as the evolution of demographic trends, migration patterns, changes of the socio-political organisation and cultural development using distant-reading and other computational techniques <cite data-cite="7109337/BRZQ3MUL"></cite> <cite data-cite="7109337/L73K2ZRY"></cite> <cite data-cite="7109337/75PC3E2A"></cite> <cite data-cite="7109337/WZ6MD9YX"></cite> **REF check: (Wilson 2012; Wilson and Flohr 2016; de Light and Tacoma 2016; Hanson et al. 2017)**. While these computational studies underscore the potential of epigraphic evidence, they rarely use a dataset larger than several thousand records. Greek and Latin inscriptions, however, count hundreds of thousands spanning the Roman Empire spatially and temporally, and thus potentially form a source that can inform large-scale and long-term studies such as conducted by Ian Morris <cite data-cite="7109337/TGQ9TAPF"> </cite><cite data-cite="7109337/93X7WDDV"></cite> **REF check: (2010; 2013)**, the Seshat Project <cite data-cite="7109337/PE4PYNDX"></cite> <cite data-cite="7109337/2ASLDCJP"></cite> <cite data-cite="7109337/3L9BKAXW"></cite> **REF check: (Turchin and Scheidel 2009; Mullins et al. 2018; Turchin et al. 2018)** or Josiah Ober <cite data-cite="7109337/RB28J3CE"></cite> **REF check: (2015)**. \n',
#    '\n']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['Currently such large-scale study has been beyond the reach of any individual researcher because of the gargantuan efforts of aggregating and streamlining the thousands of inscriptions to make analysis feasible. Even the exact number of ancient inscriptions, dating between 800 BC and 800 AD, currently estimated at 600,000 surviving Latin and Greek ones, remains elusive (Bodel 2001, 4; Beltran-Lloris 2014, 135). Although numerous analogue and digital corpora exist, their contents overlap to variable degree and are not straightforward to combine. Some collections focus on specific language, mostly Latin- or Greek-language inscriptions, others collate all inscriptions from a particular modern or ancient geographic area regardless of language, others yet focus on a particular chronological period. While the challenge of technical data wrangling and distant-reading the inscriptions may be beyond a single researcher, a collaborative team equipped with both the necessary computational tools and domain-specific skill set may get further. Working from established digital repositories and building our own digital toolkit on the go, we try to address the topic that has puzzled epigraphers for nearly a century: why some people in various times and places of Roman Empire commissioned inscriptions and some did not.']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['## Epigraphic Habit(s) 40 years later: can we do any better?\n',
#    'Inscriptions vary greatly in form and contents, touching almost all aspects of life in an ancient society. Commissioning an inscription was part of a long-term cultural practice that served as a physical response to a change of circumstances, i.e. death, birth, change of legal status, social rank, building activities etc. The form and content of an inscription reflected a set of existing social norms. The inscribed texts range from short private messages on objects of daily use to extensive regulations and codes issued by a political authority, to monumental inscriptions helping to create public image and build social prestige. In contrast with literary texts that were often preserved via the act of multiple copying and editing, the text of inscription has the original unaltered form with original typographical and grammatical errors, being an ideal study subject for historical linguists. Moreover, the information preserved via inscriptions potentially has a wider demographic coverage than literary texts, as inscriptions were produced by social groups of more diverse socio-economic and cultural background than those of literary texts (Bodard 2008).\n']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['Working at the level of the province with a couple thousand inscriptions at a time, scholars have started constructing regional diachronic overviews of epigraphic production. Comparative studies between North Africa, Gaul or Greece revealed that epigraphic production in these provinces follows the same diachronic pattern. Inscription numbers peak at the end of the second century AD, during the reign of Septimius Severus (AD 193 - AD 211), and decline abruptly in the beginning of the third century AD (MacMullen 1982; Meyer 1991; Woolf 1996). Researchers started exploring different drivers for such convergence, interrogating the role of funerary habits to the popularity of public status display to the democratisation of citizenship. For instance, Elizabeth Meyer used the example of epitaphs to explain the drop in the number of inscriptions after the Constitutio Antoniniana in AD 212 granted Roman citizenship to all inhabitants of the Roman Empire. According to Meyer, being a Roman citizen lost some of its prestige and so did funerary inscriptions as public markers of societal status (Meyer 1990, 78-81). Such explanations failed to address the phenomenon of epigraphic production in all its breadth and complexity, focusing only on funerary inscriptions from selected regions. Since the time of MacMullen many scholars have attempted to study epigraphic production at the scale of the Empire (e.g., Hedrick 1999; Trout 2009; Beltran Lloris 2014; Bolle, Machado, and Witschel 2017; Nawotka 2021; Blanco Perez 2021). These efforts have been hindered first by the constraints on interoperability and integration of digital datasets, second, by the volume and diversity of epigraphic data, and finally, by the inability to precisely quantify the number of inscriptions at any point in time (Beltran Lloris 2014, 139).']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['In recent years, large digital corpora containing tens of thousands inscriptions were published online. While accessible to anyone with a computational skill set, they remain underutilised as resources for quantitative and comparative studies (Elliott 2014, 80-83; Hartmann 2018; De Santis and Rossi 2018). Although the analysis of a large body of digitized texts may seem relatively straightforward from an outsider’s point of view, epigraphic datasets pose numerous technological, methodological and even ethical challenges to digital research.']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['What are these constraints, and how do they shift as we move from a thousand inscriptions to several hundred thousand? For large-scale studies, individual catalogues need to be compatible in structure in order to be readily combined. Data in the resulting aggregate needs to be machine readable and consistent across columns. Data quality is paramount. The problem with computers is that they do not readily understand `120AD` and `AD120` and `AD 120` to be the same thing. These differences need to be normalized into one canonical form, else the analysis halts, or worse, continues and yields misleading results. When handling a dataset of thousand records, the few variants that occur can be cleaned manually. When handling data that comes from multiple sources with different formatting, the number of variations becomes so high that it is tractable only with regular expressions and other automated validation tools.']},
#  {'cell_type': 'markdown',
#   'metadata': {},
#   'source': ['When investigating spatio-temporal patterns, we need tools that help us systematically streamline and normalise temporal and spatial attributes. At the same time, all the usual difficulties of interpreting fragmented texts also remain to be tackled. Each contributing editor and editorial standard adds a new flavour to the mix, like a new ingredient in a smoothie and we need to ensure that the final concoction contains only compatible flavors. Concepts and meanings need to be mapped and related to make meaningful analysis possible.']}]

# %%
notebook_text = open("Digital_epigraphy.ipynb").read()
notebook_text[:1000]
# Out:
# '{\n "cells": [\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "title"\n    ]\n   },\n   "source": [\n    "# Inscriptions as data: digital epigraphy in macro-historical perspective "\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Petra Hermankova\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6349-0540](https://orcid.org/0000-0002-6349-0540)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Vojtech Kase\\n",\n    "Author. Aarhus University, [ORCID: 0000-0002-6601-1605](http://orcid.org/0000-0002-6601-1605)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n    "tags": [\n     "contributor"\n    ]\n   },\n   "source": [\n    "### Adela Sobotkova\\n",\n    "Author. Aarhus University, [ORCID:0000-0002-4541-3963](https://orcid.org/0000-0002-4541-3963)"\n   ]\n  },\n  {\n   "cell_type": "markdown",\n   "metadata": {\n'

# %%
citations_used = {}
for key in citation_keys_pairs.keys():
    if key in notebook_text:
        citations_used[citation_keys_pairs[key]] = citations[citation_keys_pairs[key]]
        notebook_text = notebook_text.replace(key, "<cite data-cite=\'" + citation_keys_pairs[key] + "\'></cite>")

# %%
notebook_dict = json.loads(notebook_text)
notebook_dict["metadata"]["cite2c"]["citations"] = citations_used

# %%
with open("Digital_epigraphy_cite2c_test1.ipynb", "w") as f:
    json.dump(notebook_dict, f)
